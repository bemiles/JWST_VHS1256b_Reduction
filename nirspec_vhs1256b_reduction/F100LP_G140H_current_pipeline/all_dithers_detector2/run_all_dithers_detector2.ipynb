# %% [markdown]
# This notebook was made to reduce NIRSpec dithers into a spectral cube by:
#
# 1. Using the Stage 1 Detector pipleine to turn uncalibrated detector images (_uncal.fits) into rate files (_rate.fits).
#
# 2. Using Stage 2 of the Spectroscopic pipeline to turn rate files(_rate.fits) into calibrated detector images (_cal.fits) and spectral cubes (_s3d.fits)
#
# 3. Using Stage 3 of the spectroscopic pipeline to combine the stage 2 rate files from each filter/grating combination.
#
# Other notes/caveats:
# Stage 2 cube building is redundant with Stage 3 if you are not combining dithers.

# %%
from astropy.io import fits
import glob, os
from subprocess import call
from astropy.io import fits
import time

import jwst
from jwst.pipeline import Detector1Pipeline, Spec2Pipeline, Spec3Pipeline

import matplotlib.pyplot as plt
import numpy as n

from spectral_cube import SpectralCube
from scipy import optimize


os.environ['CRDS_PATH'] = '/Users/zen/crds_cache/jwst_ops'
os.environ['CRDS_SERVER_URL'] = 'https://jwst-crds.stsci.edu'
os.environ['CRDS_CONTEXT'] = 'jwst_0977.pmap'


# Print out what pipeline version we're using
print('JWST pipeline version',jwst.__version__)
# Out:
# JWST pipeline version 1.7.2

# %%
# Functions for fitting a 2-D guassian to images to find the PSF center in collapsed spectral cubes
def gauss2d(x, y, x0, y0, offset, sigma_x, sigma_y, A):

    x_exp = ( ( x - x0 )**2) / (2 * sigma_x ** 2)
    y_exp = ( ( y - y0 )**2) / (2 * sigma_y ** 2)
    f = A * n.exp( - x_exp - y_exp) + offset

    return f

def image_solve(constants, im):

    x0_val, y0_val, offset_val, sigma_x_val, sigma_y_val, A_val = constants

    y_len, x_len = im.shape
    y_arr = n.arange(0, y_len)
    x_arr = n.arange(0, x_len)
    xx, yy = n.meshgrid(x_arr, y_arr)

    fit = gauss2d(xx, yy, x0_val, y0_val, offset_val, sigma_x_val, sigma_y_val, A_val)

    min_diff = n.nansum(abs(im - fit)**2)

    return min_diff

# %%
det1_dir = 'stage1/' # Detector1 pipeline outputs will go here
spec2_dir = 'stage2/' # Spec2 pipeline outputs will go here
spec3_dir = 'stage3/' # Spec3 pipeline outputs will go here

# We need to check that the desired output directories exist, and if not create them
if not os.path.exists(det1_dir):
    os.makedirs(det1_dir)
if not os.path.exists(spec2_dir):
    os.makedirs(spec2_dir)
if not os.path.exists(spec3_dir):
    os.makedirs(spec3_dir)

# %%
uncal_file_dir = '../../../sci_data/'
uncal_files = ['jw01386013001_03106_00001_nrs2_uncal.fits',
               'jw01386013001_03106_00002_nrs2_uncal.fits',
               'jw01386013001_03106_00003_nrs2_uncal.fits',
               'jw01386013001_03106_00004_nrs2_uncal.fits']



for i, file in enumerate(uncal_files):
    uncal_files[i] = uncal_file_dir + uncal_files[i]
print(uncal_files)

print('Found ' + str(len(uncal_files)) + ' input files to process')
# Out:
# ['../../../sci_data/jw01386013001_03106_00001_nrs2_uncal.fits', '../../../sci_data/jw01386013001_03106_00002_nrs2_uncal.fits', '../../../sci_data/jw01386013001_03106_00003_nrs2_uncal.fits', '../../../sci_data/jw01386013001_03106_00004_nrs2_uncal.fits']
# Found 4 input files to process

# %%
# Start a timer to keep track of runtime
time0 = time.perf_counter()

# %%
for file in uncal_files:
    
    det1 = Detector1Pipeline() # Instantiate the pipeline

    #output directory
    det1.output_dir = det1_dir # Specify where the output should go

    #defining used pipeline steps
    det1.group_scale.skip = False  #scaling factor from group images
    det1.dq_init.skip = False      #data quality check
    det1.saturation.skip = False   #check for saturated pixels
    det1.ipc.skip = False          #interpixel capacitance scaling from a reference. Usually skipped in all instrument modes
    det1.superbias.skip = False    #subtract a bias frame from the data
    det1.refpix.skip = False       #correct for drifts in read outs using reference pixels or columns
    det1.linearity.skip = False    #used to correct for non-linearity in the frames
    det1.persistence.skip = True   #according to the docs it is supposed to be hardwired to skipped
    det1.dark_current.skip = False #
    det1.jump.skip = False         #
    det1.jump.maximum_cores = 'half' #distribute the computing load across half of your computer cores to speed it up
    det1.ramp_fit.skip = False     #
    det1.ramp_fit.maximum_cores = 'half' #distribute the computing load across half of your computer cores to speed it up
    det1.gain_scale.skip = False   #


    #skipped steps that are for MIRI
    det1.firstframe.skip = True    #
    det1.lastframe.skip = True     #
    det1.reset.skip = True         # The reset correction is a MIRI step that attempts to correct for the reset anomaly effect. Skipped
    det1.rscd.skip = True          # Performs an RSCD correction to MIRI data that is also caused by reset issues. Skipped



    #choose what results to save and from what steps
    #det1.dq_init.save_results = True # save the data quality flag information
    det1.save_results = True # Save the final resulting _rate.fits files

    det1.run(file)
# Out:
# 2022-12-08 02:27:07,513 - stpipe.Detector1Pipeline - INFO - Detector1Pipeline instance created.
# 2022-12-08 02:27:07,514 - stpipe.Detector1Pipeline.group_scale - INFO - GroupScaleStep instance created.
# 2022-12-08 02:27:07,515 - stpipe.Detector1Pipeline.dq_init - INFO - DQInitStep instance created.
# 2022-12-08 02:27:07,516 - stpipe.Detector1Pipeline.saturation - INFO - SaturationStep instance created.
# 2022-12-08 02:27:07,518 - stpipe.Detector1Pipeline.ipc - INFO - IPCStep instance created.
# 2022-12-08 02:27:07,519 - stpipe.Detector1Pipeline.superbias - INFO - SuperBiasStep instance created.
# 2022-12-08 02:27:07,520 - stpipe.Detector1Pipeline.refpix - INFO - RefPixStep instance created.
# 2022-12-08 02:27:07,521 - stpipe.Detector1Pipeline.rscd - INFO - RscdStep instance created.
# 2022-12-08 02:27:07,522 - stpipe.Detector1Pipeline.firstframe - INFO - FirstFrameStep instance created.
# 2022-12-08 02:27:07,523 - stpipe.Detector1Pipeline.lastframe - INFO - LastFrameStep instance created.
# 2022-12-08 02:27:07,524 - stpipe.Detector1Pipeline.linearity - INFO - LinearityStep instance created.
# 2022-12-08 02:27:07,525 - stpipe.Detector1Pipeline.dark_current - INFO - DarkCurrentStep instance created.
# 2022-12-08 02:27:07,527 - stpipe.Detector1Pipeline.reset - INFO - ResetStep instance created.
# 2022-12-08 02:27:07,528 - stpipe.Detector1Pipeline.persistence - INFO - PersistenceStep instance created.
# 2022-12-08 02:27:07,529 - stpipe.Detector1Pipeline.jump - INFO - JumpStep instance created.
# 2022-12-08 02:27:07,530 - stpipe.Detector1Pipeline.ramp_fit - INFO - RampFitStep instance created.
# 2022-12-08 02:27:07,531 - stpipe.Detector1Pipeline.gain_scale - INFO - GainScaleStep instance created.
# 2022-12-08 02:27:07,583 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline running with args ('../../../sci_data/jw01386013001_03106_00001_nrs2_uncal.fits',).
# 2022-12-08 02:27:07,591 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': 'stage1/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_calibrated_ramp': False, 'steps': {'group_scale': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'dq_init': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'saturation': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'n_pix_grow_sat': 1}, 'ipc': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'superbias': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'refpix': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'odd_even_columns': True, 'use_side_ref_pixels': True, 'side_smoothing_length': 11, 'side_gain': 1.0, 'odd_even_rows': True}, 'rscd': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'type': 'baseline'}, 'firstframe': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'lastframe': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'linearity': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'dark_current': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'dark_output': None}, 'reset': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'persistence': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': ...
# 2022-12-08 02:27:08,709 - stpipe.Detector1Pipeline - INFO - Prefetching reference files for dataset: 'jw01386013001_03106_00001_nrs2_uncal.fits' reftypes = ['dark', 'gain', 'ipc', 'linearity', 'mask', 'readnoise', 'refpix', 'saturation', 'superbias']
# 2022-12-08 02:27:08,923 - stpipe.Detector1Pipeline - INFO - Prefetch for DARK reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_dark_0206.fits'.
# 2022-12-08 02:27:08,924 - stpipe.Detector1Pipeline - INFO - Prefetch for GAIN reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_gain_0020.fits'.
# 2022-12-08 02:27:08,925 - stpipe.Detector1Pipeline - INFO - Prefetch for IPC reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_ipc_0012.fits'.
# 2022-12-08 02:27:08,925 - stpipe.Detector1Pipeline - INFO - Prefetch for LINEARITY reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_linearity_0025.fits'.
# 2022-12-08 02:27:08,926 - stpipe.Detector1Pipeline - INFO - Prefetch for MASK reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_mask_0033.fits'.
# 2022-12-08 02:27:08,927 - stpipe.Detector1Pipeline - INFO - Prefetch for READNOISE reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_readnoise_0017.fits'.
# 2022-12-08 02:27:08,927 - stpipe.Detector1Pipeline - INFO - Prefetch for REFPIX reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_refpix_0018.fits'.
# 2022-12-08 02:27:08,927 - stpipe.Detector1Pipeline - INFO - Prefetch for SATURATION reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_saturation_0026.fits'.
# 2022-12-08 02:27:08,928 - stpipe.Detector1Pipeline - INFO - Prefetch for SUPERBIAS reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_superbias_0256.fits'.
# 2022-12-08 02:27:08,928 - stpipe.Detector1Pipeline - INFO - Starting calwebb_detector1 ...
# 2022-12-08 02:27:09,680 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale running with args (<RampModel(1, 21, 3200, 2048) from jw01386013001_03106_00001_nrs2_uncal.fits>,).
# 2022-12-08 02:27:09,681 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../sci_data'}
# 2022-12-08 02:27:10,079 - stpipe.Detector1Pipeline.group_scale - INFO - NFRAMES and FRMDIVSR are equal; correction not needed
# 2022-12-08 02:27:10,079 - stpipe.Detector1Pipeline.group_scale - INFO - Step will be skipped
# 2022-12-08 02:27:10,081 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale done
# 2022-12-08 02:27:10,192 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init running with args (<RampModel(1, 21, 3200, 2048) from jw01386013001_03106_00001_nrs2_uncal.fits>,).
# 2022-12-08 02:27:10,193 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../sci_data'}
# 2022-12-08 02:27:10,214 - stpipe.Detector1Pipeline.dq_init - INFO - Using MASK reference file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_mask_0033.fits
# 2022-12-08 02:27:10,781 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init done
# 2022-12-08 02:27:10,886 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation running with args (<RampModel(1, 21, 3200, 2048) from jw01386013001_03106_00001_nrs2_uncal.fits>,).
# 2022-12-08 02:27:10,887 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../sci_data', 'n_pix_grow_sat': 1}
# 2022-12-08 02:27:10,909 - stpipe.Detector1Pipeline.saturation - INFO - Using SATURATION reference file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_saturation_0026.fits
# 2022-12-08 02:27:13,621 - stpipe.Detector1Pipeline.saturation - INFO - Detected 34965 saturated pixels
# 2022-12-08 02:27:13,726 - stpipe.Detector1Pipeline.saturation - INFO - Detected 0 A/D floor pixels
# 2022-12-08 02:27:13,740 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation done
# 2022-12-08 02:27:13,842 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc running with args (<RampModel(1, 21, 3200, 2048) from jw01386013001_03106_00001_nrs2_uncal.fits>,).
# 2022-12-08 02:27:13,844 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../sci_data'}
# 2022-12-08 02:27:13,864 - stpipe.Detector1Pipeline.ipc - INFO - Using IPC reference file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_ipc_0012.fits
# 2022-12-08 02:27:14,954 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc done
# 2022-12-08 02:27:15,063 - stpipe.Detector1Pipeline.superbias - INFO - Step superbias running with args (<RampModel(1, 21, 3200, 2048) from jw01386013001_03106_00001_nrs2_uncal.fits>,).
# 2022-12-08 02:27:15,064 - stpipe.Detector1Pipeline.superbias - INFO - Step superbias parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../sci_data'}
# 2022-12-08 02:27:15,084 - stpipe.Detector1Pipeline.superbias - INFO - Using SUPERBIAS reference file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_superbias_0256.fits
# 2022-12-08 02:27:15,599 - stpipe.Detector1Pipeline.superbias - INFO - Step superbias done
# 2022-12-08 02:27:15,705 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix running with args (<RampModel(1, 21, 3200, 2048) from jw01386013001_03106_00001_nrs2_uncal.fits>,).
# 2022-12-08 02:27:15,706 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../sci_data', 'odd_even_columns': True, 'use_side_ref_pixels': True, 'side_smoothing_length': 11, 'side_gain': 1.0, 'odd_even_rows': True}
# 2022-12-08 02:27:15,726 - stpipe.Detector1Pipeline.refpix - INFO - Using refpix reference file: /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_refpix_0018.fits
# 2022-12-08 02:27:16,017 - stpipe.Detector1Pipeline.refpix - INFO - Working on integration 1
# 2022-12-08 02:28:09,247 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix done
# 2022-12-08 02:28:09,758 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity running with args (<RampModel(1, 21, 3200, 2048) from jw01386013001_03106_00001_nrs2_uncal.fits>,).
# 2022-12-08 02:28:09,759 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../sci_data'}
# 2022-12-08 02:28:09,780 - stpipe.Detector1Pipeline.linearity - INFO - Using Linearity reference file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_linearity_0025.fits
# 2022-12-08 02:28:09,912 - stpipe.Detector1Pipeline.linearity - WARNING - Keyword BAD_LIN_CORR does not correspond to an existing DQ mnemonic, so will be ignored
# 2022-12-08 02:28:10,642 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity done
# 2022-12-08 02:28:10,776 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current running with args (<RampModel(1, 21, 3200, 2048) from jw01386013001_03106_00001_nrs2_uncal.fits>,).
# 2022-12-08 02:28:10,777 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': 'stage1/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../sci_data', 'dark_output': None}
# 2022-12-08 02:28:11,019 - stpipe.Detector1Pipeline.dark_current - INFO - Using DARK reference file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_dark_0206.fits
# 2022-12-08 02:28:15,062 - stpipe.Detector1Pipeline.dark_current - INFO - Science data nints=1, ngroups=21, nframes=1, groupgap=0
# 2022-12-08 02:28:15,063 - stpipe.Detector1Pipeline.dark_current - INFO - Dark data nints=1, ngroups=245, nframes=1, groupgap=0
# 2022-12-08 02:28:20,291 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current done
# 2022-12-08 02:28:20,799 - stpipe.Detector1Pipeline.jump - INFO - Step jump running with args (<RampModel(1, 21, 3200, 2048) from jw01386013001_03106_00001_nrs2_uncal.fits>,).
# 2022-12-08 02:28:20,801 - stpipe.Detector1Pipeline.jump - INFO - Step jump parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../sci_data', 'rejection_threshold': 4.0, 'three_group_rejection_threshold': 6.0, 'four_group_rejection_threshold': 5.0, 'maximum_cores': 'half', 'flag_4_neighbors': True, 'max_jump_to_flag_neighbors': 1000.0, 'min_jump_to_flag_neighbors': 10.0, 'after_jump_flag_dn1': 0.0, 'after_jump_flag_time1': 0.0, 'after_jump_flag_dn2': 0.0, 'after_jump_flag_time2': 0.0}
# 2022-12-08 02:28:20,939 - stpipe.Detector1Pipeline.jump - INFO - CR rejection threshold = 4 sigma
# 2022-12-08 02:28:20,940 - stpipe.Detector1Pipeline.jump - INFO - Maximum cores to use = half
# 2022-12-08 02:28:21,086 - stpipe.Detector1Pipeline.jump - INFO - Using GAIN reference file: /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_gain_0020.fits
# 2022-12-08 02:28:21,253 - stpipe.Detector1Pipeline.jump - INFO - Using READNOISE reference file: /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_readnoise_0017.fits
# 2022-12-08 02:28:22,080 - stpipe.Detector1Pipeline.jump - INFO - Executing two-point difference method
# 2022-12-08 02:28:22,219 - stpipe.Detector1Pipeline.jump - INFO - Creating 5 processes for jump detection
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/jump/twopoint_difference.py:154: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/jump/twopoint_difference.py:154: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/jump/twopoint_difference.py:154: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/jump/twopoint_difference.py:154: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/jump/twopoint_difference.py:154: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
# 2022-12-08 02:28:30,589 - stpipe.Detector1Pipeline.jump - INFO - Total elapsed time = 8.50798 sec
# 2022-12-08 02:28:30,611 - stpipe.Detector1Pipeline.jump - INFO - The execution time in seconds: 9.671604
# 2022-12-08 02:28:30,617 - stpipe.Detector1Pipeline.jump - INFO - Step jump done
# 2022-12-08 02:28:30,771 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit running with args (<RampModel(1, 21, 3200, 2048) from jw01386013001_03106_00001_nrs2_uncal.fits>,).
# 2022-12-08 02:28:30,773 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': 'stage1/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../sci_data', 'int_name': '', 'save_opt': False, 'opt_name': '', 'suppress_one_group': True, 'maximum_cores': 'half'}
# 2022-12-08 02:28:31,092 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using READNOISE reference file: /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_readnoise_0017.fits
# 2022-12-08 02:28:31,092 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using GAIN reference file: /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_gain_0020.fits
# 2022-12-08 02:28:31,166 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using algorithm = ols
# 2022-12-08 02:28:31,166 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using weighting = optimal
# 2022-12-08 02:28:31,516 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of processors used for multiprocessing: 5
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/ramp_fitting/ols_fit.py:1089: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/ramp_fitting/ols_fit.py:1089: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/ramp_fitting/ols_fit.py:1089: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/ramp_fitting/ols_fit.py:1089: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/ramp_fitting/ols_fit.py:1089: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# 2022-12-08 02:28:59,248 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit done
# 2022-12-08 02:28:59,407 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<IFUImageModel(2048, 2048) from jw01386013001_03106_00001_nrs2_uncal.fits>,).
# 2022-12-08 02:28:59,409 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'gain_scale', 'search_output_file': True, 'input_dir': '../../../sci_data'}
# 2022-12-08 02:28:59,474 - stpipe.Detector1Pipeline.gain_scale - INFO - Rescaling by 1.0
# 2022-12-08 02:28:59,489 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# 2022-12-08 02:28:59,555 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<CubeModel(1, 2048, 2048) from jw01386013001_03106_00001_nrs2_uncal.fits>,).
# 2022-12-08 02:28:59,557 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'gain_scaleints', 'search_output_file': True, 'input_dir': '../../../sci_data'}
# 2022-12-08 02:28:59,598 - stpipe.Detector1Pipeline.gain_scale - INFO - Rescaling by 1.0
# 2022-12-08 02:28:59,607 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# 2022-12-08 02:28:59,849 - stpipe.Detector1Pipeline - INFO - Saved model in stage1/jw01386013001_03106_00001_nrs2_rateints.fits
# 2022-12-08 02:28:59,850 - stpipe.Detector1Pipeline - INFO - ... ending calwebb_detector1
# 2022-12-08 02:28:59,850 - stpipe.Detector1Pipeline - INFO - Results used CRDS context: jwst_0977.pmap
# 2022-12-08 02:29:00,053 - stpipe.Detector1Pipeline - INFO - Saved model in stage1/jw01386013001_
- stpipe.Detector1Pipeline - INFO - Prefetch for REFPIX reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_refpix_0018.fits'.
# 2022-12-08 02:32:21,586 - stpipe.Detector1Pipeline - INFO - Prefetch for SATURATION reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_saturation_0026.fits'.
# 2022-12-08 02:32:21,587 - stpipe.Detector1Pipeline - INFO - Prefetch for SUPERBIAS reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_superbias_0256.fits'.
# 2022-12-08 02:32:21,587 - stpipe.Detector1Pipeline - INFO - Starting calwebb_detector1 ...
# 2022-12-08 02:32:22,300 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale running with args (<RampModel(1, 21, 3200, 2048) from jw01386013001_03106_00004_nrs2_uncal.fits>,).
# 2022-12-08 02:32:22,302 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../sci_data'}
# 2022-12-08 02:32:22,657 - stpipe.Detector1Pipeline.group_scale - INFO - NFRAMES and FRMDIVSR are equal; correction not needed
# 2022-12-08 02:32:22,658 - stpipe.Detector1Pipeline.group_scale - INFO - Step will be skipped
# 2022-12-08 02:32:22,660 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale done
# 2022-12-08 02:32:22,766 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init running with args (<RampModel(1, 21, 3200, 2048) from jw01386013001_03106_00004_nrs2_uncal.fits>,).
# 2022-12-08 02:32:22,767 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../sci_data'}
# 2022-12-08 02:32:22,787 - stpipe.Detector1Pipeline.dq_init - INFO - Using MASK reference file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_mask_0033.fits
# 2022-12-08 02:32:23,317 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init done
# 2022-12-08 02:32:23,417 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation running with args (<RampModel(1, 21, 3200, 2048) from jw01386013001_03106_00004_nrs2_uncal.fits>,).
# 2022-12-08 02:32:23,419 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../sci_data', 'n_pix_grow_sat': 1}
# 2022-12-08 02:32:23,439 - stpipe.Detector1Pipeline.saturation - INFO - Using SATURATION reference file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_saturation_0026.fits
# 2022-12-08 02:32:26,098 - stpipe.Detector1Pipeline.saturation - INFO - Detected 34970 saturated pixels
# 2022-12-08 02:32:26,198 - stpipe.Detector1Pipeline.saturation - INFO - Detected 0 A/D floor pixels
# 2022-12-08 02:32:26,209 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation done
# 2022-12-08 02:32:26,312 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc running with args (<RampModel(1, 21, 3200, 2048) from jw01386013001_03106_00004_nrs2_uncal.fits>,).
# 2022-12-08 02:32:26,313 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../sci_data'}
# 2022-12-08 02:32:26,334 - stpipe.Detector1Pipeline.ipc - INFO - Using IPC reference file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_ipc_0012.fits
# 2022-12-08 02:32:27,339 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc done
# 2022-12-08 02:32:27,438 - stpipe.Detector1Pipeline.superbias - INFO - Step superbias running with args (<RampModel(1, 21, 3200, 2048) from jw01386013001_03106_00004_nrs2_uncal.fits>,).
# 2022-12-08 02:32:27,439 - stpipe.Detector1Pipeline.superbias - INFO - Step superbias parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../sci_data'}
# 2022-12-08 02:32:27,460 - stpipe.Detector1Pipeline.superbias - INFO - Using SUPERBIAS reference file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_superbias_0256.fits
# 2022-12-08 02:32:27,917 - stpipe.Detector1Pipeline.superbias - INFO - Step superbias done
# 2022-12-08 02:32:28,018 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix running with args (<RampModel(1, 21, 3200, 2048) from jw01386013001_03106_00004_nrs2_uncal.fits>,).
# 2022-12-08 02:32:28,019 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../sci_data', 'odd_even_columns': True, 'use_side_ref_pixels': True, 'side_smoothing_length': 11, 'side_gain': 1.0, 'odd_even_rows': True}
# 2022-12-08 02:32:28,040 - stpipe.Detector1Pipeline.refpix - INFO - Using refpix reference file: /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_refpix_0018.fits
# 2022-12-08 02:32:28,331 - stpipe.Detector1Pipeline.refpix - INFO - Working on integration 1
# 2022-12-08 02:33:09,310 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix done
# 2022-12-08 02:33:09,440 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity running with args (<RampModel(1, 21, 3200, 2048) from jw01386013001_03106_00004_nrs2_uncal.fits>,).
# 2022-12-08 02:33:09,441 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../sci_data'}
# 2022-12-08 02:33:09,460 - stpipe.Detector1Pipeline.linearity - INFO - Using Linearity reference file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_linearity_0025.fits
# 2022-12-08 02:33:09,548 - stpipe.Detector1Pipeline.linearity - WARNING - Keyword BAD_LIN_CORR does not correspond to an existing DQ mnemonic, so will be ignored
# 2022-12-08 02:33:10,226 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity done
# 2022-12-08 02:33:10,365 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current running with args (<RampModel(1, 21, 3200, 2048) from jw01386013001_03106_00004_nrs2_uncal.fits>,).
# 2022-12-08 02:33:10,366 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': 'stage1/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../sci_data', 'dark_output': None}
# 2022-12-08 02:33:10,610 - stpipe.Detector1Pipeline.dark_current - INFO - Using DARK reference file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_dark_0206.fits
# 2022-12-08 02:33:14,536 - stpipe.Detector1Pipeline.dark_current - INFO - Science data nints=1, ngroups=21, nframes=1, groupgap=0
# 2022-12-08 02:33:14,537 - stpipe.Detector1Pipeline.dark_current - INFO - Dark data nints=1, ngroups=245, nframes=1, groupgap=0
# 2022-12-08 02:33:19,838 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current done
# 2022-12-08 02:33:20,324 - stpipe.Detector1Pipeline.jump - INFO - Step jump running with args (<RampModel(1, 21, 3200, 2048) from jw01386013001_03106_00004_nrs2_uncal.fits>,).
# 2022-12-08 02:33:20,325 - stpipe.Detector1Pipeline.jump - INFO - Step jump parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../sci_data', 'rejection_threshold': 4.0, 'three_group_rejection_threshold': 6.0, 'four_group_rejection_threshold': 5.0, 'maximum_cores': 'half', 'flag_4_neighbors': True, 'max_jump_to_flag_neighbors': 1000.0, 'min_jump_to_flag_neighbors': 10.0, 'after_jump_flag_dn1': 0.0, 'after_jump_flag_time1': 0.0, 'after_jump_flag_dn2': 0.0, 'after_jump_flag_time2': 0.0}
# 2022-12-08 02:33:20,463 - stpipe.Detector1Pipeline.jump - INFO - CR rejection threshold = 4 sigma
# 2022-12-08 02:33:20,463 - stpipe.Detector1Pipeline.jump - INFO - Maximum cores to use = half
# 2022-12-08 02:33:20,604 - stpipe.Detector1Pipeline.jump - INFO - Using GAIN reference file: /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_gain_0020.fits
# 2022-12-08 02:33:20,771 - stpipe.Detector1Pipeline.jump - INFO - Using READNOISE reference file: /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_readnoise_0017.fits
# 2022-12-08 02:33:21,548 - stpipe.Detector1Pipeline.jump - INFO - Executing two-point difference method
# 2022-12-08 02:33:21,680 - stpipe.Detector1Pipeline.jump - INFO - Creating 5 processes for jump detection
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/jump/twopoint_difference.py:154: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/jump/twopoint_difference.py:154: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/jump/twopoint_difference.py:154: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/jump/twopoint_difference.py:154: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/jump/twopoint_difference.py:154: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
# 2022-12-08 02:33:30,022 - stpipe.Detector1Pipeline.jump - INFO - Total elapsed time = 8.47261 sec
# 2022-12-08 02:33:30,043 - stpipe.Detector1Pipeline.jump - INFO - The execution time in seconds: 9.579768
# 2022-12-08 02:33:30,047 - stpipe.Detector1Pipeline.jump - INFO - Step jump done
# 2022-12-08 02:33:30,209 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit running with args (<RampModel(1, 21, 3200, 2048) from jw01386013001_03106_00004_nrs2_uncal.fits>,).
# 2022-12-08 02:33:30,210 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': 'stage1/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../sci_data', 'int_name': '', 'save_opt': False, 'opt_name': '', 'suppress_one_group': True, 'maximum_cores': 'half'}
# 2022-12-08 02:33:30,531 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using READNOISE reference file: /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_readnoise_0017.fits
# 2022-12-08 02:33:30,531 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using GAIN reference file: /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_gain_0020.fits
# 2022-12-08 02:33:30,604 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using algorithm = ols
# 2022-12-08 02:33:30,605 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using weighting = optimal
# 2022-12-08 02:33:30,961 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of processors used for multiprocessing: 5
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/ramp_fitting/ols_fit.py:1089: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/ramp_fitting/ols_fit.py:1089: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/ramp_fitting/ols_fit.py:1089: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/ramp_fitting/ols_fit.py:1089: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/ramp_fitting/ols_fit.py:1089: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# 2022-12-08 02:34:05,067 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit done
# 2022-12-08 02:34:05,232 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<IFUImageModel(2048, 2048) from jw01386013001_03106_00004_nrs2_uncal.fits>,).
# 2022-12-08 02:34:05,234 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'gain_scale', 'search_output_file': True, 'input_dir': '../../../sci_data'}
# 2022-12-08 02:34:05,298 - stpipe.Detector1Pipeline.gain_scale - INFO - Rescaling by 1.0
# 2022-12-08 02:34:05,312 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# 2022-12-08 02:34:05,372 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<CubeModel(1, 2048, 2048) from jw01386013001_03106_00004_nrs2_uncal.fits>,).
# 2022-12-08 02:34:05,374 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'gain_scaleints', 'search_output_file': True, 'input_dir': '../../../sci_data'}
# 2022-12-08 02:34:05,415 - stpipe.Detector1Pipeline.gain_scale - INFO - Rescaling by 1.0
# 2022-12-08 02:34:05,424 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# 2022-12-08 02:34:05,633 - stpipe.Detector1Pipeline - INFO - Saved model in stage1/jw01386013001_03106_00004_nrs2_rateints.fits
# 2022-12-08 02:34:05,634 - stpipe.Detector1Pipeline - INFO - ... ending calwebb_detector1
# 2022-12-08 02:34:05,634 - stpipe.Detector1Pipeline - INFO - Results used CRDS context: jwst_0977.pmap
# 2022-12-08 02:34:05,829 - stpipe.Detector1Pipeline - INFO - Saved model in stage1/jw01386013001_03106_00004_nrs2_rate.fits
# 2022-12-08 02:34:05,830 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline done

# %%
# Print out the time benchmark
time1 = time.perf_counter()
print(f"Runtime so far: {time1 - time0:0.4f} seconds")
# Out:
# Runtime so far: 418.8110 seconds

# %%
# Look for input uncalibrated slope files from the Detector1 pipeline
sstring = 'stage1/'+ '*_rate.fits'
rate_files = sorted(glob.glob(sstring))
print('Found ' + str(len(rate_files)) + ' input files to process')
# Out:
# Found 4 input files to process

# %%
# Start a timer to keep track of runtime
time0 = time.perf_counter()

# %%
# Setting up steps and running the Spec2 portion of the pipeline. 

spec2 = Spec2Pipeline()
spec2.output_dir = spec2_dir
spec2.assign_wcs.skip = False
spec2.bkg_subtract.skip = False
spec2.imprint_subtract.skip = False
spec2.msa_flagging.skip = False
spec2.srctype.source_type = 'POINT'
spec2.flat_field.skip = False
spec2.pathloss.skip = False
spec2.photom.skip = False
spec2.cube_build.skip = False
spec2.extract_1d.skip = True

##extra steps that only apply to other instruments modes.
spec2.extract_2d.skip = True
spec2.master_background_mos.skip = True
spec2.barshadow.skip = True
spec2.wavecorr.skip = True
spec2.straylight.skip = True
spec2.fringe.skip = True
#spec2.residual_fringe.skip = True   # is not used in 1.7.2 works in 1.8.4
spec2.wfss_contam.skip = True
spec2.resample_spec.skip = True

#choose what results to save and from what steps
spec2.save_results = True
spec2.run(rate_files)
# Out:
# 2022-12-08 11:50:36,584 - stpipe.Spec2Pipeline - INFO - Spec2Pipeline instance created.
# 2022-12-08 11:50:36,586 - stpipe.Spec2Pipeline.bkg_subtract - INFO - BackgroundStep instance created.
# 2022-12-08 11:50:36,588 - stpipe.Spec2Pipeline.assign_wcs - INFO - AssignWcsStep instance created.
# 2022-12-08 11:50:36,589 - stpipe.Spec2Pipeline.imprint_subtract - INFO - ImprintStep instance created.
# 2022-12-08 11:50:36,589 - stpipe.Spec2Pipeline.msa_flagging - INFO - MSAFlagOpenStep instance created.
# 2022-12-08 11:50:36,590 - stpipe.Spec2Pipeline.extract_2d - INFO - Extract2dStep instance created.
# 
- stpipe.Spec2Pipeline.srctype - INFO - Input EXP_TYPE is NRS_IFU
# 2022-12-08 12:19:48,355 - stpipe.Spec2Pipeline.srctype - INFO - Input SRCTYAPT = UNKNOWN
# 2022-12-08 12:19:48,355 - stpipe.Spec2Pipeline.srctype - WARNING - Based on user-input, setting SRCTYPE = POINT
# 2022-12-08 12:19:48,359 - stpipe.Spec2Pipeline.srctype - INFO - Step srctype done
# 2022-12-08 12:19:48,722 - stpipe.Spec2Pipeline.flat_field - INFO - Step flat_field running with args (<IFUImageModel(2048, 2048) from jw01386013001_03106_00004_nrs2_rate.fits>,).
# 2022-12-08 12:19:48,723 - stpipe.Spec2Pipeline.flat_field - INFO - Step flat_field parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'flat_field', 'search_output_file': True, 'input_dir': '', 'save_interpolated_flat': False, 'user_supplied_flat': None, 'inverse': False}
# 2022-12-08 12:25:31,944 - stpipe.Spec2Pipeline.flat_field - INFO - Step flat_field done
# 2022-12-08 12:25:32,891 - stpipe.Spec2Pipeline.straylight - INFO - Step straylight running with args (<IFUImageModel(2048, 2048) from jw01386013001_03106_00004_nrs2_rate.fits>,).
# 2022-12-08 12:25:32,892 - stpipe.Spec2Pipeline.straylight - INFO - Step straylight parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': 'straylight', 'search_output_file': True, 'input_dir': ''}
# 2022-12-08 12:25:32,893 - stpipe.Spec2Pipeline.straylight - INFO - Step skipped.
# 2022-12-08 12:25:32,895 - stpipe.Spec2Pipeline.straylight - INFO - Step straylight done
# 2022-12-08 12:25:33,338 - stpipe.Spec2Pipeline.fringe - INFO - Step fringe running with args (<IFUImageModel(2048, 2048) from jw01386013001_03106_00004_nrs2_rate.fits>,).
# 2022-12-08 12:25:33,340 - stpipe.Spec2Pipeline.fringe - INFO - Step fringe parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': 'fringe', 'search_output_file': True, 'input_dir': ''}
# 2022-12-08 12:25:33,340 - stpipe.Spec2Pipeline.fringe - INFO - Step skipped.
# 2022-12-08 12:25:33,343 - stpipe.Spec2Pipeline.fringe - INFO - Step fringe done
# 2022-12-08 12:25:33,776 - stpipe.Spec2Pipeline.pathloss - INFO - Step pathloss running with args (<IFUImageModel(2048, 2048) from jw01386013001_03106_00004_nrs2_rate.fits>,).
# 2022-12-08 12:25:33,778 - stpipe.Spec2Pipeline.pathloss - INFO - Step pathloss parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'pathloss', 'search_output_file': True, 'input_dir': '', 'inverse': False, 'source_type': None}
# 2022-12-08 12:25:33,796 - stpipe.Spec2Pipeline.pathloss - INFO - Using PATHLOSS reference file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_pathloss_0003.fits
# 2022-12-08 12:25:33,823 - stpipe.Spec2Pipeline.pathloss - INFO - Input exposure type is NRS_IFU
# 2022-12-08 12:26:35,601 - stpipe.Spec2Pipeline.pathloss - INFO - Step pathloss done
# 2022-12-08 12:26:36,284 - stpipe.Spec2Pipeline.barshadow - INFO - Step barshadow running with args (<IFUImageModel(2048, 2048) from jw01386013001_03106_00004_nrs2_rate.fits>,).
# 2022-12-08 12:26:36,285 - stpipe.Spec2Pipeline.barshadow - INFO - Step barshadow parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': 'barshadow', 'search_output_file': True, 'input_dir': '', 'inverse': False, 'source_type': None}
# 2022-12-08 12:26:36,285 - stpipe.Spec2Pipeline.barshadow - INFO - Step skipped.
# 2022-12-08 12:26:36,287 - stpipe.Spec2Pipeline.barshadow - INFO - Step barshadow done
# 2022-12-08 12:26:36,722 - stpipe.Spec2Pipeline.photom - INFO - Step photom running with args (<IFUImageModel(2048, 2048) from jw01386013001_03106_00004_nrs2_rate.fits>,).
# 2022-12-08 12:26:36,723 - stpipe.Spec2Pipeline.photom - INFO - Step photom parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'photom', 'search_output_file': True, 'input_dir': '', 'inverse': False, 'source_type': None}
# 2022-12-08 12:26:36,750 - stpipe.Spec2Pipeline.photom - INFO - Using photom reference file: /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_photom_0016.fits
# 2022-12-08 12:26:36,751 - stpipe.Spec2Pipeline.photom - INFO - Using area reference file: /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_area_0005.fits
# 2022-12-08 12:26:39,254 - stpipe.Spec2Pipeline.photom - INFO - Using instrument: NIRSPEC
# 2022-12-08 12:26:39,254 - stpipe.Spec2Pipeline.photom - INFO -  detector: NRS2
# 2022-12-08 12:26:39,255 - stpipe.Spec2Pipeline.photom - INFO -  exp_type: NRS_IFU
# 2022-12-08 12:26:39,255 - stpipe.Spec2Pipeline.photom - INFO -  filter: F100LP
# 2022-12-08 12:26:39,255 - stpipe.Spec2Pipeline.photom - INFO -  grating: G140H
# 2022-12-08 12:26:39,304 - stpipe.Spec2Pipeline.photom - INFO - PHOTMJSR value: 1
# 2022-12-08 12:27:38,942 - stpipe.Spec2Pipeline.photom - INFO - Step photom done
# 2022-12-08 12:27:39,981 - stpipe.Spec2Pipeline.cube_build - INFO - Step cube_build running with args (<IFUImageModel(2048, 2048) from stage2/jw01386013001_03106_00004_nrs2_cal.fits>,).
# 2022-12-08 12:27:39,982 - stpipe.Spec2Pipeline.cube_build - INFO - Step cube_build parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 's3d', 'search_output_file': False, 'input_dir': '', 'channel': 'all', 'band': 'all', 'grating': 'all', 'filter': 'all', 'output_type': 'multi', 'scale1': 0.0, 'scale2': 0.0, 'scalew': 0.0, 'weighting': 'drizzle', 'coord_system': 'skyalign', 'rois': 0.0, 'roiw': 0.0, 'weight_power': 2.0, 'wavemin': None, 'wavemax': None, 'single': False, 'skip_dqflagging': True}
# 2022-12-08 12:27:39,982 - stpipe.Spec2Pipeline.cube_build - INFO - Starting IFU Cube Building Step
# 2022-12-08 12:27:39,983 - stpipe.Spec2Pipeline.cube_build - INFO - Input interpolation: drizzle
# 2022-12-08 12:27:39,983 - stpipe.Spec2Pipeline.cube_build - INFO - Coordinate system to use: skyalign
# 2022-12-08 12:27:40,009 - stpipe.Spec2Pipeline.cube_build - INFO - Reading cube parameter file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_cubepar_0003.fits
# 2022-12-08 12:27:40,052 - stpipe.Spec2Pipeline.cube_build - INFO - Output IFUcube are constructed from all the data
# 2022-12-08 12:27:40,053 - stpipe.Spec2Pipeline.cube_build - INFO - Number of IFU cubes produced by this run = 1
# 2022-12-08 12:27:40,056 - stpipe.Spec2Pipeline.cube_build - INFO - Increasing spatial region of interest default value set for 4 dithers nan
# 2022-12-08 12:27:40,058 - stpipe.Spec2Pipeline.cube_build - INFO - Cube Geometry:
# 2022-12-08 12:27:40,059 - stpipe.Spec2Pipeline.cube_build - INFO - axis#  Naxis  CRPIX    CRVAL      CDELT(arcsec)  Min & Max (xi, eta arcsec)
# 2022-12-08 12:27:40,059 - stpipe.Spec2Pipeline.cube_build - INFO - Axis 1    47  24.00 -165.99403655   0.10000000  -2.35000004   2.35000004
# 2022-12-08 12:27:40,059 - stpipe.Spec2Pipeline.cube_build - INFO - Axis 2    43  22.00 -12.95911433   0.10000000  -2.15000003   2.15000003
# 2022-12-08 12:27:40,059 - stpipe.Spec2Pipeline.cube_build - INFO - axis#  Naxis  CRPIX    CRVAL      CDELT(microns)  Min & Max (microns)
# 2022-12-08 12:27:40,060 - stpipe.Spec2Pipeline.cube_build - INFO - Axis 3  1918   1.00   1.44272032   0.00023500   1.44260282   1.89333281
# 2022-12-08 12:27:40,060 - stpipe.Spec2Pipeline.cube_build - INFO - Cube covers grating, filter: g140h, f100lp
# 2022-12-08 12:27:40,060 - stpipe.Spec2Pipeline.cube_build - INFO - Output Name: stage2/jw01386013001_03106_00004_nrs2_s3d.fits
# 2022-12-08 12:27:43,819 - stpipe.Spec2Pipeline.cube_build - INFO - Mapping each NIRSpec slice to sky for input file: stage2/jw01386013001_03106_00004_nrs2_cal.fits
# 2022-12-08 12:29:02,565 - stpipe.Spec2Pipeline.cube_build - INFO - Average # of holes/wavelength plane is < 1
# 2022-12-08 12:29:02,566 - stpipe.Spec2Pipeline.cube_build - INFO - Total # of holes for IFU cube is : 0
# 2022-12-08 12:29:02,567 - stpipe.Spec2Pipeline.cube_build - INFO - Number of wavelength planes removed with no data: 18
# 2022-12-08 12:29:02,670 - stpipe.Spec2Pipeline.cube_build - INFO - Update S_REGION to POLYGON ICRS  194.005307861 -12.959697658 194.005307861 -12.958530991 194.006619036 -12.958530991 194.006619036 -12.959697658
# 2022-12-08 12:29:02,676 - stpipe.Spec2Pipeline.cube_build - INFO - Step cube_build done
# 2022-12-08 12:29:02,890 - stpipe.Spec2Pipeline - INFO - Saved model in stage2/jw01386013001_03106_00004_nrs2_s3d.fits
# 2022-12-08 12:29:03,498 - stpipe.Spec2Pipeline.extract_1d - INFO - Step extract_1d running with args (<ModelContainer>,).
# 2022-12-08 12:29:03,500 - stpipe.Spec2Pipeline.extract_1d - INFO - Step extract_1d parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': True, 'suffix': 'x1d', 'search_output_file': True, 'input_dir': '', 'smoothing_length': None, 'bkg_fit': None, 'bkg_order': None, 'bkg_sigma_clip': 3.0, 'log_increment': 50, 'subtract_background': None, 'use_source_posn': None, 'center_xy': None, 'apply_apcorr': True, 'soss_threshold': 0.01, 'soss_n_os': 2, 'soss_transform': None, 'soss_tikfac': None, 'soss_width': 40.0, 'soss_bad_pix': 'model', 'soss_modelname': None}
# 2022-12-08 12:29:03,501 - stpipe.Spec2Pipeline.extract_1d - INFO - Step skipped.
# 2022-12-08 12:29:03,503 - stpipe.Spec2Pipeline.extract_1d - INFO - Step extract_1d done
# 2022-12-08 12:29:03,504 - stpipe.Spec2Pipeline - INFO - Finished processing product stage1/jw01386013001_03106_00004_nrs2
# 2022-12-08 12:29:03,504 - stpipe.Spec2Pipeline - INFO - Ending calwebb_spec2
# 2022-12-08 12:29:03,504 - stpipe.Spec2Pipeline - INFO - Results used CRDS context: jwst_0977.pmap
# 2022-12-08 12:29:03,505 - stpipe.Spec2Pipeline - INFO - Results used CRDS context: jwst_0977.pmap
# 2022-12-08 12:29:03,505 - stpipe.Spec2Pipeline - INFO - Results used CRDS context: jwst_0977.pmap
# 2022-12-08 12:29:03,505 - stpipe.Spec2Pipeline - INFO - Results used CRDS context: jwst_0977.pmap
# 2022-12-08 12:29:05,963 - stpipe.Spec2Pipeline - INFO - Saved model in stage2/jw01386013001_03106_00001_nrs2_cal.fits
# 2022-12-08 12:29:08,947 - stpipe.Spec2Pipeline - INFO - Saved model in stage2/jw01386013001_03106_00002_nrs2_cal.fits
# 2022-12-08 12:29:11,922 - stpipe.Spec2Pipeline - INFO - Saved model in stage2/jw01386013001_03106_00003_nrs2_cal.fits
# 2022-12-08 12:29:14,821 - stpipe.Spec2Pipeline - INFO - Saved model in stage2/jw01386013001_03106_00004_nrs2_cal.fits
# 2022-12-08 12:29:14,821 - stpipe.Spec2Pipeline - INFO - Step Spec2Pipeline done
# [<IFUImageModel(2048, 2048) from jw01386013001_03106_00001_nrs2_cal.fits>,
#  <IFUImageModel(2048, 2048) from jw01386013001_03106_00002_nrs2_cal.fits>,
#  <IFUImageModel(2048, 2048) from jw01386013001_03106_00003_nrs2_cal.fits>,
#  <IFUImageModel(2048, 2048) from jw01386013001_03106_00004_nrs2_cal.fits>]

# %%
# Print out the time benchmark
time1 = time.perf_counter()
print(f"Runtime so far: {time1 - time0:0.4f} seconds")
# Out:
# Runtime so far: 34123.6020 seconds

# %%
### Calling in the calibrated detector images produced by running the stage 2 pipeline on the modified NRS fits files
cal_files = glob.glob('stage2/*cal.fits')
print(cal_files)
# Out:
# ['stage2/jw01386013001_03106_00003_nrs2_cal.fits', 'stage2/jw01386013001_03106_00004_nrs2_cal.fits', 'stage2/jw01386013001_03106_00001_nrs2_cal.fits', 'stage2/jw01386013001_03106_00002_nrs2_cal.fits']

# %%
## create association file for dithered data. Make a json file for the dither set.
call(["asn_from_list", "-o","l3_asn.json"] + cal_files + ["--product-name", "dither"])
# Out:
# 0

# %%
# Start a timer to keep track of runtime
time0 = time.perf_counter()

# %%
# This initial setup is just to make sure that we get the latest parameter reference files
# pulled in for our files.  This is a temporary workaround to get around an issue with
# how this pipeline calling method works.
#
# Setting up steps and running the Spec3 portion of the pipeline. Outlier detector is skipped
# because it tends to cut high value pixels even if it is a part of the target.

json_file = 'l3_asn.json'
crds_config = Spec3Pipeline.get_config_from_reference(json_file)# The exact asn file used doesn't matter
spec3 = Spec3Pipeline.from_config_section(crds_config)
spec3.output_dir = spec3_dir
spec3.assign_mtwcs.skip = True               #skipped because VHS 1256b is not a moving target
spec3.master_background.skip = False
spec3.outlier_detection.skip = True
spec3.cube_build.skip = False
spec3.cube_build.coord_system = 'skyalign'   
spec3.cube_build.output_type = 'band'        # is the default mode for calspec3 and creates IFU cubes containing only one band (channel/sub-channel for MIRI or grating/filter combination for NIRSpec).

#used on MRS or other modes
spec3.mrs_imatch.skip = True
spec3.resample_spec.skip = False
spec3.combine_1d.skip = True

#save results
spec3.save_results = True
spec3(json_file)
# Out:
# 2022-12-08 12:29:20,041 - stpipe.Spec3Pipeline - INFO - Spec3Pipeline instance created.
# 2022-12-08 12:29:20,042 - stpipe.Spec3Pipeline.assign_mtwcs - INFO - AssignMTWcsStep instance created.
# 2022-12-08 12:29:20,043 - stpipe.Spec3Pipeline.master_background - INFO - MasterBackgroundStep instance created.
# 2022-12-08 12:29:20,044 - stpipe.Spec3Pipeline.mrs_imatch - INFO - MRSIMatchStep instance created.
# 2022-12-08 12:29:20,045 - stpipe.Spec3Pipeline.outlier_detection - INFO - OutlierDetectionStep instance created.
# 2022-12-08 12:29:20,046 - stpipe.Spec3Pipeline.resample_spec - INFO - ResampleSpecStep instance created.
# 2022-12-08 12:29:20,048 - stpipe.Spec3Pipeline.cube_build - INFO - CubeBuildStep instance created.
# 2022-12-08 12:29:20,049 - stpipe.Spec3Pipeline.extract_1d - INFO - Extract1dStep instance created.
# 2022-12-08 12:29:20,050 - stpipe.Spec3Pipeline.photom - INFO - PhotomStep instance created.
# 2022-12-08 12:29:20,051 - stpipe.Spec3Pipeline.combine_1d - INFO - Combine1dStep instance created.
# 2022-12-08 12:29:20,618 - stpipe.Spec3Pipeline - INFO - Step Spec3Pipeline running with args ('l3_asn.json',).
# 2022-12-08 12:29:20,625 - stpipe.Spec3Pipeline - INFO - Step Spec3Pipeline parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': 'stage3/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'steps': {'assign_mtwcs': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': 'assign_mtwcs', 'search_output_file': True, 'input_dir': ''}, 'master_background': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'user_background': None, 'save_background': False, 'force_subtract': False}, 'mrs_imatch': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'bkg_degree': 1, 'subtract': False}, 'outlier_detection': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': False, 'input_dir': '', 'weight_type': 'ivm', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'nlow': 0, 'nhigh': 0, 'maskpt': 0.7, 'grow': 1, 'snr': '5.0 4.0', 'scale': '1.2 0.7', 'backg': 0.0, 'save_intermediate_results': False, 'resample_data': True, 'good_bits': '~DO_NOT_USE', 'scale_detection': False, 'allowed_memory': None, 'in_memory': False}, 'resample_spec': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'weight_type': 'ivm', 'output_shape': None, 'crpix': None, 'crval': None, 'rotation': None, 'pixel_scale_ratio': 1.0, 'pixel_scale': None, 'single': False, 'blendheaders': True, 'allowed_memory': None, 'in_memory': True}, 'cube_build': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': False, 'input_dir': '', 'channel': 'all', 'band': 'all', 'grating': 'all', 'filter': 'all', 'output_type': 'band', 'scale1': 0.0, 'scale2': 0.0, 'scalew': 0.0, 'weighting': 'drizzle', 'coord_system': 'skyalign', 'rois': 0.0, 'roiw': 0.0, 'weight_power': 2.0, 'wavemin': None, 'wavemax': None, 'single': False, 'skip_dqflagging': False}, 'extract_1d': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'smoothing_length': None, 'bkg_fit': None, 'bkg_order': None, 'bkg_sigma_clip': 3.0, 'log_increment': 50, 'subtract_background': None, 'use_source_posn': None, 'center_xy': None, 'apply_apcorr': True, 'soss_threshold': 0.01, 'soss_n_os': 2, 'soss_transform': None, 'soss_tikfac': None, 'soss_width': 40.0, 'soss_bad_pix': 'model', 'soss_modelname': None}, 'photom': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'inverse': False, 'source_type': None}, 'combine_1d': {'pre_hooks': [], 'post_hooks': [], 'outp ...
# 2022-12-08 12:29:23,494 - stpipe.Spec3Pipeline - INFO - Prefetching reference files for dataset: 'jw01386013001_03106_00003_nrs2_cal.fits' reftypes = ['apcorr', 'area', 'cubepar', 'drizpars', 'extract1d', 'photom', 'speckernel', 'specprofile', 'spectrace', 'wavemap']
# 2022-12-08 12:29:23,498 - stpipe.Spec3Pipeline - INFO - Prefetch for APCORR reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_apcorr_0009.asdf'.
# 2022-12-08 12:29:23,498 - stpipe.Spec3Pipeline - INFO - Prefetch for AREA reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_area_0005.fits'.
# 2022-12-08 12:29:23,499 - stpipe.Spec3Pipeline - INFO - Prefetch for CUBEPAR reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_cubepar_0003.fits'.
# 2022-12-08 12:29:23,499 - stpipe.Spec3Pipeline - INFO - Prefetch for DRIZPARS reference file is 'N/A'.
# 2022-12-08 12:29:23,499 - stpipe.Spec3Pipeline - INFO - Prefetch for EXTRACT1D reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_extract1d_0001.asdf'.
# 2022-12-08 12:29:23,500 - stpipe.Spec3Pipeline - INFO - Prefetch for PHOTOM reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_photom_0016.fits'.
# 2022-12-08 12:29:23,500 - stpipe.Spec3Pipeline - INFO - Prefetch for SPECKERNEL reference file is 'N/A'.
# 2022-12-08 12:29:23,500 - stpipe.Spec3Pipeline - INFO - Prefetch for SPECPROFILE reference file is 'N/A'.
# 2022-12-08 12:29:23,501 - stpipe.Spec3Pipeline - INFO - Prefetch for SPECTRACE reference file is 'N/A'.
# 2022-12-08 12:29:23,501 - stpipe.Spec3Pipeline - INFO - Prefetch for WAVEMAP reference file is 'N/A'.
# 2022-12-08 12:29:23,502 - stpipe.Spec3Pipeline - INFO - Starting calwebb_spec3 ...
# 2022-12-08 12:29:37,466 - stpipe.Spec3Pipeline.outlier_detection - INFO - Step outlier_detection running with args (<ModelContainer>,).
# 2022-12-08 12:29:37,468 - stpipe.Spec3Pipeline.outlier_detection - INFO - Step outlier_detection parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': True, 'suffix': 'crf', 'search_output_file': False, 'input_dir': '', 'weight_type': 'ivm', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'nlow': 0, 'nhigh': 0, 'maskpt': 0.7, 'grow': 1, 'snr': '5.0 4.0', 'scale': '1.2 0.7', 'backg': 0.0, 'save_intermediate_results': False, 'resample_data': True, 'good_bits': '~DO_NOT_USE', 'scale_detection': False, 'allowed_memory': None, 'in_memory': False}
# 2022-12-08 12:29:37,468 - stpipe.Spec3Pipeline.outlier_detection - INFO - Step skipped.
# 2022-12-08 12:29:37,476 - stpipe.Spec3Pipeline.outlier_detection - INFO - Step outlier_detection done
# 2022-12-08 12:29:38,116 - stpipe.Spec3Pipeline.cube_build - INFO - Step cube_build running with args (<ModelContainer>,).
# 2022-12-08 12:29:38,117 - stpipe.Spec3Pipeline.cube_build - INFO - Step cube_build parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': 's3d', 'search_output_file': False, 'input_dir': '', 'channel': 'all', 'band': 'all', 'grating': 'all', 'filter': 'all', 'output_type': 'band', 'scale1': 0.0, 'scale2': 0.0, 'scalew': 0.0, 'weighting': 'drizzle', 'coord_system': 'skyalign', 'rois': 0.0, 'roiw': 0.0, 'weight_power': 2.0, 'wavemin': None, 'wavemax': None, 'single': False, 'skip_dqflagging': False}
# 2022-12-08 12:29:38,118 - stpipe.Spec3Pipeline.cube_build - INFO - Starting IFU Cube Building Step
# 2022-12-08 12:29:38,118 - stpipe.Spec3Pipeline.cube_build - INFO - Input interpolation: drizzle
# 2022-12-08 12:29:38,118 - stpipe.Spec3Pipeline.cube_build - INFO - Coordinate system to use: skyalign
# 2022-12-08 12:29:38,166 - stpipe.Spec3Pipeline.cube_build - INFO - Reading cube parameter file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_cubepar_0003.fits
# 2022-12-08 12:29:38,211 - stpipe.Spec3Pipeline.cube_build - INFO - Output Cubes are single grating, single filter IFU Cubes
# 2022-12-08 12:29:38,211 - stpipe.Spec3Pipeline.cube_build - INFO - Number of IFU cubes produced by this run = 1
# 2022-12-08 12:29:38,217 - stpipe.Spec3Pipeline.cube_build - INFO - Cube Geometry:
# 2022-12-08 12:29:38,217 - stpipe.Spec3Pipeline.cube_build - INFO - axis#  Naxis  CRPIX    CRVAL      CDELT(arcsec)  Min & Max (xi, eta arcsec)
# 2022-12-08 12:29:38,218 - stpipe.Spec3Pipeline.cube_build - INFO - Axis 1    69  35.00 -165.99433924   0.10000000  -3.45000005   3.45000005
# 2022-12-08 12:29:38,218 - stpipe.Spec3Pipeline.cube_build - INFO - Axis 2    65  33.00 -12.95900642   0.10000000  -3.25000005   3.25000005
# 2022-12-08 12:29:38,218 - stpipe.Spec3Pipeline.cube_build - INFO - axis#  Naxis  CRPIX    CRVAL      CDELT(microns)  Min & Max (microns)
# 2022-12-08 12:29:38,218 - stpipe.Spec3Pipeline.cube_build - INFO - Axis 3  1918   1.00   1.44272032   0.00023500   1.44260282   1.89333281
# 2022-12-08 12:29:38,219 - stpipe.Spec3Pipeline.cube_build - INFO - Cube covers grating, filter: g140h, f100lp
# 2022-12-08 12:29:38,219 - stpipe.Spec3Pipeline.cube_build - INFO - Output Name: dither_g140h-f100lp_s3d.fits
# 2022-12-08 12:29:41,461 - stpipe.Spec3Pipeline.cube_build - INFO - Mapping each NIRSpec slice to sky for input file: jw01386013001_03106_00003_nrs2_cal.fits
# 2022-12-08 12:31:04,135 - stpipe.Spec3Pipeline.cube_build - INFO - Mapping each NIRSpec slice to sky for input file: jw01386013001_03106_00004_nrs2_cal.fits
# 2022-12-08 12:32:25,190 - stpipe.Spec3Pipeline.cube_build - INFO - Mapping each NIRSpec slice to sky for input file: jw01386013001_03106_00001_nrs2_cal.fits
# 2022-12-08 12:33:48,018 - stpipe.Spec3Pipeline.cube_build - INFO - Mapping each NIRSpec slice to sky for input file: jw01386013001_03106_00002_nrs2_cal.fits
# 2022-12-08 12:35:09,444 - stpipe.Spec3Pipeline.cube_build - INFO - Average # of holes/wavelength plane: 13
# 2022-12-08 12:35:09,445 - stpipe.Spec3Pipeline.cube_build - INFO - Total # of holes for IFU cube is : 25084
# 2022-12-08 12:35:09,447 - stpipe.Spec3Pipeline.cube_build - INFO - Number of wavelength planes removed with no data: 18
# 2022-12-08 12:35:12,822 - stpipe.Spec3Pipeline.cube_build - INFO - Update S_REGION to POLYGON ICRS  194.004691628 -12.959895306 194.004691628 -12.958117528 194.006629890 -12.958117528 194.006629890 -12.959895306
# 2022-12-08 12:35:13,466 - stpipe.Spec3Pipeline.cube_build - INFO - Saved model in stage3/dither_g140h-f100lp_s3d.fits
# 2022-12-08 12:35:13,467 - stpipe.Spec3Pipeline.cube_build - INFO - Step cube_build done
# 2022-12-08 12:35:14,349 - stpipe.Spec3Pipeline.extract_1d - INFO - Step extract_1d running with args (<ModelContainer>,).
# 2022-12-08 12:35:14,350 - stpipe.Spec3Pipeline.extract_1d - INFO - Step extract_1d parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': 'x1d', 'search_output_file': False, 'input_dir': '', 'smoothing_length': None, 'bkg_fit': None, 'bkg_order': None, 'bkg_sigma_clip': 3.0, 'log_increment': 50, 'subtract_background': None, 'use_source_posn': None, 'center_xy': None, 'apply_apcorr': True, 'soss_threshold': 0.01, 'soss_n_os': 2, 'soss_transform': None, 'soss_tikfac': None, 'soss_width': 40.0, 'soss_bad_pix': 'model', 'soss_modelname': None}
# 2022-12-08 12:35:14,364 - stpipe.Spec3Pipeline.extract_1d - INFO - Using EXTRACT1D reference file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_extract1d_0001.asdf
# 2022-12-08 12:35:14,374 - stpipe.Spec3Pipeline.extract_1d - INFO - Using APCORR file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_apcorr_0009.asdf
# 2022-12-08 12:35:15,297 - stpipe.Spec3Pipeline.extract_1d - INFO - Turning on source position correction for exp_type = NRS_IFU
# 2022-12-08 12:35:15,298 - stpipe.Spec3Pipeline.extract_1d - INFO - Source type = POINT
# 2022-12-08 12:35:15,312 - stpipe.Spec3Pipeline.extract_1d - INFO - Input model does not break out variance information. Passing only generalized errors.
# 2022-12-08 12:35:15,325 - stpipe.Spec3Pipeline.extract_1d - INFO - Using x_center = 1, y_center = 53, based on TARG_RA and TARG_DEC
# 2022-12-08 12:35:25,010 - stpipe.Spec3Pipeline.extract_1d - INFO - Applying Aperture correction.
# 2022-12-08 12:35:26,033 - stpipe.Spec3Pipeline.extract_1d - INFO - Saved model in stage3/dither_g140h-f100lp_x1d.fits
# 2022-12-08 12:35:26,033 - stpipe.Spec3Pipeline.extract_1d - INFO - Step extract_1d done
# 2022-12-08 12:35:26,037 - stpipe.Spec3Pipeline - INFO - Ending calwebb_spec3
# 2022-12-08 12:35:26,037 - stpipe.Spec3Pipeline - INFO - Step Spec3Pipeline done

# %%
# Print out the time benchmark
time1 = time.perf_counter()
print(f"Runtime so far: {time1 - time0:0.4f} seconds")
# Out:
# Runtime so far: 369.7711 seconds

# %%
# check the extracted spectrum from the JWST pipeline
data = fits.getdata('stage3/dither_g140h-f100lp_x1d.fits')
wavelength = data['wavelength']
flux  = data['flux']
flux_error = data['flux_error']

# %matplotlib notebook
plt.plot(wavelength, flux, label = 'stage 3')
plt.ylabel('Jy')
plt.xlabel('Wavelength (microns)')
#plt.ylim([0,1e-3])
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
cube_data = fits.getdata('stage3/dither_g140h-f100lp_s3d.fits')
cube=SpectralCube.read('stage3/dither_g140h-f100lp_s3d.fits',hdu=1)

wavelength=cube.spectral_axis
wavelength=n.array(wavelength)

cube_collapse = n.nanmedian(cube_data, axis = 0)
cube_collapse /= n.nanmax(cube_collapse) #the image is normalized so the 2-D Gaussian fit is easier.

# %%
# %matplotlib notebook
plt.figure('collapsed cube')
plt.title('Median Collapsed Spectral Cube')
plt.imshow((cube_collapse))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
## fitting a gaussian to the collapsed cube which is a median image to remove high pixels
image = cube_collapse
y_len, x_len = image.shape
bounds = ((0, 0, n.nanmin(image), 1, 1, n.nanmedian(image)) , (x_len, y_len, n.nanmax(image), x_len, y_len, 2 * n.nanmax(image)) )
guess = n.array([35, 34, n.nanmin(image), 1.2, 1.2, n.nanmax(image)])
fit_arr = optimize.least_squares(image_solve, guess, args = (image,), bounds = bounds )#, bounds=bounds)
x0_fit, y0_fit, offset_fit, sigma_x_fit, sigma_y_fit, A_fit = fit_arr.x


x0_fit = n.round(x0_fit, decimals = 0) #rounding because jwst pipeline does not take float values
y0_fit = n.round(y0_fit, decimals = 0) #rounding because jwst pipeline does not take float values


print('centroids (x, y)')
print(x0_fit, y0_fit)
print('sigmax, sigma y')
print(sigma_x_fit, sigma_y_fit)
# Out:
# centroids (x, y)
# 35.0 34.0
# sigmax, sigma y
# 1.0144233468496626 1.00845253101527

# %%
#re-running the jwst pipeline extraction step to ensure the extraction radius is centered.
spec3.extract_1d.center_xy = (int(x0_fit), int(y0_fit))
spec3.extract_1d('stage3/dither_g140h-f100lp_s3d.fits')
# Out:
# 2022-12-09 13:55:18,536 - stpipe.Spec3Pipeline.extract_1d - INFO - Step extract_1d running with args ('stage3/dither_g140h-f100lp_s3d.fits',).
# 2022-12-09 13:55:18,538 - stpipe.Spec3Pipeline.extract_1d - INFO - Step extract_1d parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': 'x1d', 'search_output_file': False, 'input_dir': '', 'smoothing_length': None, 'bkg_fit': None, 'bkg_order': None, 'bkg_sigma_clip': 3.0, 'log_increment': 50, 'subtract_background': None, 'use_source_posn': None, 'center_xy': [35, 34], 'apply_apcorr': True, 'soss_threshold': 0.01, 'soss_n_os': 2, 'soss_transform': None, 'soss_tikfac': None, 'soss_width': 40.0, 'soss_bad_pix': 'model', 'soss_modelname': None}
# 2022-12-09 13:55:18,954 - stpipe.Spec3Pipeline.extract_1d - INFO - Using EXTRACT1D reference file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_extract1d_0001.asdf
# 2022-12-09 13:55:18,964 - stpipe.Spec3Pipeline.extract_1d - INFO - Using APCORR file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_apcorr_0009.asdf
# 2022-12-09 13:55:19,880 - stpipe.Spec3Pipeline.extract_1d - INFO - Turning on source position correction for exp_type = NRS_IFU
# 2022-12-09 13:55:19,881 - stpipe.Spec3Pipeline.extract_1d - INFO - Source type = POINT
# 2022-12-09 13:55:19,895 - stpipe.Spec3Pipeline.extract_1d - INFO - Using user-supplied x_center=35, y_center=34
# 2022-12-09 13:55:19,895 - stpipe.Spec3Pipeline.extract_1d - INFO - Input model does not break out variance information. Passing only generalized errors.
# 2022-12-09 13:55:29,694 - stpipe.Spec3Pipeline.extract_1d - INFO - Applying Aperture correction.
# 2022-12-09 13:55:30,741 - stpipe.Spec3Pipeline.extract_1d - INFO - Saved model in stage3/dither_g140h-f100lp_x1d.fits
# 2022-12-09 13:55:30,741 - stpipe.Spec3Pipeline.extract_1d - INFO - Step extract_1d done
# <MultiSpecModel from dither_g140h-f100lp_x1d.fits>

# %%
# check the extracted spectrum from the JWST pipeline
data = fits.getdata('stage3/dither_g140h-f100lp_x1d.fits')
wavelength = data['wavelength']
flux  = data['flux']
flux_error = data['flux_error']

# %matplotlib notebook
plt.plot(wavelength, flux, label = 'stage 3')
plt.ylabel('Jy')
plt.xlabel('Wavelength (microns)')
plt.ylim([0,2e-3])
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
##save text
#data_out = n.vstack((wavelength,  flux , flux_error))
#data_out = n.transpose(data_out)
#
#spectra_dir = '../spectra/' # Detector1 pipeline outputs will go here
#if not os.path.exists(spectra_dir):
#    os.makedirs(spectra_dir)
#
#header = 'wavelength (microns) flux(Jy), flux error(Jy)'
#n.savetxt('../spectra/detector2_f100lp_g140h.txt', data_out, header = header)
