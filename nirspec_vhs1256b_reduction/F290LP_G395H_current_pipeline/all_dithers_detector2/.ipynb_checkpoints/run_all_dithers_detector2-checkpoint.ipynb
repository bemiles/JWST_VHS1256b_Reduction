# %% [markdown]
# This notebook was made to reduce NIRSpec dithers into a spectral cube by:
#
# 1. Using the Stage 1 Detector pipleine to turn uncalibrated detector images (_uncal.fits) into rate files (_rate.fits).
#
# 2. Using Stage 2 of the Spectroscopic pipeline to turn rate files(_rate.fits) into calibrated detector images (_cal.fits) and spectral cubes (_s3d.fits)
#
# 3. Using Stage 3 of the spectroscopic pipeline to combine the stage 2 rate files from each filter/grating combination.
#
# Other notes/caveats:
# Stage 2 cube building is redundant with Stage 3 if you are not combining dithers.

# %%
from astropy.io import fits
import glob, os
from subprocess import call
from astropy.io import fits
import time

import jwst
from jwst.pipeline import Detector1Pipeline, Spec2Pipeline, Spec3Pipeline

import matplotlib.pyplot as plt
import numpy as n

from spectral_cube import SpectralCube
from scipy import optimize


os.environ['CRDS_PATH'] = '/Users/zen/crds_cache/jwst_ops'
os.environ['CRDS_SERVER_URL'] = 'https://jwst-crds.stsci.edu'
os.environ['CRDS_CONTEXT'] = 'jwst_0977.pmap'


# Print out what pipeline version we're using
print('JWST pipeline version',jwst.__version__)
# Out:
# JWST pipeline version 1.7.2

# %%
# Functions for fitting a 2-D guassian to images to find the PSF center in collapsed spectral cubes
def gauss2d(x, y, x0, y0, offset, sigma_x, sigma_y, A):

    x_exp = ( ( x - x0 )**2) / (2 * sigma_x ** 2)
    y_exp = ( ( y - y0 )**2) / (2 * sigma_y ** 2)
    f = A * n.exp( - x_exp - y_exp) + offset

    return f

def image_solve(constants, im):

    x0_val, y0_val, offset_val, sigma_x_val, sigma_y_val, A_val = constants

    y_len, x_len = im.shape
    y_arr = n.arange(0, y_len)
    x_arr = n.arange(0, x_len)
    xx, yy = n.meshgrid(x_arr, y_arr)

    fit = gauss2d(xx, yy, x0_val, y0_val, offset_val, sigma_x_val, sigma_y_val, A_val)

    min_diff = n.nansum(abs(im - fit)**2)

    return min_diff

# %%
det1_dir = 'stage1/' # Detector1 pipeline outputs will go here
spec2_dir = 'stage2/' # Spec2 pipeline outputs will go here
spec3_dir = 'stage3/' # Spec3 pipeline outputs will go here

# We need to check that the desired output directories exist, and if not create them
if not os.path.exists(det1_dir):
    os.makedirs(det1_dir)
if not os.path.exists(spec2_dir):
    os.makedirs(spec2_dir)
if not os.path.exists(spec3_dir):
    os.makedirs(spec3_dir)

# %%
uncal_file_dir = '../../../sci_data/'

uncal_files = ['jw01386013001_03104_00001_nrs2_uncal.fits',
              'jw01386013001_03104_00002_nrs2_uncal.fits',
              'jw01386013001_03104_00003_nrs2_uncal.fits',
              'jw01386013001_03104_00004_nrs2_uncal.fits']

for i, file in enumerate(uncal_files):
    uncal_files[i] = uncal_file_dir + uncal_files[i]
print(uncal_files)

print('Found ' + str(len(uncal_files)) + ' input files to process')
# Out:
# ['../../../sci_data/jw01386013001_03104_00001_nrs2_uncal.fits', '../../../sci_data/jw01386013001_03104_00002_nrs2_uncal.fits', '../../../sci_data/jw01386013001_03104_00003_nrs2_uncal.fits', '../../../sci_data/jw01386013001_03104_00004_nrs2_uncal.fits']
# Found 4 input files to process

# %%
# Start a timer to keep track of runtime
time0 = time.perf_counter()

# %%
for file in uncal_files:
    
    det1 = Detector1Pipeline() # Instantiate the pipeline

    #output directory
    det1.output_dir = det1_dir # Specify where the output should go

    #defining used pipeline steps
    det1.group_scale.skip = False  #scaling factor from group images
    det1.dq_init.skip = False      #data quality check
    det1.saturation.skip = False   #check for saturated pixels
    det1.ipc.skip = False          #interpixel capacitance scaling from a reference. Usually skipped in all instrument modes
    det1.superbias.skip = False    #subtract a bias frame from the data
    det1.refpix.skip = False       #correct for drifts in read outs using reference pixels or columns
    det1.linearity.skip = False    #used to correct for non-linearity in the frames
    det1.persistence.skip = True   #according to the docs it is supposed to be hardwired to skipped
    det1.dark_current.skip = False #
    det1.jump.skip = False         #
    det1.jump.maximum_cores = 'half' #distribute the computing load across half of your computer cores to speed it up
    det1.ramp_fit.skip = False     #
    det1.ramp_fit.maximum_cores = 'half' #distribute the computing load across half of your computer cores to speed it up
    det1.gain_scale.skip = False   #


    #skipped steps that are for MIRI
    det1.firstframe.skip = True    #
    det1.lastframe.skip = True     #
    det1.reset.skip = True         # The reset correction is a MIRI step that attempts to correct for the reset anomaly effect. Skipped
    det1.rscd.skip = True          # Performs an RSCD correction to MIRI data that is also caused by reset issues. Skipped



    #choose what results to save and from what steps
    #det1.dq_init.save_results = True # save the data quality flag information
    det1.save_results = True # Save the final resulting _rate.fits files

    det1.run(file)
# Out:
# 2022-12-08 17:17:41,860 - stpipe.Detector1Pipeline - INFO - Detector1Pipeline instance created.
# 2022-12-08 17:17:41,861 - stpipe.Detector1Pipeline.group_scale - INFO - GroupScaleStep instance created.
# 2022-12-08 17:17:41,862 - stpipe.Detector1Pipeline.dq_init - INFO - DQInitStep instance created.
# 2022-12-08 17:17:41,863 - stpipe.Detector1Pipeline.saturation - INFO - SaturationStep instance created.
# 2022-12-08 17:17:41,864 - stpipe.Detector1Pipeline.ipc - INFO - IPCStep instance created.
# 2022-12-08 17:17:41,865 - stpipe.Detector1Pipeline.superbias - INFO - SuperBiasStep instance created.
# 2022-12-08 17:17:41,866 - stpipe.Detector1Pipeline.refpix - INFO - RefPixStep instance created.
# 2022-12-08 17:17:41,868 - stpipe.Detector1Pipeline.rscd - INFO - RscdStep instance created.
# 2022-12-08 17:17:41,869 - stpipe.Detector1Pipeline.firstframe - INFO - FirstFrameStep instance created.
# 2022-12-08 17:17:41,870 - stpipe.Detector1Pipeline.lastframe - INFO - LastFrameStep instance created.
# 2022-12-08 17:17:41,871 - stpipe.Detector1Pipeline.linearity - INFO - LinearityStep instance created.
# 2022-12-08 17:17:41,872 - stpipe.Detector1Pipeline.dark_current - INFO - DarkCurrentStep instance created.
# 2022-12-08 17:17:41,873 - stpipe.Detector1Pipeline.reset - INFO - ResetStep instance created.
# 2022-12-08 17:17:41,874 - stpipe.Detector1Pipeline.persistence - INFO - PersistenceStep instance created.
# 2022-12-08 17:17:41,875 - stpipe.Detector1Pipeline.jump - INFO - JumpStep instance created.
# 2022-12-08 17:17:41,876 - stpipe.Detector1Pipeline.ramp_fit - INFO - RampFitStep instance created.
# 2022-12-08 17:17:41,877 - stpipe.Detector1Pipeline.gain_scale - INFO - GainScaleStep instance created.
# 2022-12-08 17:17:41,924 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline running with args ('../../../sci_data/jw01386013001_03104_00001_nrs2_uncal.fits',).
# 2022-12-08 17:17:41,932 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': 'stage1/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_calibrated_ramp': False, 'steps': {'group_scale': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'dq_init': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'saturation': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'n_pix_grow_sat': 1}, 'ipc': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'superbias': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'refpix': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'odd_even_columns': True, 'use_side_ref_pixels': True, 'side_smoothing_length': 11, 'side_gain': 1.0, 'odd_even_rows': True}, 'rscd': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'type': 'baseline'}, 'firstframe': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'lastframe': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'linearity': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'dark_current': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'dark_output': None}, 'reset': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'persistence': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': ...
# 2022-12-08 17:17:43,035 - stpipe.Detector1Pipeline - INFO - Prefetching reference files for dataset: 'jw01386013001_03104_00001_nrs2_uncal.fits' reftypes = ['dark', 'gain', 'ipc', 'linearity', 'mask', 'readnoise', 'refpix', 'saturation', 'superbias']
# 2022-12-08 17:17:43,249 - stpipe.Detector1Pipeline - INFO - Prefetch for DARK reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_dark_0206.fits'.
# 2022-12-08 17:17:43,249 - stpipe.Detector1Pipeline - INFO - Prefetch for GAIN reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_gain_0020.fits'.
# 2022-12-08 17:17:43,250 - stpipe.Detector1Pipeline - INFO - Prefetch for IPC reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_ipc_0012.fits'.
# 2022-12-08 17:17:43,250 - stpipe.Detector1Pipeline - INFO - Prefetch for LINEARITY reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_linearity_0025.fits'.
# 2022-12-08 17:17:43,250 - stpipe.Detector1Pipeline - INFO - Prefetch for MASK reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_mask_0033.fits'.
# 2022-12-08 17:17:43,251 - stpipe.Detector1Pipeline - INFO - Prefetch for READNOISE reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_readnoise_0017.fits'.
# 2022-12-08 17:17:43,251 - stpipe.Detector1Pipeline - INFO - Prefetch for REFPIX reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_refpix_0018.fits'.
# 2022-12-08 17:17:43,251 - stpipe.Detector1Pipeline - INFO - Prefetch for SATURATION reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_saturation_0026.fits'.
# 2022-12-08 17:17:43,252 - stpipe.Detector1Pipeline - INFO - Prefetch for SUPERBIAS reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_superbias_0256.fits'.
# 2022-12-08 17:17:43,252 - stpipe.Detector1Pipeline - INFO - Starting calwebb_detector1 ...
# 2022-12-08 17:17:43,975 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale running with args (<RampModel(1, 21, 3200, 2048) from jw01386013001_03104_00001_nrs2_uncal.fits>,).
# 2022-12-08 17:17:43,976 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../sci_data'}
# 2022-12-08 17:17:44,440 - stpipe.Detector1Pipeline.group_scale - INFO - NFRAMES and FRMDIVSR are equal; correction not needed
# 2022-12-08 17:17:44,442 - stpipe.Detector1Pipeline.group_scale - INFO - Step will be skipped
# 2022-12-08 17:17:44,444 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale done
# 2022-12-08 17:17:44,577 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init running with args (<RampModel(1, 21, 3200, 2048) from jw01386013001_03104_00001_nrs2_uncal.fits>,).
# 2022-12-08 17:17:44,578 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../sci_data'}
# 2022-12-08 17:17:44,600 - stpipe.Detector1Pipeline.dq_init - INFO - Using MASK reference file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_mask_0033.fits
# 2022-12-08 17:17:45,217 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init done
# 2022-12-08 17:17:45,332 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation running with args (<RampModel(1, 21, 3200, 2048) from jw01386013001_03104_00001_nrs2_uncal.fits>,).
# 2022-12-08 17:17:45,333 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../sci_data', 'n_pix_grow_sat': 1}
# 2022-12-08 17:17:45,353 - stpipe.Detector1Pipeline.saturation - INFO - Using SATURATION reference file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_saturation_0026.fits
# 2022-12-08 17:17:47,946 - stpipe.Detector1Pipeline.saturation - INFO - Detected 35158 saturated pixels
# 2022-12-08 17:17:48,057 - stpipe.Detector1Pipeline.saturation - INFO - Detected 0 A/D floor pixels
# 2022-12-08 17:17:48,072 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation done
# 2022-12-08 17:17:48,186 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc running with args (<RampModel(1, 21, 3200, 2048) from jw01386013001_03104_00001_nrs2_uncal.fits>,).
# 2022-12-08 17:17:48,188 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../sci_data'}
# 2022-12-08 17:17:48,209 - stpipe.Detector1Pipeline.ipc - INFO - Using IPC reference file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_ipc_0012.fits
# 2022-12-08 17:17:49,315 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc done
# 2022-12-08 17:17:49,428 - stpipe.Detector1Pipeline.superbias - INFO - Step superbias running with args (<RampModel(1, 21, 3200, 2048) from jw01386013001_03104_00001_nrs2_uncal.fits>,).
# 2022-12-08 17:17:49,429 - stpipe.Detector1Pipeline.superbias - INFO - Step superbias parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../sci_data'}
# 2022-12-08 17:17:49,450 - stpipe.Detector1Pipeline.superbias - INFO - Using SUPERBIAS reference file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_superbias_0256.fits
# 2022-12-08 17:17:49,982 - stpipe.Detector1Pipeline.superbias - INFO - Step superbias done
# 2022-12-08 17:17:50,092 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix running with args (<RampModel(1, 21, 3200, 2048) from jw01386013001_03104_00001_nrs2_uncal.fits>,).
# 2022-12-08 17:17:50,093 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../sci_data', 'odd_even_columns': True, 'use_side_ref_pixels': True, 'side_smoothing_length': 11, 'side_gain': 1.0, 'odd_even_rows': True}
# 2022-12-08 17:17:50,114 - stpipe.Detector1Pipeline.refpix - INFO - Using refpix reference file: /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_refpix_0018.fits
# 2022-12-08 17:17:50,434 - stpipe.Detector1Pipeline.refpix - INFO - Working on integration 1
# 2022-12-08 17:18:31,697 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix done
# 2022-12-08 17:18:31,846 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity running with args (<RampModel(1, 21, 3200, 2048) from jw01386013001_03104_00001_nrs2_uncal.fits>,).
# 2022-12-08 17:18:31,848 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../sci_data'}
# 2022-12-08 17:18:31,868 - stpipe.Detector1Pipeline.linearity - INFO - Using Linearity reference file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_linearity_0025.fits
# 2022-12-08 17:18:31,952 - stpipe.Detector1Pipeline.linearity - WARNING - Keyword BAD_LIN_CORR does not correspond to an existing DQ mnemonic, so will be ignored
# 2022-12-08 17:18:32,654 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity done
# 2022-12-08 17:18:32,805 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current running with args (<RampModel(1, 21, 3200, 2048) from jw01386013001_03104_00001_nrs2_uncal.fits>,).
# 2022-12-08 17:18:32,806 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': 'stage1/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../sci_data', 'dark_output': None}
# 2022-12-08 17:18:33,062 - stpipe.Detector1Pipeline.dark_current - INFO - Using DARK reference file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_dark_0206.fits
# 2022-12-08 17:18:38,205 - stpipe.Detector1Pipeline.dark_current - INFO - Science data nints=1, ngroups=21, nframes=1, groupgap=0
# 2022-12-08 17:18:38,207 - stpipe.Detector1Pipeline.dark_current - INFO - Dark data nints=1, ngroups=245, nframes=1, groupgap=0
# 2022-12-08 17:18:43,593 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current done
# 2022-12-08 17:18:44,039 - stpipe.Detector1Pipeline.jump - INFO - Step jump running with args (<RampModel(1, 21, 3200, 2048) from jw01386013001_03104_00001_nrs2_uncal.fits>,).
# 2022-12-08 17:18:44,041 - stpipe.Detector1Pipeline.jump - INFO - Step jump parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../sci_data', 'rejection_threshold': 4.0, 'three_group_rejection_threshold': 6.0, 'four_group_rejection_threshold': 5.0, 'maximum_cores': 'half', 'flag_4_neighbors': True, 'max_jump_to_flag_neighbors': 1000.0, 'min_jump_to_flag_neighbors': 10.0, 'after_jump_flag_dn1': 0.0, 'after_jump_flag_time1': 0.0, 'after_jump_flag_dn2': 0.0, 'after_jump_flag_time2': 0.0}
# 2022-12-08 17:18:44,163 - stpipe.Detector1Pipeline.jump - INFO - CR rejection threshold = 4 sigma
# 2022-12-08 17:18:44,163 - stpipe.Detector1Pipeline.jump - INFO - Maximum cores to use = half
# 2022-12-08 17:18:44,308 - stpipe.Detector1Pipeline.jump - INFO - Using GAIN reference file: /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_gain_0020.fits
# 2022-12-08 17:18:44,482 - stpipe.Detector1Pipeline.jump - INFO - Using READNOISE reference file: /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_readnoise_0017.fits
# 2022-12-08 17:18:45,283 - stpipe.Detector1Pipeline.jump - INFO - Executing two-point difference method
# 2022-12-08 17:18:45,417 - stpipe.Detector1Pipeline.jump - INFO - Creating 5 processes for jump detection
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/jump/twopoint_difference.py:154: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/jump/twopoint_difference.py:154: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/jump/twopoint_difference.py:154: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/jump/twopoint_difference.py:154: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/jump/twopoint_difference.py:154: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
# 2022-12-08 17:18:53,612 - stpipe.Detector1Pipeline.jump - INFO - Total elapsed time = 8.32874 sec
# 2022-12-08 17:18:53,631 - stpipe.Detector1Pipeline.jump - INFO - The execution time in seconds: 9.468073
# 2022-12-08 17:18:53,637 - stpipe.Detector1Pipeline.jump - INFO - Step jump done
# 2022-12-08 17:18:53,795 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit running with args (<RampModel(1, 21, 3200, 2048) from jw01386013001_03104_00001_nrs2_uncal.fits>,).
# 2022-12-08 17:18:53,796 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': 'stage1/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../sci_data', 'int_name': '', 'save_opt': False, 'opt_name': '', 'suppress_one_group': True, 'maximum_cores': 'half'}
# 2022-12-08 17:18:54,110 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using READNOISE reference file: /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_readnoise_0017.fits
# 2022-12-08 17:18:54,111 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using GAIN reference file: /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_gain_0020.fits
# 2022-12-08 17:18:54,185 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using algorithm = ols
# 2022-12-08 17:18:54,186 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using weighting = optimal
# 2022-12-08 17:18:54,549 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of processors used for multiprocessing: 5
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/ramp_fitting/ols_fit.py:1089: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/ramp_fitting/ols_fit.py:1089: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/ramp_fitting/ols_fit.py:1089: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/ramp_fitting/ols_fit.py:1089: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/ramp_fitting/ols_fit.py:1089: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# 2022-12-08 17:19:25,726 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit done
# 2022-12-08 17:19:25,874 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<IFUImageModel(2048, 2048) from jw01386013001_03104_00001_nrs2_uncal.fits>,).
# 2022-12-08 17:19:25,875 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'gain_scale', 'search_output_file': True, 'input_dir': '../../../sci_data'}
# 2022-12-08 17:19:25,939 - stpipe.Detector1Pipeline.gain_scale - INFO - Rescaling by 1.0
# 2022-12-08 17:19:25,953 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# 2022-12-08 17:19:26,007 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<CubeModel(1, 2048, 2048) from jw01386013001_03104_00001_nrs2_uncal.fits>,).
# 2022-12-08 17:19:26,008 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'gain_scaleints', 'search_output_file': True, 'input_dir': '../../../sci_data'}
# 2022-12-08 17:19:26,041 - stpipe.Detector1Pipeline.gain_scale - INFO - Rescaling by 1.0
# 2022-12-08 17:19:26,049 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# 2022-12-08 17:19:26,283 - stpipe.Detector1Pipeline - INFO - Saved model in stage1/jw01386013001_03104_00001_nrs2_rateints.fits
# 2022-12-08 17:19:26,284 - stpipe.Detector1Pipeline - INFO - ... ending calwebb_detector1
# 2022-12-08 17:19:26,284 - stpipe.Detector1Pipeline - INFO - Results used CRDS context: jwst_0977.pmap
# 2022-12-08 17:19:26,473 - stpipe.Detector1Pipeline - INFO - Saved model in stage1/jw01386013001_03104_00001_nrs2_rate.fits
# 2022-12-08 17:19:26,473 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline done
# 2022-12-08 17:19:26,481 - stpipe.Detector1Pipeline - INFO - Detector1Pipeline instance created.
# 2022-12-08 17:19:26,482 - stpipe.Detector1Pipeline.group_scale - INFO - GroupScaleStep instance created.
# 2022-12-08 17:19:26,483 - stpipe.Detector1Pipeline.dq_init - INFO - DQInitStep instance created.
# 2022-12-08 17:19:26,483 - stpipe.Detector1Pipeline.saturation - INFO - SaturationStep instance created.
# 2022-12-08 17:19:26,485 - stpipe.Detector1Pipeline.ipc - INFO - IPCStep instance created.
# 2022-12-08 17:19:26,485 - stpipe.Detector1Pipeline.superbias - INFO - SuperBiasStep instance created.
# 2022-12-08 17:19:26,486 - stpipe.Detector1Pipeline.refpix - INFO - RefPixStep instance created.
# 2022-12-08 17:19:26,487 - stpipe.Detector1Pipeline.rscd - INFO - RscdStep instance created.
# 2022-12-08 17:19:26,488 - stpipe.Detector1Pipeline.firstframe - INFO - FirstFrameStep instance created.
# 2022-12-08 17:19:26,489 - stpipe.Detector1Pipeline.lastframe - INFO - LastFrameStep instance created.
# 2022-12-08 17:19:26,490 - stpipe.Detector1Pipeline.linearity - INFO - LinearityStep instance created.
# 2022-12-08 17:19:26,491 - stpipe.Detector1Pipeline.dark_current - INFO - DarkCurrentStep instance created.
# 2022-12-08 17:19:26,491 - stpipe.Detector1Pipeline.reset - INFO - ResetStep instance created.
# 2022-12-08 17:19:26,493 - stpipe.Detector1Pipeline.persistence - INFO - PersistenceStep instance created.
# 2022-12-08 17:19:26,494 - stpipe.Detector1Pipeline.jump - INFO - JumpStep instance created.
# 2022-12-08 17:19:26,495 - stpipe.Detector1Pipeline.ramp_fit - INFO - RampFitStep instance created.
# 2022-12-08 17:19:26,496 - stpipe.Detector1Pipeline.gain_scale - INFO - GainScaleStep instance created.
# 2022-12-08 17:19:26,565 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline running with args ('../../../sci_data/jw01386013001_03104_00002_nrs2_uncal.fits',).
# 2022-12-08 17:19:26,573 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': 'stage1/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_calibrated_ramp': False, 'steps': {'group_scale': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'dq_init': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'saturation': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'n_pix_grow_sat': 1}, 'ipc': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'superbias': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'refpix': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'odd_even_columns': True, 'use_side_ref_pixels': True, 'side_smoothing_length': 11, 'side_gain': 1.0, 'odd_even_rows': True}, 'rscd': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'type': 'baseline'}, 'firstframe': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'lastframe': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'linearity': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'dark_current': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'dark_output': None}, 'reset': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'persistence': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': ...
# 2022-12-08 17:19:26,907 - stpipe.Detector1Pipeline - INFO - Prefetching reference files for dataset: 'jw01386013001_03104_00002_nrs2_uncal.fits' reftypes = ['dark', 'gain', 'ipc', 'linearity', 'mask', 'readnoise', 'refpix', 'saturation', 'superbias']
# 2022-12-08 17:19:26,911 - stpipe.Detector1Pipeline - INFO - Prefetch for DARK reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_dark_0206.fits'.
# 2022-12-08 17:19:26,912 - stpipe.Detector1Pipeline - INFO - Prefetch for GAIN reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_gain_0020.fits'.
# 2022-12-08 17:19:26,912 - stpipe.Detector1Pipeline - INFO - Prefetch for IPC reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_ipc_0012.fits'.
# 2022-12-08 17:19:26,913 - stpipe.Detector1Pipeline - INFO - Prefetch for LINEARITY reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_linearity_0025.fits'.
# 2022-12-08 17:19:26,913 - stpipe.Detector1Pipeline - INFO - Prefetch for MASK reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_mask_0033.fits'.
# 2022-12-08 17:19:26,914 - stpipe.Detector1Pipeline - INFO - Prefetch for READNOISE reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_readnoise_0017.fits'.
# 2022-12-08 17:19:26,914 - stpipe.Detector1Pipeline - INFO - Prefetch for REFPIX reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_refpix_0018.fits'.
# 2022-12-08 17:19:26,914 - stpipe.Detector1Pipeline - INFO - Prefetch for SATURATION reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_saturation_0026.fits'.
# 2022-12-08 17:19:26,915 - stpipe.Detector1Pipeline - INFO - Prefetch for SUPERBIAS reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_superbias_0256.fits'.
# 2022-12-08 17:19:26,915 - stpipe.Detector1Pipeline - INFO - Starting calwebb_detector1 ...
# 2022-12-08 17:19:27,608 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale running with args (<RampModel(1, 21, 3200, 2048) from jw01386013001_03104_00002_nrs2_uncal.fits>,).
# 2022-12-08 17:19:27,609 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../sci_data'}
# 2022-12-08 17:19:27,946 - stpipe.Detector1Pipeline.group_scale - INFO - NFRAMES and FRMDIVSR are equal; correction not needed
# 2022-12-08 17:19:27,946 - stpipe.Detector1Pipeline.group_scale - INFO - Step will be skipped
# 2022-12-08 17:19:27,948 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale done
# 2022-12-08 17:19:28,049 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init running with args (<RampModel(1, 21, 3200, 2048) from jw01386013001_03104_00002_nrs2_uncal.fits>,).
# 2022-12-08 17:19:28,050 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../sci_data'}
# 2022-12-08 17:19:28,070 - stpipe.Detector1Pipeline.dq_init - INFO - Using MASK reference file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_mask_0033.fits
# 2022-12-08 17:19:28,570 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init done
# 2022-12-08 17:19:28,663 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation running with args (<RampModel(1, 21, 3200, 2048) from jw01386013001_03104_00002_nrs2_uncal.fits>,).
# 2022-12-08 17:19:28,664 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../sci_data', 'n_pix_grow_sat': 1}
# 2022-12-08 17:19:28,685 - stpipe.Detector1Pipeline.saturation - INFO - Using SATURATION reference file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_saturation_0026.fits
# 2022-12-08 17:19:31,008 - stpipe.Detector1Pipeline.saturation - INFO - Detected 35189 saturated pixels
# 2022-12-08 17:19:31,103 - stpipe.Detector1Pipeline.saturation - INFO - Detected 0 A/D floor pixels
# 2022-12-08 17:19:31,114 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation done
# 2022-12-08 17:19:31,220 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc running with args (<RampModel(1, 21, 3200, 2048) from jw01386013001_03104_00002_nrs2_uncal.fits>,).
# 2022-12-08 17:19:31,221 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../sci_data'}
# 2022-12-08 17:19:31,241 - stpipe.Detector1Pipeline.ipc - INFO - Using IPC reference file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_ipc_0012.fits
# 2022-12-08 17:19:32,229 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc done
# 2022-12-08 17:19:32,327 - stpipe.Detector1Pipeline.superbias - INFO - Step superbias running with args (<RampModel(1, 21, 3200, 2048) from jw01386013001_03104_00002_nrs2_uncal.fits>,).
# 2022-12-08 17:19:32,328 - stpipe.Detector1Pipeline.superbias - INFO - Step superbias parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../sci_data'}
# 2022-12-08 17:19:32,348 - stpipe.Detector1Pipeline.superbias - INFO - Using SUPERBIAS reference file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_superbias_0256.fits
# 2022-12-08 17:19:32,787 - stpipe.Detector1Pipeline.superbias - INFO - Step superbias done
# 2022-12-08 17:19:32,883 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix running with args (<RampModel(1, 21, 3200, 2048) from jw01386013001_03104_00002_nrs2_uncal.fits>,).
# 2022-12-08 17:19:32,884 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../sci_data', 'odd_even_columns': True, 'use_side_ref_pixels': True, 'side_smoothing_length': 11, 'side_gain': 1.0, 'odd_even_rows': True}
# 2022-12-08 17:19:32,905 - stpipe.Detector1Pipeline.refpix - INFO - Using refpix reference file: /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_refpix_0018.fits
# 2022-12-08 17:19:33,192 - stpipe.Detector1Pipeline.refpix - INFO - Working on integration 1
# 2022-12-08 17:20:14,660 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix done
# 2022-12-08 17:20:14,784 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity running with args (<RampModel(1, 21, 3200, 2048) from jw01386013001_03104_00002_nrs2_uncal.fits>,).
# 2022-12-08 17:20:14,785 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../sci_data'}
# 2022-12-08 17:20:14,806 - stpipe.Detector1Pipeline.linearity - INFO - Using Linearity reference file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_linearity_0025.fits
# 2022-12-08 17:20:14,893 - stpipe.Detector1Pipeline.linearity - WARNING - Keyword BAD_LIN_CORR does not correspond to an existing DQ mnemonic, so will be ignored
# 2022-12-08 17:20:15,564 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity done
# 2022-12-08 17:20:15,685 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current running with args (<RampModel(1, 21, 3200, 2048) from jw01386013001_03104_00002_nrs2_uncal.fits>,).
# 2022-12-08 17:20:15,686 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': 'stage1/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../sci_data', 'dark_output': None}
# 2022-12-08 17:20:15,920 - stpipe.Detector1Pipeline.dark_current - INFO - Using DARK reference file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_dark_0206.fits
# 2022-12-08 17:20:20,192 - stpipe.Detector1Pipeline.dark_current - INFO - Science data nints=1, ngroups=21, nframes=1, groupgap=0
# 2022-12-08 17:20:20,192 - stpipe.Detector1Pipeline.dark_current - INFO - Dark data nints=1, ngroups=245, nframes=1, groupgap=0
# 2022-12-08 17:20:25,701 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current done
# 2022-12-08 17:20:26,222 - stpipe.Detector1Pipeline.jump - INFO - Step jump running with args (<RampModel(1, 21, 3200, 2048) from jw01386013001_03104_00002_nrs2_uncal.fits>,).
# 2022-12-08 17:20:26,224 - stpipe.Detector1Pipeline.jump - INFO - Step jump parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../sci_data', 'rejection_threshold': 4.0, 'three_group_rejection_threshold': 6.0, 'four_group_rejection_threshold': 5.0, 'maximum_cores': 'half', 'flag_4_neighbors': True, 'max_jump_to_flag_neighbors': 1000.0, 'min_jump_to_flag_neighbors': 10.0, 'after_jump_flag_dn1': 0.0, 'after_jump_flag_time1': 0.0, 'after_jump_flag_dn2': 0.0, 'after_jump_flag_time2': 0.0}
# 2022-12-08 17:20:26,363 - stpipe.Detector1Pipeline.jump - INFO - CR rejection threshold = 4 sigma
# 2022-12-08 17:20:26,364 - stpipe.Detector1Pipeline.jump - INFO - Maximum cores to use = half
# 2022-12-08 17:20:26,504 - stpipe.Detector1Pipeline.jump - INFO - Using GAIN reference file: /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_gain_0020.fits
# 2022-12-08 17:20:26,670 - stpipe.Detector1Pipeline.jump - INFO - Using READNOISE reference file: /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_readnoise_0017.fits
# 2022-12-08 17:20:27,450 - stpipe.Detector1Pipeline.jump - INFO - Executing two-point difference method
# 2022-12-08 17:20:27,581 - stpipe.Detector1Pipeline.jump - INFO - Creating 5 processes for jump detection
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/jump/twopoint_difference.py:154: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/jump/twopoint_difference.py:154: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/jump/twopoint_difference.py:154: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/jump/twopoint_difference.py:154: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/jump/twopoint_difference.py:154: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
# 2022-12-08 17:20:36,001 - stpipe.Detector1Pipeline.jump - INFO - Total elapsed time = 8.55035 sec
# 2022-12-08 17:20:36,023 - stpipe.Detector1Pipeline.jump - INFO - The execution time in seconds: 9.660092
# 2022-12-08 17:20:36,028 - stpipe.Detector1Pipeline.jump - INFO - Step jump done
# 2022-12-08 17:20:36,179 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit running with args (<RampModel(1, 21, 3200, 2048) from jw01386013001_03104_00002_nrs2_uncal.fits>,).
# 2022-12-08 17:20:36,180 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': 'stage1/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../sci_data', 'int_name': '', 'save_opt': False, 'opt_name': '', 'suppress_one_group': True, 'maximum_cores': 'half'}
# 2022-12-08 17:20:36,504 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using READNOISE reference file: /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_readnoise_0017.fits
# 2022-12-08 17:20:36,505 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using GAIN reference file: /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_gain_0020.fits
# 2022-12-08 17:20:36,581 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using algorithm = ols
# 2022-12-08 17:20:36,581 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using weighting = optimal
# 2022-12-08 17:20:36,940 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of processors used for multiprocessing: 5
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/ramp_fitting/ols_fit.py:1089: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/ramp_fitting/ols_fit.py:1089: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/ramp_fitting/ols_fit.py:1089: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/ramp_fitting/ols_fit.py:1089: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/ramp_fitting/ols_fit.py:1089: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# 2022-12-08 17:21:09,856 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit done
# 2022-12-08 17:21:09,998 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<IFUImageModel(2048, 2048) from jw01386013001_03104_00002_nrs2_uncal.fits>,).
# 2022-12-08 17:21:10,000 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'gain_scale', 'search_output_file': True, 'input_dir': '../../../sci_data'}
# 2022-12-08 17:21:10,064 - stpipe.Detector1Pipeline.gain_scale - INFO - Rescaling by 1.0
# 2022-12-08 17:21:10,078 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# 2022-12-08 17:21:10,134 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<CubeModel(1, 2048, 2048) from jw01386013001_03104_00002_nrs2_uncal.fits>,).
# 2022-12-08 17:21:10,135 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'gain_scaleints', 'search_output_file': True, 'input_dir': '../../../sci_data'}
# 2022-12-08 17:21:10,169 - stpipe.Detector1Pipeline.gain_scale - INFO - Rescaling by 1.0
# 2022-12-08 17:21:10,177 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# 2022-12-08 17:21:10,386 - stpipe.Detector1Pipeline - INFO - Saved model in stage1/jw01386013001_03104_00002_nrs2_rateints.fits
# 2022-12-08 17:21:10,386 - stpipe.Detector1Pipeline - INFO - ... ending calwebb_detector1
# 2022-12-08 17:21:10,387 - stpipe.Detector1Pipeline - INFO - Results used CRDS context: jwst_0977.pmap
# 2022-12-08 17:21:10,581 - stpipe.Detector1Pipeline - INFO - Saved model in stage1/jw01386013001_03104_00002_nrs2_rate.fits
# 2022-12-08 17:21:10,581 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline done
# 2022-12-08 17:21:10,588 - stpipe.Detector1Pipeline - INFO - Detector1Pipeline instance created.
# 2022-12-08 17:21:10,589 - stpipe.Detector1Pipeline.group_scale - INFO - GroupScaleStep instance created.
# 2022-12-08 17:21:10,590 - stpipe.Detector1Pipeline.dq_init - INFO - DQInitStep instance created.
# 2022-12-08 17:21:10,591 - stpipe.Detector1Pipeline.saturation - INFO - SaturationStep instance created.
# 2022-12-08 17:21:10,591 - stpipe.Detector1Pipeline.ipc - INFO - IPCStep instance created.
# 2022-12-08 17:21:10,592 - stpipe.Detector1Pipeline.superbias - INFO - SuperBiasStep instance created.
# 2022-12-08 17:21:10,593 - stpipe.Detector1Pipeline.refpix - INFO - RefPixStep instance created.
# 2022-12-08 17:21:10,594 - stpipe.Detector1Pipeline.rscd - INFO - RscdStep instance created.
# 2022-12-08 17:21:10,595 - stpipe.Detector1Pipeline.firstframe - INFO - FirstFrameStep instance created.
# 2022-12-08 17:21:10,596 - stpipe.Detector1Pipeline.lastframe - INFO - LastFrameStep instance created.
# 2022-12-08 17:21:10,597 - stpipe.Detector1Pipeline.linearity - INFO - LinearityStep instance created.
# 2022-12-08 17:21:10,597 - stpipe.Detector1Pipeline.dark_current - INFO - DarkCurrentStep instance created.
# 2022-12-08 17:21:10,598 - stpipe.Detector1Pipeline.reset - INFO - ResetStep instance created.
# 2022-12-08 17:21:10,599 - stpipe.Detector1Pipeline.persistence - INFO - PersistenceStep instance created.
# 2022-12-08 17:21:10,600 - stpipe.Detector1Pipeline.jump - INFO - JumpStep instance created.
# 2022-12-08 17:21:10,601 - stpipe.Detector1Pipeline.ramp_fit - INFO - RampFitStep instance created.
# 2022-12-08 17:21:10,602 - stpipe.Detector1Pipeline.gain_scale - INFO - GainScaleStep instance created.
# 2022-12-08 17:21:10,675 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline running with args ('../../../sci_data/jw01386013001_03104_00003_nrs2_uncal.fits',).
# ...
# 2022-12-08 17:22:54,293 - stpipe.Detector1Pipeline - INFO - Prefetch for READNOISE reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_readnoise_0017.fits'.
# 2022-12-08 17:22:54,293 - stpipe.Detector1Pipeline - INFO - Prefetch for REFPIX reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_refpix_0018.fits'.
# 2022-12-08 17:22:54,293 - stpipe.Detector1Pipeline - INFO - Prefetch for SATURATION reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_saturation_0026.fits'.
# 2022-12-08 17:22:54,294 - stpipe.Detector1Pipeline - INFO - Prefetch for SUPERBIAS reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_superbias_0256.fits'.
# 2022-12-08 17:22:54,294 - stpipe.Detector1Pipeline - INFO - Starting calwebb_detector1 ...
# 2022-12-08 17:22:54,994 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale running with args (<RampModel(1, 21, 3200, 2048) from jw01386013001_03104_00004_nrs2_uncal.fits>,).
# 2022-12-08 17:22:54,995 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../sci_data'}
# 2022-12-08 17:22:55,352 - stpipe.Detector1Pipeline.group_scale - INFO - NFRAMES and FRMDIVSR are equal; correction not needed
# 2022-12-08 17:22:55,352 - stpipe.Detector1Pipeline.group_scale - INFO - Step will be skipped
# 2022-12-08 17:22:55,355 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale done
# 2022-12-08 17:22:55,460 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init running with args (<RampModel(1, 21, 3200, 2048) from jw01386013001_03104_00004_nrs2_uncal.fits>,).
# 2022-12-08 17:22:55,461 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../sci_data'}
# 2022-12-08 17:22:55,480 - stpipe.Detector1Pipeline.dq_init - INFO - Using MASK reference file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_mask_0033.fits
# 2022-12-08 17:22:56,001 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init done
# 2022-12-08 17:22:56,099 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation running with args (<RampModel(1, 21, 3200, 2048) from jw01386013001_03104_00004_nrs2_uncal.fits>,).
# 2022-12-08 17:22:56,100 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../sci_data', 'n_pix_grow_sat': 1}
# 2022-12-08 17:22:56,119 - stpipe.Detector1Pipeline.saturation - INFO - Using SATURATION reference file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_saturation_0026.fits
# 2022-12-08 17:22:58,471 - stpipe.Detector1Pipeline.saturation - INFO - Detected 34595 saturated pixels
# 2022-12-08 17:22:58,571 - stpipe.Detector1Pipeline.saturation - INFO - Detected 0 A/D floor pixels
# 2022-12-08 17:22:58,582 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation done
# 2022-12-08 17:22:58,684 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc running with args (<RampModel(1, 21, 3200, 2048) from jw01386013001_03104_00004_nrs2_uncal.fits>,).
# 2022-12-08 17:22:58,685 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../sci_data'}
# 2022-12-08 17:22:58,706 - stpipe.Detector1Pipeline.ipc - INFO - Using IPC reference file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_ipc_0012.fits
# 2022-12-08 17:22:59,711 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc done
# 2022-12-08 17:22:59,813 - stpipe.Detector1Pipeline.superbias - INFO - Step superbias running with args (<RampModel(1, 21, 3200, 2048) from jw01386013001_03104_00004_nrs2_uncal.fits>,).
# 2022-12-08 17:22:59,814 - stpipe.Detector1Pipeline.superbias - INFO - Step superbias parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../sci_data'}
# 2022-12-08 17:22:59,835 - stpipe.Detector1Pipeline.superbias - INFO - Using SUPERBIAS reference file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_superbias_0256.fits
# 2022-12-08 17:23:00,302 - stpipe.Detector1Pipeline.superbias - INFO - Step superbias done
# 2022-12-08 17:23:00,401 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix running with args (<RampModel(1, 21, 3200, 2048) from jw01386013001_03104_00004_nrs2_uncal.fits>,).
# 2022-12-08 17:23:00,402 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../sci_data', 'odd_even_columns': True, 'use_side_ref_pixels': True, 'side_smoothing_length': 11, 'side_gain': 1.0, 'odd_even_rows': True}
# 2022-12-08 17:23:00,423 - stpipe.Detector1Pipeline.refpix - INFO - Using refpix reference file: /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_refpix_0018.fits
# 2022-12-08 17:23:00,715 - stpipe.Detector1Pipeline.refpix - INFO - Working on integration 1
# 2022-12-08 17:23:42,319 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix done
# 2022-12-08 17:23:42,455 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity running with args (<RampModel(1, 21, 3200, 2048) from jw01386013001_03104_00004_nrs2_uncal.fits>,).
# 2022-12-08 17:23:42,456 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../sci_data'}
# 2022-12-08 17:23:42,475 - stpipe.Detector1Pipeline.linearity - INFO - Using Linearity reference file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_linearity_0025.fits
# 2022-12-08 17:23:42,561 - stpipe.Detector1Pipeline.linearity - WARNING - Keyword BAD_LIN_CORR does not correspond to an existing DQ mnemonic, so will be ignored
# 2022-12-08 17:23:43,239 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity done
# 2022-12-08 17:23:43,364 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current running with args (<RampModel(1, 21, 3200, 2048) from jw01386013001_03104_00004_nrs2_uncal.fits>,).
# 2022-12-08 17:23:43,365 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': 'stage1/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../sci_data', 'dark_output': None}
# 2022-12-08 17:23:43,599 - stpipe.Detector1Pipeline.dark_current - INFO - Using DARK reference file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_dark_0206.fits
# 2022-12-08 17:23:47,448 - stpipe.Detector1Pipeline.dark_current - INFO - Science data nints=1, ngroups=21, nframes=1, groupgap=0
# 2022-12-08 17:23:47,449 - stpipe.Detector1Pipeline.dark_current - INFO - Dark data nints=1, ngroups=245, nframes=1, groupgap=0
# 2022-12-08 17:23:53,295 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current done
# 2022-12-08 17:23:53,788 - stpipe.Detector1Pipeline.jump - INFO - Step jump running with args (<RampModel(1, 21, 3200, 2048) from jw01386013001_03104_00004_nrs2_uncal.fits>,).
# 2022-12-08 17:23:53,789 - stpipe.Detector1Pipeline.jump - INFO - Step jump parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../sci_data', 'rejection_threshold': 4.0, 'three_group_rejection_threshold': 6.0, 'four_group_rejection_threshold': 5.0, 'maximum_cores': 'half', 'flag_4_neighbors': True, 'max_jump_to_flag_neighbors': 1000.0, 'min_jump_to_flag_neighbors': 10.0, 'after_jump_flag_dn1': 0.0, 'after_jump_flag_time1': 0.0, 'after_jump_flag_dn2': 0.0, 'after_jump_flag_time2': 0.0}
# 2022-12-08 17:23:53,929 - stpipe.Detector1Pipeline.jump - INFO - CR rejection threshold = 4 sigma
# 2022-12-08 17:23:53,930 - stpipe.Detector1Pipeline.jump - INFO - Maximum cores to use = half
# 2022-12-08 17:23:54,066 - stpipe.Detector1Pipeline.jump - INFO - Using GAIN reference file: /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_gain_0020.fits
# 2022-12-08 17:23:54,230 - stpipe.Detector1Pipeline.jump - INFO - Using READNOISE reference file: /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_readnoise_0017.fits
# 2022-12-08 17:23:55,010 - stpipe.Detector1Pipeline.jump - INFO - Executing two-point difference method
# 2022-12-08 17:23:55,143 - stpipe.Detector1Pipeline.jump - INFO - Creating 5 processes for jump detection
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/jump/twopoint_difference.py:154: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/jump/twopoint_difference.py:154: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/jump/twopoint_difference.py:154: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/jump/twopoint_difference.py:154: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/jump/twopoint_difference.py:154: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
# 2022-12-08 17:24:03,851 - stpipe.Detector1Pipeline.jump - INFO - Total elapsed time = 8.84079 sec
# 2022-12-08 17:24:03,873 - stpipe.Detector1Pipeline.jump - INFO - The execution time in seconds: 9.944129
# 2022-12-08 17:24:03,878 - stpipe.Detector1Pipeline.jump - INFO - Step jump done
# 2022-12-08 17:24:04,037 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit running with args (<RampModel(1, 21, 3200, 2048) from jw01386013001_03104_00004_nrs2_uncal.fits>,).
# 2022-12-08 17:24:04,039 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': 'stage1/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../sci_data', 'int_name': '', 'save_opt': False, 'opt_name': '', 'suppress_one_group': True, 'maximum_cores': 'half'}
# 2022-12-08 17:24:04,365 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using READNOISE reference file: /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_readnoise_0017.fits
# 2022-12-08 17:24:04,365 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using GAIN reference file: /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_gain_0020.fits
# 2022-12-08 17:24:04,439 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using algorithm = ols
# 2022-12-08 17:24:04,439 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using weighting = optimal
# 2022-12-08 17:24:04,795 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of processors used for multiprocessing: 5
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/ramp_fitting/ols_fit.py:1089: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/ramp_fitting/ols_fit.py:1089: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/ramp_fitting/ols_fit.py:1089: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/ramp_fitting/ols_fit.py:1089: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/ramp_fitting/ols_fit.py:1089: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# 2022-12-08 17:24:32,685 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit done
# 2022-12-08 17:24:32,841 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<IFUImageModel(2048, 2048) from jw01386013001_03104_00004_nrs2_uncal.fits>,).
# 2022-12-08 17:24:32,842 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'gain_scale', 'search_output_file': True, 'input_dir': '../../../sci_data'}
# 2022-12-08 17:24:32,907 - stpipe.Detector1Pipeline.gain_scale - INFO - Rescaling by 1.0
# 2022-12-08 17:24:32,921 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# 2022-12-08 17:24:32,980 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<CubeModel(1, 2048, 2048) from jw01386013001_03104_00004_nrs2_uncal.fits>,).
# 2022-12-08 17:24:32,981 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'gain_scaleints', 'search_output_file': True, 'input_dir': '../../../sci_data'}
# 2022-12-08 17:24:33,015 - stpipe.Detector1Pipeline.gain_scale - INFO - Rescaling by 1.0
# 2022-12-08 17:24:33,024 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# 2022-12-08 17:24:33,228 - stpipe.Detector1Pipeline - INFO - Saved model in stage1/jw01386013001_03104_00004_nrs2_rateints.fits
# 2022-12-08 17:24:33,229 - stpipe.Detector1Pipeline - INFO - ... ending calwebb_detector1
# 2022-12-08 17:24:33,229 - stpipe.Detector1Pipeline - INFO - Results used CRDS context: jwst_0977.pmap
# 2022-12-08 17:24:33,419 - stpipe.Detector1Pipeline - INFO - Saved model in stage1/jw01386013001_03104_00004_nrs2_rate.fits
# 2022-12-08 17:24:33,420 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline done

# %%
# Print out the time benchmark
time1 = time.perf_counter()
print(f"Runtime so far: {time1 - time0:0.4f} seconds")
# Out:
# Runtime so far: 411.5763 seconds

# %%
# Look for input uncalibrated slope files from the Detector1 pipeline
sstring = 'stage1/'+ '*_rate.fits'
rate_files = sorted(glob.glob(sstring))
print('Found ' + str(len(rate_files)) + ' input files to process')
# Out:
# Found 4 input files to process

# %%
# Start a timer to keep track of runtime
time0 = time.perf_counter()

# %%
# Setting up steps and running the Spec2 portion of the pipeline. 

spec2 = Spec2Pipeline()
spec2.output_dir = spec2_dir
spec2.assign_wcs.skip = False
spec2.bkg_subtract.skip = False
spec2.imprint_subtract.skip = False
spec2.msa_flagging.skip = False
spec2.srctype.source_type = 'POINT'
spec2.flat_field.skip = False
spec2.pathloss.skip = False
spec2.photom.skip = False
spec2.cube_build.skip = False
spec2.extract_1d.skip = True

##extra steps that only apply to other instruments modes.
spec2.extract_2d.skip = True
spec2.master_background_mos.skip = True
spec2.barshadow.skip = True
spec2.wavecorr.skip = True
spec2.straylight.skip = True
spec2.fringe.skip = True
#spec2.residual_fringe.skip = True   # is not used in 1.7.2 works in 1.8.4
spec2.wfss_contam.skip = True
spec2.resample_spec.skip = True

#choose what results to save and from what steps
spec2.save_results = True
spec2.run(rate_files)
# Out:
# 2022-12-08 17:24:33,455 - stpipe.Spec2Pipeline - INFO - Spec2Pipeline instance created.
# 2022-12-08 17:24:33,456 - stpipe.Spec2Pipeline.bkg_subtract - INFO - BackgroundStep instance created.
# 2022-12-08 17:24:33,458 - stpipe.Spec2Pipeline.assign_wcs - INFO - AssignWcsStep instance created.
# 2022-12-08 17:24:33,459 - stpipe.Spec2Pipeline.imprint_subtract - INFO - ImprintStep instance created.
# 2022-12-08 17:24:33,460 - stpipe.Spec2Pipeline.msa_flagging - INFO - MSAFlagOpenStep instance created.
# 2022-12-08 17:24:33,461 - stpipe.Spec2Pipeline.extract_2d - INFO - Extract2dStep instance created.
# 2022-12-08 17:24:33,464 - stpipe.Spec2Pipeline.master_background_mos - INFO - MasterBackgroundMosStep instance created.
# 2022-12-08 17:24:33,465 - stpipe.Spec2Pipeline.master_background_mos.flat_field - INFO - FlatFieldStep instance created.
# 2022-12-08 17:24:33,466 - stpipe.Spec2Pipeline.master_background_mos.pathloss - INFO - PathLossStep instance created.
# 2022-12-08 17:24:33,467 - stpipe.Spec2Pipeline.master_background_mos.barshadow - INFO - BarShadowStep instance created.
# 2022-12-08 17:24:33,468 - stpipe.Spec2Pipeline.master_background_mos.photom - INFO - PhotomStep instance created.
# 2022-12-08 17:24:33,469 - stpipe.Spec2Pipeline.wavecorr - INFO - WavecorrStep instance created.
# 2022-12-08 17:24:33,470 - stpipe.Spec2Pipeline.flat_field - INFO - FlatFieldStep instance created.
# 2022-12-08 17:24:33,471 - stpipe.Spec2Pipeline.srctype - INFO - SourceTypeStep instance created.
# 2022-12-08 17:24:33,472 - stpipe.Spec2Pipeline.straylight - INFO - StraylightStep instance created.
# 2022-12-08 17:24:33,473 - stpipe.Spec2Pipeline.fringe - INFO - FringeStep instance created.
# 2022-12-08 17:24:33,474 - stpipe.Spec2Pipeline.pathloss - INFO - PathLossStep instance created.
# 2022-12-08 17:24:33,475 - stpipe.Spec2Pipeline.barshadow - INFO - BarShadowStep instance created.
# 2022-12-08 17:24:33,476 - stpipe.Spec2Pipeline.wfss_contam - INFO - WfssContamStep instance created.
# 2022-12-08 17:24:33,477 - stpipe.Spec2Pipeline.photom - INFO - PhotomStep instance created.
# 2022-12-08 17:24:33,478 - stpipe.Spec2Pipeline.resample_spec - INFO - ResampleSpecStep instance created.
# 2022-12-08 17:24:33,480 - stpipe.Spec2Pipeline.cube_build - INFO - CubeBuildStep instance created.
# 2022-12-08 17:24:33,481 - stpipe.Spec2Pipeline.extract_1d - INFO - Extract1dStep instance created.
# 2022-12-08 17:24:33,559 - stpipe.Spec2Pipeline - INFO - Step Spec2Pipeline running with args (['stage1/jw01386013001_03104_00001_nrs2_rate.fits', 'stage1/jw01386013001_03104_00002_nrs2_rate.fits', 'stage1/jw01386013001_03104_00003_nrs2_rate.fits', 'stage1/jw01386013001_03104_00004_nrs2_rate.fits'],).
# 2022-12-08 17:24:33,571 - stpipe.Spec2Pipeline - INFO - Step Spec2Pipeline parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': 'stage2/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_bsub': False, 'fail_on_exception': True, 'save_wfss_esec': False, 'steps': {'bkg_subtract': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_combined_background': False, 'sigma': 3.0, 'maxiters': None, 'wfss_mmag_extract': None}, 'assign_wcs': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'sip_approx': True, 'sip_max_pix_error': 0.25, 'sip_degree': None, 'sip_max_inv_pix_error': 0.25, 'sip_inv_degree': None, 'sip_npoints': 32, 'slit_y_low': -0.55, 'slit_y_high': 0.55}, 'imprint_subtract': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'msa_flagging': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'extract_2d': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'slit_name': None, 'extract_orders': None, 'grism_objects': None, 'tsgrism_extract_height': None, 'wfss_extract_half_height': 5, 'wfss_mmag_extract': None, 'wfss_nbright': 1000}, 'master_background_mos': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'force_subtract': False, 'save_background': False, 'user_background': None, 'inverse': False, 'steps': {'flat_field': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_interpolated_flat': False, 'user_supplied_flat': None, 'inverse': False}, 'pathloss': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'inverse': False, 'source_type': None}, 'barshadow': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'inverse': False, 'source_type': None}, 'photom': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'inverse': False, 'source_type': None}}}, 'wavecorr': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': Fa ...
# 2022-12-08 17:24:33,776 - stpipe.Spec2Pipeline - INFO - Prefetching reference files for dataset: 'jw01386013001_03104_00001_nrs2_rate.fits' reftypes = ['area', 'camera', 'collimator', 'cubepar', 'dflat', 'disperser', 'distortion', 'fflat', 'filteroffset', 'flat', 'fore', 'fpa', 'ifufore', 'ifupost', 'ifuslicer', 'msa', 'msaoper', 'ote', 'pathloss', 'photom', 'regions', 'sflat', 'specwcs', 'wavelengthrange', 'wfssbkg']
# 2022-12-08 17:24:33,781 - stpipe.Spec2Pipeline - INFO - Prefetch for AREA reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_area_0009.fits'.
# 2022-12-08 17:24:33,781 - stpipe.Spec2Pipeline - INFO - Prefetch for CAMERA reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_camera_0007.asdf'.
# 2022-12-08 17:24:33,782 - stpipe.Spec2Pipeline - INFO - Prefetch for COLLIMATOR reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_collimator_0007.asdf'.
# 2022-12-08 17:24:33,782 - stpipe.Spec2Pipeline - INFO - Prefetch for CUBEPAR reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_cubepar_0003.fits'.
# 2022-12-08 17:24:33,782 - stpipe.Spec2Pipeline - INFO - Prefetch for DFLAT reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_dflat_0002.fits'.
# 2022-12-08 17:24:33,783 - stpipe.Spec2Pipeline - INFO - Prefetch for DISPERSER reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_disperser_0056.asdf'.
# 2022-12-08 17:24:33,783 - stpipe.Spec2Pipeline - INFO - Prefetch for DISTORTION reference file is 'N/A'.
# 2022-12-08 17:24:33,783 - stpipe.Spec2Pipeline - INFO - Prefetch for FFLAT reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_fflat_0023.fits'.
# 2022-12-08 17:24:33,784 - stpipe.Spec2Pipeline - INFO - Prefetch for FILTEROFFSET reference file is 'N/A'.
# 2022-12-08 17:24:33,784 - stpipe.Spec2Pipeline - INFO - Prefetch for FLAT reference file is 'N/A'.
# 2022-12-08 17:24:33,785 - stpipe.Spec2Pipeline - INFO - Prefetch for FORE reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_fore_0047.asdf'.
# 2022-12-08 17:24:33,785 - stpipe.Spec2Pipeline - INFO - Prefetch for FPA reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_fpa_0008.asdf'.
# 2022-12-08 17:24:33,785 - stpipe.Spec2Pipeline - INFO - Prefetch for IFUFORE reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_ifufore_0010.asdf'.
# 2022-12-08 17:24:33,786 - stpipe.Spec2Pipeline - INFO - Prefetch for IFUPOST reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_ifupost_0009.asdf'.
# 2022-12-08 17:24:33,786 - stpipe.Spec2Pipeline - INFO - Prefetch for IFUSLICER reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_ifuslicer_0010.asdf'.
# 2022-12-08 17:24:33,786 - stpipe.Spec2Pipeline - INFO - Prefetch for MSA reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_msa_0008.asdf'.
# 2022-12-08 17:24:33,787 - stpipe.Spec2Pipeline - INFO - Prefetch for MSAOPER reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_msaoper_0004.json'.
# 2022-12-08 17:24:33,787 - stpipe.Spec2Pipeline - INFO - Prefetch for OTE reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_ote_0008.asdf'.
# 2022-12-08 17:24:33,788 - stpipe.Spec2Pipeline - INFO - Prefetch for PATHLOSS reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_pathloss_0003.fits'.
# 2022-12-08 17:24:33,788 - stpipe.Spec2Pipeline - INFO - Prefetch for PHOTOM reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_photom_0016.fits'.
# 2022-12-08 17:24:33,788 - stpipe.Spec2Pipeline - INFO - Prefetch for REGIONS reference file is 'N/A'.
# 2022-12-08 17:24:33,789 - stpipe.Spec2Pipeline - INFO - Prefetch for SFLAT reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_sflat_0105.fits'.
# 2022-12-08 17:24:33,789 - stpipe.Spec2Pipeline - INFO - Prefetch for SPECWCS reference file is 'N/A'.
# 2022-12-08 17:24:33,789 - stpipe.Spec2Pipeline - INFO - Prefetch for WAVELENGTHRANGE reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_wavelengthrange_0006.asdf'.
# 2022-12-08 17:24:33,790 - stpipe.Spec2Pipeline - INFO - Prefetch for WFSSBKG reference file is 'N/A'.
# 2022-12-08 17:24:33,790 - stpipe.Spec2Pipeline - INFO - Prefetching reference files for dataset: 'jw01386013001_03104_00002_nrs2_rate.fits' reftypes = ['area', 'camera', 'collimator', 'cubepar', 'dflat', 'disperser', 'distortion', 'fflat', 'filteroffset', 'flat', 'fore', 'fpa', 'ifufore', 'ifupost', 'ifuslicer', 'msa', 'msaoper', 'ote', 'pathloss', 'photom', 'regions', 'sflat', 'specwcs', 'wavelengthrange', 'wfssbkg']
# 2022-12-08 17:24:33,795 - stpipe.Spec2Pipeline - INFO - Prefetch for AREA reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_area_0009.fits'.
# 2022-12-08 17:24:33,795 - stpipe.Spec2Pipeline - INFO - Prefetch for CAMERA reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_camera_0007.asdf'.
# 2022-12-08 17:24:33,795 - stpipe.Spec2Pipeline - INFO - Prefetch for COLLIMATOR reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_collimator_0007.asdf'.
# 2022-12-08 17:24:33,796 - stpipe.Spec2Pipeline - INFO - Prefetch for CUBEPAR reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_cubepar_0003.fits'.
# 2022-12-08 17:24:33,796 - stpipe.Spec2Pipeline - INFO - Prefetch for DFLAT reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_dflat_0002.fits'.
# 2022-12-08 17:24:33,796 - stpipe.Spec2Pipeline - INFO - Prefetch for DISPERSER reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_disperser_0056.asdf'.
# 2022-12-08 17:24:33,797 - stpipe.Spec2Pipeline - INFO - Prefetch for DISTORTION reference file is 'N/A'.
# 2022-12-08 17:24:33,797 - stpipe.Spec2Pipeline - INFO - Prefetch for FFLAT reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_fflat_0023.fits'.
# 2022-12-08 17:24:33,797 - stpipe.Spec2Pipeline - INFO - Prefetch for FILTEROFFSET reference file is 'N/A'.
# 2022-12-08 17:24:33,798 - stpipe.Spec2Pipeline - INFO - Prefetch for FLAT reference file is 'N/A'.
# 2022-12-08 17:24:33,798 - stpipe.Spec2Pipeline - INFO - Prefetch for FORE reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_fore_0047.asdf'.
# 2022-12-08 17:24:33,798 - stpipe.Spec2Pipeline - INFO - Prefetch for FPA reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_fpa_0008.asdf'.
# 2022-12-08 17:24:33,799 - stpipe.Spec2Pipeline - INFO - Prefetch for IFUFORE reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_ifufore_0010.asdf'.
# 2022-12-08 17:24:33,799 - stpipe.Spec2Pipeline - INFO - Prefetch for IFUPOST reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_ifupost_0009.asdf'.
# 2022-12-08 17:24:33,800 - stpipe.Spec2Pipeline - INFO - Prefetch for IFUSLICER reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_ifuslicer_0010.asdf'.
# 2022-12-08 17:24:33,800 - stpipe.Spec2Pipeline - INFO - Prefetch for MSA reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_msa_0008.asdf'.
# 2022-12-08 17:24:33,800 - stpipe.Spec2Pipeline - INFO - Prefetch for MSAOPER reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_msaoper_0004.json'.
# 2022-12-08 17:24:33,801 - stpipe.Spec2Pipeline - INFO - Prefetch for OTE reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_ote_0008.asdf'.
# 2022-12-08 17:24:33,801 - stpipe.Spec2Pipeline - INFO - Prefetch for PATHLOSS reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_pathloss_0003.fits'.
# 2022-12-08 17:24:33,802 - stpipe.Spec2Pipeline - INFO - Prefetch for PHOTOM reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_photom_0016.fits'.
# 2022-12-08 17:24:33,802 - stpipe.Spec2Pipeline - INFO - Prefetch for REGIONS reference file is 'N/A'.
# 2022-12-08 17:24:33,803 - stpipe.Spec2Pipeline - INFO - Prefetch for SFLAT reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_sflat_0105.fits'.
# 2022-12-08 17:24:33,803 - stpipe.Spec2Pipeline - INFO - Prefetch for SPECWCS reference file is 'N/A'.
# 2022-12-08 17:24:33,803 - stpipe.Spec2Pipeline - INFO - Prefetch for WAVELENGTHRANGE reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_wavelengthrange_0006.asdf'.
# 2022-12-08 17:24:33,804 - stpipe.Spec2Pipeline - INFO - Prefetch for WFSSBKG reference file is 'N/A'.
# 2022-12-08 17:24:33,804 - stpipe.Spec2Pipeline - INFO - Prefetching reference files for dataset: 'jw01386013001_03104_00003_nrs2_rate.fits' reftypes = ['area', 'camera', 'collimator', 'cubepar', 'dflat', 'disperser', 'distortion', 'fflat', 'filteroffset', 'flat', 'fore', 'fpa', 'ifufore', 'ifupost', 'ifuslicer', 'msa', 'msaoper', 'ote', 'pathloss', 'photom', 'regions', 'sflat', 'specwcs', 'wavelengthrange', 'wfssbkg']
# 2022-12-08 17:24:33,808 - stpipe.Spec2Pipeline - INFO - Prefetch for AREA reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_area_0009.fits'.
# 2022-12-08 17:24:33,809 - stpipe.Spec2Pipeline - INFO - Prefetch for CAMERA reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_camera_0007.asdf'.
# 2022-12-08 17:24:33,809 - stpipe.Spec2Pipeline - INFO - Prefetch for COLLIMATOR reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_collimator_0007.asdf'.
# 2022-12-08 17:24:33,810 - stpipe.Spec2Pipeline - INFO - Prefetch for CUBEPAR reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_cubepar_0003.fits'.
# 2022-12-08 17:24:33,810 - stpipe.Spec2Pipeline - INFO - Prefetch for DFLAT reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_dflat_0002.fits'.
# 2022-12-08 17:24:33,810 - stpipe.Spec2Pipeline - INFO - Prefetch for DISPERSER reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_disperser_0056.asdf'.
# 2022-12-08 17:24:33,811 - stpipe.Spec2Pipeline - INFO - Prefetch for DISTORTION reference file is 'N/A'.
# 2022-12-08 17:24:33,811 - stpipe.Spec2Pipeline - INFO - Prefetch for FFLAT reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_fflat_0023.fits'.
# 2022-12-08 17:24:33,811 - stpipe.Spec2Pipeline - INFO - Prefetch for FILTEROFFSET reference file is 'N/A'.
# 2022-12-08 17:24:33,811 - stpipe.Spec2Pipeline - INFO - Prefetch for FLAT reference file is 'N/A'.
# 2022-12-08 17:24:33,812 - stpipe.Spec2Pipeline - INFO - Prefetch for FORE reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_fore_0047.asdf'.
# 2022-12-08 17:24:33,812 - stpipe.Spec2Pipeline - INFO - Prefetch for FPA reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_fpa_0008.asdf'.
# 2022-12-08 17:24:33,813 - stpipe.Spec2Pipeline - INFO - Prefetch for IFUFORE reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_ifufore_0010.asdf'.
# 2022-12-08 17:24:33,813 - stpipe.Spec2Pipeline - INFO - Prefetch for IFUPOST reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_ifupost_0009.asdf'.
# 2022-12-08 17:24:33,813 - stpipe.Spec2Pipeline - INFO - Prefetch for IFUSLICER reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_ifuslicer_0010.asdf'.
# 2022-12-08 17:24:33,814 - stpipe.Spec2Pipeline - INFO - Prefetch for MSA reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_msa_0008.asdf'.
# 2022-12-08 17:24:33,814 - stpipe.Spec2Pipeline - INFO - Prefetch for MSAOPER reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_msaoper_0004.json'.
# 2022-12-08 17:24:33,815 - stpipe.Spec2Pipeline - INFO - Prefetch for OTE reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_ote_0008.asdf'.
# 2022-12-08 17:24:33,815 - stpipe.Spec2Pipeline - INFO - Prefetch for PATHLOSS reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_pathloss_0003.fits'.
# 2022-12-08 17:24:33,815 - stpipe.Spec2Pipeline - INFO - Prefetch for PHOTOM reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_photom_0016.fits'.
# 2022-12-08 17:24:33,816 - stpipe.Spec2Pipeline - INFO - Prefetch for REGIONS reference file is 'N/A'.
# 2022-12-08 17:24:33,816 - stpipe.Spec2Pipeline - INFO - Prefetch for SFLAT reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_sflat_0105.fits'.
# 2022-12-08 17:24:33,816 - stpipe.Spec2Pipeline - INFO - Prefetch for SPECWCS reference file is 'N/A'.
# 2022-12-08 17:24:33,817 - stpipe.Spec2Pipeline - INFO - Prefetch for WAVELENGTHRANGE reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_wavelengthrange_0006.asdf'.
# 2022-12-08 17:24:33,817 - stpipe.Spec2Pipeline - INFO - Prefetch for WFSSBKG reference file is 'N/A'.
# 2022-12-08 17:24:33,818 - stpipe.Spec2Pipeline - INFO - Prefetching reference files for dataset: 'jw01386013001_03104_00004_nrs2_rate.fits' reftypes = ['area', 'camera', 'collimator', 'cubepar', 'dflat', 'disperser', 'distortion', 'fflat', 'filteroffset', 'flat', 'fore', 'fpa', 'ifufore', 'ifupost', 'ifuslicer', 'msa', 'msaoper', 'ote', 'pathloss', 'photom', 'regions', 'sflat', 'specwcs', 'wavelengthrange', 'wfssbkg']
# 2022-12-08 17:24:33,822 - stpipe.Spec2Pipeline - INFO - Prefetch for AREA reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_area_0009.fits'.
# 2022-12-08 17:24:33,822 - stpipe.Spec2Pipeline - INFO - Prefetch for CAMERA reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_camera_0007.asdf'.
# 2022-12-08 17:24:33,823 - stpipe.Spec2Pipeline - INFO - Prefetch for COLLIMATOR reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_collimator_0007.asdf'.
# 2022-12-08 17:24:33,823 - stpipe.Spec2Pipeline - INFO - Prefetch for CUBEPAR reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_cubepar_0003.fits'.
# 2022-12-08 17:24:33,823 - stpipe.Spec2Pipeline - INFO - Prefetch for DFLAT reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_dflat_0002.fits'.
# 2022-12-08 17:24:33,824 - stpipe.Spec2Pipeline - INFO - Prefetch for DISPERSER reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_disperser_0056.asdf'.
# 2022-12-08 17:24:33,824 - stpipe.Spec2Pipeline - INFO - Prefetch for DISTORTION reference file is 'N/A'.
# 2022-12-08 17:24:33,824 - stpipe.Spec2Pipeline - INFO - Prefetch for FFLAT reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_fflat_0023.fits'.
# 2022-12-08 17:24:33,825 - stpipe.Spec2Pipeline - INFO - Prefetch for FILTEROFFSET reference file is 'N/A'.
# 2022-12-08 17:24:33,825 - stpipe.Spec2Pipeline - INFO - Prefetch for FLAT reference file is 'N/A'.
# 2022-12-08 17:24:33,826 - stpipe.Spec2Pipeline - INFO - Prefetch for FORE reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_fore_0047.asdf'.
# 2022-12-08 17:24:33,826 - stpipe.Spec2Pipeline - INFO - Prefetch for FPA reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_fpa_0008.asdf'.
# 2022-12-08 17:24:33,826 - stpipe.Spec2Pipeline - INFO - Prefetch for IFUFORE reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_ifufore_0010.asdf'.
# 2022-12-08 17:24:33,826 - stpipe.Spec2Pipeline - INFO - Prefetch for IFUPOST reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_ifupost_0009.asdf'.
# 2022-12-08 17:24:33,827 - stpipe.Spec2Pipeline - INFO - Prefetch for IFUSLICER reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_ifuslicer_0010.asdf'.
# 2022-12-08 17:24:33,827 - stpipe.Spec2Pipeline - INFO - Prefetch for MSA reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_msa_0008.asdf'.
# 2022-12-08 17:24:33,827 - stpipe.Spec2Pipeline - INFO - Prefetch for MSAOPER reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_msaoper_0004.json'.
# 2022-12-08 17:24:33,828 - stpipe.Spec2Pipeline - INFO - Prefetch for OTE reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_ote_0008.asdf'.
# 2022-12-08 17:24:33,828 - stpipe.Spec2Pipeline - INFO - Prefetch for PATHLOSS reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_pathloss_0003.fits'.
# 2022-12-08 17:24:33,829 - stpipe.Spec2Pipeline - INFO - Prefetch for PHOTOM reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_photom_0016.fits'.
# 2022-12-08 17:24:33,829 - stpipe.Spec2Pipeline - INFO - Prefetch for REGIONS reference file is 'N/A'.
# 2022-12-08 17:24:33,829 - stpipe.Spec2Pipeline - INFO - Prefetch for SFLAT reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_sflat_0105.fits'.
# 2022-12-08 17:24:33,830 - stpipe.Spec2Pipeline - INFO - Prefetch for SPECWCS reference file is 'N/A'.
# 2022-12-08 17:24:33,830 - stpipe.Spec2Pipeline - INFO - Prefetch for WAVELENGTHRANGE reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_wavelengthrange_0006.asdf'.
# 2022-12-08 17:24:33,830 - stpipe.Spec2Pipeline - INFO - Prefetch for WFSSBKG reference file is 'N/A'.
# 2022-12-08 17:24:33,831 - stpipe.Spec2Pipeline - INFO - Starting calwebb_spec2 ...
# 2022-12-08 17:24:33,837 - stpipe.Spec2Pipeline - INFO - Processing product stage1/jw01386013001_03104_00001_nrs2
# 2022-12-08 17:24:33,838 - stpipe.Spec2Pipeline - INFO - Working on input stage1/jw01386013001_03104_00001_nrs2_rate.fits ...
# 2022-12-08 17:24:33,950 - stpipe.Spec2Pipeline.assign_wcs - INFO - Step assign_wcs running with args (<IFUImageModel(2048, 2048) from jw01386013001_03104_00001_nrs2_rate.fits>,).
# 2022-12-08 17:24:33,952 - stpipe.Spec2Pipeline.assign_wcs - INFO - Step assign_wcs parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'sip_approx': True, 'sip_max_pix_error': 0.25, 'sip_degree': None, 'sip_max_inv_pix_error': 0.25, 'sip_inv_degree': None, 'sip_npoints': 32, 'slit_y_low': -0.55, 'slit_y_high': 0.55}
# 2022-12-08 17:24:34,162 - stpipe.Spec2Pipeline.assign_wcs - INFO - gwa_ytilt is 0.144618199999999 deg
# 2022-12-08 17:24:34,163 - stpipe.Spec2Pipeline.assign_wcs - INFO - gwa_xtilt is 0.3170879479999983 deg
# 2022-12-08 17:24:34,163 - stpipe.Spec2Pipeline.assign_wcs - INFO - theta_y correction: 0.0027504070775445496 deg
# 2022-12-08 17:24:34,164 - stpipe.Spec2Pipeline.assign_wcs - INFO - theta_x correction: 3.6475661033321673e-05 deg
# 2022-12-08 17:24:34,249 - stpipe.Spec2Pipeline.assign_wcs - INFO - Applied Barycentric velocity correction : 0.9999031525074483
# 2022-12-08 17:24:37,077 - stpipe.Spec2Pipeline.assign_wcs - INFO - Created a NIRSPEC nrs_ifu pipeline with references {'distortion': None, 'filteroffset': None, 'specwcs': None, 'regions': None, 'wavelengthrange': '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_wavelengthrange_0006.asdf', 'camera': '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_camera_0007.asdf', 'collimator': '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_collimator_0007.asdf', 'disperser': '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_disperser_0056.asdf', 'fore': '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_fore_0047.asdf', 'fpa': '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_fpa_0008.asdf', 'msa': '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_msa_0008.asdf', 'ote': '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_ote_0008.asdf', 'ifupost': '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_ifupost_0009.asdf', 'ifufore': '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_ifufore_0010.asdf', 'ifuslicer': '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_ifuslicer_0010.asdf'}
# 2022-12-08 17:24:42,525 - stpipe.Spec2Pipeline.assign_wcs - INFO - Update S_REGION to POLYGON ICRS  194.004905636 -12.959844705 194.006132616 -12.959844705 194.006132616 -12.958750682 194.004905636 -12.958750682
# 2022-12-08 17:24:42,526 - stpipe.Spec2Pipeline.assign_wcs - INFO - COMPLETED assign_wcs
# 2022-12-08 17:24:42,538 - stpipe.Spec2Pipeline.assign_wcs - INFO - Step assign_wcs done
# 2022-12-08 17:24:42,682 - stpipe.Spec2Pipeline.bkg_subtract - INFO - Step bkg_subtract running with args (<IFUImageModel(2048, 2048) from jw01386013001_03104_00001_nrs2_rate.fits>, []).
# 2022-12-08 17:24:42,684 - stpipe.Spec2Pipeline.bkg_subtract - INFO - Step bkg_subtract parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_combined_background': False, 'sigma': 3.0, 'maxiters': None, 'wfss_mmag_extract': None}
# 2022-12-08 17:24:42,684 - stpipe.Spec2Pipeline.bkg_subtract - INFO - Step skipped.
# 2022-12-08 17:24:42,686 - stpipe.Spec2Pipeline.bkg_subtract - INFO - Step bkg_subtract done
# 2022-12-08 17:24:42,784 - stpipe.Spec2Pipeline.imprint_subtract - INFO - Step imprint_subtract running with args (<IFUImageModel(2048, 2048) from jw01386013001_03104_00001_nrs2_rate.fits>, []).
# 2022-12-08 17:24:42,785 - stpipe.Spec2Pipeline.imprint_subtract - INFO - Step imprint_subtract parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': ''}
# 2022-12-08 17:24:42,786 - stpipe.Spec2Pipeline.imprint_subtract - INFO - Step skipped.
# 2022-12-08 17:24:42,788 - stpipe.Spec2Pipeline.imprint_subtract - INFO - Step imprint_subtract done
# 2022-12-08 17:24:42,886 - stpipe.Spec2Pipeline.msa_flagging - INFO - Step msa_flagging running with args (<IFUImageModel(2048, 2048) from jw01386013001_03104_00001_nrs2_rate.fits>,).
# 2022-12-08 17:24:42,888 - stpipe.Spec2Pipeline.msa_flagging - INFO - Step msa_flagging parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}
# 2022-12-08 17:24:42,906 - stpipe.Spec2Pipeline.msa_flagging - INFO - Using reference file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_msaoper_0004.json
# 2022-12-08 17:24:42,907 - stpipe.JwstStep - INFO - JwstStep instance created.
# 2022-12-08 17:24:43,039 - stpipe.Spec2Pipeline.msa_flagging - INFO - gwa_ytilt is 0.144618199999999 deg
# 2022-12-08 17:24:43,039 - stpipe.Spec2Pipeline.msa_flagging - INFO - gwa_xtilt is 0.3170879479999983 deg
# 2022-12-08 17:24:43,040 - stpipe.Spec2Pipeline.msa_flagging - INFO - theta_y correction: 0.0027504070775445496 deg
# 2022-12-08 17:24:43,041 - stpipe.Spec2Pipeline.msa_flagging - INFO - theta_x correction: 3.6475661033321673e-05 deg
# 2022-12-08 17:24:43,056 - stpipe.Spec2Pipeline.msa_flagging - INFO - SPORDER= -1, wrange=[2.87e-06, 5.27e-06]
# 2022-12-08 17:24:43,147 - stpipe.Spec2Pipeline.msa_flagging - INFO - Applied Barycentric velocity correction : 0.9999031525074483
# 2022-12-08 17:24:43,185 - stpipe.Spec2Pipeline.msa_flagging - INFO - There are 6 open slits in quadrant 1
# 2022-12-08 17:24:43,229 - stpipe.Spec2Pipeline.msa_flagging - INFO - There are 3 open slits in quadrant 2
# 2022-12-08 17:24:43,253 - stpipe.Spec2Pipeline.msa_flagging - INFO - There are 12 open slits in quadrant 3
# 2022-12-08 17:24:43,338 - stpipe.Spec2Pipeline.msa_flagging - INFO - There are 3 open slits in quadrant 4
# 2022-12-08 17:24:43,361 - stpipe.Spec2Pipeline.msa_flagging - INFO - There are 0 open slits in quadrant 5
# 2022-12-08 17:24:58,663 - stpipe.Spec2Pipeline.msa_flagging - INFO - Step msa_flagging done
# 2022-12-08 17:24:58,967 - stpipe.Spec2Pipeline.srctype - INFO - Step srctype running with args (<IFUImageModel(2048, 2048) from jw01386013001_03104_00001_nrs2_rate.fits>,).
# 2022-12-08 17:24:58,968 - stpipe.Spec2Pipeline.srctype - INFO - Step srctype parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'source_type': 'POINT'}
# 2022-12-08 17:24:58,976 - stpipe.Spec2Pipeline.srctype - INFO - Input EXP_TYPE is NRS_IFU
# 2022-12-08 17:24:58,976 - stpipe.Spec2Pipeline.srctype - INFO - Input SRCTYAPT = UNKNOWN
# 2022-12-08 17:24:58,976 - stpipe.Spec2Pipeline.srctype - WARNING - Based on user-input, setting SRCTYPE = POINT
# 2022-12-08 17:24:58,980 - stpipe.Spec2Pipeline.srctype - INFO - Step srctype done
# 2022-12-08 17:24:59,080 - stpipe.Spec2Pipeline.flat_field - INFO - Step flat_field running with args (<IFUImageModel(2048, 2048) from jw01386013001_03104_00001_nrs2_rate.fits>,).
# 2022-12-08 17:24:59,081 - stpipe.Spec2Pipeline.flat_field - INFO - Step flat_field parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_interpolated_flat': False, 'user_supplied_flat': None, 'inverse': False}
# 2022-12-08 17:30:12,877 - stpipe.Spec2Pipeline.flat_field - INFO - Step flat_field done
# 2022-12-08 17:30:13,293 - stpipe.Spec2Pipeline.straylight - INFO - Step straylight running with args (<IFUImageModel(2048, 2048) from jw01386013001_03104_00001_nrs2_rate.fits>,).
# 2022-12-08 17:30:13,294 - stpipe.Spec2Pipeline.straylight - INFO - Step straylight parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': ''}
# 2022-12-08 17:30:13,294 - stpipe.Spec2Pipeline.straylight - INFO - Step skipped.
# 2022-12-08 17:30:13,296 - stpipe.Spec2Pipeline.straylight - INFO - Step straylight done
# 2022-12-08 17:30:13,451 - stpipe.Spec2Pipeline.fringe - INFO - Step fringe running with args (<IFUImageModel(2048, 2048) from jw01386013001_03104_00001_nrs2_rate.fits>,).
# 2022-12-08 17:30:13,452 - stpipe.Spec2Pipeline.fringe - INFO - Step fringe parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': ''}
# 2022-12-08 17:30:13,453 - stpipe.Spec2Pipeline.fringe - INFO - Step skipped.
# 2022-12-08 17:30:13,455 - stpipe.Spec2Pipeline.fringe - INFO - Step fringe done
# 2022-12-08 17:30:13,610 - stpipe.Spec2Pipeline.pathloss - INFO - Step pathloss running with args (<IFUImageModel(2048, 2048) from jw01386013001_03104_00001_nrs2_rate.fits>,).
# 2022-12-08 17:30:13,611 - stpipe.Spec2Pipeline.pathloss - INFO - Step pathloss parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'inverse': False, 'source_type': None}
# 2022-12-08 17:30:13,628 - stpipe.Spec2Pipeline.pathloss - INFO - Using PATHLOSS reference file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_pathloss_0003.fits
# 2022-12-08 17:30:13,663 - stpipe.Spec2Pipeline.pathloss - INFO - Input exposure type is NRS_IFU
# 2022-12-08 17:31:10,246 - stpipe.Spec2Pipeline.pathloss - INFO - Step pathloss done
# 2022-12-08 17:31:10,607 - stpipe.Spec2Pipeline.barshadow - INFO - Step barshadow running with args (<IFUImageModel(2048, 2048) from jw01386013001_03104_00001_nrs2_rate.fits>,).
# 2022-12-08 17:31:10,608 - stpipe.Spec2Pipeline.barshadow - INFO - Step barshadow parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'inverse': False, 'source_type': None}
# 2022-12-08 17:31:10,608 - stpipe.Spec2Pipeline.barshadow - INFO - Step skipped.
# 2022-12-08 17:31:10,611 - stpipe.Spec2Pipeline.barshadow - INFO - Step barshadow done
# 2022-12-08 17:31:10,765 - stpipe.Spec2Pipeline.photom - INFO - Step photom running with args (<IFUImageModel(2048, 2048) from jw01386013001_03104_00001_nrs2_rate.fits>,).
# 2022-12-08 17:31:10,766 - stpipe.Spec2Pipeline.photom - INFO - Step photom parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'inverse': False, 'source_type': None}
# 2022-12-08 17:31:10,795 - stpipe.Spec2Pipeline.photom - INFO - Using photom reference file: /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_photom_0016.fits
# 2022-12-08 17:31:10,795 - stpipe.Spec2Pipeline.photom - INFO - Using area reference file: /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_area_0009.fits
# 2022-12-08 17:31:13,320 - stpipe.Spec2Pipeline.photom - INFO - Using instrument: NIRSPEC
# 2022-12-08 17:31:13,320 - stpipe.Spec2Pipeline.photom - INFO -  detector: NRS2
# 2022-12-08 17:31:13,320 - stpipe.Spec2Pipeline.photom - INFO -  exp_type: NRS_IFU
# 2022-12-08 17:31:13,321 - stpipe.Spec2Pipeline.photom - INFO -  filter: F290LP
# 2022-12-08 17:31:13,321 - stpipe.Spec2Pipeline.photom - INFO -  grating: G395H
# 2022-12-08 17:31:13,371 - stpipe.Spec2Pipeline.photom - INFO - PHOTMJSR value: 1
# 2022-12-08 17:32:07,110 - stpipe.Spec2Pipeline.photom - INFO - Step photom done
# 2022-12-08 17:32:07,834 - stpipe.Spec2Pipeline.cube_build - INFO - Step cube_build running with args (<IFUImageModel(2048, 2048) from stage2/jw01386013001_03104_00001_nrs2_cal.fits>,).
# 2022-12-08 17:32:07,836 - stpipe.Spec2Pipeline.cube_build - INFO - Step cube_build parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': False, 'input_dir': '', 'channel': 'all', 'band': 'all', 'grating': 'all', 'filter': 'all', 'output_type': 'multi', 'scale1': 0.0, 'scale2': 0.0, 'scalew': 0.0, 'weighting': 'drizzle', 'coord_system': 'skyalign', 'rois': 0.0, 'roiw': 0.0, 'weight_power': 2.0, 'wavemin': None, 'wavemax': None, 'single': False, 'skip_dqflagging': True}
# 2022-12-08 17:32:07,836 - stpipe.Spec2Pipeline.cube_build - INFO - Starting IFU Cube Building Step
# 2022-12-08 17:32:07,836 - stpipe.Spec2Pipeline.cube_build - INFO - Input interpolation: drizzle
# 2022-12-08 17:32:07,836 - stpipe.Spec2Pipeline.cube_build - INFO - Coordinate system to use: skyalign
# 2022-12-08 17:32:07,861 - stpipe.Spec2Pipeline.cube_build - INFO - Reading cube parameter file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_cubepar_0003.fits
# 2022-12-08 17:32:07,908 - stpipe.Spec2Pipeline.cube_build - INFO - Output IFUcube are constructed from all the data
# 2022-12-08 17:32:07,908 - stpipe.Spec2Pipeline.cube_build - INFO - Number of IFU cubes produced by this run = 1
# 2022-12-08 17:32:07,911 - stpipe.Spec2Pipeline.cube_build - INFO - Increasing spatial region of interest default value set for 4 dithers nan
# 2022-12-08 17:32:07,913 - stpipe.Spec2Pipeline.cube_build - INFO - Cube Geometry:
# 2022-12-08 17:32:07,914 - stpipe.Spec2Pipeline.cube_build - INFO - axis#  Naxis  CRPIX    CRVAL      CDELT(arcsec)  Min & Max (xi, eta arcsec)
# 2022-12-08 17:32:07,914 - stpipe.Spec2Pipeline.cube_build - INFO - Axis 1    47  24.00 -165.99448087   0.10000000  -2.35000004   2.35000004
# 2022-12-08 17:32:07,914 - stpipe.Spec2Pipeline.cube_build - INFO - Axis 2    43  22.00 -12.95929769   0.10000000  -2.15000003   2.15000003
# 2022-12-08 17:32:07,914 - stpipe.Spec2Pipeline.cube_build - INFO - axis#  Naxis  CRPIX    CRVAL      CDELT(microns)  Min & Max (microns)
# 2022-12-08 17:32:07,915 - stpipe.Spec2Pipeline.cube_build - INFO - Axis 3  1802   1.00   4.08126367   0.00066500   4.08093117   5.27926117
# 2022-12-08 17:32:07,915 - stpipe.Spec2Pipeline.cube_build - INFO - Cube covers grating, filter: g395h, f290lp
# 2022-12-08 17:32:07,915 - stpipe.Spec2Pipeline.cube_build - INFO - Output Name: stage2/jw01386013001_03104_00001_nrs2_s3d.fits
# 2022-12-08 17:32:11,435 - stpipe.Spec2Pipeline.cube_build - INFO - Mapping each NIRSpec slice to sky for input file: stage2/jw01386013001_03104_00001_nrs2_cal.fits
# 2022-12-08 17:33:22,149 - stpipe.Spec2Pipeline.cube_build - INFO - Average # of holes/wavelength plane is < 1
# 2022-12-08 17:33:22,150 - stpipe.Spec2Pipeline.cube_build - INFO - Total # of holes for IFU cube is : 0
# 2022-12-08 17:33:22,151 - stpipe.Spec2Pipeline.cube_build - INFO - Number of wavelength planes removed with no data: 17
# 2022-12-08 17:33:22,253 - stpipe.Spec2Pipeline.cube_build - INFO - Update S_REGION to POLYGON ICRS  194.004863538 -12.959881026 194.004863538 -12.958714359 194.006174714 -12.958714359 194.006174714 -12.959881026
# 2022-12-08 17:33:22,258 - stpipe.Spec2Pipeline.cube_build - INFO - Step cube_build done
# 2022-12-08 17:33:22,451 - stpipe.Spec2Pipeline - INFO - Saved model in stage2/jw01386013001_03104_00001_nrs2_s3d.fits
# 2022-12-08 17:33:22,684 - stpipe.Spec2Pipeline.extract_1d - INFO - Step extract_1d running with args (<ModelContainer>,).
# 2022-12-08 17:33:22,686 - stpipe.Spec2Pipeline.extract_1d - INFO - Step extract_1d parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': True, 'suffix': 'x1d', 'search_output_file': True, 'input_dir': '', 'smoothing_length': None, 'bkg_fit': None, 'bkg_order': None, 'bkg_sigma_clip': 3.0, 'log_increment': 50, 'subtract_background': None, 'use_source_posn': None, 'center_xy': None, 'apply_apcorr': True, 'soss_threshold': 0.01, 'soss_n_os': 2, 'soss_transform': None, 'soss_tikfac': None, 'soss_width': 40.0, 'soss_bad_pix': 'model', 'soss_modelname': None}
# 2022-12-08 17:33:22,687 - stpipe.Spec2Pipeline.extract_1d - INFO - Step skipped.
# 2022-12-08 17:33:22,689 - stpipe.Spec2Pipeline.extract_1d - INFO - Step extract_1d done
# 2022-12-08 17:33:22,689 - stpipe.Spec2Pipeline - INFO - Finished processing product stage1/jw01386013001_03104_00001_nrs2
# 2022-12-08 17:33:22,690 - stpipe.Spec2Pipeline - INFO - Processing product stage1/jw01386013001_03104_00002_nrs2
# 2022-12-08 17:33:22,690 - stpipe.Spec2Pipeline - INFO - Working on input stage1/jw01386013001_03104_00002_nrs2_rate.fits ...
# 2022-12-08 17:33:22,865 - stpipe.Spec2Pipeline.assign_wcs - INFO - Step assign_wcs running with args (<IFUImageModel(2048, 2048) from jw01386013001_03104_00002_nrs2_rate.fits>,).
# 2022-12-08 17:33:22,866 - stpipe.Spec2Pipeline.assign_wcs - INFO - Step assign_wcs parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'assign_wcs', 'search_output_file': True, 'input_dir': '', 'sip_approx': True, 'sip_max_pix_error': 0.25, 'sip_degree': None, 'sip_max_inv_pix_error': 0.25, 'sip_inv_degree': None, 'sip_npoints': 32, 'slit_y_low': -0.55, 'slit_y_high': 0.55}
# 2022-12-08 17:33:23,061 - stpipe.Spec2Pipeline.assign_wcs - INFO - gwa_ytilt is 0.144618199999999 deg
# 2022-12-08 17:33:23,062 - stpipe.Spec2Pipeline.assign_wcs - INFO - gwa_xtilt is 0.3170879479999983 deg
# 2022-12-08 17:33:23,062 - stpipe.Spec2Pipeline.assign_wcs - INFO - theta_y correction: 0.0027504070775445496 deg
# 2022-12-08 17:33:23,063 - stpipe.Spec2Pipeline.assign_wcs - INFO - theta_x correction: 3.6475661033321673e-05 deg
# 2022-12-08 17:33:23,154 - stpipe.Spec2Pipeline.assign_wcs - INFO - Applied Barycentric velocity correction : 0.9999031518737992
# 2022-12-08 17:33:26,149 - stpipe.Spec2Pipeline.assign_wcs - INFO - Created a NIRSPEC nrs_ifu pipeline with references {'distortion': None, 'filteroffset': None, 'specwcs': None, 'regions': None, 'wavelengthrange': '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_wavelengthrange_0006.asdf', 'camera': '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_camera_0007.asdf', 'collimator': '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_collimator_0007.asdf', 'disperser': '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_disperser_0056.asdf', 'fore': '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_fore_0047.asdf', 'fpa': '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_fpa_0008.asdf', 'msa': '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_msa_0008.asdf', 'ote': '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_ote_0008.asdf', 'ifupost': '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_ifupost_0009.asdf', 'ifufore': '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_ifufore_0010.asdf', 'ifuslicer': '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_ifuslicer_0010.asdf'}
# 2022-12-08 17:33:30,932 - stpipe.Spec2Pipeline.assign_wcs - INFO - Update S_REGION to POLYGON ICRS  194.005198500 -12.959253675 194.006425479 -12.959253675 194.006425479 -12.958159651 194.005198500 -12.958159651
# 2022-12-08 17:33:30,933 - stpipe.Spec2Pipeline.assign_wcs - INFO - COMPLETED assign_wcs
# 2022-12-08 17:33:30,944 - stpipe.Spec2Pipeline.assign_wcs - INFO - Step assign_wcs done
# 2022-12-08 17:33:31,163 - stpipe.Spec2Pipeline.bkg_subtract - INFO - Step bkg_subtract running with args (<IFUImageModel(2048, 2048) from jw01386013001_03104_00002_nrs2_rate.fits>, []).
# 2022-12-08 17:33:31,164 - stpipe.Spec2Pipeline.bkg_subtract - INFO - Step bkg_subtract parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': 'bkg_subtract', 'search_output_file': True, 'input_dir': '', 'save_combined_background': False, 'sigma': 3.0, 'maxiters': None, 'wfss_mmag_extract': None}
# 2022-12-08 17:33:31,165 - stpipe.Spec2Pipeline.bkg_subtract - INFO - Step skipped.
# 2022-12-08 17:33:31,167 - stpipe.Spec2Pipeline.bkg_subtract - INFO - Step bkg_subtract done
# 2022-12-08 17:33:31,339 - stpipe.Spec2Pipeline.imprint_subtract - INFO - Step imprint_subtract running with args (<IFUImageModel(2048, 2048) from jw01386013001_03104_00002_nrs2_rate.fits>, []).
# 2022-12-08 17:33:31,340 - stpipe.Spec2Pipeline.imprint_subtract - INFO - Step imprint_subtract parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': 'imprint_subtract', 'search_output_file': True, 'input_dir': ''}
# 2022-12-08 17:33:31,340 - stpipe.Spec2Pipeline.imprint_subtract - INFO - Step skipped.
# 2022-12-08 17:33:31,342 - stpipe.Spec2Pipeline.imprint_subtract - INFO - Step imprint_subtract done
# 2022-12-08 17:33:31,512 - stpipe.Spec2Pipeline.msa_flagging - INFO - Step msa_flagging running with args (<IFUImageModel(2048, 2048) from jw01386013001_03104_00002_nrs2_rate.fits>,).
# 2022-12-08 17:33:31,513 - stpipe.Spec2Pipeline.msa_flagging - INFO - Step msa_flagging parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'msa_flagging', 'search_output_file': True, 'input_dir': ''}
# ...
# 2022-12-08 17:51:27,706 - stpipe.Spec2Pipeline.assign_wcs - INFO - Step assign_wcs done
# 2022-12-08 17:51:28,130 - stpipe.Spec2Pipeline.bkg_subtract - INFO - Step bkg_subtract running with args (<IFUImageModel(2048, 2048) from jw01386013001_03104_00004_nrs2_rate.fits>, []).
# 2022-12-08 17:51:28,131 - stpipe.Spec2Pipeline.bkg_subtract - INFO - Step bkg_subtract parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': 'bkg_subtract', 'search_output_file': True, 'input_dir': '', 'save_combined_background': False, 'sigma': 3.0, 'maxiters': None, 'wfss_mmag_extract': None}
# 2022-12-08 17:51:28,132 - stpipe.Spec2Pipeline.bkg_subtract - INFO - Step skipped.
# 2022-12-08 17:51:28,134 - stpipe.Spec2Pipeline.bkg_subtract - INFO - Step bkg_subtract done
# 2022-12-08 17:51:28,463 - stpipe.Spec2Pipeline.imprint_subtract - INFO - Step imprint_subtract running with args (<IFUImageModel(2048, 2048) from jw01386013001_03104_00004_nrs2_rate.fits>, []).
# 2022-12-08 17:51:28,464 - stpipe.Spec2Pipeline.imprint_subtract - INFO - Step imprint_subtract parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': 'imprint_subtract', 'search_output_file': True, 'input_dir': ''}
# 2022-12-08 17:51:28,464 - stpipe.Spec2Pipeline.imprint_subtract - INFO - Step skipped.
# 2022-12-08 17:51:28,466 - stpipe.Spec2Pipeline.imprint_subtract - INFO - Step imprint_subtract done
# 2022-12-08 17:51:28,794 - stpipe.Spec2Pipeline.msa_flagging - INFO - Step msa_flagging running with args (<IFUImageModel(2048, 2048) from jw01386013001_03104_00004_nrs2_rate.fits>,).
# 2022-12-08 17:51:28,795 - stpipe.Spec2Pipeline.msa_flagging - INFO - Step msa_flagging parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'msa_flagging', 'search_output_file': True, 'input_dir': ''}
# 2022-12-08 17:51:28,812 - stpipe.Spec2Pipeline.msa_flagging - INFO - Using reference file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_msaoper_0004.json
# 2022-12-08 17:51:28,813 - stpipe.JwstStep - INFO - JwstStep instance created.
# 2022-12-08 17:51:28,948 - stpipe.Spec2Pipeline.msa_flagging - INFO - gwa_ytilt is 0.144618199999999 deg
# 2022-12-08 17:51:28,948 - stpipe.Spec2Pipeline.msa_flagging - INFO - gwa_xtilt is 0.3170879479999983 deg
# 2022-12-08 17:51:28,949 - stpipe.Spec2Pipeline.msa_flagging - INFO - theta_y correction: 0.0027504070775445496 deg
# 2022-12-08 17:51:28,950 - stpipe.Spec2Pipeline.msa_flagging - INFO - theta_x correction: 3.6475661033321673e-05 deg
# 2022-12-08 17:51:28,963 - stpipe.Spec2Pipeline.msa_flagging - INFO - SPORDER= -1, wrange=[2.87e-06, 5.27e-06]
# 2022-12-08 17:51:29,055 - stpipe.Spec2Pipeline.msa_flagging - INFO - Applied Barycentric velocity correction : 0.999903150006202
# 2022-12-08 17:51:29,088 - stpipe.Spec2Pipeline.msa_flagging - INFO - There are 6 open slits in quadrant 1
# 2022-12-08 17:51:29,156 - stpipe.Spec2Pipeline.msa_flagging - INFO - There are 3 open slits in quadrant 2
# 2022-12-08 17:51:29,180 - stpipe.Spec2Pipeline.msa_flagging - INFO - There are 12 open slits in quadrant 3
# 2022-12-08 17:51:29,267 - stpipe.Spec2Pipeline.msa_flagging - INFO - There are 3 open slits in quadrant 4
# 2022-12-08 17:51:29,290 - stpipe.Spec2Pipeline.msa_flagging - INFO - There are 0 open slits in quadrant 5
# 2022-12-08 17:51:45,328 - stpipe.Spec2Pipeline.msa_flagging - INFO - Step msa_flagging done
# 2022-12-08 17:51:45,933 - stpipe.Spec2Pipeline.srctype - INFO - Step srctype running with args (<IFUImageModel(2048, 2048) from jw01386013001_03104_00004_nrs2_rate.fits>,).
# 2022-12-08 17:51:45,934 - stpipe.Spec2Pipeline.srctype - INFO - Step srctype parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'srctype', 'search_output_file': True, 'input_dir': '', 'source_type': 'POINT'}
# 2022-12-08 17:51:45,942 - stpipe.Spec2Pipeline.srctype - INFO - Input EXP_TYPE is NRS_IFU
# 2022-12-08 17:51:45,942 - stpipe.Spec2Pipeline.srctype - INFO - Input SRCTYAPT = UNKNOWN
# 2022-12-08 17:51:45,943 - stpipe.Spec2Pipeline.srctype - WARNING - Based on user-input, setting SRCTYPE = POINT
# 2022-12-08 17:51:45,946 - stpipe.Spec2Pipeline.srctype - INFO - Step srctype done
# 2022-12-08 17:51:46,294 - stpipe.Spec2Pipeline.flat_field - INFO - Step flat_field running with args (<IFUImageModel(2048, 2048) from jw01386013001_03104_00004_nrs2_rate.fits>,).
# 2022-12-08 17:51:46,295 - stpipe.Spec2Pipeline.flat_field - INFO - Step flat_field parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'flat_field', 'search_output_file': True, 'input_dir': '', 'save_interpolated_flat': False, 'user_supplied_flat': None, 'inverse': False}
# 2022-12-08 17:57:01,835 - stpipe.Spec2Pipeline.flat_field - INFO - Step flat_field done
# 2022-12-08 17:57:02,551 - stpipe.Spec2Pipeline.straylight - INFO - Step straylight running with args (<IFUImageModel(2048, 2048) from jw01386013001_03104_00004_nrs2_rate.fits>,).
# 2022-12-08 17:57:02,552 - stpipe.Spec2Pipeline.straylight - INFO - Step straylight parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': 'straylight', 'search_output_file': True, 'input_dir': ''}
# 2022-12-08 17:57:02,552 - stpipe.Spec2Pipeline.straylight - INFO - Step skipped.
# 2022-12-08 17:57:02,555 - stpipe.Spec2Pipeline.straylight - INFO - Step straylight done
# 2022-12-08 17:57:02,961 - stpipe.Spec2Pipeline.fringe - INFO - Step fringe running with args (<IFUImageModel(2048, 2048) from jw01386013001_03104_00004_nrs2_rate.fits>,).
# 2022-12-08 17:57:02,962 - stpipe.Spec2Pipeline.fringe - INFO - Step fringe parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': 'fringe', 'search_output_file': True, 'input_dir': ''}
# 2022-12-08 17:57:02,963 - stpipe.Spec2Pipeline.fringe - INFO - Step skipped.
# 2022-12-08 17:57:02,965 - stpipe.Spec2Pipeline.fringe - INFO - Step fringe done
# 2022-12-08 17:57:03,372 - stpipe.Spec2Pipeline.pathloss - INFO - Step pathloss running with args (<IFUImageModel(2048, 2048) from jw01386013001_03104_00004_nrs2_rate.fits>,).
# 2022-12-08 17:57:03,373 - stpipe.Spec2Pipeline.pathloss - INFO - Step pathloss parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'pathloss', 'search_output_file': True, 'input_dir': '', 'inverse': False, 'source_type': None}
# 2022-12-08 17:57:03,390 - stpipe.Spec2Pipeline.pathloss - INFO - Using PATHLOSS reference file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_pathloss_0003.fits
# 2022-12-08 17:57:03,416 - stpipe.Spec2Pipeline.pathloss - INFO - Input exposure type is NRS_IFU
# 2022-12-08 17:58:01,773 - stpipe.Spec2Pipeline.pathloss - INFO - Step pathloss done
# 2022-12-08 17:58:02,426 - stpipe.Spec2Pipeline.barshadow - INFO - Step barshadow running with args (<IFUImageModel(2048, 2048) from jw01386013001_03104_00004_nrs2_rate.fits>,).
# 2022-12-08 17:58:02,427 - stpipe.Spec2Pipeline.barshadow - INFO - Step barshadow parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': 'barshadow', 'search_output_file': True, 'input_dir': '', 'inverse': False, 'source_type': None}
# 2022-12-08 17:58:02,427 - stpipe.Spec2Pipeline.barshadow - INFO - Step skipped.
# 2022-12-08 17:58:02,429 - stpipe.Spec2Pipeline.barshadow - INFO - Step barshadow done
# 2022-12-08 17:58:02,819 - stpipe.Spec2Pipeline.photom - INFO - Step photom running with args (<IFUImageModel(2048, 2048) from jw01386013001_03104_00004_nrs2_rate.fits>,).
# 2022-12-08 17:58:02,820 - stpipe.Spec2Pipeline.photom - INFO - Step photom parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'photom', 'search_output_file': True, 'input_dir': '', 'inverse': False, 'source_type': None}
# 2022-12-08 17:58:02,848 - stpipe.Spec2Pipeline.photom - INFO - Using photom reference file: /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_photom_0016.fits
# 2022-12-08 17:58:02,848 - stpipe.Spec2Pipeline.photom - INFO - Using area reference file: /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_area_0009.fits
# 2022-12-08 17:58:05,197 - stpipe.Spec2Pipeline.photom - INFO - Using instrument: NIRSPEC
# 2022-12-08 17:58:05,198 - stpipe.Spec2Pipeline.photom - INFO -  detector: NRS2
# 2022-12-08 17:58:05,198 - stpipe.Spec2Pipeline.photom - INFO -  exp_type: NRS_IFU
# 2022-12-08 17:58:05,198 - stpipe.Spec2Pipeline.photom - INFO -  filter: F290LP
# 2022-12-08 17:58:05,199 - stpipe.Spec2Pipeline.photom - INFO -  grating: G395H
# 2022-12-08 17:58:05,244 - stpipe.Spec2Pipeline.photom - INFO - PHOTMJSR value: 1
# 2022-12-08 17:59:01,580 - stpipe.Spec2Pipeline.photom - INFO - Step photom done
# 2022-12-08 17:59:02,550 - stpipe.Spec2Pipeline.cube_build - INFO - Step cube_build running with args (<IFUImageModel(2048, 2048) from stage2/jw01386013001_03104_00004_nrs2_cal.fits>,).
# 2022-12-08 17:59:02,551 - stpipe.Spec2Pipeline.cube_build - INFO - Step cube_build parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 's3d', 'search_output_file': False, 'input_dir': '', 'channel': 'all', 'band': 'all', 'grating': 'all', 'filter': 'all', 'output_type': 'multi', 'scale1': 0.0, 'scale2': 0.0, 'scalew': 0.0, 'weighting': 'drizzle', 'coord_system': 'skyalign', 'rois': 0.0, 'roiw': 0.0, 'weight_power': 2.0, 'wavemin': None, 'wavemax': None, 'single': False, 'skip_dqflagging': True}
# 2022-12-08 17:59:02,552 - stpipe.Spec2Pipeline.cube_build - INFO - Starting IFU Cube Building Step
# 2022-12-08 17:59:02,552 - stpipe.Spec2Pipeline.cube_build - INFO - Input interpolation: drizzle
# 2022-12-08 17:59:02,552 - stpipe.Spec2Pipeline.cube_build - INFO - Coordinate system to use: skyalign
# 2022-12-08 17:59:02,577 - stpipe.Spec2Pipeline.cube_build - INFO - Reading cube parameter file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_cubepar_0003.fits
# 2022-12-08 17:59:02,618 - stpipe.Spec2Pipeline.cube_build - INFO - Output IFUcube are constructed from all the data
# 2022-12-08 17:59:02,619 - stpipe.Spec2Pipeline.cube_build - INFO - Number of IFU cubes produced by this run = 1
# 2022-12-08 17:59:02,622 - stpipe.Spec2Pipeline.cube_build - INFO - Increasing spatial region of interest default value set for 4 dithers nan
# 2022-12-08 17:59:02,624 - stpipe.Spec2Pipeline.cube_build - INFO - Cube Geometry:
# 2022-12-08 17:59:02,624 - stpipe.Spec2Pipeline.cube_build - INFO - axis#  Naxis  CRPIX    CRVAL      CDELT(arcsec)  Min & Max (xi, eta arcsec)
# 2022-12-08 17:59:02,624 - stpipe.Spec2Pipeline.cube_build - INFO - Axis 1    47  24.00 -165.99403171   0.10000000  -2.35000004   2.35000004
# 2022-12-08 17:59:02,625 - stpipe.Spec2Pipeline.cube_build - INFO - Axis 2    43  22.00 -12.95911006   0.10000000  -2.15000003   2.15000003
# 2022-12-08 17:59:02,625 - stpipe.Spec2Pipeline.cube_build - INFO - axis#  Naxis  CRPIX    CRVAL      CDELT(microns)  Min & Max (microns)
# 2022-12-08 17:59:02,625 - stpipe.Spec2Pipeline.cube_build - INFO - Axis 3  1802   1.00   4.08126366   0.00066500   4.08093116   5.27926116
# 2022-12-08 17:59:02,625 - stpipe.Spec2Pipeline.cube_build - INFO - Cube covers grating, filter: g395h, f290lp
# 2022-12-08 17:59:02,626 - stpipe.Spec2Pipeline.cube_build - INFO - Output Name: stage2/jw01386013001_03104_00004_nrs2_s3d.fits
# 2022-12-08 17:59:06,162 - stpipe.Spec2Pipeline.cube_build - INFO - Mapping each NIRSpec slice to sky for input file: stage2/jw01386013001_03104_00004_nrs2_cal.fits
# 2022-12-08 18:00:19,715 - stpipe.Spec2Pipeline.cube_build - INFO - Average # of holes/wavelength plane is < 1
# 2022-12-08 18:00:19,715 - stpipe.Spec2Pipeline.cube_build - INFO - Total # of holes for IFU cube is : 0
# 2022-12-08 18:00:19,716 - stpipe.Spec2Pipeline.cube_build - INFO - Number of wavelength planes removed with no data: 17
# 2022-12-08 18:00:19,810 - stpipe.Spec2Pipeline.cube_build - INFO - Update S_REGION to POLYGON ICRS  194.005312703 -12.959693392 194.005312703 -12.958526725 194.006623878 -12.958526725 194.006623878 -12.959693392
# 2022-12-08 18:00:19,815 - stpipe.Spec2Pipeline.cube_build - INFO - Step cube_build done
# 2022-12-08 18:00:20,009 - stpipe.Spec2Pipeline - INFO - Saved model in stage2/jw01386013001_03104_00004_nrs2_s3d.fits
# 2022-12-08 18:00:20,596 - stpipe.Spec2Pipeline.extract_1d - INFO - Step extract_1d running with args (<ModelContainer>,).
# 2022-12-08 18:00:20,598 - stpipe.Spec2Pipeline.extract_1d - INFO - Step extract_1d parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': True, 'suffix': 'x1d', 'search_output_file': True, 'input_dir': '', 'smoothing_length': None, 'bkg_fit': None, 'bkg_order': None, 'bkg_sigma_clip': 3.0, 'log_increment': 50, 'subtract_background': None, 'use_source_posn': None, 'center_xy': None, 'apply_apcorr': True, 'soss_threshold': 0.01, 'soss_n_os': 2, 'soss_transform': None, 'soss_tikfac': None, 'soss_width': 40.0, 'soss_bad_pix': 'model', 'soss_modelname': None}
# 2022-12-08 18:00:20,598 - stpipe.Spec2Pipeline.extract_1d - INFO - Step skipped.
# 2022-12-08 18:00:20,600 - stpipe.Spec2Pipeline.extract_1d - INFO - Step extract_1d done
# 2022-12-08 18:00:20,601 - stpipe.Spec2Pipeline - INFO - Finished processing product stage1/jw01386013001_03104_00004_nrs2
# 2022-12-08 18:00:20,601 - stpipe.Spec2Pipeline - INFO - Ending calwebb_spec2
# 2022-12-08 18:00:20,602 - stpipe.Spec2Pipeline - INFO - Results used CRDS context: jwst_0977.pmap
# 2022-12-08 18:00:20,602 - stpipe.Spec2Pipeline - INFO - Results used CRDS context: jwst_0977.pmap
# 2022-12-08 18:00:20,602 - stpipe.Spec2Pipeline - INFO - Results used CRDS context: jwst_0977.pmap
# 2022-12-08 18:00:20,602 - stpipe.Spec2Pipeline - INFO - Results used CRDS context: jwst_0977.pmap
# 2022-12-08 18:00:22,873 - stpipe.Spec2Pipeline - INFO - Saved model in stage2/jw01386013001_03104_00001_nrs2_cal.fits
# 2022-12-08 18:00:25,539 - stpipe.Spec2Pipeline - INFO - Saved model in stage2/jw01386013001_03104_00002_nrs2_cal.fits
# 2022-12-08 18:00:28,309 - stpipe.Spec2Pipeline - INFO - Saved model in stage2/jw01386013001_03104_00003_nrs2_cal.fits
# 2022-12-08 18:00:30,994 - stpipe.Spec2Pipeline - INFO - Saved model in stage2/jw01386013001_03104_00004_nrs2_cal.fits
# 2022-12-08 18:00:30,994 - stpipe.Spec2Pipeline - INFO - Step Spec2Pipeline done
# [<IFUImageModel(2048, 2048) from jw01386013001_03104_00001_nrs2_cal.fits>,
#  <IFUImageModel(2048, 2048) from jw01386013001_03104_00002_nrs2_cal.fits>,
#  <IFUImageModel(2048, 2048) from jw01386013001_03104_00003_nrs2_cal.fits>,
#  <IFUImageModel(2048, 2048) from jw01386013001_03104_00004_nrs2_cal.fits>]

# %%
# Print out the time benchmark
time1 = time.perf_counter()
print(f"Runtime so far: {time1 - time0:0.4f} seconds")
# Out:
# Runtime so far: 2157.5942 seconds

# %%
### Calling in the calibrated detector images produced by running the stage 2 pipeline on the modified NRS fits files
cal_files = glob.glob('stage2/*cal.fits')
print(cal_files)
# Out:
# ['stage2/jw01386013001_03104_00003_nrs2_cal.fits', 'stage2/jw01386013001_03104_00004_nrs2_cal.fits', 'stage2/jw01386013001_03104_00001_nrs2_cal.fits', 'stage2/jw01386013001_03104_00002_nrs2_cal.fits']

# %%
## create association file for dithered data. Make a json file for the dither set.
call(["asn_from_list", "-o","l3_asn.json"] + cal_files + ["--product-name", "dither"])
# Out:
# 0

# %%
# Start a timer to keep track of runtime
time0 = time.perf_counter()

# %%
# This initial setup is just to make sure that we get the latest parameter reference files
# pulled in for our files.  This is a temporary workaround to get around an issue with
# how this pipeline calling method works.
#
# Setting up steps and running the Spec3 portion of the pipeline. Outlier detector is skipped
# because it tends to cut high value pixels even if it is a part of the target.

json_file = 'l3_asn.json'
crds_config = Spec3Pipeline.get_config_from_reference(json_file)# The exact asn file used doesn't matter
spec3 = Spec3Pipeline.from_config_section(crds_config)
spec3.output_dir = spec3_dir
spec3.assign_mtwcs.skip = True               #skipped because VHS 1256b is not a moving target
spec3.master_background.skip = False
spec3.outlier_detection.skip = True
spec3.cube_build.skip = False
spec3.cube_build.coord_system = 'skyalign'   
spec3.cube_build.output_type = 'band'        # is the default mode for calspec3 and creates IFU cubes containing only one band (channel/sub-channel for MIRI or grating/filter combination for NIRSpec).

#used on MRS or other modes
spec3.mrs_imatch.skip = True
spec3.resample_spec.skip = False
spec3.combine_1d.skip = True

#save results
spec3.save_results = True
spec3(json_file)
# Out:
# 2022-12-08 18:00:35,865 - stpipe.Spec3Pipeline - INFO - Spec3Pipeline instance created.
# 2022-12-08 18:00:35,866 - stpipe.Spec3Pipeline.assign_mtwcs - INFO - AssignMTWcsStep instance created.
# 2022-12-08 18:00:35,866 - stpipe.Spec3Pipeline.master_background - INFO - MasterBackgroundStep instance created.
# 2022-12-08 18:00:35,867 - stpipe.Spec3Pipeline.mrs_imatch - INFO - MRSIMatchStep instance created.
# 2022-12-08 18:00:35,868 - stpipe.Spec3Pipeline.outlier_detection - INFO - OutlierDetectionStep instance created.
# 2022-12-08 18:00:35,870 - stpipe.Spec3Pipeline.resample_spec - INFO - ResampleSpecStep instance created.
# 2022-12-08 18:00:35,871 - stpipe.Spec3Pipeline.cube_build - INFO - CubeBuildStep instance created.
# 2022-12-08 18:00:35,872 - stpipe.Spec3Pipeline.extract_1d - INFO - Extract1dStep instance created.
# 2022-12-08 18:00:35,873 - stpipe.Spec3Pipeline.photom - INFO - PhotomStep instance created.
# 2022-12-08 18:00:35,874 - stpipe.Spec3Pipeline.combine_1d - INFO - Combine1dStep instance created.
# 2022-12-08 18:00:36,353 - stpipe.Spec3Pipeline - INFO - Step Spec3Pipeline running with args ('l3_asn.json',).
# 2022-12-08 18:00:36,359 - stpipe.Spec3Pipeline - INFO - Step Spec3Pipeline parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': 'stage3/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'steps': {'assign_mtwcs': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': 'assign_mtwcs', 'search_output_file': True, 'input_dir': ''}, 'master_background': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'user_background': None, 'save_background': False, 'force_subtract': False}, 'mrs_imatch': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'bkg_degree': 1, 'subtract': False}, 'outlier_detection': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': False, 'input_dir': '', 'weight_type': 'ivm', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'nlow': 0, 'nhigh': 0, 'maskpt': 0.7, 'grow': 1, 'snr': '5.0 4.0', 'scale': '1.2 0.7', 'backg': 0.0, 'save_intermediate_results': False, 'resample_data': True, 'good_bits': '~DO_NOT_USE', 'scale_detection': False, 'allowed_memory': None, 'in_memory': False}, 'resample_spec': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'weight_type': 'ivm', 'output_shape': None, 'crpix': None, 'crval': None, 'rotation': None, 'pixel_scale_ratio': 1.0, 'pixel_scale': None, 'single': False, 'blendheaders': True, 'allowed_memory': None, 'in_memory': True}, 'cube_build': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': False, 'input_dir': '', 'channel': 'all', 'band': 'all', 'grating': 'all', 'filter': 'all', 'output_type': 'band', 'scale1': 0.0, 'scale2': 0.0, 'scalew': 0.0, 'weighting': 'drizzle', 'coord_system': 'skyalign', 'rois': 0.0, 'roiw': 0.0, 'weight_power': 2.0, 'wavemin': None, 'wavemax': None, 'single': False, 'skip_dqflagging': False}, 'extract_1d': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'smoothing_length': None, 'bkg_fit': None, 'bkg_order': None, 'bkg_sigma_clip': 3.0, 'log_increment': 50, 'subtract_background': None, 'use_source_posn': None, 'center_xy': None, 'apply_apcorr': True, 'soss_threshold': 0.01, 'soss_n_os': 2, 'soss_transform': None, 'soss_tikfac': None, 'soss_width': 40.0, 'soss_bad_pix': 'model', 'soss_modelname': None}, 'photom': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'inverse': False, 'source_type': None}, 'combine_1d': {'pre_hooks': [], 'post_hooks': [], 'outp ...
# 2022-12-08 18:00:39,052 - stpipe.Spec3Pipeline - INFO - Prefetching reference files for dataset: 'jw01386013001_03104_00003_nrs2_cal.fits' reftypes = ['apcorr', 'area', 'cubepar', 'drizpars', 'extract1d', 'photom', 'speckernel', 'specprofile', 'spectrace', 'wavemap']
# 2022-12-08 18:00:39,055 - stpipe.Spec3Pipeline - INFO - Prefetch for APCORR reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_apcorr_0005.asdf'.
# 2022-12-08 18:00:39,055 - stpipe.Spec3Pipeline - INFO - Prefetch for AREA reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_area_0009.fits'.
# 2022-12-08 18:00:39,056 - stpipe.Spec3Pipeline - INFO - Prefetch for CUBEPAR reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_cubepar_0003.fits'.
# 2022-12-08 18:00:39,056 - stpipe.Spec3Pipeline - INFO - Prefetch for DRIZPARS reference file is 'N/A'.
# 2022-12-08 18:00:39,056 - stpipe.Spec3Pipeline - INFO - Prefetch for EXTRACT1D reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_extract1d_0001.asdf'.
# 2022-12-08 18:00:39,057 - stpipe.Spec3Pipeline - INFO - Prefetch for PHOTOM reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_photom_0016.fits'.
# 2022-12-08 18:00:39,058 - stpipe.Spec3Pipeline - INFO - Prefetch for SPECKERNEL reference file is 'N/A'.
# 2022-12-08 18:00:39,058 - stpipe.Spec3Pipeline - INFO - Prefetch for SPECPROFILE reference file is 'N/A'.
# 2022-12-08 18:00:39,058 - stpipe.Spec3Pipeline - INFO - Prefetch for SPECTRACE reference file is 'N/A'.
# 2022-12-08 18:00:39,059 - stpipe.Spec3Pipeline - INFO - Prefetch for WAVEMAP reference file is 'N/A'.
# 2022-12-08 18:00:39,059 - stpipe.Spec3Pipeline - INFO - Starting calwebb_spec3 ...
# 2022-12-08 18:00:52,561 - stpipe.Spec3Pipeline.outlier_detection - INFO - Step outlier_detection running with args (<ModelContainer>,).
# 2022-12-08 18:00:52,562 - stpipe.Spec3Pipeline.outlier_detection - INFO - Step outlier_detection parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': True, 'suffix': 'crf', 'search_output_file': False, 'input_dir': '', 'weight_type': 'ivm', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'nlow': 0, 'nhigh': 0, 'maskpt': 0.7, 'grow': 1, 'snr': '5.0 4.0', 'scale': '1.2 0.7', 'backg': 0.0, 'save_intermediate_results': False, 'resample_data': True, 'good_bits': '~DO_NOT_USE', 'scale_detection': False, 'allowed_memory': None, 'in_memory': False}
# 2022-12-08 18:00:52,562 - stpipe.Spec3Pipeline.outlier_detection - INFO - Step skipped.
# 2022-12-08 18:00:52,570 - stpipe.Spec3Pipeline.outlier_detection - INFO - Step outlier_detection done
# 2022-12-08 18:00:53,177 - stpipe.Spec3Pipeline.cube_build - INFO - Step cube_build running with args (<ModelContainer>,).
# 2022-12-08 18:00:53,179 - stpipe.Spec3Pipeline.cube_build - INFO - Step cube_build parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': 's3d', 'search_output_file': False, 'input_dir': '', 'channel': 'all', 'band': 'all', 'grating': 'all', 'filter': 'all', 'output_type': 'band', 'scale1': 0.0, 'scale2': 0.0, 'scalew': 0.0, 'weighting': 'drizzle', 'coord_system': 'skyalign', 'rois': 0.0, 'roiw': 0.0, 'weight_power': 2.0, 'wavemin': None, 'wavemax': None, 'single': False, 'skip_dqflagging': False}
# 2022-12-08 18:00:53,179 - stpipe.Spec3Pipeline.cube_build - INFO - Starting IFU Cube Building Step
# 2022-12-08 18:00:53,179 - stpipe.Spec3Pipeline.cube_build - INFO - Input interpolation: drizzle
# 2022-12-08 18:00:53,180 - stpipe.Spec3Pipeline.cube_build - INFO - Coordinate system to use: skyalign
# 2022-12-08 18:00:53,226 - stpipe.Spec3Pipeline.cube_build - INFO - Reading cube parameter file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_cubepar_0003.fits
# 2022-12-08 18:00:53,267 - stpipe.Spec3Pipeline.cube_build - INFO - Output Cubes are single grating, single filter IFU Cubes
# 2022-12-08 18:00:53,268 - stpipe.Spec3Pipeline.cube_build - INFO - Number of IFU cubes produced by this run = 1
# 2022-12-08 18:00:53,273 - stpipe.Spec3Pipeline.cube_build - INFO - Cube Geometry:
# 2022-12-08 18:00:53,273 - stpipe.Spec3Pipeline.cube_build - INFO - axis#  Naxis  CRPIX    CRVAL      CDELT(arcsec)  Min & Max (xi, eta arcsec)
# 2022-12-08 18:00:53,274 - stpipe.Spec3Pipeline.cube_build - INFO - Axis 1    69  35.00 -165.99433436   0.10000000  -3.45000005   3.45000005
# 2022-12-08 18:00:53,274 - stpipe.Spec3Pipeline.cube_build - INFO - Axis 2    65  33.00 -12.95900218   0.10000000  -3.25000005   3.25000005
# 2022-12-08 18:00:53,274 - stpipe.Spec3Pipeline.cube_build - INFO - axis#  Naxis  CRPIX    CRVAL      CDELT(microns)  Min & Max (microns)
# 2022-12-08 18:00:53,274 - stpipe.Spec3Pipeline.cube_build - INFO - Axis 3  1802   1.00   4.08126366   0.00066500   4.08093116   5.27926116
# 2022-12-08 18:00:53,275 - stpipe.Spec3Pipeline.cube_build - INFO - Cube covers grating, filter: g395h, f290lp
# 2022-12-08 18:00:53,275 - stpipe.Spec3Pipeline.cube_build - INFO - Output Name: dither_g395h-f290lp_s3d.fits
# 2022-12-08 18:00:56,311 - stpipe.Spec3Pipeline.cube_build - INFO - Mapping each NIRSpec slice to sky for input file: jw01386013001_03104_00003_nrs2_cal.fits
# 2022-12-08 18:02:13,534 - stpipe.Spec3Pipeline.cube_build - INFO - Mapping each NIRSpec slice to sky for input file: jw01386013001_03104_00004_nrs2_cal.fits
# 2022-12-08 18:03:30,344 - stpipe.Spec3Pipeline.cube_build - INFO - Mapping each NIRSpec slice to sky for input file: jw01386013001_03104_00001_nrs2_cal.fits
# 2022-12-08 18:04:46,119 - stpipe.Spec3Pipeline.cube_build - INFO - Mapping each NIRSpec slice to sky for input file: jw01386013001_03104_00002_nrs2_cal.fits
# 2022-12-08 18:06:01,326 - stpipe.Spec3Pipeline.cube_build - INFO - Average # of holes/wavelength plane: 13
# 2022-12-08 18:06:01,327 - stpipe.Spec3Pipeline.cube_build - INFO - Total # of holes for IFU cube is : 24488
# 2022-12-08 18:06:01,330 - stpipe.Spec3Pipeline.cube_build - INFO - Number of wavelength planes removed with no data: 17
# 2022-12-08 18:06:05,292 - stpipe.Spec3Pipeline.cube_build - INFO - Update S_REGION to POLYGON ICRS  194.004696512 -12.959891065 194.004696512 -12.958113287 194.006634774 -12.958113287 194.006634774 -12.959891065
# 2022-12-08 18:06:05,905 - stpipe.Spec3Pipeline.cube_build - INFO - Saved model in stage3/dither_g395h-f290lp_s3d.fits
# 2022-12-08 18:06:05,906 - stpipe.Spec3Pipeline.cube_build - INFO - Step cube_build done
# 2022-12-08 18:06:06,590 - stpipe.Spec3Pipeline.extract_1d - INFO - Step extract_1d running with args (<ModelContainer>,).
# 2022-12-08 18:06:06,591 - stpipe.Spec3Pipeline.extract_1d - INFO - Step extract_1d parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': 'x1d', 'search_output_file': False, 'input_dir': '', 'smoothing_length': None, 'bkg_fit': None, 'bkg_order': None, 'bkg_sigma_clip': 3.0, 'log_increment': 50, 'subtract_background': None, 'use_source_posn': None, 'center_xy': None, 'apply_apcorr': True, 'soss_threshold': 0.01, 'soss_n_os': 2, 'soss_transform': None, 'soss_tikfac': None, 'soss_width': 40.0, 'soss_bad_pix': 'model', 'soss_modelname': None}
# 2022-12-08 18:06:06,605 - stpipe.Spec3Pipeline.extract_1d - INFO - Using EXTRACT1D reference file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_extract1d_0001.asdf
# 2022-12-08 18:06:06,615 - stpipe.Spec3Pipeline.extract_1d - INFO - Using APCORR file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_apcorr_0005.asdf
# 2022-12-08 18:06:07,507 - stpipe.Spec3Pipeline.extract_1d - INFO - Turning on source position correction for exp_type = NRS_IFU
# 2022-12-08 18:06:07,507 - stpipe.Spec3Pipeline.extract_1d - INFO - Source type = POINT
# 2022-12-08 18:06:07,520 - stpipe.Spec3Pipeline.extract_1d - INFO - Input model does not break out variance information. Passing only generalized errors.
# 2022-12-08 18:06:07,534 - stpipe.Spec3Pipeline.extract_1d - INFO - Using x_center = 1, y_center = 53, based on TARG_RA and TARG_DEC
# 2022-12-08 18:06:16,475 - stpipe.Spec3Pipeline.extract_1d - INFO - Applying Aperture correction.
# 2022-12-08 18:06:17,442 - stpipe.Spec3Pipeline.extract_1d - INFO - Saved model in stage3/dither_g395h-f290lp_x1d.fits
# 2022-12-08 18:06:17,442 - stpipe.Spec3Pipeline.extract_1d - INFO - Step extract_1d done
# 2022-12-08 18:06:17,444 - stpipe.Spec3Pipeline - INFO - Ending calwebb_spec3
# 2022-12-08 18:06:17,444 - stpipe.Spec3Pipeline - INFO - Step Spec3Pipeline done

# %%
# Print out the time benchmark
time1 = time.perf_counter()
print(f"Runtime so far: {time1 - time0:0.4f} seconds")
# Out:
# Runtime so far: 344.9649 seconds

# %%
# check the extracted spectrum from the JWST pipeline
data = fits.getdata('stage3/dither_g395h-f290lp_x1d.fits')
wavelength = data['wavelength']
flux  = data['flux']
flux_error = data['flux_error']

# %matplotlib notebook
plt.plot(wavelength, flux, label = 'stage 3')
#plt.ylim([0,8])
plt.ylabel('Jy')
plt.xlabel('Wavelength (microns)')
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
cube_data = fits.getdata('stage3/dither_g395h-f290lp_s3d.fits')
cube=SpectralCube.read('stage3/dither_g395h-f290lp_s3d.fits',hdu=1)

wavelength=cube.spectral_axis
wavelength=n.array(wavelength)

cube_collapse = n.nanmedian(cube_data, axis = 0)
cube_collapse /= n.nanmax(cube_collapse) #the image is normalized so the 2-D Gaussian fit is easier.

# %%
# %matplotlib notebook
plt.figure('collapsed cube')
plt.title('Median Collapsed Spectral Cube')
plt.imshow((cube_collapse))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
## fitting a gaussian to the collapsed cube which is a median image to remove high pixels
image = cube_collapse
y_len, x_len = image.shape
bounds = ((0, 0, n.nanmin(image), 1, 1, n.nanmedian(image)) , (x_len, y_len, n.nanmax(image), x_len, y_len, 2 * n.nanmax(image)) )
guess = n.array([35, 33, n.nanmin(image), 1.2, 1.2, n.nanmax(image)])
fit_arr = optimize.least_squares(image_solve, guess, args = (image,), bounds = bounds )#, bounds=bounds)
x0_fit, y0_fit, offset_fit, sigma_x_fit, sigma_y_fit, A_fit = fit_arr.x


x0_fit = n.round(x0_fit, decimals = 0) #rounding because jwst pipeline does not take float values
y0_fit = n.round(y0_fit, decimals = 0) #rounding because jwst pipeline does not take float values


print('centroids (x, y)')
print(x0_fit, y0_fit)
print('sigmax, sigma y')
print(sigma_x_fit, sigma_y_fit)
# Out:
# centroids (x, y)
# 35.0 33.0
# sigmax, sigma y
# 1.0152755883698301 1.002831703640778

# %%
#re-running the jwst pipeline extraction step to ensure the extraction radius is centered.
spec3.extract_1d.center_xy = (int(x0_fit), int(y0_fit))
spec3.extract_1d('stage3/dither_g395h-f290lp_s3d.fits')
# Out:
# 2022-12-09 11:57:29,563 - stpipe.Spec3Pipeline.extract_1d - INFO - Step extract_1d running with args ('stage3/dither_g395h-f290lp_s3d.fits',).
# 2022-12-09 11:57:29,565 - stpipe.Spec3Pipeline.extract_1d - INFO - Step extract_1d parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': 'x1d', 'search_output_file': False, 'input_dir': '', 'smoothing_length': None, 'bkg_fit': None, 'bkg_order': None, 'bkg_sigma_clip': 3.0, 'log_increment': 50, 'subtract_background': None, 'use_source_posn': None, 'center_xy': [35, 33], 'apply_apcorr': True, 'soss_threshold': 0.01, 'soss_n_os': 2, 'soss_transform': None, 'soss_tikfac': None, 'soss_width': 40.0, 'soss_bad_pix': 'model', 'soss_modelname': None}
# 2022-12-09 11:57:29,875 - stpipe.Spec3Pipeline.extract_1d - INFO - Using EXTRACT1D reference file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_extract1d_0001.asdf
# 2022-12-09 11:57:29,886 - stpipe.Spec3Pipeline.extract_1d - INFO - Using APCORR file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_apcorr_0005.asdf
# 2022-12-09 11:57:30,842 - stpipe.Spec3Pipeline.extract_1d - INFO - Turning on source position correction for exp_type = NRS_IFU
# 2022-12-09 11:57:30,843 - stpipe.Spec3Pipeline.extract_1d - INFO - Source type = POINT
# 2022-12-09 11:57:30,858 - stpipe.Spec3Pipeline.extract_1d - INFO - Using user-supplied x_center=35, y_center=33
# 2022-12-09 11:57:30,858 - stpipe.Spec3Pipeline.extract_1d - INFO - Input model does not break out variance information. Passing only generalized errors.
# 2022-12-09 11:57:41,003 - stpipe.Spec3Pipeline.extract_1d - INFO - Applying Aperture correction.
# 2022-12-09 11:57:42,046 - stpipe.Spec3Pipeline.extract_1d - INFO - Saved model in stage3/dither_g395h-f290lp_x1d.fits
# 2022-12-09 11:57:42,046 - stpipe.Spec3Pipeline.extract_1d - INFO - Step extract_1d done
# <MultiSpecModel from dither_g395h-f290lp_x1d.fits>

# %%
# check the extracted spectrum from the JWST pipeline
data = fits.getdata('stage3/dither_g395h-f290lp_x1d.fits')
wavelength = data['wavelength']
flux  = data['flux']
flux_error = data['flux_error']

# %matplotlib notebook
plt.plot(wavelength, flux, label = 'stage 3')
plt.ylim([0,.004])
plt.ylabel('Jy')
plt.xlabel('Wavelength (microns)')
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
##save text
#data_out = n.vstack((wavelength,  flux , flux_error))
#data_out = n.transpose(data_out)
#
#spectra_dir = '../spectra/' # Detector1 pipeline outputs will go here
#if not os.path.exists(spectra_dir):
#    os.makedirs(spectra_dir)
#
#header = 'wavelength (microns) flux(Jy), flux error(Jy)'
#n.savetxt('../spectra/detector2_f290lp_g395h.txt', data_out, header = header)
