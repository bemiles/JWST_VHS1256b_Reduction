# %%
from scipy import interpolate
import matplotlib
import matplotlib.pyplot as plt
import numpy as n
import glob
from astropy.io import fits
from scipy.interpolate import interp1d
import pickle

# %%
m2micron = 1e6       #[microns/meters]
c = 2.99792458e8     #[m/s]

def convert_Jy_to_F_lam(wave_arr, flux_arr):
    
    #flux_arr input array in jansky
    #wave_arr input array in microns
    
    wave_arr_meters = wave_arr/m2micron        #meters
    flux_arr *= 1e-26           #[W/m^2/Hz]
    flux_arr *= c/(wave_arr_meters**2) #[W/m^2/m]
    flux_arr /= m2micron        #[W/m^2/microns] 
    
    return flux_arr

# %%
spectra_files = glob.glob('/Users/zen/projects/JWST_Observations_VHS1256b/reduction/nirspec_a_star/*/spectra/*')
spectra_files

data = n.genfromtxt(spectra_files[4])
wavelength = data[:,0]
flux = data[:,1]
flux_err = data[:,2]

# %%
data = fits.open('/Users/zen/projects/JWST_Observations_VHS1256b/reduction/nirspec_a_star/cal_data/1808347_mod_004.fits')  ##TYC 4433-1900-1 (HST number 1808347)
star_wavelength = data['SCI'].data['WAVELENGTH'] #Angstrom
star_flux = data['SCI'].data['FLUX']  # Flux(erg s-1 cm-2 Ang-1)    


star_flux = (3.34 * 1e4) * (star_wavelength**2) * star_flux #Jy'
star_wavelength = star_wavelength * 0.0001  #microns
star_flux = convert_Jy_to_F_lam(star_wavelength, star_flux)  #[W/m^2/microns]

# %%
x = np.arange(0, 2*np.pi+np.pi/4, 2*np.pi/8)
y = np.sin(x)
tck = interpolate.splrep(x, y, s=0)
xnew = np.arange(0, 2*np.pi, np.pi/50)
ynew = interpolate.splev(xnew, tck, der=0)

# %%
# %matplotlib notebook
plt.figure()
plt.plot(x, y, 'x', xnew, ynew, xnew, np.sin(xnew), x, y, 'b')
plt.legend(['Linear', 'Cubic Spline', 'True'])
plt.axis([-0.05, 6.33, -1.05, 1.05])
plt.title('Cubic-spline interpolation')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
cal_f = interpolate.splrep(wavelength, flux, s=0)
cal_fit = interpolate.splev(wavelength, spec_f, der=0)

x= n.arange(0,10)
y=n.arange(0,10)

good = n.where(n.isnan(flux) == False)

cal_coef = n.polyfit(wavelength[good], flux[good], 4)
cal_fit = n.polyval(cal_coef,wavelength)

#cal_coef = n.polyfit(x, y, deg = 3)

# %%
# %matplotlib notebook
plt.figure()
plt.plot(wavelength, flux)
plt.plot(wavelength, cal_fit)
#plt.plot(wavelength, spec_fit)
#         , xnew, ynew, xnew, np.sin(xnew), x, y, 'b')
#plt.legend(['Linear', 'Cubic Spline', 'True'])
#plt.axis([-0.05, 6.33, -1.05, 1.05])
#plt.title('Cubic-spline interpolation')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
3
