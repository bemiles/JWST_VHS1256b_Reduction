# %% [markdown]
# This notebook was made to reduce NIRSpec dithers into a spectral cube by:
#
# 1. Using the Stage 1 Detector pipleine to turn uncalibrated detector images (_uncal.fits) into rate files (_rate.fits).
#
# 2. Using Stage 2 of the Spectroscopic pipeline to turn rate files(_rate.fits) into calibrated detector images (_cal.fits) and spectral cubes (_s3d.fits)
#
# 3. Using Stage 3 of the spectroscopic pipeline to combine the stage 2 rate files from each filter/grating combination.
#
# Other notes/caveats:
# Stage 2 cube building is redundant with Stage 3 if you are not combining dithers.

# %%
from astropy.io import fits
import glob, os
from subprocess import call
from astropy.io import fits
import time

import jwst
from jwst.pipeline import Detector1Pipeline, Spec2Pipeline, Spec3Pipeline

import matplotlib.pyplot as plt
import numpy as n

from spectral_cube import SpectralCube
from scipy import optimize


os.environ['CRDS_PATH'] = '/Users/zen/crds_cache/jwst_ops'
os.environ['CRDS_SERVER_URL'] = 'https://jwst-crds.stsci.edu'
os.environ['CRDS_CONTEXT'] = 'jwst_0977.pmap'



# Print out what pipeline version we're using
print('JWST pipeline version',jwst.__version__)
# Out:
# JWST pipeline version 1.7.2

# %%
# Functions for fitting a 2-D guassian to images to find the PSF center in collapsed spectral cubes
def gauss2d(x, y, x0, y0, offset, sigma_x, sigma_y, A):

    x_exp = ( ( x - x0 )**2) / (2 * sigma_x ** 2)
    y_exp = ( ( y - y0 )**2) / (2 * sigma_y ** 2)
    f = A * n.exp( - x_exp - y_exp) + offset

    return f

def image_solve(constants, im):

    x0_val, y0_val, offset_val, sigma_x_val, sigma_y_val, A_val = constants

    y_len, x_len = im.shape
    y_arr = n.arange(0, y_len)
    x_arr = n.arange(0, x_len)
    xx, yy = n.meshgrid(x_arr, y_arr)

    fit = gauss2d(xx, yy, x0_val, y0_val, offset_val, sigma_x_val, sigma_y_val, A_val)

    min_diff = n.nansum(abs(im - fit)**2)

    return min_diff

# %%
det1_dir = 'stage1/' # Detector1 pipeline outputs will go here
spec2_dir = 'stage2/' # Spec2 pipeline outputs will go here
spec3_dir = 'stage3/' # Spec3 pipeline outputs will go here

# We need to check that the desired output directories exist, and if not create them
if not os.path.exists(det1_dir):
    os.makedirs(det1_dir)
if not os.path.exists(spec2_dir):
    os.makedirs(spec2_dir)
if not os.path.exists(spec3_dir):
    os.makedirs(spec3_dir)

# %%
uncal_file_dir = '../../../cal_data/'
uncal_files = ['jw01128009001_03104_00001_nrs1_uncal.fits',
              'jw01128009001_03104_00002_nrs1_uncal.fits',
              'jw01128009001_03104_00003_nrs1_uncal.fits',
              'jw01128009001_03104_00004_nrs1_uncal.fits']

for i, file in enumerate(uncal_files):
    uncal_files[i] = uncal_file_dir + uncal_files[i]
print(uncal_files)

print('Found ' + str(len(uncal_files)) + ' input files to process')
# Out:
# ['../../../cal_data/jw01128009001_03104_00001_nrs1_uncal.fits', '../../../cal_data/jw01128009001_03104_00002_nrs1_uncal.fits', '../../../cal_data/jw01128009001_03104_00003_nrs1_uncal.fits', '../../../cal_data/jw01128009001_03104_00004_nrs1_uncal.fits']
# Found 4 input files to process

# %%
# Start a timer to keep track of runtime
time0 = time.perf_counter()

# %%
for file in uncal_files:
    
    det1 = Detector1Pipeline() # Instantiate the pipeline

    #output directory
    det1.output_dir = det1_dir # Specify where the output should go

    #defining used pipeline steps
    det1.group_scale.skip = False  #scaling factor from group images
    det1.dq_init.skip = False      #data quality check
    det1.saturation.skip = False   #check for saturated pixels
    det1.ipc.skip = False          #interpixel capacitance scaling from a reference. Usually skipped in all instrument modes
    det1.superbias.skip = False    #subtract a bias frame from the data
    det1.refpix.skip = False       #correct for drifts in read outs using reference pixels or columns
    det1.linearity.skip = False    #used to correct for non-linearity in the frames
    det1.persistence.skip = True   #according to the docs it is supposed to be hardwired to skipped
    det1.dark_current.skip = False #
    det1.jump.skip = False         #
    det1.jump.maximum_cores = 'half' #distribute the computing load across half of your computer cores to speed it up
    det1.ramp_fit.skip = False     #
    det1.ramp_fit.maximum_cores = 'half' #distribute the computing load across half of your computer cores to speed it up
    det1.gain_scale.skip = False   #


    #skipped steps that are for MIRI
    det1.firstframe.skip = True    #
    det1.lastframe.skip = True     #
    det1.reset.skip = True         # The reset correction is a MIRI step that attempts to correct for the reset anomaly effect. Skipped
    det1.rscd.skip = True          # Performs an RSCD correction to MIRI data that is also caused by reset issues. Skipped



    #choose what results to save and from what steps
    #det1.dq_init.save_results = True # save the data quality flag information
    det1.save_results = True # Save the final resulting _rate.fits files

    det1.run(file)
# Out:
# 2022-12-08 01:16:21,805 - stpipe.Detector1Pipeline - INFO - Detector1Pipeline instance created.
# 2022-12-08 01:16:21,807 - stpipe.Detector1Pipeline.group_scale - INFO - GroupScaleStep instance created.
# 2022-12-08 01:16:21,808 - stpipe.Detector1Pipeline.dq_init - INFO - DQInitStep instance created.
# 2022-12-08 01:16:21,810 - stpipe.Detector1Pipeline.saturation - INFO - SaturationStep instance created.
# 2022-12-08 01:16:21,812 - stpipe.Detector1Pipeline.ipc - INFO - IPCStep instance created.
# 2022-12-08 01:16:21,813 - stpipe.Detector1Pipeline.superbias - INFO - SuperBiasStep instance created.
# 2022-12-08 01:16:21,814 - stpipe.Detector1Pipeline.refpix - INFO - RefPixStep instance created.
# 2022-12-08 01:16:21,816 - stpipe.Detector1Pipeline.rscd - INFO - RscdStep instance created.
# 2022-12-08 01:16:21,817 - stpipe.Detector1Pipeline.firstframe - INFO - FirstFrameStep instance created.
# 2022-12-08 01:16:21,819 - stpipe.Detector1Pipeline.lastframe - INFO - LastFrameStep instance created.
# 2022-12-08 01:16:21,820 - stpipe.Detector1Pipeline.linearity - INFO - LinearityStep instance created.
# 2022-12-08 01:16:21,821 - stpipe.Detector1Pipeline.dark_current - INFO - DarkCurrentStep instance created.
# 2022-12-08 01:16:21,823 - stpipe.Detector1Pipeline.reset - INFO - ResetStep instance created.
# 2022-12-08 01:16:21,825 - stpipe.Detector1Pipeline.persistence - INFO - PersistenceStep instance created.
# 2022-12-08 01:16:21,826 - stpipe.Detector1Pipeline.jump - INFO - JumpStep instance created.
# 2022-12-08 01:16:21,828 - stpipe.Detector1Pipeline.ramp_fit - INFO - RampFitStep instance created.
# 2022-12-08 01:16:21,829 - stpipe.Detector1Pipeline.gain_scale - INFO - GainScaleStep instance created.
# 2022-12-08 01:16:21,879 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline running with args ('../../../cal_data/jw01128009001_03104_00001_nrs1_uncal.fits',).
# 2022-12-08 01:16:21,887 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': 'stage1/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_calibrated_ramp': False, 'steps': {'group_scale': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'dq_init': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'saturation': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'n_pix_grow_sat': 1}, 'ipc': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'superbias': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'refpix': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'odd_even_columns': True, 'use_side_ref_pixels': True, 'side_smoothing_length': 11, 'side_gain': 1.0, 'odd_even_rows': True}, 'rscd': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'type': 'baseline'}, 'firstframe': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'lastframe': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'linearity': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'dark_current': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'dark_output': None}, 'reset': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'persistence': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': ...
# 2022-12-08 01:16:22,898 - stpipe.Detector1Pipeline - INFO - Prefetching reference files for dataset: 'jw01128009001_03104_00001_nrs1_uncal.fits' reftypes = ['dark', 'gain', 'ipc', 'linearity', 'mask', 'readnoise', 'refpix', 'saturation', 'superbias']
# 2022-12-08 01:16:23,114 - stpipe.Detector1Pipeline - INFO - Prefetch for DARK reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_dark_0204.fits'.
# 2022-12-08 01:16:23,114 - stpipe.Detector1Pipeline - INFO - Prefetch for GAIN reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_gain_0023.fits'.
# 2022-12-08 01:16:23,114 - stpipe.Detector1Pipeline - INFO - Prefetch for IPC reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_ipc_0011.fits'.
# 2022-12-08 01:16:23,115 - stpipe.Detector1Pipeline - INFO - Prefetch for LINEARITY reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_linearity_0022.fits'.
# 2022-12-08 01:16:23,115 - stpipe.Detector1Pipeline - INFO - Prefetch for MASK reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_mask_0030.fits'.
# 2022-12-08 01:16:23,116 - stpipe.Detector1Pipeline - INFO - Prefetch for READNOISE reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_readnoise_0018.fits'.
# 2022-12-08 01:16:23,116 - stpipe.Detector1Pipeline - INFO - Prefetch for REFPIX reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_refpix_0019.fits'.
# 2022-12-08 01:16:23,116 - stpipe.Detector1Pipeline - INFO - Prefetch for SATURATION reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_saturation_0027.fits'.
# 2022-12-08 01:16:23,117 - stpipe.Detector1Pipeline - INFO - Prefetch for SUPERBIAS reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_superbias_0254.fits'.
# 2022-12-08 01:16:23,117 - stpipe.Detector1Pipeline - INFO - Starting calwebb_detector1 ...
# 2022-12-08 01:16:23,547 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale running with args (<RampModel(1, 10, 3200, 2048) from jw01128009001_03104_00001_nrs1_uncal.fits>,).
# 2022-12-08 01:16:23,548 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../cal_data'}
# 2022-12-08 01:16:23,750 - stpipe.Detector1Pipeline.group_scale - INFO - NFRAMES and FRMDIVSR are equal; correction not needed
# 2022-12-08 01:16:23,751 - stpipe.Detector1Pipeline.group_scale - INFO - Step will be skipped
# 2022-12-08 01:16:23,753 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale done
# 2022-12-08 01:16:23,838 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init running with args (<RampModel(1, 10, 3200, 2048) from jw01128009001_03104_00001_nrs1_uncal.fits>,).
# 2022-12-08 01:16:23,839 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../cal_data'}
# 2022-12-08 01:16:23,859 - stpipe.Detector1Pipeline.dq_init - INFO - Using MASK reference file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_mask_0030.fits
# 2022-12-08 01:16:24,240 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init done
# 2022-12-08 01:16:24,322 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation running with args (<RampModel(1, 10, 3200, 2048) from jw01128009001_03104_00001_nrs1_uncal.fits>,).
# 2022-12-08 01:16:24,323 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../cal_data', 'n_pix_grow_sat': 1}
# 2022-12-08 01:16:24,343 - stpipe.Detector1Pipeline.saturation - INFO - Using SATURATION reference file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_saturation_0027.fits
# 2022-12-08 01:16:25,410 - stpipe.Detector1Pipeline.saturation - INFO - Detected 53014 saturated pixels
# 2022-12-08 01:16:25,423 - stpipe.Detector1Pipeline.saturation - INFO - Detected 0 A/D floor pixels
# 2022-12-08 01:16:25,436 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation done
# 2022-12-08 01:16:25,518 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc running with args (<RampModel(1, 10, 3200, 2048) from jw01128009001_03104_00001_nrs1_uncal.fits>,).
# 2022-12-08 01:16:25,519 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../cal_data'}
# 2022-12-08 01:16:25,538 - stpipe.Detector1Pipeline.ipc - INFO - Using IPC reference file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_ipc_0011.fits
# 2022-12-08 01:16:26,056 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc done
# 2022-12-08 01:16:26,133 - stpipe.Detector1Pipeline.superbias - INFO - Step superbias running with args (<RampModel(1, 10, 3200, 2048) from jw01128009001_03104_00001_nrs1_uncal.fits>,).
# 2022-12-08 01:16:26,134 - stpipe.Detector1Pipeline.superbias - INFO - Step superbias parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../cal_data'}
# 2022-12-08 01:16:26,156 - stpipe.Detector1Pipeline.superbias - INFO - Using SUPERBIAS reference file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_superbias_0254.fits
# 2022-12-08 01:16:26,438 - stpipe.Detector1Pipeline.superbias - INFO - Step superbias done
# 2022-12-08 01:16:26,517 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix running with args (<RampModel(1, 10, 3200, 2048) from jw01128009001_03104_00001_nrs1_uncal.fits>,).
# 2022-12-08 01:16:26,518 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../cal_data', 'odd_even_columns': True, 'use_side_ref_pixels': True, 'side_smoothing_length': 11, 'side_gain': 1.0, 'odd_even_rows': True}
# 2022-12-08 01:16:26,540 - stpipe.Detector1Pipeline.refpix - INFO - Using refpix reference file: /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_refpix_0019.fits
# 2022-12-08 01:16:26,722 - stpipe.Detector1Pipeline.refpix - INFO - Working on integration 1
# 2022-12-08 01:16:45,805 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix done
# 2022-12-08 01:16:45,913 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity running with args (<RampModel(1, 10, 3200, 2048) from jw01128009001_03104_00001_nrs1_uncal.fits>,).
# 2022-12-08 01:16:45,914 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../cal_data'}
# 2022-12-08 01:16:45,933 - stpipe.Detector1Pipeline.linearity - INFO - Using Linearity reference file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_linearity_0022.fits
# 2022-12-08 01:16:46,018 - stpipe.Detector1Pipeline.linearity - WARNING - Keyword BAD_LIN_CORR does not correspond to an existing DQ mnemonic, so will be ignored
# 2022-12-08 01:16:46,401 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity done
# 2022-12-08 01:16:46,496 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current running with args (<RampModel(1, 10, 3200, 2048) from jw01128009001_03104_00001_nrs1_uncal.fits>,).
# 2022-12-08 01:16:46,497 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': 'stage1/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../cal_data', 'dark_output': None}
# 2022-12-08 01:16:46,625 - stpipe.Detector1Pipeline.dark_current - INFO - Using DARK reference file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_dark_0204.fits
# 2022-12-08 01:16:50,949 - stpipe.Detector1Pipeline.dark_current - INFO - Science data nints=1, ngroups=10, nframes=1, groupgap=0
# 2022-12-08 01:16:50,950 - stpipe.Detector1Pipeline.dark_current - INFO - Dark data nints=1, ngroups=245, nframes=1, groupgap=0
# 2022-12-08 01:16:53,716 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current done
# 2022-12-08 01:16:54,223 - stpipe.Detector1Pipeline.jump - INFO - Step jump running with args (<RampModel(1, 10, 3200, 2048) from jw01128009001_03104_00001_nrs1_uncal.fits>,).
# 2022-12-08 01:16:54,224 - stpipe.Detector1Pipeline.jump - INFO - Step jump parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../cal_data', 'rejection_threshold': 4.0, 'three_group_rejection_threshold': 6.0, 'four_group_rejection_threshold': 5.0, 'maximum_cores': 'half', 'flag_4_neighbors': True, 'max_jump_to_flag_neighbors': 1000.0, 'min_jump_to_flag_neighbors': 10.0, 'after_jump_flag_dn1': 0.0, 'after_jump_flag_time1': 0.0, 'after_jump_flag_dn2': 0.0, 'after_jump_flag_time2': 0.0}
# 2022-12-08 01:16:54,295 - stpipe.Detector1Pipeline.jump - INFO - CR rejection threshold = 4 sigma
# 2022-12-08 01:16:54,296 - stpipe.Detector1Pipeline.jump - INFO - Maximum cores to use = half
# 2022-12-08 01:16:54,368 - stpipe.Detector1Pipeline.jump - INFO - Using GAIN reference file: /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_gain_0023.fits
# 2022-12-08 01:16:54,464 - stpipe.Detector1Pipeline.jump - INFO - Using READNOISE reference file: /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_readnoise_0018.fits
# 2022-12-08 01:16:54,742 - stpipe.Detector1Pipeline.jump - INFO - Executing two-point difference method
# 2022-12-08 01:16:54,797 - stpipe.Detector1Pipeline.jump - INFO - Creating 5 processes for jump detection
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/jump/twopoint_difference.py:154: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/jump/twopoint_difference.py:154: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/jump/twopoint_difference.py:154: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/jump/twopoint_difference.py:154: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/jump/twopoint_difference.py:154: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
# 2022-12-08 01:16:59,505 - stpipe.Detector1Pipeline.jump - INFO - Total elapsed time = 4.76186 sec
# 2022-12-08 01:16:59,516 - stpipe.Detector1Pipeline.jump - INFO - The execution time in seconds: 5.221298
# 2022-12-08 01:16:59,521 - stpipe.Detector1Pipeline.jump - INFO - Step jump done
# 2022-12-08 01:16:59,648 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit running with args (<RampModel(1, 10, 3200, 2048) from jw01128009001_03104_00001_nrs1_uncal.fits>,).
# 2022-12-08 01:16:59,649 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': 'stage1/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../cal_data', 'int_name': '', 'save_opt': False, 'opt_name': '', 'suppress_one_group': True, 'maximum_cores': 'half'}
# 2022-12-08 01:16:59,817 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using READNOISE reference file: /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_readnoise_0018.fits
# 2022-12-08 01:16:59,818 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using GAIN reference file: /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_gain_0023.fits
# 2022-12-08 01:16:59,905 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using algorithm = ols
# 2022-12-08 01:16:59,906 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using weighting = optimal
# 2022-12-08 01:17:00,105 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of processors used for multiprocessing: 5
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/ramp_fitting/ols_fit.py:1089: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/ramp_fitting/ols_fit.py:1089: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/ramp_fitting/ols_fit.py:1089: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/ramp_fitting/ols_fit.py:1089: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/ramp_fitting/ols_fit.py:1089: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# 2022-12-08 01:17:10,860 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit done
# 2022-12-08 01:17:10,974 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<IFUImageModel(2048, 2048) from jw01128009001_03104_00001_nrs1_uncal.fits>,).
# 2022-12-08 01:17:10,975 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'gain_scale', 'search_output_file': True, 'input_dir': '../../../cal_data'}
# 2022-12-08 01:17:11,033 - stpipe.Detector1Pipeline.gain_scale - INFO - Rescaling by 1.0
# 2022-12-08 01:17:11,048 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# 2022-12-08 01:17:11,104 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<CubeModel(1, 2048, 2048) from jw01128009001_03104_00001_nrs1_uncal.fits>,).
# 2022-12-08 01:17:11,105 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'gain_scaleints', 'search_output_file': True, 'input_dir': '../../../cal_data'}
# 2022-12-08 01:17:11,139 - stpipe.Detector1Pipeline.gain_scale - INFO - Rescaling by 1.0
# 2022-12-08 01:17:11,149 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# 2022-12-08 01:17:11,380 - stpipe.Detector1Pipeline - INFO - Saved model in stage1/jw01128009001_03104_00001_nrs1_rateints.fits
# 2022-12-08 01:17:11,381 - stpipe.Detector1Pipeline - INFO - ... ending calwebb_detector1
# 2022-12-08 01:17:11,381 - stpipe.Detector1Pipeline - INFO - Results used CRDS context: jwst_0977.pmap
# 2022-12-08 01:17:11,581 - stpipe.Detector1Pipeline - INFO - Saved model in stage1/jw01128009001_03104_00001_nrs1_rate.fits
# 2022-12-08 01:17:11,582 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline done
# 2022-12-08 01:17:11,588 - stpipe.Detector1Pipeline - INFO - Detector1Pipeline instance created.
# 2022-12-08 01:17:11,589 - stpipe.Detector1Pipeline.group_scale - INFO - GroupScaleStep instance created.
# 2022-12-08 01:17:11,590 - stpipe.Detector1Pipeline.dq_init - INFO - DQInitStep instance created.
# 2022-12-08 01:17:11,591 - stpipe.Detector1Pipeline.saturation - INFO - SaturationStep instance created.
# 2022-12-08 01:17:11,592 - stpipe.Detector1Pipeline.ipc - INFO - IPCStep instance created.
# 2022-12-08 01:17:11,593 - stpipe.Detector1Pipeline.superbias - INFO - SuperBiasStep instance created.
# 2022-12-08 01:17:11,595 - stpipe.Detector1Pipeline.refpix - INFO - RefPixStep instance created.
# 2022-12-08 01:17:11,596 - stpipe.Detector1Pipeline.rscd - INFO - RscdStep instance created.
# 2022-12-08 01:17:11,597 - stpipe.Detector1Pipeline.firstframe - INFO - FirstFrameStep instance created.
# 2022-12-08 01:17:11,598 - stpipe.Detector1Pipeline.lastframe - INFO - LastFrameStep instance created.
# 2022-12-08 01:17:11,599 - stpipe.Detector1Pipeline.linearity - INFO - LinearityStep instance created.
# 2022-12-08 01:17:11,600 - stpipe.Detector1Pipeline.dark_current - INFO - DarkCurrentStep instance created.
# 2022-12-08 01:17:11,601 - stpipe.Detector1Pipeline.reset - INFO - ResetStep instance created.
# 2022-12-08 01:17:11,603 - stpipe.Detector1Pipeline.persistence - INFO - PersistenceStep instance created.
# 2022-12-08 01:17:11,604 - stpipe.Detector1Pipeline.jump - INFO - JumpStep instance created.
# 2022-12-08 01:17:11,605 - stpipe.Detector1Pipeline.ramp_fit - INFO - RampFitStep instance created.
# 2022-12-08 01:17:11,606 - stpipe.Detector1Pipeline.gain_scale - INFO - GainScaleStep instance created.
# 2022-12-08 01:17:11,670 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline running with args ('../../../cal_data/jw01128009001_03104_00002_nrs1_uncal.fits',).
# 2022-12-08 01:17:11,677 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': 'stage1/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_calibrated_ramp': False, 'steps': {'group_scale': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'dq_init': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'saturation': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'n_pix_grow_sat': 1}, 'ipc': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'superbias': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'refpix': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'odd_even_columns': True, 'use_side_ref_pixels': True, 'side_smoothing_length': 11, 'side_gain': 1.0, 'odd_even_rows': True}, 'rscd': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'type': 'baseline'}, 'firstframe': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'lastframe': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'linearity': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'dark_current': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'dark_output': None}, 'reset': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'persistence': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': ...
# 2022-12-08 01:17:11,919 - stpipe.Detector1Pipeline - INFO - Prefetching reference files for dataset: 'jw01128009001_03104_00002_nrs1_uncal.fits' reftypes = ['dark', 'gain', 'ipc', 'linearity', 'mask', 'readnoise', 'refpix', 'saturation', 'superbias']
# 2022-12-08 01:17:11,922 - stpipe.Detector1Pipeline - INFO - Prefetch for DARK reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_dark_0204.fits'.
# 2022-12-08 01:17:11,923 - stpipe.Detector1Pipeline - INFO - Prefetch for GAIN reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_gain_0023.fits'.
# 2022-12-08 01:17:11,923 - stpipe.Detector1Pipeline - INFO - Prefetch for IPC reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_ipc_0011.fits'.
# 2022-12-08 01:17:11,923 - stpipe.Detector1Pipeline - INFO - Prefetch for LINEARITY reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_linearity_0022.fits'.
# 2022-12-08 01:17:11,924 - stpipe.Detector1Pipeline - INFO - Prefetch for MASK reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_mask_0030.fits'.
# 2022-12-08 01:17:11,924 - stpipe.Detector1Pipeline - INFO - Prefetch for READNOISE reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_readnoise_0018.fits'.
# 2022-12-08 01:17:11,924 - stpipe.Detector1Pipeline - INFO - Prefetch for REFPIX reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_refpix_0019.fits'.
# 2022-12-08 01:17:11,925 - stpipe.Detector1Pipeline - INFO - Prefetch for SATURATION reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_saturation_0027.fits'.
# 2022-12-08 01:17:11,925 - stpipe.Detector1Pipeline - INFO - Prefetch for SUPERBIAS reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_superbias_0254.fits'.
# 2022-12-08 01:17:11,925 - stpipe.Detector1Pipeline - INFO - Starting calwebb_detector1 ...
# 2022-12-08 01:17:12,345 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale running with args (<RampModel(1, 10, 3200, 2048) from jw01128009001_03104_00002_nrs1_uncal.fits>,).
# 2022-12-08 01:17:12,346 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../cal_data'}
# 2022-12-08 01:17:12,530 - stpipe.Detector1Pipeline.group_scale - INFO - NFRAMES and FRMDIVSR are equal; correction not needed
# 2022-12-08 01:17:12,530 - stpipe.Detector1Pipeline.group_scale - INFO - Step will be skipped
# 2022-12-08 01:17:12,532 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale done
# 2022-12-08 01:17:12,609 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init running with args (<RampModel(1, 10, 3200, 2048) from jw01128009001_03104_00002_nrs1_uncal.fits>,).
# 2022-12-08 01:17:12,610 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../cal_data'}
# 2022-12-08 01:17:12,630 - stpipe.Detector1Pipeline.dq_init - INFO - Using MASK reference file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_mask_0030.fits
# 2022-12-08 01:17:12,963 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init done
# 2022-12-08 01:17:13,037 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation running with args (<RampModel(1, 10, 3200, 2048) from jw01128009001_03104_00002_nrs1_uncal.fits>,).
# 2022-12-08 01:17:13,038 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../cal_data', 'n_pix_grow_sat': 1}
# 2022-12-08 01:17:13,058 - stpipe.Detector1Pipeline.saturation - INFO - Using SATURATION reference file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_saturation_0027.fits
# 2022-12-08 01:17:14,077 - stpipe.Detector1Pipeline.saturation - INFO - Detected 57011 saturated pixels
# 2022-12-08 01:17:14,091 - stpipe.Detector1Pipeline.saturation - INFO - Detected 0 A/D floor pixels
# 2022-12-08 01:17:14,103 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation done
# 2022-12-08 01:17:14,188 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc running with args (<RampModel(1, 10, 3200, 2048) from jw01128009001_03104_00002_nrs1_uncal.fits>,).
# 2022-12-08 01:17:14,190 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../cal_data'}
# 2022-12-08 01:17:14,210 - stpipe.Detector1Pipeline.ipc - INFO - Using IPC reference file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_ipc_0011.fits
# 2022-12-08 01:17:14,694 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc done
# 2022-12-08 01:17:14,771 - stpipe.Detector1Pipeline.superbias - INFO - Step superbias running with args (<RampModel(1, 10, 3200, 2048) from jw01128009001_03104_00002_nrs1_uncal.fits>,).
# 2022-12-08 01:17:14,772 - stpipe.Detector1Pipeline.superbias - INFO - Step superbias parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../cal_data'}
# 2022-12-08 01:17:14,792 - stpipe.Detector1Pipeline.superbias - INFO - Using SUPERBIAS reference file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_superbias_0254.fits
# 2022-12-08 01:17:15,051 - stpipe.Detector1Pipeline.superbias - INFO - Step superbias done
# 2022-12-08 01:17:15,127 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix running with args (<RampModel(1, 10, 3200, 2048) from jw01128009001_03104_00002_nrs1_uncal.fits>,).
# 2022-12-08 01:17:15,128 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../cal_data', 'odd_even_columns': True, 'use_side_ref_pixels': True, 'side_smoothing_length': 11, 'side_gain': 1.0, 'odd_even_rows': True}
# 2022-12-08 01:17:15,149 - stpipe.Detector1Pipeline.refpix - INFO - Using refpix reference file: /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_refpix_0019.fits
# 2022-12-08 01:17:15,336 - stpipe.Detector1Pipeline.refpix - INFO - Working on integration 1
# 2022-12-08 01:17:33,684 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix done
# 2022-12-08 01:17:33,786 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity running with args (<RampModel(1, 10, 3200, 2048) from jw01128009001_03104_00002_nrs1_uncal.fits>,).
# 2022-12-08 01:17:33,787 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../cal_data'}
# 2022-12-08 01:17:33,807 - stpipe.Detector1Pipeline.linearity - INFO - Using Linearity reference file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_linearity_0022.fits
# 2022-12-08 01:17:33,888 - stpipe.Detector1Pipeline.linearity - WARNING - Keyword BAD_LIN_CORR does not correspond to an existing DQ mnemonic, so will be ignored
# 2022-12-08 01:17:34,262 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity done
# 2022-12-08 01:17:34,348 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current running with args (<RampModel(1, 10, 3200, 2048) from jw01128009001_03104_00002_nrs1_uncal.fits>,).
# 2022-12-08 01:17:34,349 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': 'stage1/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../cal_data', 'dark_output': None}
# 2022-12-08 01:17:34,472 - stpipe.Detector1Pipeline.dark_current - INFO - Using DARK reference file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_dark_0204.fits
# 2022-12-08 01:17:38,060 - stpipe.Detector1Pipeline.dark_current - INFO - Science data nints=1, ngroups=10, nframes=1, groupgap=0
# 2022-12-08 01:17:38,061 - stpipe.Detector1Pipeline.dark_current - INFO - Dark data nints=1, ngroups=245, nframes=1, groupgap=0
# 2022-12-08 01:17:41,125 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current done
# 2022-12-08 01:17:41,603 - stpipe.Detector1Pipeline.jump - INFO - Step jump running with args (<RampModel(1, 10, 3200, 2048) from jw01128009001_03104_00002_nrs1_uncal.fits>,).
# 2022-12-08 01:17:41,604 - stpipe.Detector1Pipeline.jump - INFO - Step jump parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../cal_data', 'rejection_threshold': 4.0, 'three_group_rejection_threshold': 6.0, 'four_group_rejection_threshold': 5.0, 'maximum_cores': 'half', 'flag_4_neighbors': True, 'max_jump_to_flag_neighbors': 1000.0, 'min_jump_to_flag_neighbors': 10.0, 'after_jump_flag_dn1': 0.0, 'after_jump_flag_time1': 0.0, 'after_jump_flag_dn2': 0.0, 'after_jump_flag_time2': 0.0}
# 2022-12-08 01:17:41,669 - stpipe.Detector1Pipeline.jump - INFO - CR rejection threshold = 4 sigma
# 2022-12-08 01:17:41,670 - stpipe.Detector1Pipeline.jump - INFO - Maximum cores to use = half
# 2022-12-08 01:17:41,744 - stpipe.Detector1Pipeline.jump - INFO - Using GAIN reference file: /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_gain_0023.fits
# 2022-12-08 01:17:41,839 - stpipe.Detector1Pipeline.jump - INFO - Using READNOISE reference file: /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_readnoise_0018.fits
# 2022-12-08 01:17:42,114 - stpipe.Detector1Pipeline.jump - INFO - Executing two-point difference method
# 2022-12-08 01:17:42,167 - stpipe.Detector1Pipeline.jump - INFO - Creating 5 processes for jump detection
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/jump/twopoint_difference.py:154: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/jump/twopoint_difference.py:154: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/jump/twopoint_difference.py:154: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/jump/twopoint_difference.py:154: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/jump/twopoint_difference.py:154: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
# 2022-12-08 01:17:46,654 - stpipe.Detector1Pipeline.jump - INFO - Total elapsed time = 4.53948 sec
# 2022-12-08 01:17:46,666 - stpipe.Detector1Pipeline.jump - INFO - The execution time in seconds: 4.996450
# 2022-12-08 01:17:46,671 - stpipe.Detector1Pipeline.jump - INFO - Step jump done
# 2022-12-08 01:17:46,815 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit running with args (<RampModel(1, 10, 3200, 2048) from jw01128009001_03104_00002_nrs1_uncal.fits>,).
# 2022-12-08 01:17:46,816 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': 'stage1/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../cal_data', 'int_name': '', 'save_opt': False, 'opt_name': '', 'suppress_one_group': True, 'maximum_cores': 'half'}
# 2022-12-08 01:17:46,989 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using READNOISE reference file: /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_readnoise_0018.fits
# 2022-12-08 01:17:46,990 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using GAIN reference file: /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_gain_0023.fits
# 2022-12-08 01:17:47,075 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using algorithm = ols
# 2022-12-08 01:17:47,076 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using weighting = optimal
# 2022-12-08 01:17:47,287 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of processors used for multiprocessing: 5
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/ramp_fitting/ols_fit.py:1089: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/ramp_fitting/ols_fit.py:1089: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/ramp_fitting/ols_fit.py:1089: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/ramp_fitting/ols_fit.py:1089: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/ramp_fitting/ols_fit.py:1089: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# 2022-12-08 01:17:57,575 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit done
# 2022-12-08 01:17:57,692 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<IFUImageModel(2048, 2048) from jw01128009001_03104_00002_nrs1_uncal.fits>,).
# 2022-12-08 01:17:57,693 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'gain_scale', 'search_output_file': True, 'input_dir': '../../../cal_data'}
# 2022-12-08 01:17:57,755 - stpipe.Detector1Pipeline.gain_scale - INFO - Rescaling by 1.0
# 2022-12-08 01:17:57,769 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# 2022-12-08 01:17:57,828 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<CubeModel(1, 2048, 2048) from jw01128009001_03104_00002_nrs1_uncal.fits>,).
# 2022-12-08 01:17:57,829 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'gain_scaleints', 'search_output_file': True, 'input_dir': '../../../cal_data'}
# 2022-12-08 01:17:57,866 - stpipe.Detector1Pipeline.gain_scale - INFO - Rescaling by 1.0
# 2022-12-08 01:17:57,875 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# 2022-12-08 01:17:58,075 - stpipe.Detector1Pipeline - INFO - Saved model in stage1/jw01128009001_03104_00002_nrs1_rateints.fits
# 2022-12-08 01:17:58,075 - stpipe.Detector1Pipeline - INFO - ... ending calwebb_detector1
# 2022-12-08 01:17:58,076 - stpipe.Detector1Pipeline - INFO - Results used CRDS context: jwst_0977.pmap
# 2022-12-08 01:17:58,264 - stpipe.Detector1Pipeline - INFO - Saved model in stage1/jw01128009001_03104_00002_nrs1_rate.fits
# 2022-12-08 01:17:58,264 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline done
# 2022-12-08 01:17:58,271 - stpipe.Detector1Pipeline - INFO - Detector1Pipeline instance created.
# 2022-12-08 01:17:58,272 - stpipe.Detector1Pipeline.group_scale - INFO - GroupScaleStep instance created.
# 2022-12-08 01:17:58,273 - stpipe.Detector1Pipeline.dq_init - INFO - DQInitStep instance created.
# 2022-12-08 01:17:58,274 - stpipe.Detector1Pipeline.saturation - INFO - SaturationStep instance created.
# 2022-12-08 01:17:58,274 - stpipe.Detector1Pipeline.ipc - INFO - IPCStep instance created.
# 2022-12-08 01:17:58,275 - stpipe.Detector1Pipeline.superbias - INFO - SuperBiasStep instance created.
# 2022-12-08 01:17:58,276 - stpipe.Detector1Pipeline.refpix - INFO - RefPixStep instance created.
# 2022-12-08 01:17:58,277 - stpipe.Detector1Pipeline.rscd - INFO - RscdStep instance created.
# 2022-12-08 01:17:58,278 - stpipe.Detector1Pipeline.firstframe - INFO - FirstFrameStep instance created.
# 2022-12-08 01:17:58,279 - stpipe.Detector1Pipeline.lastframe - INFO - LastFrameStep instance created.
# 2022-12-08 01:17:58,280 - stpipe.Detector1Pipeline.linearity - INFO - LinearityStep instance created.
# 2022-12-08 01:17:58,280 - stpipe.Detector1Pipeline.dark_current - INFO - DarkCurrentStep instance created.
# 2022-12-08 01:17:58,281 - stpipe.Detector1Pipeline.reset - INFO - ResetStep instance created.
# 2022-12-08 01:17:58,282 - stpipe.Detector1Pipeline.persistence - INFO - PersistenceStep instance created.
# 2022-12-08 01:17:58,283 - stpipe.Detector1Pipeline.jump - INFO - JumpStep instance created.
# 2022-12-08 01:17:58,284 - stpipe.Detector1Pipeline.ramp_fit - INFO - RampFitStep instance created.
# 2022-12-08 01:17:58,285 - stpipe.Detector1Pipeline.gain_scale - INFO - GainScaleStep instance created.
# 2022-12-08 01:17:58,353 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline running with args ('../../../cal_data/jw01128009001_03104_00003_nrs1_uncal.fits',).
# ...
# 2022-12-08 01:18:44,830 - stpipe.Detector1Pipeline - INFO - Prefetch for READNOISE reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_readnoise_0018.fits'.
# 2022-12-08 01:18:44,831 - stpipe.Detector1Pipeline - INFO - Prefetch for REFPIX reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_refpix_0019.fits'.
# 2022-12-08 01:18:44,831 - stpipe.Detector1Pipeline - INFO - Prefetch for SATURATION reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_saturation_0027.fits'.
# 2022-12-08 01:18:44,831 - stpipe.Detector1Pipeline - INFO - Prefetch for SUPERBIAS reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_superbias_0254.fits'.
# 2022-12-08 01:18:44,832 - stpipe.Detector1Pipeline - INFO - Starting calwebb_detector1 ...
# 2022-12-08 01:18:45,251 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale running with args (<RampModel(1, 10, 3200, 2048) from jw01128009001_03104_00004_nrs1_uncal.fits>,).
# 2022-12-08 01:18:45,252 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../cal_data'}
# 2022-12-08 01:18:45,435 - stpipe.Detector1Pipeline.group_scale - INFO - NFRAMES and FRMDIVSR are equal; correction not needed
# 2022-12-08 01:18:45,435 - stpipe.Detector1Pipeline.group_scale - INFO - Step will be skipped
# 2022-12-08 01:18:45,438 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale done
# 2022-12-08 01:18:45,515 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init running with args (<RampModel(1, 10, 3200, 2048) from jw01128009001_03104_00004_nrs1_uncal.fits>,).
# 2022-12-08 01:18:45,516 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../cal_data'}
# 2022-12-08 01:18:45,535 - stpipe.Detector1Pipeline.dq_init - INFO - Using MASK reference file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_mask_0030.fits
# 2022-12-08 01:18:45,876 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init done
# 2022-12-08 01:18:45,955 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation running with args (<RampModel(1, 10, 3200, 2048) from jw01128009001_03104_00004_nrs1_uncal.fits>,).
# 2022-12-08 01:18:45,956 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../cal_data', 'n_pix_grow_sat': 1}
# 2022-12-08 01:18:45,975 - stpipe.Detector1Pipeline.saturation - INFO - Using SATURATION reference file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_saturation_0027.fits
# 2022-12-08 01:18:46,996 - stpipe.Detector1Pipeline.saturation - INFO - Detected 56925 saturated pixels
# 2022-12-08 01:18:47,009 - stpipe.Detector1Pipeline.saturation - INFO - Detected 0 A/D floor pixels
# 2022-12-08 01:18:47,020 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation done
# 2022-12-08 01:18:47,111 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc running with args (<RampModel(1, 10, 3200, 2048) from jw01128009001_03104_00004_nrs1_uncal.fits>,).
# 2022-12-08 01:18:47,112 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../cal_data'}
# 2022-12-08 01:18:47,131 - stpipe.Detector1Pipeline.ipc - INFO - Using IPC reference file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_ipc_0011.fits
# 2022-12-08 01:18:47,617 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc done
# 2022-12-08 01:18:47,694 - stpipe.Detector1Pipeline.superbias - INFO - Step superbias running with args (<RampModel(1, 10, 3200, 2048) from jw01128009001_03104_00004_nrs1_uncal.fits>,).
# 2022-12-08 01:18:47,695 - stpipe.Detector1Pipeline.superbias - INFO - Step superbias parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../cal_data'}
# 2022-12-08 01:18:47,714 - stpipe.Detector1Pipeline.superbias - INFO - Using SUPERBIAS reference file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_superbias_0254.fits
# 2022-12-08 01:18:47,974 - stpipe.Detector1Pipeline.superbias - INFO - Step superbias done
# 2022-12-08 01:18:48,050 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix running with args (<RampModel(1, 10, 3200, 2048) from jw01128009001_03104_00004_nrs1_uncal.fits>,).
# 2022-12-08 01:18:48,051 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../cal_data', 'odd_even_columns': True, 'use_side_ref_pixels': True, 'side_smoothing_length': 11, 'side_gain': 1.0, 'odd_even_rows': True}
# 2022-12-08 01:18:48,070 - stpipe.Detector1Pipeline.refpix - INFO - Using refpix reference file: /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_refpix_0019.fits
# 2022-12-08 01:18:48,249 - stpipe.Detector1Pipeline.refpix - INFO - Working on integration 1
# 2022-12-08 01:19:07,062 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix done
# 2022-12-08 01:19:07,169 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity running with args (<RampModel(1, 10, 3200, 2048) from jw01128009001_03104_00004_nrs1_uncal.fits>,).
# 2022-12-08 01:19:07,170 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../cal_data'}
# 2022-12-08 01:19:07,190 - stpipe.Detector1Pipeline.linearity - INFO - Using Linearity reference file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_linearity_0022.fits
# 2022-12-08 01:19:07,269 - stpipe.Detector1Pipeline.linearity - WARNING - Keyword BAD_LIN_CORR does not correspond to an existing DQ mnemonic, so will be ignored
# 2022-12-08 01:19:07,648 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity done
# 2022-12-08 01:19:07,738 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current running with args (<RampModel(1, 10, 3200, 2048) from jw01128009001_03104_00004_nrs1_uncal.fits>,).
# 2022-12-08 01:19:07,739 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': 'stage1/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../cal_data', 'dark_output': None}
# 2022-12-08 01:19:07,862 - stpipe.Detector1Pipeline.dark_current - INFO - Using DARK reference file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_dark_0204.fits
# 2022-12-08 01:19:11,620 - stpipe.Detector1Pipeline.dark_current - INFO - Science data nints=1, ngroups=10, nframes=1, groupgap=0
# 2022-12-08 01:19:11,642 - stpipe.Detector1Pipeline.dark_current - INFO - Dark data nints=1, ngroups=245, nframes=1, groupgap=0
# 2022-12-08 01:19:14,614 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current done
# 2022-12-08 01:19:15,087 - stpipe.Detector1Pipeline.jump - INFO - Step jump running with args (<RampModel(1, 10, 3200, 2048) from jw01128009001_03104_00004_nrs1_uncal.fits>,).
# 2022-12-08 01:19:15,089 - stpipe.Detector1Pipeline.jump - INFO - Step jump parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../cal_data', 'rejection_threshold': 4.0, 'three_group_rejection_threshold': 6.0, 'four_group_rejection_threshold': 5.0, 'maximum_cores': 'half', 'flag_4_neighbors': True, 'max_jump_to_flag_neighbors': 1000.0, 'min_jump_to_flag_neighbors': 10.0, 'after_jump_flag_dn1': 0.0, 'after_jump_flag_time1': 0.0, 'after_jump_flag_dn2': 0.0, 'after_jump_flag_time2': 0.0}
# 2022-12-08 01:19:15,152 - stpipe.Detector1Pipeline.jump - INFO - CR rejection threshold = 4 sigma
# 2022-12-08 01:19:15,153 - stpipe.Detector1Pipeline.jump - INFO - Maximum cores to use = half
# 2022-12-08 01:19:15,225 - stpipe.Detector1Pipeline.jump - INFO - Using GAIN reference file: /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_gain_0023.fits
# 2022-12-08 01:19:15,323 - stpipe.Detector1Pipeline.jump - INFO - Using READNOISE reference file: /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_readnoise_0018.fits
# 2022-12-08 01:19:15,592 - stpipe.Detector1Pipeline.jump - INFO - Executing two-point difference method
# 2022-12-08 01:19:15,645 - stpipe.Detector1Pipeline.jump - INFO - Creating 5 processes for jump detection
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/jump/twopoint_difference.py:154: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/jump/twopoint_difference.py:154: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/jump/twopoint_difference.py:154: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/jump/twopoint_difference.py:154: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/jump/twopoint_difference.py:154: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
# 2022-12-08 01:19:20,031 - stpipe.Detector1Pipeline.jump - INFO - Total elapsed time = 4.43816 sec
# 2022-12-08 01:19:20,042 - stpipe.Detector1Pipeline.jump - INFO - The execution time in seconds: 4.890179
# 2022-12-08 01:19:20,047 - stpipe.Detector1Pipeline.jump - INFO - Step jump done
# 2022-12-08 01:19:20,182 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit running with args (<RampModel(1, 10, 3200, 2048) from jw01128009001_03104_00004_nrs1_uncal.fits>,).
# 2022-12-08 01:19:20,183 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': 'stage1/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../cal_data', 'int_name': '', 'save_opt': False, 'opt_name': '', 'suppress_one_group': True, 'maximum_cores': 'half'}
# 2022-12-08 01:19:20,351 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using READNOISE reference file: /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_readnoise_0018.fits
# 2022-12-08 01:19:20,352 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using GAIN reference file: /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_gain_0023.fits
# 2022-12-08 01:19:20,435 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using algorithm = ols
# 2022-12-08 01:19:20,436 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using weighting = optimal
# 2022-12-08 01:19:20,640 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of processors used for multiprocessing: 5
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/ramp_fitting/ols_fit.py:1089: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/ramp_fitting/ols_fit.py:1089: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/ramp_fitting/ols_fit.py:1089: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/ramp_fitting/ols_fit.py:1089: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/ramp_fitting/ols_fit.py:1089: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# 2022-12-08 01:19:30,464 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit done
# 2022-12-08 01:19:30,581 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<IFUImageModel(2048, 2048) from jw01128009001_03104_00004_nrs1_uncal.fits>,).
# 2022-12-08 01:19:30,583 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'gain_scale', 'search_output_file': True, 'input_dir': '../../../cal_data'}
# 2022-12-08 01:19:30,640 - stpipe.Detector1Pipeline.gain_scale - INFO - Rescaling by 1.0
# 2022-12-08 01:19:30,653 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# 2022-12-08 01:19:30,713 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<CubeModel(1, 2048, 2048) from jw01128009001_03104_00004_nrs1_uncal.fits>,).
# 2022-12-08 01:19:30,714 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'gain_scaleints', 'search_output_file': True, 'input_dir': '../../../cal_data'}
# 2022-12-08 01:19:30,748 - stpipe.Detector1Pipeline.gain_scale - INFO - Rescaling by 1.0
# 2022-12-08 01:19:30,757 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# 2022-12-08 01:19:30,955 - stpipe.Detector1Pipeline - INFO - Saved model in stage1/jw01128009001_03104_00004_nrs1_rateints.fits
# 2022-12-08 01:19:30,956 - stpipe.Detector1Pipeline - INFO - ... ending calwebb_detector1
# 2022-12-08 01:19:30,956 - stpipe.Detector1Pipeline - INFO - Results used CRDS context: jwst_0977.pmap
# 2022-12-08 01:19:31,151 - stpipe.Detector1Pipeline - INFO - Saved model in stage1/jw01128009001_03104_00004_nrs1_rate.fits
# 2022-12-08 01:19:31,152 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline done

# %%
# Print out the time benchmark
time1 = time.perf_counter()
print(f"Runtime so far: {time1 - time0:0.4f} seconds")
# Out:
# Runtime so far: 231.7868 seconds

# %%
# Look for input uncalibrated slope files from the Detector1 pipeline
sstring = 'stage1/'+ '*_rate.fits'
rate_files = sorted(glob.glob(sstring))
print('Found ' + str(len(rate_files)) + ' input files to process')
# Out:
# Found 4 input files to process

# %%
# Start a timer to keep track of runtime
time0 = time.perf_counter()

# %%
# Setting up steps and running the Spec2 portion of the pipeline. 

spec2 = Spec2Pipeline()
spec2.output_dir = spec2_dir
spec2.assign_wcs.skip = False
spec2.bkg_subtract.skip = False
spec2.imprint_subtract.skip = False
spec2.msa_flagging.skip = False
spec2.srctype.source_type = 'POINT'
spec2.flat_field.skip = False
spec2.pathloss.skip = False
spec2.photom.skip = False
spec2.cube_build.skip = False
spec2.extract_1d.skip = True

##extra steps that only apply to other instruments modes.
spec2.extract_2d.skip = True
spec2.master_background_mos.skip = True
spec2.barshadow.skip = True
spec2.wavecorr.skip = True
spec2.straylight.skip = True
spec2.fringe.skip = True
#spec2.residual_fringe.skip = True   # is not used in 1.7.2 works in 1.8.4
spec2.wfss_contam.skip = True
spec2.resample_spec.skip = True

#choose what results to save and from what steps
spec2.save_results = True
spec2.run(rate_files)
# Out:
# 2022-12-08 01:20:15,051 - stpipe.Spec2Pipeline - INFO - Spec2Pipeline instance created.
# 2022-12-08 01:20:15,054 - stpipe.Spec2Pipeline.bkg_subtract - INFO - BackgroundStep instance created.
# 2022-12-08 01:20:15,056 - stpipe.Spec2Pipeline.assign_wcs - INFO - AssignWcsStep instance created.
# 2022-12-08 01:20:15,057 - stpipe.Spec2Pipeline.imprint_subtract - INFO - ImprintStep instance created.
# 2022-12-08 01:20:15,059 - stpipe.Spec2Pipeline.msa_flagging - INFO - MSAFlagOpenStep instance created.
# 2022-12-08 01:20:15,060 - stpipe.Spec2Pipeline.extract_2d - INFO - Extract2dStep instance created.
# 2022-12-08 01:20:15,063 - stpipe.Spec2Pipeline.master_background_mos - INFO - MasterBackgroundMosStep instance created.
# 2022-12-08 01:20:15,064 - stpipe.Spec2Pipeline.master_background_mos.flat_field - INFO - FlatFieldStep instance created.
# 2022-12-08 01:20:15,065 - stpipe.Spec2Pipeline.master_background_mos.pathloss - INFO - PathLossStep instance created.
# 2022-12-08 01:20:15,066 - stpipe.Spec2Pipeline.master_background_mos.barshadow - INFO - BarShadowStep instance created.
# 2022-12-08 01:20:15,067 - stpipe.Spec2Pipeline.master_background_mos.photom - INFO - PhotomStep instance created.
# 2022-12-08 01:20:15,069 - stpipe.Spec2Pipeline.wavecorr - INFO - WavecorrStep instance created.
# 2022-12-08 01:20:15,071 - stpipe.Spec2Pipeline.flat_field - INFO - FlatFieldStep instance created.
# 2022-12-08 01:20:15,072 - stpipe.Spec2Pipeline.srctype - INFO - SourceTypeStep instance created.
# 2022-12-08 01:20:15,073 - stpipe.Spec2Pipeline.straylight - INFO - StraylightStep instance created.
# 2022-12-08 01:20:15,074 - stpipe.Spec2Pipeline.fringe - INFO - FringeStep instance created.
# 2022-12-08 01:20:15,076 - stpipe.Spec2Pipeline.pathloss - INFO - PathLossStep instance created.
# 2022-12-08 01:20:15,077 - stpipe.Spec2Pipeline.barshadow - INFO - BarShadowStep instance created.
# 2022-12-08 01:20:15,078 - stpipe.Spec2Pipeline.wfss_contam - INFO - WfssContamStep instance created.
# 2022-12-08 01:20:15,079 - stpipe.Spec2Pipeline.photom - INFO - PhotomStep instance created.
# 2022-12-08 01:20:15,082 - stpipe.Spec2Pipeline.resample_spec - INFO - ResampleSpecStep instance created.
# 2022-12-08 01:20:15,084 - stpipe.Spec2Pipeline.cube_build - INFO - CubeBuildStep instance created.
# 2022-12-08 01:20:15,086 - stpipe.Spec2Pipeline.extract_1d - INFO - Extract1dStep instance created.
# 2022-12-08 01:20:15,165 - stpipe.Spec2Pipeline - INFO - Step Spec2Pipeline running with args (['stage1/jw01128009001_03104_00001_nrs1_rate.fits', 'stage1/jw01128009001_03104_00002_nrs1_rate.fits', 'stage1/jw01128009001_03104_00003_nrs1_rate.fits', 'stage1/jw01128009001_03104_00004_nrs1_rate.fits'],).
# 2022-12-08 01:20:15,176 - stpipe.Spec2Pipeline - INFO - Step Spec2Pipeline parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': 'stage2/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_bsub': False, 'fail_on_exception': True, 'save_wfss_esec': False, 'steps': {'bkg_subtract': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_combined_background': False, 'sigma': 3.0, 'maxiters': None, 'wfss_mmag_extract': None}, 'assign_wcs': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'sip_approx': True, 'sip_max_pix_error': 0.25, 'sip_degree': None, 'sip_max_inv_pix_error': 0.25, 'sip_inv_degree': None, 'sip_npoints': 32, 'slit_y_low': -0.55, 'slit_y_high': 0.55}, 'imprint_subtract': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'msa_flagging': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'extract_2d': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'slit_name': None, 'extract_orders': None, 'grism_objects': None, 'tsgrism_extract_height': None, 'wfss_extract_half_height': 5, 'wfss_mmag_extract': None, 'wfss_nbright': 1000}, 'master_background_mos': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'force_subtract': False, 'save_background': False, 'user_background': None, 'inverse': False, 'steps': {'flat_field': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_interpolated_flat': False, 'user_supplied_flat': None, 'inverse': False}, 'pathloss': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'inverse': False, 'source_type': None}, 'barshadow': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'inverse': False, 'source_type': None}, 'photom': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'inverse': False, 'source_type': None}}}, 'wavecorr': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': Fa ...
# 2022-12-08 01:20:15,384 - stpipe.Spec2Pipeline - INFO - Prefetching reference files for dataset: 'jw01128009001_03104_00001_nrs1_rate.fits' reftypes = ['area', 'camera', 'collimator', 'cubepar', 'dflat', 'disperser', 'distortion', 'fflat', 'filteroffset', 'flat', 'fore', 'fpa', 'ifufore', 'ifupost', 'ifuslicer', 'msa', 'msaoper', 'ote', 'pathloss', 'photom', 'regions', 'sflat', 'specwcs', 'wavelengthrange', 'wfssbkg']
# 2022-12-08 01:20:15,389 - stpipe.Spec2Pipeline - INFO - Prefetch for AREA reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_area_0005.fits'.
# 2022-12-08 01:20:15,389 - stpipe.Spec2Pipeline - INFO - Prefetch for CAMERA reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_camera_0007.asdf'.
# 2022-12-08 01:20:15,390 - stpipe.Spec2Pipeline - INFO - Prefetch for COLLIMATOR reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_collimator_0007.asdf'.
# 2022-12-08 01:20:15,390 - stpipe.Spec2Pipeline - INFO - Prefetch for CUBEPAR reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_cubepar_0003.fits'.
# 2022-12-08 01:20:15,390 - stpipe.Spec2Pipeline - INFO - Prefetch for DFLAT reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_dflat_0001.fits'.
# 2022-12-08 01:20:15,391 - stpipe.Spec2Pipeline - INFO - Prefetch for DISPERSER reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_disperser_0061.asdf'.
# 2022-12-08 01:20:15,391 - stpipe.Spec2Pipeline - INFO - Prefetch for DISTORTION reference file is 'N/A'.
# 2022-12-08 01:20:15,391 - stpipe.Spec2Pipeline - INFO - Prefetch for FFLAT reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_fflat_0029.fits'.
# 2022-12-08 01:20:15,391 - stpipe.Spec2Pipeline - INFO - Prefetch for FILTEROFFSET reference file is 'N/A'.
# 2022-12-08 01:20:15,392 - stpipe.Spec2Pipeline - INFO - Prefetch for FLAT reference file is 'N/A'.
# 2022-12-08 01:20:15,392 - stpipe.Spec2Pipeline - INFO - Prefetch for FORE reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_fore_0045.asdf'.
# 2022-12-08 01:20:15,392 - stpipe.Spec2Pipeline - INFO - Prefetch for FPA reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_fpa_0008.asdf'.
# 2022-12-08 01:20:15,393 - stpipe.Spec2Pipeline - INFO - Prefetch for IFUFORE reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_ifufore_0010.asdf'.
# 2022-12-08 01:20:15,393 - stpipe.Spec2Pipeline - INFO - Prefetch for IFUPOST reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_ifupost_0009.asdf'.
# 2022-12-08 01:20:15,393 - stpipe.Spec2Pipeline - INFO - Prefetch for IFUSLICER reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_ifuslicer_0010.asdf'.
# 2022-12-08 01:20:15,394 - stpipe.Spec2Pipeline - INFO - Prefetch for MSA reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_msa_0008.asdf'.
# 2022-12-08 01:20:15,395 - stpipe.Spec2Pipeline - INFO - Prefetch for MSAOPER reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_msaoper_0003.json'.
# 2022-12-08 01:20:15,395 - stpipe.Spec2Pipeline - INFO - Prefetch for OTE reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_ote_0008.asdf'.
# 2022-12-08 01:20:15,396 - stpipe.Spec2Pipeline - INFO - Prefetch for PATHLOSS reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_pathloss_0003.fits'.
# 2022-12-08 01:20:15,396 - stpipe.Spec2Pipeline - INFO - Prefetch for PHOTOM reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_photom_0016.fits'.
# 2022-12-08 01:20:15,397 - stpipe.Spec2Pipeline - INFO - Prefetch for REGIONS reference file is 'N/A'.
# 2022-12-08 01:20:15,397 - stpipe.Spec2Pipeline - INFO - Prefetch for SFLAT reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_sflat_0067.fits'.
# 2022-12-08 01:20:15,397 - stpipe.Spec2Pipeline - INFO - Prefetch for SPECWCS reference file is 'N/A'.
# 2022-12-08 01:20:15,398 - stpipe.Spec2Pipeline - INFO - Prefetch for WAVELENGTHRANGE reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_wavelengthrange_0006.asdf'.
# 2022-12-08 01:20:15,398 - stpipe.Spec2Pipeline - INFO - Prefetch for WFSSBKG reference file is 'N/A'.
# 2022-12-08 01:20:15,399 - stpipe.Spec2Pipeline - INFO - Prefetching reference files for dataset: 'jw01128009001_03104_00002_nrs1_rate.fits' reftypes = ['area', 'camera', 'collimator', 'cubepar', 'dflat', 'disperser', 'distortion', 'fflat', 'filteroffset', 'flat', 'fore', 'fpa', 'ifufore', 'ifupost', 'ifuslicer', 'msa', 'msaoper', 'ote', 'pathloss', 'photom', 'regions', 'sflat', 'specwcs', 'wavelengthrange', 'wfssbkg']
# 2022-12-08 01:20:15,405 - stpipe.Spec2Pipeline - INFO - Prefetch for AREA reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_area_0005.fits'.
# 2022-12-08 01:20:15,405 - stpipe.Spec2Pipeline - INFO - Prefetch for CAMERA reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_camera_0007.asdf'.
# 2022-12-08 01:20:15,406 - stpipe.Spec2Pipeline - INFO - Prefetch for COLLIMATOR reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_collimator_0007.asdf'.
# 2022-12-08 01:20:15,407 - stpipe.Spec2Pipeline - INFO - Prefetch for CUBEPAR reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_cubepar_0003.fits'.
# 2022-12-08 01:20:15,408 - stpipe.Spec2Pipeline - INFO - Prefetch for DFLAT reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_dflat_0001.fits'.
# 2022-12-08 01:20:15,408 - stpipe.Spec2Pipeline - INFO - Prefetch for DISPERSER reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_disperser_0061.asdf'.
# 2022-12-08 01:20:15,409 - stpipe.Spec2Pipeline - INFO - Prefetch for DISTORTION reference file is 'N/A'.
# 2022-12-08 01:20:15,410 - stpipe.Spec2Pipeline - INFO - Prefetch for FFLAT reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_fflat_0029.fits'.
# 2022-12-08 01:20:15,411 - stpipe.Spec2Pipeline - INFO - Prefetch for FILTEROFFSET reference file is 'N/A'.
# 2022-12-08 01:20:15,411 - stpipe.Spec2Pipeline - INFO - Prefetch for FLAT reference file is 'N/A'.
# 2022-12-08 01:20:15,412 - stpipe.Spec2Pipeline - INFO - Prefetch for FORE reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_fore_0045.asdf'.
# 2022-12-08 01:20:15,413 - stpipe.Spec2Pipeline - INFO - Prefetch for FPA reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_fpa_0008.asdf'.
# 2022-12-08 01:20:15,413 - stpipe.Spec2Pipeline - INFO - Prefetch for IFUFORE reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_ifufore_0010.asdf'.
# 2022-12-08 01:20:15,414 - stpipe.Spec2Pipeline - INFO - Prefetch for IFUPOST reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_ifupost_0009.asdf'.
# 2022-12-08 01:20:15,414 - stpipe.Spec2Pipeline - INFO - Prefetch for IFUSLICER reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_ifuslicer_0010.asdf'.
# 2022-12-08 01:20:15,415 - stpipe.Spec2Pipeline - INFO - Prefetch for MSA reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_msa_0008.asdf'.
# 2022-12-08 01:20:15,415 - stpipe.Spec2Pipeline - INFO - Prefetch for MSAOPER reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_msaoper_0003.json'.
# 2022-12-08 01:20:15,416 - stpipe.Spec2Pipeline - INFO - Prefetch for OTE reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_ote_0008.asdf'.
# 2022-12-08 01:20:15,416 - stpipe.Spec2Pipeline - INFO - Prefetch for PATHLOSS reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_pathloss_0003.fits'.
# 2022-12-08 01:20:15,417 - stpipe.Spec2Pipeline - INFO - Prefetch for PHOTOM reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_photom_0016.fits'.
# 2022-12-08 01:20:15,418 - stpipe.Spec2Pipeline - INFO - Prefetch for REGIONS reference file is 'N/A'.
# 2022-12-08 01:20:15,418 - stpipe.Spec2Pipeline - INFO - Prefetch for SFLAT reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_sflat_0067.fits'.
# 2022-12-08 01:20:15,419 - stpipe.Spec2Pipeline - INFO - Prefetch for SPECWCS reference file is 'N/A'.
# 2022-12-08 01:20:15,419 - stpipe.Spec2Pipeline - INFO - Prefetch for WAVELENGTHRANGE reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_wavelengthrange_0006.asdf'.
# 2022-12-08 01:20:15,420 - stpipe.Spec2Pipeline - INFO - Prefetch for WFSSBKG reference file is 'N/A'.
# 2022-12-08 01:20:15,421 - stpipe.Spec2Pipeline - INFO - Prefetching reference files for dataset: 'jw01128009001_03104_00003_nrs1_rate.fits' reftypes = ['area', 'camera', 'collimator', 'cubepar', 'dflat', 'disperser', 'distortion', 'fflat', 'filteroffset', 'flat', 'fore', 'fpa', 'ifufore', 'ifupost', 'ifuslicer', 'msa', 'msaoper', 'ote', 'pathloss', 'photom', 'regions', 'sflat', 'specwcs', 'wavelengthrange', 'wfssbkg']
# 2022-12-08 01:20:15,427 - stpipe.Spec2Pipeline - INFO - Prefetch for AREA reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_area_0005.fits'.
# 2022-12-08 01:20:15,428 - stpipe.Spec2Pipeline - INFO - Prefetch for CAMERA reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_camera_0007.asdf'.
# 2022-12-08 01:20:15,429 - stpipe.Spec2Pipeline - INFO - Prefetch for COLLIMATOR reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_collimator_0007.asdf'.
# 2022-12-08 01:20:15,429 - stpipe.Spec2Pipeline - INFO - Prefetch for CUBEPAR reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_cubepar_0003.fits'.
# 2022-12-08 01:20:15,430 - stpipe.Spec2Pipeline - INFO - Prefetch for DFLAT reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_dflat_0001.fits'.
# 2022-12-08 01:20:15,430 - stpipe.Spec2Pipeline - INFO - Prefetch for DISPERSER reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_disperser_0061.asdf'.
# 2022-12-08 01:20:15,430 - stpipe.Spec2Pipeline - INFO - Prefetch for DISTORTION reference file is 'N/A'.
# 2022-12-08 01:20:15,430 - stpipe.Spec2Pipeline - INFO - Prefetch for FFLAT reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_fflat_0029.fits'.
# 2022-12-08 01:20:15,431 - stpipe.Spec2Pipeline - INFO - Prefetch for FILTEROFFSET reference file is 'N/A'.
# 2022-12-08 01:20:15,431 - stpipe.Spec2Pipeline - INFO - Prefetch for FLAT reference file is 'N/A'.
# 2022-12-08 01:20:15,431 - stpipe.Spec2Pipeline - INFO - Prefetch for FORE reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_fore_0045.asdf'.
# 2022-12-08 01:20:15,432 - stpipe.Spec2Pipeline - INFO - Prefetch for FPA reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_fpa_0008.asdf'.
# 2022-12-08 01:20:15,433 - stpipe.Spec2Pipeline - INFO - Prefetch for IFUFORE reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_ifufore_0010.asdf'.
# 2022-12-08 01:20:15,433 - stpipe.Spec2Pipeline - INFO - Prefetch for IFUPOST reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_ifupost_0009.asdf'.
# 2022-12-08 01:20:15,434 - stpipe.Spec2Pipeline - INFO - Prefetch for IFUSLICER reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_ifuslicer_0010.asdf'.
# 2022-12-08 01:20:15,434 - stpipe.Spec2Pipeline - INFO - Prefetch for MSA reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_msa_0008.asdf'.
# 2022-12-08 01:20:15,435 - stpipe.Spec2Pipeline - INFO - Prefetch for MSAOPER reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_msaoper_0003.json'.
# 2022-12-08 01:20:15,435 - stpipe.Spec2Pipeline - INFO - Prefetch for OTE reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_ote_0008.asdf'.
# 2022-12-08 01:20:15,436 - stpipe.Spec2Pipeline - INFO - Prefetch for PATHLOSS reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_pathloss_0003.fits'.
# 2022-12-08 01:20:15,436 - stpipe.Spec2Pipeline - INFO - Prefetch for PHOTOM reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_photom_0016.fits'.
# 2022-12-08 01:20:15,437 - stpipe.Spec2Pipeline - INFO - Prefetch for REGIONS reference file is 'N/A'.
# 2022-12-08 01:20:15,437 - stpipe.Spec2Pipeline - INFO - Prefetch for SFLAT reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_sflat_0067.fits'.
# 2022-12-08 01:20:15,437 - stpipe.Spec2Pipeline - INFO - Prefetch for SPECWCS reference file is 'N/A'.
# 2022-12-08 01:20:15,438 - stpipe.Spec2Pipeline - INFO - Prefetch for WAVELENGTHRANGE reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_wavelengthrange_0006.asdf'.
# 2022-12-08 01:20:15,438 - stpipe.Spec2Pipeline - INFO - Prefetch for WFSSBKG reference file is 'N/A'.
# 2022-12-08 01:20:15,439 - stpipe.Spec2Pipeline - INFO - Prefetching reference files for dataset: 'jw01128009001_03104_00004_nrs1_rate.fits' reftypes = ['area', 'camera', 'collimator', 'cubepar', 'dflat', 'disperser', 'distortion', 'fflat', 'filteroffset', 'flat', 'fore', 'fpa', 'ifufore', 'ifupost', 'ifuslicer', 'msa', 'msaoper', 'ote', 'pathloss', 'photom', 'regions', 'sflat', 'specwcs', 'wavelengthrange', 'wfssbkg']
# 2022-12-08 01:20:15,444 - stpipe.Spec2Pipeline - INFO - Prefetch for AREA reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_area_0005.fits'.
# 2022-12-08 01:20:15,444 - stpipe.Spec2Pipeline - INFO - Prefetch for CAMERA reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_camera_0007.asdf'.
# 2022-12-08 01:20:15,445 - stpipe.Spec2Pipeline - INFO - Prefetch for COLLIMATOR reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_collimator_0007.asdf'.
# 2022-12-08 01:20:15,445 - stpipe.Spec2Pipeline - INFO - Prefetch for CUBEPAR reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_cubepar_0003.fits'.
# 2022-12-08 01:20:15,446 - stpipe.Spec2Pipeline - INFO - Prefetch for DFLAT reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_dflat_0001.fits'.
# 2022-12-08 01:20:15,446 - stpipe.Spec2Pipeline - INFO - Prefetch for DISPERSER reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_disperser_0061.asdf'.
# 2022-12-08 01:20:15,446 - stpipe.Spec2Pipeline - INFO - Prefetch for DISTORTION reference file is 'N/A'.
# 2022-12-08 01:20:15,446 - stpipe.Spec2Pipeline - INFO - Prefetch for FFLAT reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_fflat_0029.fits'.
# 2022-12-08 01:20:15,447 - stpipe.Spec2Pipeline - INFO - Prefetch for FILTEROFFSET reference file is 'N/A'.
# 2022-12-08 01:20:15,447 - stpipe.Spec2Pipeline - INFO - Prefetch for FLAT reference file is 'N/A'.
# 2022-12-08 01:20:15,447 - stpipe.Spec2Pipeline - INFO - Prefetch for FORE reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_fore_0045.asdf'.
# 2022-12-08 01:20:15,448 - stpipe.Spec2Pipeline - INFO - Prefetch for FPA reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_fpa_0008.asdf'.
# 2022-12-08 01:20:15,448 - stpipe.Spec2Pipeline - INFO - Prefetch for IFUFORE reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_ifufore_0010.asdf'.
# 2022-12-08 01:20:15,449 - stpipe.Spec2Pipeline - INFO - Prefetch for IFUPOST reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_ifupost_0009.asdf'.
# 2022-12-08 01:20:15,449 - stpipe.Spec2Pipeline - INFO - Prefetch for IFUSLICER reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_ifuslicer_0010.asdf'.
# 2022-12-08 01:20:15,449 - stpipe.Spec2Pipeline - INFO - Prefetch for MSA reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_msa_0008.asdf'.
# 2022-12-08 01:20:15,450 - stpipe.Spec2Pipeline - INFO - Prefetch for MSAOPER reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_msaoper_0003.json'.
# 2022-12-08 01:20:15,451 - stpipe.Spec2Pipeline - INFO - Prefetch for OTE reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_ote_0008.asdf'.
# 2022-12-08 01:20:15,451 - stpipe.Spec2Pipeline - INFO - Prefetch for PATHLOSS reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_pathloss_0003.fits'.
# 2022-12-08 01:20:15,452 - stpipe.Spec2Pipeline - INFO - Prefetch for PHOTOM reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_photom_0016.fits'.
# 2022-12-08 01:20:15,452 - stpipe.Spec2Pipeline - INFO - Prefetch for REGIONS reference file is 'N/A'.
# 2022-12-08 01:20:15,452 - stpipe.Spec2Pipeline - INFO - Prefetch for SFLAT reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_sflat_0067.fits'.
# 2022-12-08 01:20:15,453 - stpipe.Spec2Pipeline - INFO - Prefetch for SPECWCS reference file is 'N/A'.
# 2022-12-08 01:20:15,453 - stpipe.Spec2Pipeline - INFO - Prefetch for WAVELENGTHRANGE reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_wavelengthrange_0006.asdf'.
# 2022-12-08 01:20:15,453 - stpipe.Spec2Pipeline - INFO - Prefetch for WFSSBKG reference file is 'N/A'.
# 2022-12-08 01:20:15,454 - stpipe.Spec2Pipeline - INFO - Starting calwebb_spec2 ...
# 2022-12-08 01:20:15,462 - stpipe.Spec2Pipeline - INFO - Processing product stage1/jw01128009001_03104_00001_nrs1
# 2022-12-08 01:20:15,462 - stpipe.Spec2Pipeline - INFO - Working on input stage1/jw01128009001_03104_00001_nrs1_rate.fits ...
# 2022-12-08 01:20:15,589 - stpipe.Spec2Pipeline.assign_wcs - INFO - Step assign_wcs running with args (<IFUImageModel(2048, 2048) from jw01128009001_03104_00001_nrs1_rate.fits>,).
# 2022-12-08 01:20:15,591 - stpipe.Spec2Pipeline.assign_wcs - INFO - Step assign_wcs parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'sip_approx': True, 'sip_max_pix_error': 0.25, 'sip_degree': None, 'sip_max_inv_pix_error': 0.25, 'sip_inv_degree': None, 'sip_npoints': 32, 'slit_y_low': -0.55, 'slit_y_high': 0.55}
# 2022-12-08 01:20:15,799 - stpipe.Spec2Pipeline.assign_wcs - INFO - gwa_ytilt is 0.1335551290000001 deg
# 2022-12-08 01:20:15,799 - stpipe.Spec2Pipeline.assign_wcs - INFO - gwa_xtilt is 0.3572343290000005 deg
# 2022-12-08 01:20:15,800 - stpipe.Spec2Pipeline.assign_wcs - INFO - theta_y correction: 0.004247317616010567 deg
# 2022-12-08 01:20:15,801 - stpipe.Spec2Pipeline.assign_wcs - INFO - theta_x correction: 0.0003912459150999502 deg
# 2022-12-08 01:20:15,886 - stpipe.Spec2Pipeline.assign_wcs - INFO - Applied Barycentric velocity correction : 1.0000003652528175
# 2022-12-08 01:20:18,836 - stpipe.Spec2Pipeline.assign_wcs - INFO - Created a NIRSPEC nrs_ifu pipeline with references {'distortion': None, 'filteroffset': None, 'specwcs': None, 'regions': None, 'wavelengthrange': '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_wavelengthrange_0006.asdf', 'camera': '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_camera_0007.asdf', 'collimator': '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_collimator_0007.asdf', 'disperser': '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_disperser_0061.asdf', 'fore': '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_fore_0045.asdf', 'fpa': '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_fpa_0008.asdf', 'msa': '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_msa_0008.asdf', 'ote': '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_ote_0008.asdf', 'ifupost': '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_ifupost_0009.asdf', 'ifufore': '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_ifufore_0010.asdf', 'ifuslicer': '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_ifuslicer_0010.asdf'}
# 2022-12-08 01:20:24,197 - stpipe.Spec2Pipeline.assign_wcs - INFO - Update S_REGION to POLYGON ICRS  272.141969361 69.457684287 272.145465423 69.457684287 272.145465423 69.458964695 272.141969361 69.458964695
# 2022-12-08 01:20:24,198 - stpipe.Spec2Pipeline.assign_wcs - INFO - COMPLETED assign_wcs
# 2022-12-08 01:20:24,210 - stpipe.Spec2Pipeline.assign_wcs - INFO - Step assign_wcs done
# 2022-12-08 01:20:24,367 - stpipe.Spec2Pipeline.bkg_subtract - INFO - Step bkg_subtract running with args (<IFUImageModel(2048, 2048) from jw01128009001_03104_00001_nrs1_rate.fits>, []).
# 2022-12-08 01:20:24,368 - stpipe.Spec2Pipeline.bkg_subtract - INFO - Step bkg_subtract parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_combined_background': False, 'sigma': 3.0, 'maxiters': None, 'wfss_mmag_extract': None}
# 2022-12-08 01:20:24,368 - stpipe.Spec2Pipeline.bkg_subtract - INFO - Step skipped.
# 2022-12-08 01:20:24,370 - stpipe.Spec2Pipeline.bkg_subtract - INFO - Step bkg_subtract done
# 2022-12-08 01:20:24,480 - stpipe.Spec2Pipeline.imprint_subtract - INFO - Step imprint_subtract running with args (<IFUImageModel(2048, 2048) from jw01128009001_03104_00001_nrs1_rate.fits>, []).
# 2022-12-08 01:20:24,481 - stpipe.Spec2Pipeline.imprint_subtract - INFO - Step imprint_subtract parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': ''}
# 2022-12-08 01:20:24,481 - stpipe.Spec2Pipeline.imprint_subtract - INFO - Step skipped.
# 2022-12-08 01:20:24,483 - stpipe.Spec2Pipeline.imprint_subtract - INFO - Step imprint_subtract done
# 2022-12-08 01:20:24,590 - stpipe.Spec2Pipeline.msa_flagging - INFO - Step msa_flagging running with args (<IFUImageModel(2048, 2048) from jw01128009001_03104_00001_nrs1_rate.fits>,).
# 2022-12-08 01:20:24,591 - stpipe.Spec2Pipeline.msa_flagging - INFO - Step msa_flagging parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}
# 2022-12-08 01:20:24,610 - stpipe.Spec2Pipeline.msa_flagging - INFO - Using reference file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_msaoper_0003.json
# 2022-12-08 01:20:24,611 - stpipe.JwstStep - INFO - JwstStep instance created.
# 2022-12-08 01:20:24,739 - stpipe.Spec2Pipeline.msa_flagging - INFO - gwa_ytilt is 0.1335551290000001 deg
# 2022-12-08 01:20:24,740 - stpipe.Spec2Pipeline.msa_flagging - INFO - gwa_xtilt is 0.3572343290000005 deg
# 2022-12-08 01:20:24,740 - stpipe.Spec2Pipeline.msa_flagging - INFO - theta_y correction: 0.004247317616010567 deg
# 2022-12-08 01:20:24,742 - stpipe.Spec2Pipeline.msa_flagging - INFO - theta_x correction: 0.0003912459150999502 deg
# 2022-12-08 01:20:24,756 - stpipe.Spec2Pipeline.msa_flagging - INFO - SPORDER= -1, wrange=[9.7e-07, 1.89e-06]
# 2022-12-08 01:20:24,854 - stpipe.Spec2Pipeline.msa_flagging - INFO - Applied Barycentric velocity correction : 1.0000003652528175
# 2022-12-08 01:20:24,894 - stpipe.Spec2Pipeline.msa_flagging - INFO - There are 6 open slits in quadrant 1
# 2022-12-08 01:20:24,953 - stpipe.Spec2Pipeline.msa_flagging - INFO - There are 3 open slits in quadrant 2
# 2022-12-08 01:20:24,980 - stpipe.Spec2Pipeline.msa_flagging - INFO - There are 10 open slits in quadrant 3
# 2022-12-08 01:20:25,053 - stpipe.Spec2Pipeline.msa_flagging - INFO - There are 2 open slits in quadrant 4
# 2022-12-08 01:20:25,072 - stpipe.Spec2Pipeline.msa_flagging - INFO - There are 0 open slits in quadrant 5
# 2022-12-08 01:20:28,741 - stpipe.Spec2Pipeline.msa_flagging - WARNING - /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/astropy/modeling/bounding_box.py:83: RuntimeWarning: Invalid interval: upper bound 2047.5 is strictly less than lower bound 2345.589533311416.
#   warnings.warn(f"Invalid interval: upper bound {upper} "
#
# 2022-12-08 01:20:29,304 - stpipe.Spec2Pipeline.msa_flagging - WARNING - /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/astropy/modeling/bounding_box.py:83: RuntimeWarning: Invalid interval: upper bound 2047.5 is strictly less than lower bound 2137.516888430826.
#   warnings.warn(f"Invalid interval: upper bound {upper} "
#
# 2022-12-08 01:20:29,681 - stpipe.Spec2Pipeline.msa_flagging - WARNING - /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/astropy/modeling/bounding_box.py:83: RuntimeWarning: Invalid interval: upper bound 2047.5 is strictly less than lower bound 2060.9308439432393.
#   warnings.warn(f"Invalid interval: upper bound {upper} "
#
# 2022-12-08 01:20:31,450 - stpipe.Spec2Pipeline.msa_flagging - WARNING - /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/astropy/modeling/bounding_box.py:83: RuntimeWarning: Invalid interval: upper bound 2047.5 is strictly less than lower bound 2204.6162665075267.
#   warnings.warn(f"Invalid interval: upper bound {upper} "
#
# 2022-12-08 01:20:38,109 - stpipe.Spec2Pipeline.msa_flagging - INFO - Step msa_flagging done
# 2022-12-08 01:20:38,419 - stpipe.Spec2Pipeline.srctype - INFO - Step srctype running with args (<IFUImageModel(2048, 2048) from jw01128009001_03104_00001_nrs1_rate.fits>,).
# 2022-12-08 01:20:38,420 - stpipe.Spec2Pipeline.srctype - INFO - Step srctype parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'source_type': 'POINT'}
# 2022-12-08 01:20:38,428 - stpipe.Spec2Pipeline.srctype - INFO - Input EXP_TYPE is NRS_IFU
# 2022-12-08 01:20:38,429 - stpipe.Spec2Pipeline.srctype - INFO - Input SRCTYAPT = UNKNOWN
# 2022-12-08 01:20:38,429 - stpipe.Spec2Pipeline.srctype - WARNING - Based on user-input, setting SRCTYPE = POINT
# 2022-12-08 01:20:38,432 - stpipe.Spec2Pipeline.srctype - INFO - Step srctype done
# 2022-12-08 01:20:38,538 - stpipe.Spec2Pipeline.flat_field - INFO - Step flat_field running with args (<IFUImageModel(2048, 2048) from jw01128009001_03104_00001_nrs1_rate.fits>,).
# 2022-12-08 01:20:38,539 - stpipe.Spec2Pipeline.flat_field - INFO - Step flat_field parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_interpolated_flat': False, 'user_supplied_flat': None, 'inverse': False}
# 2022-12-08 01:26:45,640 - stpipe.Spec2Pipeline.flat_field - INFO - Step flat_field done
# 2022-12-08 01:26:46,949 - stpipe.Spec2Pipeline.straylight - INFO - Step straylight running with args (<IFUImageModel(2048, 2048) from jw01128009001_03104_00001_nrs1_rate.fits>,).
# 2022-12-08 01:26:46,950 - stpipe.Spec2Pipeline.straylight - INFO - Step straylight parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': ''}
# 2022-12-08 01:26:46,951 - stpipe.Spec2Pipeline.straylight - INFO - Step skipped.
# 2022-12-08 01:26:46,954 - stpipe.Spec2Pipeline.straylight - INFO - Step straylight done
# 2022-12-08 01:26:47,135 - stpipe.Spec2Pipeline.fringe - INFO - Step fringe running with args (<IFUImageModel(2048, 2048) from jw01128009001_03104_00001_nrs1_rate.fits>,).
# 2022-12-08 01:26:47,137 - stpipe.Spec2Pipeline.fringe - INFO - Step fringe parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': ''}
# 2022-12-08 01:26:47,138 - stpipe.Spec2Pipeline.fringe - INFO - Step skipped.
# 2022-12-08 01:26:47,140 - stpipe.Spec2Pipeline.fringe - INFO - Step fringe done
# 2022-12-08 01:26:47,319 - stpipe.Spec2Pipeline.pathloss - INFO - Step pathloss running with args (<IFUImageModel(2048, 2048) from jw01128009001_03104_00001_nrs1_rate.fits>,).
# 2022-12-08 01:26:47,321 - stpipe.Spec2Pipeline.pathloss - INFO - Step pathloss parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'inverse': False, 'source_type': None}
# 2022-12-08 01:26:47,342 - stpipe.Spec2Pipeline.pathloss - INFO - Using PATHLOSS reference file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_pathloss_0003.fits
# 2022-12-08 01:26:47,374 - stpipe.Spec2Pipeline.pathloss - INFO - Input exposure type is NRS_IFU
# 2022-12-08 01:27:47,313 - stpipe.Spec2Pipeline.pathloss - INFO - Step pathloss done
# 2022-12-08 01:27:47,785 - stpipe.Spec2Pipeline.barshadow - INFO - Step barshadow running with args (<IFUImageModel(2048, 2048) from jw01128009001_03104_00001_nrs1_rate.fits>,).
# 2022-12-08 01:27:47,786 - stpipe.Spec2Pipeline.barshadow - INFO - Step barshadow parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'inverse': False, 'source_type': None}
# 2022-12-08 01:27:47,787 - stpipe.Spec2Pipeline.barshadow - INFO - Step skipped.
# 2022-12-08 01:27:47,790 - stpipe.Spec2Pipeline.barshadow - INFO - Step barshadow done
# 2022-12-08 01:27:47,951 - stpipe.Spec2Pipeline.photom - INFO - Step photom running with args (<IFUImageModel(2048, 2048) from jw01128009001_03104_00001_nrs1_rate.fits>,).
# 2022-12-08 01:27:47,952 - stpipe.Spec2Pipeline.photom - INFO - Step photom parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'inverse': False, 'source_type': None}
# 2022-12-08 01:27:47,980 - stpipe.Spec2Pipeline.photom - INFO - Using photom reference file: /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_photom_0016.fits
# 2022-12-08 01:27:47,980 - stpipe.Spec2Pipeline.photom - INFO - Using area reference file: /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_area_0005.fits
# 2022-12-08 01:27:50,676 - stpipe.Spec2Pipeline.photom - INFO - Using instrument: NIRSPEC
# 2022-12-08 01:27:50,676 - stpipe.Spec2Pipeline.photom - INFO -  detector: NRS1
# 2022-12-08 01:27:50,677 - stpipe.Spec2Pipeline.photom - INFO -  exp_type: NRS_IFU
# 2022-12-08 01:27:50,677 - stpipe.Spec2Pipeline.photom - INFO -  filter: F100LP
# 2022-12-08 01:27:50,677 - stpipe.Spec2Pipeline.photom - INFO -  grating: G140H
# 2022-12-08 01:27:50,732 - stpipe.Spec2Pipeline.photom - INFO - PHOTMJSR value: 1
# 2022-12-08 01:28:47,833 - stpipe.Spec2Pipeline.photom - INFO - Step photom done
# 2022-12-08 01:28:48,477 - stpipe.Spec2Pipeline.cube_build - INFO - Step cube_build running with args (<IFUImageModel(2048, 2048) from stage2/jw01128009001_03104_00001_nrs1_cal.fits>,).
# 2022-12-08 01:28:48,480 - stpipe.Spec2Pipeline.cube_build - INFO - Step cube_build parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': False, 'input_dir': '', 'channel': 'all', 'band': 'all', 'grating': 'all', 'filter': 'all', 'output_type': 'multi', 'scale1': 0.0, 'scale2': 0.0, 'scalew': 0.0, 'weighting': 'drizzle', 'coord_system': 'skyalign', 'rois': 0.0, 'roiw': 0.0, 'weight_power': 2.0, 'wavemin': None, 'wavemax': None, 'single': False, 'skip_dqflagging': True}
# 2022-12-08 01:28:48,480 - stpipe.Spec2Pipeline.cube_build - INFO - Starting IFU Cube Building Step
# 2022-12-08 01:28:48,480 - stpipe.Spec2Pipeline.cube_build - INFO - Input interpolation: drizzle
# 2022-12-08 01:28:48,481 - stpipe.Spec2Pipeline.cube_build - INFO - Coordinate system to use: skyalign
# 2022-12-08 01:28:48,507 - stpipe.Spec2Pipeline.cube_build - INFO - Reading cube parameter file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_cubepar_0003.fits
# 2022-12-08 01:28:48,554 - stpipe.Spec2Pipeline.cube_build - INFO - Output IFUcube are constructed from all the data
# 2022-12-08 01:28:48,555 - stpipe.Spec2Pipeline.cube_build - INFO - Number of IFU cubes produced by this run = 1
# 2022-12-08 01:28:48,558 - stpipe.Spec2Pipeline.cube_build - INFO - Increasing spatial region of interest default value set for 4 dithers nan
# 2022-12-08 01:28:48,561 - stpipe.Spec2Pipeline.cube_build - INFO - Cube Geometry:
# 2022-12-08 01:28:48,562 - stpipe.Spec2Pipeline.cube_build - INFO - axis#  Naxis  CRPIX    CRVAL      CDELT(arcsec)  Min & Max (xi, eta arcsec)
# 2022-12-08 01:28:48,562 - stpipe.Spec2Pipeline.cube_build - INFO - Axis 1    49  25.00 -87.85628261   0.10000000  -2.45000004   2.45000004
# 2022-12-08 01:28:48,563 - stpipe.Spec2Pipeline.cube_build - INFO - Axis 2    51  26.00  69.45832449   0.10000000  -2.55000004   2.55000004
# 2022-12-08 01:28:48,563 - stpipe.Spec2Pipeline.cube_build - INFO - axis#  Naxis  CRPIX    CRVAL      CDELT(microns)  Min & Max (microns)
# 2022-12-08 01:28:48,563 - stpipe.Spec2Pipeline.cube_build - INFO - Axis 3  2057   1.00   0.96635916   0.00023500   0.96624166   1.44963666
# 2022-12-08 01:28:48,564 - stpipe.Spec2Pipeline.cube_build - INFO - Cube covers grating, filter: g140h, f100lp
# 2022-12-08 01:28:48,564 - stpipe.Spec2Pipeline.cube_build - INFO - Output Name: stage2/jw01128009001_03104_00001_nrs1_s3d.fits
# 2022-12-08 01:28:52,247 - stpipe.Spec2Pipeline.cube_build - INFO - Mapping each NIRSpec slice to sky for input file: stage2/jw01128009001_03104_00001_nrs1_cal.fits
# 2022-12-08 01:30:09,482 - stpipe.Spec2Pipeline.cube_build - INFO - Average # of holes/wavelength plane is < 1
# 2022-12-08 01:30:09,483 - stpipe.Spec2Pipeline.cube_build - INFO - Total # of holes for IFU cube is : 0
# 2022-12-08 01:30:09,485 - stpipe.Spec2Pipeline.cube_build - INFO - Number of wavelength planes removed with no data: 20
# 2022-12-08 01:30:09,604 - stpipe.Spec2Pipeline.cube_build - INFO - Update S_REGION to POLYGON ICRS  272.141817392 69.457630036 272.141817392 69.459018925 272.145617392 69.459018925 272.145617392 69.457630036
# 2022-12-08 01:30:09,610 - stpipe.Spec2Pipeline.cube_build - INFO - Step cube_build done
# 2022-12-08 01:30:09,849 - stpipe.Spec2Pipeline - INFO - Saved model in stage2/jw01128009001_03104_00001_nrs1_s3d.fits
# 2022-12-08 01:30:10,090 - stpipe.Spec2Pipeline.extract_1d - INFO - Step extract_1d running with args (<ModelContainer>,).
# 2022-12-08 01:30:10,092 - stpipe.Spec2Pipeline.extract_1d - INFO - Step extract_1d parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': True, 'suffix': 'x1d', 'search_output_file': True, 'input_dir': '', 'smoothing_length': None, 'bkg_fit': None, 'bkg_order': None, 'bkg_sigma_clip': 3.0, 'log_increment': 50, 'subtract_background': None, 'use_source_posn': None, 'center_xy': None, 'apply_apcorr': True, 'soss_threshold': 0.01, 'soss_n_os': 2, 'soss_transform': None, 'soss_tikfac': None, 'soss_width': 40.0, 'soss_bad_pix': 'model', 'soss_modelname': None}
# 2022-12-08 01:30:10,092 - stpipe.Spec2Pipeline.extract_1d - INFO - Step skipped.
# 2022-12-08 01:30:10,095 - stpipe.Spec2Pipeline.extract_1d - INFO - Step extract_1d done
# 2022-12-08 01:30:10,096 - stpipe.Spec2Pipeline - INFO - Finished processing product stage1/jw01128009001_03104_00001_nrs1
# 2022-12-08 01:30:10,096 - stpipe.Spec2Pipeline - INFO - Processing product stage1/jw01128009001_03104_00002_nrs1
# 2022-12-08 01:30:10,096 - stpipe.Spec2Pipeline - INFO - Working on input stage1/jw01128009001_03104_00002_nrs1_rate.fits ...
# 2022-12-08 01:30:10,282 - stpipe.Spec2Pipeline.assign_wcs - INFO - Step assign_wcs running with args (<IFUImageModel(2048, 2048) from jw01128009001_03104_00002_nrs1_rate.fits>,).
# 2022-12-08 01:30:10,283 - stpipe.Spec2Pipeline.assign_wcs - INFO - Step assign_wcs parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'assign_wcs', 'search_output_file': True, 'input_dir': '', 'sip_approx': True, 'sip_max_pix_error': 0.25, 'sip_degree': None, 'sip_max_inv_pix_error': 0.25, 'sip_inv_degree': None, 'sip_npoints': 32, 'slit_y_low': -0.55, 'slit_y_high': 0.55}
# 2022-12-08 01:30:10,486 - stpipe.Spec2Pipeline.assign_wcs - INFO - gwa_ytilt is 0.1335551290000001 deg
# 2022-12-08 01:30:10,486 - stpipe.Spec2Pipeline.assign_wcs - INFO - gwa_xtilt is 0.3572343290000005 deg
# 2022-12-08 01:30:10,486 - stpipe.Spec2Pipeline.assign_wcs - INFO - theta_y correction: 0.004247317616010567 deg
# 2022-12-08 01:30:10,488 - stpipe.Spec2Pipeline.assign_wcs - INFO - theta_x correction: 0.0003912459150999502 deg
# 2022-12-08 01:30:10,584 - stpipe.Spec2Pipeline.assign_wcs - INFO - Applied Barycentric velocity correction : 1.0000003652528175
# 2022-12-08 01:30:13,705 - stpipe.Spec2Pipeline.assign_wcs - INFO - Created a NIRSPEC nrs_ifu pipeline with references {'distortion': None, 'filteroffset': None, 'specwcs': None, 'regions': None, 'wavelengthrange': '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_wavelengthrange_0006.asdf', 'camera': '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_camera_0007.asdf', 'collimator': '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_collimator_0007.asdf', 'disperser': '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_disperser_0061.asdf', 'fore': '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_fore_0045.asdf', 'fpa': '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_fpa_0008.asdf', 'msa': '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_msa_0008.asdf', 'ote': '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_ote_0008.asdf', 'ifupost': '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_ifupost_0009.asdf', 'ifufore': '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_ifufore_0010.asdf', 'ifuslicer': '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_ifuslicer_0010.asdf'}
# 2022-12-08 01:30:18,915 - stpipe.Spec2Pipeline.assign_wcs - INFO - Update S_REGION to POLYGON ICRS  272.143806705 69.457561352 272.147302717 69.457561352 272.147302717 69.458841755 272.143806705 69.458841755
# 2022-12-08 01:30:18,916 - stpipe.Spec2Pipeline.assign_wcs - INFO - COMPLETED assign_wcs
# 2022-12-08 01:30:18,927 - stpipe.Spec2Pipeline.assign_wcs - INFO - Step assign_wcs done
# 2022-12-08 01:30:19,150 - stpipe.Spec2Pipeline.bkg_subtract - INFO - Step bkg_subtract running with args (<IFUImageModel(2048, 2048) from jw01128009001_03104_00002_nrs1_rate.fits>, []).
# 2022-12-08 01:30:19,151 - stpipe.Spec2Pipeline.bkg_subtract - INFO - Step bkg_subtract parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': 'bkg_subtract', 'search_output_file': True, 'input_dir': '', 'save_combined_background': False, 'sigma': 3.0, 'maxiters': None, 'wfss_mmag_extract': None}
# 2022-12-08 01:30:19,151 - stpipe.Spec2Pipeline.bkg_subtract - INFO - Step skipped.
# 2022-12-08 01:30:19,154 - stpipe.Spec2Pipeline.bkg_subtract - INFO - Step bkg_subtract done
# ...
# 2022-12-08 01:50:03,725 - stpipe.Spec2Pipeline.imprint_subtract - INFO - Step skipped.
# 2022-12-08 01:50:03,728 - stpipe.Spec2Pipeline.imprint_subtract - INFO - Step imprint_subtract done
# 2022-12-08 01:50:04,058 - stpipe.Spec2Pipeline.msa_flagging - INFO - Step msa_flagging running with args (<IFUImageModel(2048, 2048) from jw01128009001_03104_00004_nrs1_rate.fits>,).
# 2022-12-08 01:50:04,059 - stpipe.Spec2Pipeline.msa_flagging - INFO - Step msa_flagging parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'msa_flagging', 'search_output_file': True, 'input_dir': ''}
# 2022-12-08 01:50:04,077 - stpipe.Spec2Pipeline.msa_flagging - INFO - Using reference file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_msaoper_0003.json
# 2022-12-08 01:50:04,078 - stpipe.JwstStep - INFO - JwstStep instance created.
# 2022-12-08 01:50:04,212 - stpipe.Spec2Pipeline.msa_flagging - INFO - gwa_ytilt is 0.1335551290000001 deg
# 2022-12-08 01:50:04,213 - stpipe.Spec2Pipeline.msa_flagging - INFO - gwa_xtilt is 0.3572343290000005 deg
# 2022-12-08 01:50:04,213 - stpipe.Spec2Pipeline.msa_flagging - INFO - theta_y correction: 0.004247317616010567 deg
# 2022-12-08 01:50:04,214 - stpipe.Spec2Pipeline.msa_flagging - INFO - theta_x correction: 0.0003912459150999502 deg
# 2022-12-08 01:50:04,228 - stpipe.Spec2Pipeline.msa_flagging - INFO - SPORDER= -1, wrange=[9.7e-07, 1.89e-06]
# 2022-12-08 01:50:04,323 - stpipe.Spec2Pipeline.msa_flagging - INFO - Applied Barycentric velocity correction : 1.0000003664870056
# 2022-12-08 01:50:04,357 - stpipe.Spec2Pipeline.msa_flagging - INFO - There are 6 open slits in quadrant 1
# 2022-12-08 01:50:04,404 - stpipe.Spec2Pipeline.msa_flagging - INFO - There are 3 open slits in quadrant 2
# 2022-12-08 01:50:04,428 - stpipe.Spec2Pipeline.msa_flagging - INFO - There are 10 open slits in quadrant 3
# 2022-12-08 01:50:04,501 - stpipe.Spec2Pipeline.msa_flagging - INFO - There are 2 open slits in quadrant 4
# 2022-12-08 01:50:04,517 - stpipe.Spec2Pipeline.msa_flagging - INFO - There are 0 open slits in quadrant 5
# 2022-12-08 01:50:08,308 - stpipe.Spec2Pipeline.msa_flagging - WARNING - /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/astropy/modeling/bounding_box.py:83: RuntimeWarning: Invalid interval: upper bound 2047.5 is strictly less than lower bound 2345.589533311416.
#   warnings.warn(f"Invalid interval: upper bound {upper} "
#
# 2022-12-08 01:50:08,676 - stpipe.Spec2Pipeline.msa_flagging - WARNING - /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/astropy/modeling/bounding_box.py:83: RuntimeWarning: Invalid interval: upper bound 2047.5 is strictly less than lower bound 2137.516888430826.
#   warnings.warn(f"Invalid interval: upper bound {upper} "
#
# 2022-12-08 01:50:09,041 - stpipe.Spec2Pipeline.msa_flagging - WARNING - /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/astropy/modeling/bounding_box.py:83: RuntimeWarning: Invalid interval: upper bound 2047.5 is strictly less than lower bound 2060.9308439432393.
#   warnings.warn(f"Invalid interval: upper bound {upper} "
#
# 2022-12-08 01:50:11,045 - stpipe.Spec2Pipeline.msa_flagging - WARNING - /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/astropy/modeling/bounding_box.py:83: RuntimeWarning: Invalid interval: upper bound 2047.5 is strictly less than lower bound 2204.6162665075267.
#   warnings.warn(f"Invalid interval: upper bound {upper} "
#
# 2022-12-08 01:50:17,573 - stpipe.Spec2Pipeline.msa_flagging - INFO - Step msa_flagging done
# 2022-12-08 01:50:18,195 - stpipe.Spec2Pipeline.srctype - INFO - Step srctype running with args (<IFUImageModel(2048, 2048) from jw01128009001_03104_00004_nrs1_rate.fits>,).
# 2022-12-08 01:50:18,196 - stpipe.Spec2Pipeline.srctype - INFO - Step srctype parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'srctype', 'search_output_file': True, 'input_dir': '', 'source_type': 'POINT'}
# 2022-12-08 01:50:18,204 - stpipe.Spec2Pipeline.srctype - INFO - Input EXP_TYPE is NRS_IFU
# 2022-12-08 01:50:18,204 - stpipe.Spec2Pipeline.srctype - INFO - Input SRCTYAPT = UNKNOWN
# 2022-12-08 01:50:18,205 - stpipe.Spec2Pipeline.srctype - WARNING - Based on user-input, setting SRCTYPE = POINT
# 2022-12-08 01:50:18,208 - stpipe.Spec2Pipeline.srctype - INFO - Step srctype done
# 2022-12-08 01:50:18,544 - stpipe.Spec2Pipeline.flat_field - INFO - Step flat_field running with args (<IFUImageModel(2048, 2048) from jw01128009001_03104_00004_nrs1_rate.fits>,).
# 2022-12-08 01:50:18,545 - stpipe.Spec2Pipeline.flat_field - INFO - Step flat_field parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'flat_field', 'search_output_file': True, 'input_dir': '', 'save_interpolated_flat': False, 'user_supplied_flat': None, 'inverse': False}
# 2022-12-08 01:56:18,523 - stpipe.Spec2Pipeline.flat_field - INFO - Step flat_field done
# 2022-12-08 01:56:19,320 - stpipe.Spec2Pipeline.straylight - INFO - Step straylight running with args (<IFUImageModel(2048, 2048) from jw01128009001_03104_00004_nrs1_rate.fits>,).
# 2022-12-08 01:56:19,321 - stpipe.Spec2Pipeline.straylight - INFO - Step straylight parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': 'straylight', 'search_output_file': True, 'input_dir': ''}
# 2022-12-08 01:56:19,322 - stpipe.Spec2Pipeline.straylight - INFO - Step skipped.
# 2022-12-08 01:56:19,324 - stpipe.Spec2Pipeline.straylight - INFO - Step straylight done
# 2022-12-08 01:56:19,750 - stpipe.Spec2Pipeline.fringe - INFO - Step fringe running with args (<IFUImageModel(2048, 2048) from jw01128009001_03104_00004_nrs1_rate.fits>,).
# 2022-12-08 01:56:19,751 - stpipe.Spec2Pipeline.fringe - INFO - Step fringe parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': 'fringe', 'search_output_file': True, 'input_dir': ''}
# 2022-12-08 01:56:19,752 - stpipe.Spec2Pipeline.fringe - INFO - Step skipped.
# 2022-12-08 01:56:19,754 - stpipe.Spec2Pipeline.fringe - INFO - Step fringe done
# 2022-12-08 01:56:20,222 - stpipe.Spec2Pipeline.pathloss - INFO - Step pathloss running with args (<IFUImageModel(2048, 2048) from jw01128009001_03104_00004_nrs1_rate.fits>,).
# 2022-12-08 01:56:20,223 - stpipe.Spec2Pipeline.pathloss - INFO - Step pathloss parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'pathloss', 'search_output_file': True, 'input_dir': '', 'inverse': False, 'source_type': None}
# 2022-12-08 01:56:20,242 - stpipe.Spec2Pipeline.pathloss - INFO - Using PATHLOSS reference file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_pathloss_0003.fits
# 2022-12-08 01:56:20,275 - stpipe.Spec2Pipeline.pathloss - INFO - Input exposure type is NRS_IFU
# 2022-12-08 01:57:22,411 - stpipe.Spec2Pipeline.pathloss - INFO - Step pathloss done
# 2022-12-08 01:57:23,152 - stpipe.Spec2Pipeline.barshadow - INFO - Step barshadow running with args (<IFUImageModel(2048, 2048) from jw01128009001_03104_00004_nrs1_rate.fits>,).
# 2022-12-08 01:57:23,154 - stpipe.Spec2Pipeline.barshadow - INFO - Step barshadow parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': 'barshadow', 'search_output_file': True, 'input_dir': '', 'inverse': False, 'source_type': None}
# 2022-12-08 01:57:23,154 - stpipe.Spec2Pipeline.barshadow - INFO - Step skipped.
# 2022-12-08 01:57:23,156 - stpipe.Spec2Pipeline.barshadow - INFO - Step barshadow done
# 2022-12-08 01:57:23,575 - stpipe.Spec2Pipeline.photom - INFO - Step photom running with args (<IFUImageModel(2048, 2048) from jw01128009001_03104_00004_nrs1_rate.fits>,).
# 2022-12-08 01:57:23,576 - stpipe.Spec2Pipeline.photom - INFO - Step photom parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'photom', 'search_output_file': True, 'input_dir': '', 'inverse': False, 'source_type': None}
# 2022-12-08 01:57:23,605 - stpipe.Spec2Pipeline.photom - INFO - Using photom reference file: /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_photom_0016.fits
# 2022-12-08 01:57:23,605 - stpipe.Spec2Pipeline.photom - INFO - Using area reference file: /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_area_0005.fits
# 2022-12-08 01:57:26,123 - stpipe.Spec2Pipeline.photom - INFO - Using instrument: NIRSPEC
# 2022-12-08 01:57:26,124 - stpipe.Spec2Pipeline.photom - INFO -  detector: NRS1
# 2022-12-08 01:57:26,124 - stpipe.Spec2Pipeline.photom - INFO -  exp_type: NRS_IFU
# 2022-12-08 01:57:26,124 - stpipe.Spec2Pipeline.photom - INFO -  filter: F100LP
# 2022-12-08 01:57:26,125 - stpipe.Spec2Pipeline.photom - INFO -  grating: G140H
# 2022-12-08 01:57:26,175 - stpipe.Spec2Pipeline.photom - INFO - PHOTMJSR value: 1
# 2022-12-08 01:58:25,841 - stpipe.Spec2Pipeline.photom - INFO - Step photom done
# 2022-12-08 01:58:26,969 - stpipe.Spec2Pipeline.cube_build - INFO - Step cube_build running with args (<IFUImageModel(2048, 2048) from stage2/jw01128009001_03104_00004_nrs1_cal.fits>,).
# 2022-12-08 01:58:26,970 - stpipe.Spec2Pipeline.cube_build - INFO - Step cube_build parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 's3d', 'search_output_file': False, 'input_dir': '', 'channel': 'all', 'band': 'all', 'grating': 'all', 'filter': 'all', 'output_type': 'multi', 'scale1': 0.0, 'scale2': 0.0, 'scalew': 0.0, 'weighting': 'drizzle', 'coord_system': 'skyalign', 'rois': 0.0, 'roiw': 0.0, 'weight_power': 2.0, 'wavemin': None, 'wavemax': None, 'single': False, 'skip_dqflagging': True}
# 2022-12-08 01:58:26,971 - stpipe.Spec2Pipeline.cube_build - INFO - Starting IFU Cube Building Step
# 2022-12-08 01:58:26,971 - stpipe.Spec2Pipeline.cube_build - INFO - Input interpolation: drizzle
# 2022-12-08 01:58:26,971 - stpipe.Spec2Pipeline.cube_build - INFO - Coordinate system to use: skyalign
# 2022-12-08 01:58:26,999 - stpipe.Spec2Pipeline.cube_build - INFO - Reading cube parameter file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_cubepar_0003.fits
# 2022-12-08 01:58:27,048 - stpipe.Spec2Pipeline.cube_build - INFO - Output IFUcube are constructed from all the data
# 2022-12-08 01:58:27,049 - stpipe.Spec2Pipeline.cube_build - INFO - Number of IFU cubes produced by this run = 1
# 2022-12-08 01:58:27,053 - stpipe.Spec2Pipeline.cube_build - INFO - Increasing spatial region of interest default value set for 4 dithers nan
# 2022-12-08 01:58:27,055 - stpipe.Spec2Pipeline.cube_build - INFO - Cube Geometry:
# 2022-12-08 01:58:27,055 - stpipe.Spec2Pipeline.cube_build - INFO - axis#  Naxis  CRPIX    CRVAL      CDELT(arcsec)  Min & Max (xi, eta arcsec)
# 2022-12-08 01:58:27,056 - stpipe.Spec2Pipeline.cube_build - INFO - Axis 1    49  25.00 -87.85544384   0.10000000  -2.45000004   2.45000004
# 2022-12-08 01:58:27,056 - stpipe.Spec2Pipeline.cube_build - INFO - Axis 2    51  26.00  69.45795020   0.10000000  -2.55000004   2.55000004
# 2022-12-08 01:58:27,057 - stpipe.Spec2Pipeline.cube_build - INFO - axis#  Naxis  CRPIX    CRVAL      CDELT(microns)  Min & Max (microns)
# 2022-12-08 01:58:27,057 - stpipe.Spec2Pipeline.cube_build - INFO - Axis 3  2057   1.00   0.96635916   0.00023500   0.96624166   1.44963666
# 2022-12-08 01:58:27,057 - stpipe.Spec2Pipeline.cube_build - INFO - Cube covers grating, filter: g140h, f100lp
# 2022-12-08 01:58:27,058 - stpipe.Spec2Pipeline.cube_build - INFO - Output Name: stage2/jw01128009001_03104_00004_nrs1_s3d.fits
# 2022-12-08 01:58:30,722 - stpipe.Spec2Pipeline.cube_build - INFO - Mapping each NIRSpec slice to sky for input file: stage2/jw01128009001_03104_00004_nrs1_cal.fits
# 2022-12-08 01:59:52,435 - stpipe.Spec2Pipeline.cube_build - INFO - Average # of holes/wavelength plane is < 1
# 2022-12-08 01:59:52,436 - stpipe.Spec2Pipeline.cube_build - INFO - Total # of holes for IFU cube is : 0
# 2022-12-08 01:59:52,437 - stpipe.Spec2Pipeline.cube_build - INFO - Number of wavelength planes removed with no data: 20
# 2022-12-08 01:59:52,550 - stpipe.Spec2Pipeline.cube_build - INFO - Update S_REGION to POLYGON ICRS  272.142656195 69.457255744 272.142656195 69.458644633 272.146456128 69.458644633 272.146456128 69.457255744
# 2022-12-08 01:59:52,556 - stpipe.Spec2Pipeline.cube_build - INFO - Step cube_build done
# 2022-12-08 01:59:52,800 - stpipe.Spec2Pipeline - INFO - Saved model in stage2/jw01128009001_03104_00004_nrs1_s3d.fits
# 2022-12-08 01:59:53,313 - stpipe.Spec2Pipeline.extract_1d - INFO - Step extract_1d running with args (<ModelContainer>,).
# 2022-12-08 01:59:53,314 - stpipe.Spec2Pipeline.extract_1d - INFO - Step extract_1d parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': True, 'suffix': 'x1d', 'search_output_file': True, 'input_dir': '', 'smoothing_length': None, 'bkg_fit': None, 'bkg_order': None, 'bkg_sigma_clip': 3.0, 'log_increment': 50, 'subtract_background': None, 'use_source_posn': None, 'center_xy': None, 'apply_apcorr': True, 'soss_threshold': 0.01, 'soss_n_os': 2, 'soss_transform': None, 'soss_tikfac': None, 'soss_width': 40.0, 'soss_bad_pix': 'model', 'soss_modelname': None}
# 2022-12-08 01:59:53,314 - stpipe.Spec2Pipeline.extract_1d - INFO - Step skipped.
# 2022-12-08 01:59:53,317 - stpipe.Spec2Pipeline.extract_1d - INFO - Step extract_1d done
# 2022-12-08 01:59:53,317 - stpipe.Spec2Pipeline - INFO - Finished processing product stage1/jw01128009001_03104_00004_nrs1
# 2022-12-08 01:59:53,317 - stpipe.Spec2Pipeline - INFO - Ending calwebb_spec2
# 2022-12-08 01:59:53,318 - stpipe.Spec2Pipeline - INFO - Results used CRDS context: jwst_0977.pmap
# 2022-12-08 01:59:53,318 - stpipe.Spec2Pipeline - INFO - Results used CRDS context: jwst_0977.pmap
# 2022-12-08 01:59:53,318 - stpipe.Spec2Pipeline - INFO - Results used CRDS context: jwst_0977.pmap
# 2022-12-08 01:59:53,318 - stpipe.Spec2Pipeline - INFO - Results used CRDS context: jwst_0977.pmap
# 2022-12-08 01:59:55,701 - stpipe.Spec2Pipeline - INFO - Saved model in stage2/jw01128009001_03104_00001_nrs1_cal.fits
# 2022-12-08 01:59:58,515 - stpipe.Spec2Pipeline - INFO - Saved model in stage2/jw01128009001_03104_00002_nrs1_cal.fits
# 2022-12-08 02:00:01,373 - stpipe.Spec2Pipeline - INFO - Saved model in stage2/jw01128009001_03104_00003_nrs1_cal.fits
# 2022-12-08 02:00:04,147 - stpipe.Spec2Pipeline - INFO - Saved model in stage2/jw01128009001_03104_00004_nrs1_cal.fits
# 2022-12-08 02:00:04,148 - stpipe.Spec2Pipeline - INFO - Step Spec2Pipeline done
# [<IFUImageModel(2048, 2048) from jw01128009001_03104_00001_nrs1_cal.fits>,
#  <IFUImageModel(2048, 2048) from jw01128009001_03104_00002_nrs1_cal.fits>,
#  <IFUImageModel(2048, 2048) from jw01128009001_03104_00003_nrs1_cal.fits>,
#  <IFUImageModel(2048, 2048) from jw01128009001_03104_00004_nrs1_cal.fits>]

# %%
# Print out the time benchmark
time1 = time.perf_counter()
print(f"Runtime so far: {time1 - time0:0.4f} seconds")
# Out:
# Runtime so far: 2389.4317 seconds

# %%
### Calling in the calibrated detector images produced by running the stage 2 pipeline on the modified NRS fits files
cal_files = glob.glob('stage2/*cal.fits')
print(cal_files)
# Out:
# ['stage2/jw01128009001_03104_00001_nrs1_cal.fits', 'stage2/jw01128009001_03104_00002_nrs1_cal.fits', 'stage2/jw01128009001_03104_00003_nrs1_cal.fits', 'stage2/jw01128009001_03104_00004_nrs1_cal.fits']

# %%
## create association file for dithered data. Make a json file for the dither set.
call(["asn_from_list", "-o","l3_asn.json"] + cal_files + ["--product-name", "dither"])
# Out:
# 0

# %%
# Start a timer to keep track of runtime
time0 = time.perf_counter()

# %%
# This initial setup is just to make sure that we get the latest parameter reference files
# pulled in for our files.  This is a temporary workaround to get around an issue with
# how this pipeline calling method works.
#
# Setting up steps and running the Spec3 portion of the pipeline. Outlier detector is skipped
# because it tends to cut high value pixels even if it is a part of the target.

json_file = 'l3_asn.json'
crds_config = Spec3Pipeline.get_config_from_reference(json_file)# The exact asn file used doesn't matter
spec3 = Spec3Pipeline.from_config_section(crds_config)
spec3.output_dir = spec3_dir
spec3.assign_mtwcs.skip = True               #skipped because VHS 1256b is not a moving target
spec3.master_background.skip = False
spec3.outlier_detection.skip = True
spec3.cube_build.skip = False
spec3.cube_build.coord_system = 'skyalign'   
spec3.cube_build.output_type = 'band'        # is the default mode for calspec3 and creates IFU cubes containing only one band (channel/sub-channel for MIRI or grating/filter combination for NIRSpec).

#used on MRS or other modes
spec3.mrs_imatch.skip = True
spec3.resample_spec.skip = False
spec3.combine_1d.skip = True

#save results
spec3.save_results = True
spec3(json_file)
# Out:
# 2022-12-09 11:52:31,675 - stpipe.Spec3Pipeline - INFO - Spec3Pipeline instance created.
# 2022-12-09 11:52:31,676 - stpipe.Spec3Pipeline.assign_mtwcs - INFO - AssignMTWcsStep instance created.
# 2022-12-09 11:52:31,677 - stpipe.Spec3Pipeline.master_background - INFO - MasterBackgroundStep instance created.
# 2022-12-09 11:52:31,678 - stpipe.Spec3Pipeline.mrs_imatch - INFO - MRSIMatchStep instance created.
# 2022-12-09 11:52:31,679 - stpipe.Spec3Pipeline.outlier_detection - INFO - OutlierDetectionStep instance created.
# 2022-12-09 11:52:31,681 - stpipe.Spec3Pipeline.resample_spec - INFO - ResampleSpecStep instance created.
# 2022-12-09 11:52:31,682 - stpipe.Spec3Pipeline.cube_build - INFO - CubeBuildStep instance created.
# 2022-12-09 11:52:31,683 - stpipe.Spec3Pipeline.extract_1d - INFO - Extract1dStep instance created.
# 2022-12-09 11:52:31,684 - stpipe.Spec3Pipeline.photom - INFO - PhotomStep instance created.
# 2022-12-09 11:52:31,685 - stpipe.Spec3Pipeline.combine_1d - INFO - Combine1dStep instance created.
# 2022-12-09 11:52:32,469 - stpipe.Spec3Pipeline - INFO - Step Spec3Pipeline running with args ('l3_asn.json',).
# 2022-12-09 11:52:32,476 - stpipe.Spec3Pipeline - INFO - Step Spec3Pipeline parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': 'stage3/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'steps': {'assign_mtwcs': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': 'assign_mtwcs', 'search_output_file': True, 'input_dir': ''}, 'master_background': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'user_background': None, 'save_background': False, 'force_subtract': False}, 'mrs_imatch': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'bkg_degree': 1, 'subtract': False}, 'outlier_detection': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': False, 'input_dir': '', 'weight_type': 'ivm', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'nlow': 0, 'nhigh': 0, 'maskpt': 0.7, 'grow': 1, 'snr': '5.0 4.0', 'scale': '1.2 0.7', 'backg': 0.0, 'save_intermediate_results': False, 'resample_data': True, 'good_bits': '~DO_NOT_USE', 'scale_detection': False, 'allowed_memory': None, 'in_memory': False}, 'resample_spec': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'weight_type': 'ivm', 'output_shape': None, 'crpix': None, 'crval': None, 'rotation': None, 'pixel_scale_ratio': 1.0, 'pixel_scale': None, 'single': False, 'blendheaders': True, 'allowed_memory': None, 'in_memory': True}, 'cube_build': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': False, 'input_dir': '', 'channel': 'all', 'band': 'all', 'grating': 'all', 'filter': 'all', 'output_type': 'band', 'scale1': 0.0, 'scale2': 0.0, 'scalew': 0.0, 'weighting': 'drizzle', 'coord_system': 'skyalign', 'rois': 0.0, 'roiw': 0.0, 'weight_power': 2.0, 'wavemin': None, 'wavemax': None, 'single': False, 'skip_dqflagging': False}, 'extract_1d': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'smoothing_length': None, 'bkg_fit': None, 'bkg_order': None, 'bkg_sigma_clip': 3.0, 'log_increment': 50, 'subtract_background': None, 'use_source_posn': None, 'center_xy': None, 'apply_apcorr': True, 'soss_threshold': 0.01, 'soss_n_os': 2, 'soss_transform': None, 'soss_tikfac': None, 'soss_width': 40.0, 'soss_bad_pix': 'model', 'soss_modelname': None}, 'photom': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'inverse': False, 'source_type': None}, 'combine_1d': {'pre_hooks': [], 'post_hooks': [], 'outp ...
# 2022-12-09 11:52:35,374 - stpipe.Spec3Pipeline - INFO - Prefetching reference files for dataset: 'jw01128009001_03104_00001_nrs1_cal.fits' reftypes = ['apcorr', 'area', 'cubepar', 'drizpars', 'extract1d', 'photom', 'speckernel', 'specprofile', 'spectrace', 'wavemap']
# 2022-12-09 11:52:35,378 - stpipe.Spec3Pipeline - INFO - Prefetch for APCORR reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_apcorr_0009.asdf'.
# 2022-12-09 11:52:35,379 - stpipe.Spec3Pipeline - INFO - Prefetch for AREA reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_area_0005.fits'.
# 2022-12-09 11:52:35,379 - stpipe.Spec3Pipeline - INFO - Prefetch for CUBEPAR reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_cubepar_0003.fits'.
# 2022-12-09 11:52:35,380 - stpipe.Spec3Pipeline - INFO - Prefetch for DRIZPARS reference file is 'N/A'.
# 2022-12-09 11:52:35,380 - stpipe.Spec3Pipeline - INFO - Prefetch for EXTRACT1D reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_extract1d_0001.asdf'.
# 2022-12-09 11:52:35,380 - stpipe.Spec3Pipeline - INFO - Prefetch for PHOTOM reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_photom_0016.fits'.
# 2022-12-09 11:52:35,381 - stpipe.Spec3Pipeline - INFO - Prefetch for SPECKERNEL reference file is 'N/A'.
# 2022-12-09 11:52:35,381 - stpipe.Spec3Pipeline - INFO - Prefetch for SPECPROFILE reference file is 'N/A'.
# 2022-12-09 11:52:35,381 - stpipe.Spec3Pipeline - INFO - Prefetch for SPECTRACE reference file is 'N/A'.
# 2022-12-09 11:52:35,381 - stpipe.Spec3Pipeline - INFO - Prefetch for WAVEMAP reference file is 'N/A'.
# 2022-12-09 11:52:35,382 - stpipe.Spec3Pipeline - INFO - Starting calwebb_spec3 ...
# 2022-12-09 11:52:49,937 - stpipe.Spec3Pipeline.outlier_detection - INFO - Step outlier_detection running with args (<ModelContainer>,).
# 2022-12-09 11:52:49,939 - stpipe.Spec3Pipeline.outlier_detection - INFO - Step outlier_detection parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': True, 'suffix': 'crf', 'search_output_file': False, 'input_dir': '', 'weight_type': 'ivm', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'nlow': 0, 'nhigh': 0, 'maskpt': 0.7, 'grow': 1, 'snr': '5.0 4.0', 'scale': '1.2 0.7', 'backg': 0.0, 'save_intermediate_results': False, 'resample_data': True, 'good_bits': '~DO_NOT_USE', 'scale_detection': False, 'allowed_memory': None, 'in_memory': False}
# 2022-12-09 11:52:49,939 - stpipe.Spec3Pipeline.outlier_detection - INFO - Step skipped.
# 2022-12-09 11:52:49,947 - stpipe.Spec3Pipeline.outlier_detection - INFO - Step outlier_detection done
# 2022-12-09 11:52:50,673 - stpipe.Spec3Pipeline.cube_build - INFO - Step cube_build running with args (<ModelContainer>,).
# 2022-12-09 11:52:50,676 - stpipe.Spec3Pipeline.cube_build - INFO - Step cube_build parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': 's3d', 'search_output_file': False, 'input_dir': '', 'channel': 'all', 'band': 'all', 'grating': 'all', 'filter': 'all', 'output_type': 'band', 'scale1': 0.0, 'scale2': 0.0, 'scalew': 0.0, 'weighting': 'drizzle', 'coord_system': 'skyalign', 'rois': 0.0, 'roiw': 0.0, 'weight_power': 2.0, 'wavemin': None, 'wavemax': None, 'single': False, 'skip_dqflagging': False}
# 2022-12-09 11:52:50,676 - stpipe.Spec3Pipeline.cube_build - INFO - Starting IFU Cube Building Step
# 2022-12-09 11:52:50,677 - stpipe.Spec3Pipeline.cube_build - INFO - Input interpolation: drizzle
# 2022-12-09 11:52:50,677 - stpipe.Spec3Pipeline.cube_build - INFO - Coordinate system to use: skyalign
# 2022-12-09 11:52:50,735 - stpipe.Spec3Pipeline.cube_build - INFO - Reading cube parameter file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_cubepar_0003.fits
# 2022-12-09 11:52:50,786 - stpipe.Spec3Pipeline.cube_build - INFO - Output Cubes are single grating, single filter IFU Cubes
# 2022-12-09 11:52:50,786 - stpipe.Spec3Pipeline.cube_build - INFO - Number of IFU cubes produced by this run = 1
# 2022-12-09 11:52:50,793 - stpipe.Spec3Pipeline.cube_build - INFO - Cube Geometry:
# 2022-12-09 11:52:50,793 - stpipe.Spec3Pipeline.cube_build - INFO - axis#  Naxis  CRPIX    CRVAL      CDELT(arcsec)  Min & Max (xi, eta arcsec)
# 2022-12-09 11:52:50,794 - stpipe.Spec3Pipeline.cube_build - INFO - Axis 1    71  36.00 -87.85536396   0.10000000  -3.55000005   3.55000005
# 2022-12-09 11:52:50,794 - stpipe.Spec3Pipeline.cube_build - INFO - Axis 2    73  37.00  69.45826313   0.10000000  -3.65000005   3.65000005
# 2022-12-09 11:52:50,795 - stpipe.Spec3Pipeline.cube_build - INFO - axis#  Naxis  CRPIX    CRVAL      CDELT(microns)  Min & Max (microns)
# 2022-12-09 11:52:50,795 - stpipe.Spec3Pipeline.cube_build - INFO - Axis 3  2057   1.00   0.96635916   0.00023500   0.96624166   1.44963666
# 2022-12-09 11:52:50,795 - stpipe.Spec3Pipeline.cube_build - INFO - Cube covers grating, filter: g140h, f100lp
# 2022-12-09 11:52:50,796 - stpipe.Spec3Pipeline.cube_build - INFO - Output Name: dither_g140h-f100lp_s3d.fits
# 2022-12-09 11:52:54,392 - stpipe.Spec3Pipeline.cube_build - INFO - Mapping each NIRSpec slice to sky for input file: jw01128009001_03104_00001_nrs1_cal.fits
# 2022-12-09 11:54:24,812 - stpipe.Spec3Pipeline.cube_build - INFO - Mapping each NIRSpec slice to sky for input file: jw01128009001_03104_00002_nrs1_cal.fits
# 2022-12-09 11:55:55,071 - stpipe.Spec3Pipeline.cube_build - INFO - Mapping each NIRSpec slice to sky for input file: jw01128009001_03104_00003_nrs1_cal.fits
# 2022-12-09 11:57:23,920 - stpipe.Spec3Pipeline.cube_build - INFO - Mapping each NIRSpec slice to sky for input file: jw01128009001_03104_00004_nrs1_cal.fits
# 2022-12-09 11:58:51,393 - stpipe.Spec3Pipeline.cube_build - INFO - Average # of holes/wavelength plane is < 1
# 2022-12-09 11:58:51,394 - stpipe.Spec3Pipeline.cube_build - INFO - Total # of holes for IFU cube is : 2
# 2022-12-09 11:58:51,396 - stpipe.Spec3Pipeline.cube_build - INFO - Number of wavelength planes removed with no data: 20
# 2022-12-09 11:58:55,117 - stpipe.Spec3Pipeline.cube_build - INFO - Update S_REGION to POLYGON ICRS  272.141865175 69.457263110 272.141865175 69.459263111 272.147406903 69.459263111 272.147406903 69.457263110
# 2022-12-09 11:58:55,888 - stpipe.Spec3Pipeline.cube_build - INFO - Saved model in stage3/dither_g140h-f100lp_s3d.fits
# 2022-12-09 11:58:55,888 - stpipe.Spec3Pipeline.cube_build - INFO - Step cube_build done
# 2022-12-09 11:58:56,894 - stpipe.Spec3Pipeline.extract_1d - INFO - Step extract_1d running with args (<ModelContainer>,).
# 2022-12-09 11:58:56,896 - stpipe.Spec3Pipeline.extract_1d - INFO - Step extract_1d parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': 'x1d', 'search_output_file': False, 'input_dir': '', 'smoothing_length': None, 'bkg_fit': None, 'bkg_order': None, 'bkg_sigma_clip': 3.0, 'log_increment': 50, 'subtract_background': None, 'use_source_posn': None, 'center_xy': None, 'apply_apcorr': True, 'soss_threshold': 0.01, 'soss_n_os': 2, 'soss_transform': None, 'soss_tikfac': None, 'soss_width': 40.0, 'soss_bad_pix': 'model', 'soss_modelname': None}
# 2022-12-09 11:58:56,910 - stpipe.Spec3Pipeline.extract_1d - INFO - Using EXTRACT1D reference file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_extract1d_0001.asdf
# 2022-12-09 11:58:56,920 - stpipe.Spec3Pipeline.extract_1d - INFO - Using APCORR file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_apcorr_0009.asdf
# 2022-12-09 11:58:57,855 - stpipe.Spec3Pipeline.extract_1d - INFO - Turning on source position correction for exp_type = NRS_IFU
# 2022-12-09 11:58:57,855 - stpipe.Spec3Pipeline.extract_1d - INFO - Source type = POINT
# 2022-12-09 11:58:57,870 - stpipe.Spec3Pipeline.extract_1d - INFO - Input model does not break out variance information. Passing only generalized errors.
# 2022-12-09 11:58:57,887 - stpipe.Spec3Pipeline.extract_1d - INFO - Using x_center = 33, y_center = 26, based on TARG_RA and TARG_DEC
# 2022-12-09 11:59:08,172 - stpipe.Spec3Pipeline.extract_1d - INFO - Applying Aperture correction.
# 2022-12-09 11:59:09,298 - stpipe.Spec3Pipeline.extract_1d - INFO - Saved model in stage3/dither_g140h-f100lp_x1d.fits
# 2022-12-09 11:59:09,299 - stpipe.Spec3Pipeline.extract_1d - INFO - Step extract_1d done
# 2022-12-09 11:59:09,304 - stpipe.Spec3Pipeline - INFO - Ending calwebb_spec3
# 2022-12-09 11:59:09,304 - stpipe.Spec3Pipeline - INFO - Step Spec3Pipeline done

# %%
# Print out the time benchmark
time1 = time.perf_counter()
print(f"Runtime so far: {time1 - time0:0.4f} seconds")
# Out:
# Runtime so far: 401.6596 seconds

# %%
# check the extracted spectrum from the JWST pipeline
data = fits.getdata('stage3/dither_g140h-f100lp_x1d.fits')
wavelength = data['wavelength']
flux  = data['flux']
flux_error = data['flux_error']

# %matplotlib notebook
plt.plot(wavelength, flux, label = 'stage 3')
#plt.ylim([0,8])
plt.ylabel('Jy')
plt.xlabel('Wavelength (microns)')
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="250">

# %%
cube_data = fits.getdata('stage3/dither_g140h-f100lp_s3d.fits')
cube=SpectralCube.read('stage3/dither_g140h-f100lp_s3d.fits',hdu=1)

wavelength=cube.spectral_axis
wavelength=n.array(wavelength)

cube_collapse = n.nanmedian(cube_data, axis = 0)
cube_collapse /= n.nanmax(cube_collapse) #the image is normalized so the 2-D Gaussian fit is easier.

# %%
# %matplotlib notebook
plt.figure('collapsed cube')
plt.title('Median Collapsed Spectral Cube')
plt.imshow((cube_collapse))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
## fitting a gaussian to the collapsed cube which is a median image to remove high pixels
image = cube_collapse
y_len, x_len = image.shape
bounds = ((0, 0, n.nanmin(image), 1, 1, n.nanmedian(image)) , (x_len, y_len, n.nanmax(image), x_len, y_len, 2 * n.nanmax(image)) )
guess = n.array([34, 38, n.nanmin(image), 1.2, 1.2, n.nanmax(image)])
fit_arr = optimize.least_squares(image_solve, guess, args = (image,), bounds = bounds )#, bounds=bounds)
x0_fit, y0_fit, offset_fit, sigma_x_fit, sigma_y_fit, A_fit = fit_arr.x


x0_fit = n.round(x0_fit, decimals = 0) #rounding because jwst pipeline does not take float values
y0_fit = n.round(y0_fit, decimals = 0) #rounding because jwst pipeline does not take float values


print('centroids (x, y)')
print(x0_fit, y0_fit)
print('sigmax, sigma y')
print(sigma_x_fit, sigma_y_fit)
# Out:
# centroids (x, y)
# 34.0 38.0
# sigmax, sigma y
# 1.0000586940471072 1.0026725152739986

# %%
#re-running the jwst pipeline extraction step to ensure the extraction radius is centered.
spec3.extract_1d.center_xy = (int(x0_fit), int(y0_fit))
spec3.extract_1d('stage3/dither_g140h-f100lp_s3d.fits')
# Out:
# 2022-12-07 19:43:27,445 - stpipe.Spec3Pipeline.extract_1d - INFO - Step extract_1d running with args ('stage3/dither_g140h-f100lp_s3d.fits',).
# 2022-12-07 19:43:27,447 - stpipe.Spec3Pipeline.extract_1d - INFO - Step extract_1d parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': 'x1d', 'search_output_file': False, 'input_dir': '', 'smoothing_length': None, 'bkg_fit': None, 'bkg_order': None, 'bkg_sigma_clip': 3.0, 'log_increment': 50, 'subtract_background': None, 'use_source_posn': None, 'center_xy': [34, 38], 'apply_apcorr': True, 'soss_threshold': 0.01, 'soss_n_os': 2, 'soss_transform': None, 'soss_tikfac': None, 'soss_width': 40.0, 'soss_bad_pix': 'model', 'soss_modelname': None}
# 2022-12-07 19:43:27,723 - stpipe.Spec3Pipeline.extract_1d - INFO - Using EXTRACT1D reference file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_extract1d_0001.asdf
# 2022-12-07 19:43:27,733 - stpipe.Spec3Pipeline.extract_1d - INFO - Using APCORR file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_apcorr_0009.asdf
# 2022-12-07 19:43:28,656 - stpipe.Spec3Pipeline.extract_1d - INFO - Turning on source position correction for exp_type = NRS_IFU
# 2022-12-07 19:43:28,656 - stpipe.Spec3Pipeline.extract_1d - INFO - Source type = POINT
# 2022-12-07 19:43:28,671 - stpipe.Spec3Pipeline.extract_1d - INFO - Using user-supplied x_center=34, y_center=38
# 2022-12-07 19:43:28,671 - stpipe.Spec3Pipeline.extract_1d - INFO - Input model does not break out variance information. Passing only generalized errors.
# 2022-12-07 19:43:39,194 - stpipe.Spec3Pipeline.extract_1d - INFO - Applying Aperture correction.
# 2022-12-07 19:43:40,307 - stpipe.Spec3Pipeline.extract_1d - INFO - Saved model in stage3/dither_g140h-f100lp_x1d.fits
# 2022-12-07 19:43:40,308 - stpipe.Spec3Pipeline.extract_1d - INFO - Step extract_1d done
# <MultiSpecModel from dither_g140h-f100lp_x1d.fits>

# %%
# check the extracted spectrum from the JWST pipeline
data = fits.getdata('stage3/dither_g140h-f100lp_x1d.fits')
wavelength = data['wavelength']
flux  = data['flux']
flux_error = data['flux_error']

# %matplotlib notebook
plt.plot(wavelength, flux, label = 'stage 3')
plt.ylim([0,8])
plt.ylabel('Jy')
plt.xlabel('Wavelength (microns)')
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#save text
#data_out = n.vstack((wavelength,  flux, flux_error))
#data_out = n.transpose(data_out)

#spectra_dir = '../spectra/' # Detector1 pipeline outputs will go here
#if not os.path.exists(spectra_dir):
#    os.makedirs(spectra_dir)

#header = 'wavelength (microns) flux(Jy), flux error(Jy)'
#n.savetxt('../spectra/detector1_f100lp_g140h.txt', data_out, header = header)

# %%
cal_file
# Out:
# 'stage2/jw01128009001_03104_00001_nrs1_cal.fits'

# %%
spec3.get_pars()
# Out:
# {'pre_hooks': [],
#  'post_hooks': [],
#  'output_file': '/Users/zen/projects/JWST_Observations_VHS1256b/reduction_public/nirspec_a_star_reduction/F100LP_G140H_current_pipeline/all_dithers_detector1/dither',
#  'output_dir': 'stage3/',
#  'output_ext': '.fits',
#  'output_use_model': False,
#  'output_use_index': True,
#  'save_results': True,
#  'skip': False,
#  'suffix': 'spec3pipeline',
#  'search_output_file': True,
#  'input_dir': '',
#  'steps': {'assign_mtwcs': {'pre_hooks': [],
#    'post_hooks': [],
#    'output_file': None,
#    'output_dir': None,
#    'output_ext': '.fits',
#    'output_use_model': True,
#    'output_use_index': True,
#    'save_results': False,
#    'skip': True,
#    'suffix': 'assign_mtwcs',
#    'search_output_file': True,
#    'input_dir': ''},
#   'master_background': {'pre_hooks': [],
#    'post_hooks': [],
#    'output_file': None,
#    'output_dir': None,
#    'output_ext': '.fits',
#    'output_use_model': True,
#    'output_use_index': True,
#    'save_results': False,
#    'skip': False,
#    'suffix': 'mbsub',
#    'search_output_file': True,
#    'input_dir': '',
#    'user_background': None,
#    'save_background': False,
#    'force_subtract': False},
#   'mrs_imatch': {'pre_hooks': [],
#    'post_hooks': [],
#    'output_file': None,
#    'output_dir': None,
#    'output_ext': '.fits',
#    'output_use_model': False,
#    'output_use_index': True,
#    'save_results': False,
#    'skip': True,
#    'suffix': 'mrs_imatch',
#    'search_output_file': True,
#    'input_dir': '',
#    'bkg_degree': 1,
#    'subtract': False},
#   'outlier_detection': {'pre_hooks': [],
#    'post_hooks': [],
#    'output_file': None,
#    'output_dir': None,
#    'output_ext': '.fits',
#    'output_use_model': False,
#    'output_use_index': True,
#    'save_results': True,
#    'skip': True,
#    'suffix': 'crf',
#    'search_output_file': False,
#    'input_dir': '',
#    'weight_type': 'ivm',
#    'pixfrac': 1.0,
#    'kernel': 'square',
#    'fillval': 'INDEF',
#    'nlow': 0,
#    'nhigh': 0,
#    'maskpt': 0.7,
#    'grow': 1,
#    'snr': '5.0 4.0',
#    'scale': '1.2 0.7',
#    'backg': 0.0,
#    'save_intermediate_results': False,
#    'resample_data': True,
#    'good_bits': '~DO_NOT_USE',
#    'scale_detection': False,
#    'allowed_memory': None,
#    'in_memory': False},
#   'resample_spec': {'pre_hooks': [],
#    'post_hooks': [],
#    'output_file': None,
#    'output_dir': None,
#    'output_ext': '.fits',
#    'output_use_model': False,
#    'output_use_index': True,
#    'save_results': True,
#    'skip': False,
#    'suffix': 's2d',
#    'search_output_file': True,
#    'input_dir': '',
#    'pixfrac': 1.0,
#    'kernel': 'square',
#    'fillval': 'INDEF',
#    'weight_type': 'ivm',
#    'output_shape': None,
#    'crpix': None,
#    'crval': None,
#    'rotation': None,
#    'pixel_scale_ratio': 1.0,
#    'pixel_scale': None,
#    'single': False,
#    'blendheaders': True,
#    'allowed_memory': None,
#    'in_memory': True},
#   'cube_build': {'pre_hooks': [],
#    'post_hooks': [],
#    'output_file': None,
#    'output_dir': None,
#    'output_ext': '.fits',
#    'output_use_model': True,
#    'output_use_index': True,
#    'save_results': True,
#    'skip': False,
#    'suffix': 's3d',
#    'search_output_file': False,
#    'input_dir': '',
#    'channel': 'all',
#    'band': 'all',
#    'grating': 'all',
#    'filter': 'all',
#    'output_type': 'band',
#    'scale1': 0.0,
#    'scale2': 0.0,
#    'scalew': 0.0,
#    'weighting': 'drizzle',
#    'coord_system': 'skyalign',
#    'rois': 0.0,
#    'roiw': 0.0,
#    'weight_power': 2.0,
#    'wavemin': None,
#    'wavemax': None,
#    'single': False,
#    'skip_dqflagging': False},
#   'extract_1d': {'pre_hooks': [],
#    'post_hooks': [],
#    'output_file': None,
#    'output_dir': None,
#    'output_ext': '.fits',
#    'output_use_model': False,
#    'output_use_index': True,
#    'save_results': True,
#    'skip': False,
#    'suffix': 'x1d',
#    'search_output_file': False,
#    'input_dir': '',
#    'smoothing_length': None,
#    'bkg_fit': None,
#    'bkg_order': None,
#    'bkg_sigma_clip': 3.0,
#    'log_increment': 50,
#    'subtract_background': None,
#    'use_source_posn': None,
#    'center_xy': None,
#    'apply_apcorr': True,
#    'soss_threshold': 0.01,
#    'soss_n_os': 2,
#    'soss_transform': None,
#    'soss_tikfac': None,
#    'soss_width': 40.0,
#    'soss_bad_pix': 'model',
#    'soss_modelname': None},
#   'photom': {'pre_hooks': [],
#    'post_hooks': [],
#    'output_file': None,
#    'output_dir': None,
#    'output_ext': '.fits',
#    'output_use_model': False,
#    'output_use_index': True,
#    'save_results': False,
#    'skip': False,
#    'suffix': None,
#    'search_output_file': True,
#    'input_dir': '',
#    'inverse': False,
#    'source_type': None},
#   'combine_1d': {'pre_hooks': [],
#    'post_hooks': [],
#    'output_file': None,
#    'output_dir': None,
#    'output_ext': '.fits',
#    'output_use_model': False,
#    'output_use_index': True,
#    'save_results': True,
#    'skip': True,
#    'suffix': 'c1d',
#    'search_output_file': True,
#    'input_dir': '',
#    'exptime_key': 'exposure_time'}}}
