# %% [markdown]
# This notebook was made to reduce NIRSpec dithers into a spectral cube by:
#
# 1. Using the Stage 1 Detector pipleine to turn uncalibrated detector images (_uncal.fits) into rate files (_rate.fits).
#
# 2. Using Stage 2 of the Spectroscopic pipeline to turn rate files(_rate.fits) into calibrated detector images (_cal.fits) and spectral cubes (_s3d.fits)
#
# 3. Using Stage 3 of the spectroscopic pipeline to combine the stage 2 rate files from each filter/grating combination.
#
# Other notes/caveats:
# Stage 2 cube building is redundant with Stage 3 if you are not combining dithers.

# %%
from astropy.io import fits
import glob, os
from subprocess import call
from astropy.io import fits
import time

import jwst
from jwst.pipeline import Detector1Pipeline, Spec2Pipeline, Spec3Pipeline

import matplotlib.pyplot as plt
import numpy as n

from spectral_cube import SpectralCube
from scipy import optimize


os.environ['CRDS_PATH'] = '/Users/zen/crds_cache/jwst_ops'
os.environ['CRDS_SERVER_URL'] = 'https://jwst-crds.stsci.edu'
os.environ['CRDS_CONTEXT'] = 'jwst_0977.pmap'
os.environ['CRDS_VERSION'] = '11.16.12'


# Print out what pipeline version we're using
print('JWST pipeline version',jwst.__version__)
# Out:
# JWST pipeline version 1.7.2

# %%
# Functions for fitting a 2-D guassian to images to find the PSF center in collapsed spectral cubes
def gauss2d(x, y, x0, y0, offset, sigma_x, sigma_y, A):

    x_exp = ( ( x - x0 )**2) / (2 * sigma_x ** 2)
    y_exp = ( ( y - y0 )**2) / (2 * sigma_y ** 2)
    f = A * n.exp( - x_exp - y_exp) + offset

    return f

def image_solve(constants, im):

    x0_val, y0_val, offset_val, sigma_x_val, sigma_y_val, A_val = constants

    y_len, x_len = im.shape
    y_arr = n.arange(0, y_len)
    x_arr = n.arange(0, x_len)
    xx, yy = n.meshgrid(x_arr, y_arr)

    fit = gauss2d(xx, yy, x0_val, y0_val, offset_val, sigma_x_val, sigma_y_val, A_val)

    min_diff = n.nansum(abs(im - fit)**2)

    return min_diff

# %%
det1_dir = 'stage1/' # Detector1 pipeline outputs will go here
spec2_dir = 'stage2/' # Spec2 pipeline outputs will go here
spec3_dir = 'stage3/' # Spec3 pipeline outputs will go here

# We need to check that the desired output directories exist, and if not create them
if not os.path.exists(det1_dir):
    os.makedirs(det1_dir)
if not os.path.exists(spec2_dir):
    os.makedirs(spec2_dir)
if not os.path.exists(spec3_dir):
    os.makedirs(spec3_dir)

# %%
uncal_file_dir = '../../../cal_data/'

uncal_files = ['jw01128009001_03108_00001_nrs2_uncal.fits',
              'jw01128009001_03108_00002_nrs2_uncal.fits',
              'jw01128009001_03108_00003_nrs2_uncal.fits',
              'jw01128009001_03108_00004_nrs2_uncal.fits']

for i, file in enumerate(uncal_files):
    uncal_files[i] = uncal_file_dir + uncal_files[i]
print(uncal_files)

print('Found ' + str(len(uncal_files)) + ' input files to process')
# Out:
# ['../../../cal_data/jw01128009001_03108_00001_nrs2_uncal.fits', '../../../cal_data/jw01128009001_03108_00002_nrs2_uncal.fits', '../../../cal_data/jw01128009001_03108_00003_nrs2_uncal.fits', '../../../cal_data/jw01128009001_03108_00004_nrs2_uncal.fits']
# Found 4 input files to process

# %%
# Start a timer to keep track of runtime
time0 = time.perf_counter()

# %%
for file in uncal_files:
    
    det1 = Detector1Pipeline() # Instantiate the pipeline

    #output directory
    det1.output_dir = det1_dir # Specify where the output should go

    #defining used pipeline steps
    det1.group_scale.skip = False  #scaling factor from group images
    det1.dq_init.skip = False      #data quality check
    det1.saturation.skip = False   #check for saturated pixels
    det1.ipc.skip = False          #interpixel capacitance scaling from a reference. Usually skipped in all instrument modes
    det1.superbias.skip = False    #subtract a bias frame from the data
    det1.refpix.skip = False       #correct for drifts in read outs using reference pixels or columns
    det1.linearity.skip = False    #used to correct for non-linearity in the frames
    det1.persistence.skip = True   #according to the docs it is supposed to be hardwired to skipped
    det1.dark_current.skip = False #
    det1.jump.skip = False         #
    det1.jump.maximum_cores = 'half' #distribute the computing load across half of your computer cores to speed it up
    det1
- stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline running with args ('../../../cal_data/jw01128009001_03108_00003_nrs2_uncal.fits',).
# ...
# 2022-12-08 14:30:02,030 - stpipe.Detector1Pipeline - INFO - Prefetch for READNOISE reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_readnoise_0017.fits'.
# 2022-12-08 14:30:02,031 - stpipe.Detector1Pipeline - INFO - Prefetch for REFPIX reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_refpix_0018.fits'.
# 2022-12-08 14:30:02,031 - stpipe.Detector1Pipeline - INFO - Prefetch for SATURATION reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_saturation_0026.fits'.
# 2022-12-08 14:30:02,032 - stpipe.Detector1Pipeline - INFO - Prefetch for SUPERBIAS reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_superbias_0256.fits'.
# 2022-12-08 14:30:02,032 - stpipe.Detector1Pipeline - INFO - Starting calwebb_detector1 ...
# 2022-12-08 14:30:03,089 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale running with args (<RampModel(1, 36, 3200, 2048) from jw01128009001_03108_00004_nrs2_uncal.fits>,).
# 2022-12-08 14:30:03,090 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../cal_data'}
# 2022-12-08 14:30:03,707 - stpipe.Detector1Pipeline.group_scale - INFO - NFRAMES and FRMDIVSR are equal; correction not needed
# 2022-12-08 14:30:03,707 - stpipe.Detector1Pipeline.group_scale - INFO - Step will be skipped
# 2022-12-08 14:30:03,710 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale done
# 2022-12-08 14:30:03,848 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init running with args (<RampModel(1, 36, 3200, 2048) from jw01128009001_03108_00004_nrs2_uncal.fits>,).
# 2022-12-08 14:30:03,849 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../cal_data'}
# 2022-12-08 14:30:03,868 - stpipe.Detector1Pipeline.dq_init - INFO - Using MASK reference file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_mask_0033.fits
# 2022-12-08 14:30:04,679 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init done
# 2022-12-08 14:30:04,807 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation running with args (<RampModel(1, 36, 3200, 2048) from jw01128009001_03108_00004_nrs2_uncal.fits>,).
# 2022-12-08 14:30:04,808 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../cal_data', 'n_pix_grow_sat': 1}
# 2022-12-08 14:30:04,828 - stpipe.Detector1Pipeline.saturation - INFO - Using SATURATION reference file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_saturation_0026.fits
# 2022-12-08 14:30:09,472 - stpipe.Detector1Pipeline.saturation - INFO - Detected 38549 saturated pixels
# 2022-12-08 14:30:09,653 - stpipe.Detector1Pipeline.saturation - INFO - Detected 0 A/D floor pixels
# 2022-12-08 14:30:09,664 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation done
# 2022-12-08 14:30:09,796 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc running with args (<RampModel(1, 36, 3200, 2048) from jw01128009001_03108_00004_nrs2_uncal.fits>,).
# 2022-12-08 14:30:09,797 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../cal_data'}
# 2022-12-08 14:30:09,816 - stpipe.Detector1Pipeline.ipc - INFO - Using IPC reference file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_ipc_0012.fits
# 2022-12-08 14:30:11,567 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc done
# 2022-12-08 14:30:11,687 - stpipe.Detector1Pipeline.superbias - INFO - Step superbias running with args (<RampModel(1, 36, 3200, 2048) from jw01128009001_03108_00004_nrs2_uncal.fits>,).
# 2022-12-08 14:30:11,688 - stpipe.Detector1Pipeline.superbias - INFO - Step superbias parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../cal_data'}
# 2022-12-08 14:30:11,709 - stpipe.Detector1Pipeline.superbias - INFO - Using SUPERBIAS reference file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_superbias_0256.fits
# 2022-12-08 14:30:12,459 - stpipe.Detector1Pipeline.superbias - INFO - Step superbias done
# 2022-12-08 14:30:12,584 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix running with args (<RampModel(1, 36, 3200, 2048) from jw01128009001_03108_00004_nrs2_uncal.fits>,).
# 2022-12-08 14:30:12,585 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../cal_data', 'odd_even_columns': True, 'use_side_ref_pixels': True, 'side_smoothing_length': 11, 'side_gain': 1.0, 'odd_even_rows': True}
# 2022-12-08 14:30:12,605 - stpipe.Detector1Pipeline.refpix - INFO - Using refpix reference file: /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_refpix_0018.fits
# 2022-12-08 14:30:12,992 - stpipe.Detector1Pipeline.refpix - INFO - Working on integration 1
# 2022-12-08 14:31:26,227 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix done
# 2022-12-08 14:31:26,386 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity running with args (<RampModel(1, 36, 3200, 2048) from jw01128009001_03108_00004_nrs2_uncal.fits>,).
# 2022-12-08 14:31:26,387 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../cal_data'}
# 2022-12-08 14:31:26,407 - stpipe.Detector1Pipeline.linearity - INFO - Using Linearity reference file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_linearity_0025.fits
# 2022-12-08 14:31:26,500 - stpipe.Detector1Pipeline.linearity - WARNING - Keyword BAD_LIN_CORR does not correspond to an existing DQ mnemonic, so will be ignored
# 2022-12-08 14:31:27,657 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity done
# 2022-12-08 14:31:27,853 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current running with args (<RampModel(1, 36, 3200, 2048) from jw01128009001_03108_00004_nrs2_uncal.fits>,).
# 2022-12-08 14:31:27,854 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': 'stage1/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../cal_data', 'dark_output': None}
# 2022-12-08 14:31:28,340 - stpipe.Detector1Pipeline.dark_current - INFO - Using DARK reference file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_dark_0206.fits
# 2022-12-08 14:31:33,161 - stpipe.Detector1Pipeline.dark_current - INFO - Science data nints=1, ngroups=36, nframes=1, groupgap=0
# 2022-12-08 14:31:33,163 - stpipe.Detector1Pipeline.dark_current - INFO - Dark data nints=1, ngroups=245, nframes=1, groupgap=0
# 2022-12-08 14:31:42,640 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current done
# 2022-12-08 14:31:43,372 - stpipe.Detector1Pipeline.jump - INFO - Step jump running with args (<RampModel(1, 36, 3200, 2048) from jw01128009001_03108_00004_nrs2_uncal.fits>,).
# 2022-12-08 14:31:43,375 - stpipe.Detector1Pipeline.jump - INFO - Step jump parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../cal_data', 'rejection_threshold': 4.0, 'three_group_rejection_threshold': 6.0, 'four_group_rejection_threshold': 5.0, 'maximum_cores': 'half', 'flag_4_neighbors': True, 'max_jump_to_flag_neighbors': 1000.0, 'min_jump_to_flag_neighbors': 10.0, 'after_jump_flag_dn1': 0.0, 'after_jump_flag_time1': 0.0, 'after_jump_flag_dn2': 0.0, 'after_jump_flag_time2': 0.0}
# 2022-12-08 14:31:43,599 - stpipe.Detector1Pipeline.jump - INFO - CR rejection threshold = 4 sigma
# 2022-12-08 14:31:43,600 - stpipe.Detector1Pipeline.jump - INFO - Maximum cores to use = half
# 2022-12-08 14:31:43,833 - stpipe.Detector1Pipeline.jump - INFO - Using GAIN reference file: /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_gain_0020.fits
# 2022-12-08 14:31:44,106 - stpipe.Detector1Pipeline.jump - INFO - Using READNOISE reference file: /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_readnoise_0017.fits
# 2022-12-08 14:31:45,537 - stpipe.Detector1Pipeline.jump - INFO - Executing two-point difference method
# 2022-12-08 14:31:45,771 - stpipe.Detector1Pipeline.jump - INFO - Creating 5 processes for jump detection
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/jump/twopoint_difference.py:154: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/jump/twopoint_difference.py:154: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/jump/twopoint_difference.py:154: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/jump/twopoint_difference.py:154: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/jump/twopoint_difference.py:154: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
# 2022-12-08 14:32:00,797 - stpipe.Detector1Pipeline.jump - INFO - Total elapsed time = 15.259 sec
# 2022-12-08 14:32:00,828 - stpipe.Detector1Pipeline.jump - INFO - The execution time in seconds: 17.229304
# 2022-12-08 14:32:00,834 - stpipe.Detector1Pipeline.jump - INFO - Step jump done
# 2022-12-08 14:32:01,011 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit running with args (<RampModel(1, 36, 3200, 2048) from jw01128009001_03108_00004_nrs2_uncal.fits>,).
# 2022-12-08 14:32:01,012 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': 'stage1/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../cal_data', 'int_name': '', 'save_opt': False, 'opt_name': '', 'suppress_one_group': True, 'maximum_cores': 'half'}
# 2022-12-08 14:32:01,621 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using READNOISE reference file: /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_readnoise_0017.fits
# 2022-12-08 14:32:01,622 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using GAIN reference file: /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_gain_0020.fits
# 2022-12-08 14:32:01,720 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using algorithm = ols
# 2022-12-08 14:32:01,721 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using weighting = optimal
# 2022-12-08 14:32:02,336 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of processors used for multiprocessing: 5
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/ramp_fitting/ols_fit.py:1089: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/ramp_fitting/ols_fit.py:1089: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/ramp_fitting/ols_fit.py:1089: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/ramp_fitting/ols_fit.py:1089: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/ramp_fitting/ols_fit.py:1089: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# 2022-12-08 14:33:09,970 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit done
# 2022-12-08 14:33:10,138 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<IFUImageModel(2048, 2048) from jw01128009001_03108_00004_nrs2_uncal.fits>,).
# 2022-12-08 14:33:10,141 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'gain_scale', 'search_output_file': True, 'input_dir': '../../../cal_data'}
# 2022-12-08 14:33:10,196 - stpipe.Detector1Pipeline.gain_scale - INFO - Rescaling by 1.0
# 2022-12-08 14:33:10,205 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# 2022-12-08 14:33:10,268 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<CubeModel(1, 2048, 2048) from jw01128009001_03108_00004_nrs2_uncal.fits>,).
# 2022-12-08 14:33:10,269 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'gain_scaleints', 'search_output_file': True, 'input_dir': '../../../cal_data'}
# 2022-12-08 14:33:10,305 - stpipe.Detector1Pipeline.gain_scale - INFO - Rescaling by 1.0
# 2022-12-08 14:33:10,313 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# 2022-12-08 14:33:10,549 - stpipe.Detector1Pipeline - INFO - Saved model in stage1/jw01128009001_03108_00004_nrs2_rateints.fits
# 2022-12-08 14:33:10,550 - stpipe.Detector1Pipeline - INFO - ... ending calwebb_detector1
# 2022-12-08 14:33:10,550 - stpipe.Detector1Pipeline - INFO - Results used CRDS context: jwst_0977.pmap
# 2022-12-08 14:33:10,751 - stpipe.Detector1Pipeline - INFO - Saved model in stage1/jw01128009001_03108_00004_nrs2_rate.fits
# 2022-12-08 14:33:10,751 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline done

# %%
# Print out the time benchmark
time1 = time.perf_counter()
print(f"Runtime so far: {time1 - time0:0.4f} seconds")
# Out:
# Runtime so far: 858.8488 seconds

# %%
# Look for input uncalibrated slope files from the Detector1 pipeline
sstring = 'stage1/'+ '*_rate.fits'
rate_files = sorted(glob.glob(sstring))
print('Found ' + str(len(rate_files)) + ' input files to process')
# Out:
# Found 4 input files to process

# %%
# Start a timer to keep track of runtime
time0 = time.perf_counter()

# %%
# Setting up steps and running the Spec2 portion of the pipeline. 

spec2 = Spec2Pipeline()
spec2.output_dir = spec2_dir
spec2.assign_wcs.skip = False
spec2.bkg_subtract.skip = False
spec2.imprint_subtract.skip = False
spec2.msa_flagging.skip = False
spec2.srctype.source_type = 'POINT'
spec2.flat_field.skip = False
spec2.pathloss.skip = False
spec2.photom.skip = False
spec2.cube_build.skip = False
spec2.extract_1d.skip = True

##extra steps that only apply to other instruments modes.
spec2.extract_2d.skip = True
spec2.master_background_mos.skip = True
spec2.barshadow.skip = True
spec2.wavecorr.skip = True
spec2.straylight.skip = True
spec2.fringe.skip = True
#spec2.residual_fringe.skip = True   # is not used in 1.7.2 works in 1.8.4
spec2.wfss_contam.skip = True
spec2.resample_spec.skip = True

#choose what results to save and from what steps
spec2.save_results = True
spec2.run(rate_files)
# Out:
# 2022-12-08 14:33:10,789 - stpipe.Spec2Pipeline - INFO - Spec2Pipeline instance created.
# 
- stpipe.Spec2Pipeline.srctype - INFO - Input EXP_TYPE is NRS_IFU
# 2022-12-08 15:01:09,446 - stpipe.Spec2Pipeline.srctype - INFO - Input SRCTYAPT = UNKNOWN
# 2022-12-08 15:01:09,446 - stpipe.Spec2Pipeline.srctype - WARNING - Based on user-input, setting SRCTYPE = POINT
# 2022-12-08 15:01:09,449 - stpipe.Spec2Pipeline.srctype - INFO - Step srctype done
# 2022-12-08 15:01:09,809 - stpipe.Spec2Pipeline.flat_field - INFO - Step flat_field running with args (<IFUImageModel(2048, 2048) from jw01128009001_03108_00004_nrs2_rate.fits>,).
# 2022-12-08 15:01:09,810 - stpipe.Spec2Pipeline.flat_field - INFO - Step flat_field parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'flat_field', 'search_output_file': True, 'input_dir': '', 'save_interpolated_flat': False, 'user_supplied_flat': None, 'inverse': False}
# 2022-12-08 15:06:35,568 - stpipe.Spec2Pipeline.flat_field - INFO - Step flat_field done
# 2022-12-08 15:06:36,502 - stpipe.Spec2Pipeline.straylight - INFO - Step straylight running with args (<IFUImageModel(2048, 2048) from jw01128009001_03108_00004_nrs2_rate.fits>,).
# 2022-12-08 15:06:36,504 - stpipe.Spec2Pipeline.straylight - INFO - Step straylight parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': 'straylight', 'search_output_file': True, 'input_dir': ''}
# 2022-12-08 15:06:36,505 - stpipe.Spec2Pipeline.straylight - INFO - Step skipped.
# 2022-12-08 15:06:36,507 - stpipe.Spec2Pipeline.straylight - INFO - Step straylight done
# 2022-12-08 15:06:36,943 - stpipe.Spec2Pipeline.fringe - INFO - Step fringe running with args (<IFUImageModel(2048, 2048) from jw01128009001_03108_00004_nrs2_rate.fits>,).
# 2022-12-08 15:06:36,944 - stpipe.Spec2Pipeline.fringe - INFO - Step fringe parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': 'fringe', 'search_output_file': True, 'input_dir': ''}
# 2022-12-08 15:06:36,944 - stpipe.Spec2Pipeline.fringe - INFO - Step skipped.
# 2022-12-08 15:06:36,947 - stpipe.Spec2Pipeline.fringe - INFO - Step fringe done
# 2022-12-08 15:06:37,377 - stpipe.Spec2Pipeline.pathloss - INFO - Step pathloss running with args (<IFUImageModel(2048, 2048) from jw01128009001_03108_00004_nrs2_rate.fits>,).
# 2022-12-08 15:06:37,378 - stpipe.Spec2Pipeline.pathloss - INFO - Step pathloss parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'pathloss', 'search_output_file': True, 'input_dir': '', 'inverse': False, 'source_type': None}
# 2022-12-08 15:06:37,396 - stpipe.Spec2Pipeline.pathloss - INFO - Using PATHLOSS reference file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_pathloss_0003.fits
# 2022-12-08 15:06:37,425 - stpipe.Spec2Pipeline.pathloss - INFO - Input exposure type is NRS_IFU
# 2022-12-08 15:07:38,853 - stpipe.Spec2Pipeline.pathloss - INFO - Step pathloss done
# 2022-12-08 15:07:39,601 - stpipe.Spec2Pipeline.barshadow - INFO - Step barshadow running with args (<IFUImageModel(2048, 2048) from jw01128009001_03108_00004_nrs2_rate.fits>,).
# 2022-12-08 15:07:39,602 - stpipe.Spec2Pipeline.barshadow - INFO - Step barshadow parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': 'barshadow', 'search_output_file': True, 'input_dir': '', 'inverse': False, 'source_type': None}
# 2022-12-08 15:07:39,602 - stpipe.Spec2Pipeline.barshadow - INFO - Step skipped.
# 2022-12-08 15:07:39,604 - stpipe.Spec2Pipeline.barshadow - INFO - Step barshadow done
# 2022-12-08 15:07:40,008 - stpipe.Spec2Pipeline.photom - INFO - Step photom running with args (<IFUImageModel(2048, 2048) from jw01128009001_03108_00004_nrs2_rate.fits>,).
# 2022-12-08 15:07:40,009 - stpipe.Spec2Pipeline.photom - INFO - Step photom parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'photom', 'search_output_file': True, 'input_dir': '', 'inverse': False, 'source_type': None}
# 2022-12-08 15:07:40,038 - stpipe.Spec2Pipeline.photom - INFO - Using photom reference file: /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_photom_0016.fits
# 2022-12-08 15:07:40,039 - stpipe.Spec2Pipeline.photom - INFO - Using area reference file: /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_area_0009.fits
# 2022-12-08 15:07:42,520 - stpipe.Spec2Pipeline.photom - INFO - Using instrument: NIRSPEC
# 2022-12-08 15:07:42,521 - stpipe.Spec2Pipeline.photom - INFO -  detector: NRS2
# 2022-12-08 15:07:42,521 - stpipe.Spec2Pipeline.photom - INFO -  exp_type: NRS_IFU
# 2022-12-08 15:07:42,521 - stpipe.Spec2Pipeline.photom - INFO -  filter: F290LP
# 2022-12-08 15:07:42,521 - stpipe.Spec2Pipeline.photom - INFO -  grating: G395H
# 2022-12-08 15:07:42,570 - stpipe.Spec2Pipeline.photom - INFO - PHOTMJSR value: 1
# 2022-12-08 15:08:42,156 - stpipe.Spec2Pipeline.photom - INFO - Step photom done
# 2022-12-08 15:08:43,214 - stpipe.Spec2Pipeline.cube_build - INFO - Step cube_build running with args (<IFUImageModel(2048, 2048) from stage2/jw01128009001_03108_00004_nrs2_cal.fits>,).
# 2022-12-08 15:08:43,215 - stpipe.Spec2Pipeline.cube_build - INFO - Step cube_build parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 's3d', 'search_output_file': False, 'input_dir': '', 'channel': 'all', 'band': 'all', 'grating': 'all', 'filter': 'all', 'output_type': 'multi', 'scale1': 0.0, 'scale2': 0.0, 'scalew': 0.0, 'weighting': 'drizzle', 'coord_system': 'skyalign', 'rois': 0.0, 'roiw': 0.0, 'weight_power': 2.0, 'wavemin': None, 'wavemax': None, 'single': False, 'skip_dqflagging': True}
# 2022-12-08 15:08:43,216 - stpipe.Spec2Pipeline.cube_build - INFO - Starting IFU Cube Building Step
# 2022-12-08 15:08:43,216 - stpipe.Spec2Pipeline.cube_build - INFO - Input interpolation: drizzle
# 2022-12-08 15:08:43,216 - stpipe.Spec2Pipeline.cube_build - INFO - Coordinate system to use: skyalign
# 2022-12-08 15:08:43,244 - stpipe.Spec2Pipeline.cube_build - INFO - Reading cube parameter file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_cubepar_0003.fits
# 2022-12-08 15:08:43,292 - stpipe.Spec2Pipeline.cube_build - INFO - Output IFUcube are constructed from all the data
# 2022-12-08 15:08:43,293 - stpipe.Spec2Pipeline.cube_build - INFO - Number of IFU cubes produced by this run = 1
# 2022-12-08 15:08:43,296 - stpipe.Spec2Pipeline.cube_build - INFO - Increasing spatial region of interest default value set for 4 dithers nan
# 2022-12-08 15:08:43,299 - stpipe.Spec2Pipeline.cube_build - INFO - Cube Geometry:
# 2022-12-08 15:08:43,299 - stpipe.Spec2Pipeline.cube_build - INFO - axis#  Naxis  CRPIX    CRVAL      CDELT(arcsec)  Min & Max (xi, eta arcsec)
# 2022-12-08 15:08:43,299 - stpipe.Spec2Pipeline.cube_build - INFO - Axis 1    49  25.00 -87.85542843   0.10000000  -2.45000004   2.45000004
# 2022-12-08 15:08:43,300 - stpipe.Spec2Pipeline.cube_build - INFO - Axis 2    51  26.00  69.45794672   0.10000000  -2.55000004   2.55000004
# 2022-12-08 15:08:43,300 - stpipe.Spec2Pipeline.cube_build - INFO - axis#  Naxis  CRPIX    CRVAL      CDELT(microns)  Min & Max (microns)
# 2022-12-08 15:08:43,300 - stpipe.Spec2Pipeline.cube_build - INFO - Axis 3  1800   1.00   4.08283418   0.00066500   4.08250168   5.27950168
# 2022-12-08 15:08:43,301 - stpipe.Spec2Pipeline.cube_build - INFO - Cube covers grating, filter: g395h, f290lp
# 2022-12-08 15:08:43,301 - stpipe.Spec2Pipeline.cube_build - INFO - Output Name: stage2/jw01128009001_03108_00004_nrs2_s3d.fits
# 2022-12-08 15:08:47,089 - stpipe.Spec2Pipeline.cube_build - INFO - Mapping each NIRSpec slice to sky for input file: stage2/jw01128009001_03108_00004_nrs2_cal.fits
# 2022-12-08 15:10:02,650 - stpipe.Spec2Pipeline.cube_build - INFO - Average # of holes/wavelength plane is < 1
# 2022-12-08 15:10:02,651 - stpipe.Spec2Pipeline.cube_build - INFO - Total # of holes for IFU cube is : 0
# 2022-12-08 15:10:02,652 - stpipe.Spec2Pipeline.cube_build - INFO - Number of wavelength planes removed with no data: 18
# 2022-12-08 15:10:02,764 - stpipe.Spec2Pipeline.cube_build - INFO - Update S_REGION to POLYGON ICRS  272.142671602 69.457252265 272.142671602 69.458641154 272.146471534 69.458641154 272.146471534 69.457252265
# 2022-12-08 15:10:02,770 - stpipe.Spec2Pipeline.cube_build - INFO - Step cube_build done
# 2022-12-08 15:10:02,993 - stpipe.Spec2Pipeline - INFO - Saved model in stage2/jw01128009001_03108_00004_nrs2_s3d.fits
# 2022-12-08 15:10:03,571 - stpipe.Spec2Pipeline.extract_1d - INFO - Step extract_1d running with args (<ModelContainer>,).
# 2022-12-08 15:10:03,573 - stpipe.Spec2Pipeline.extract_1d - INFO - Step extract_1d parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': True, 'suffix': 'x1d', 'search_output_file': True, 'input_dir': '', 'smoothing_length': None, 'bkg_fit': None, 'bkg_order': None, 'bkg_sigma_clip': 3.0, 'log_increment': 50, 'subtract_background': None, 'use_source_posn': None, 'center_xy': None, 'apply_apcorr': True, 'soss_threshold': 0.01, 'soss_n_os': 2, 'soss_transform': None, 'soss_tikfac': None, 'soss_width': 40.0, 'soss_bad_pix': 'model', 'soss_modelname': None}
# 2022-12-08 15:10:03,573 - stpipe.Spec2Pipeline.extract_1d - INFO - Step skipped.
# 2022-12-08 15:10:03,576 - stpipe.Spec2Pipeline.extract_1d - INFO - Step extract_1d done
# 2022-12-08 15:10:03,576 - stpipe.Spec2Pipeline - INFO - Finished processing product stage1/jw01128009001_03108_00004_nrs2
# 2022-12-08 15:10:03,576 - stpipe.Spec2Pipeline - INFO - Ending calwebb_spec2
# 2022-12-08 15:10:03,577 - stpipe.Spec2Pipeline - INFO - Results used CRDS context: jwst_0977.pmap
# 2022-12-08 15:10:03,577 - stpipe.Spec2Pipeline - INFO - Results used CRDS context: jwst_0977.pmap
# 2022-12-08 15:10:03,577 - stpipe.Spec2Pipeline - INFO - Results used CRDS context: jwst_0977.pmap
# 2022-12-08 15:10:03,578 - stpipe.Spec2Pipeline - INFO - Results used CRDS context: jwst_0977.pmap
# 2022-12-08 15:10:05,876 - stpipe.Spec2Pipeline - INFO - Saved model in stage2/jw01128009001_03108_00001_nrs2_cal.fits
# 2022-12-08 15:10:08,589 - stpipe.Spec2Pipeline - INFO - Saved model in stage2/jw01128009001_03108_00002_nrs2_cal.fits
# 2022-12-08 15:10:11,312 - stpipe.Spec2Pipeline - INFO - Saved model in stage2/jw01128009001_03108_00003_nrs2_cal.fits
# 2022-12-08 15:10:13,998 - stpipe.Spec2Pipeline - INFO - Saved model in stage2/jw01128009001_03108_00004_nrs2_cal.fits
# 2022-12-08 15:10:13,999 - stpipe.Spec2Pipeline - INFO - Step Spec2Pipeline done
# [<IFUImageModel(2048, 2048) from jw01128009001_03108_00001_nrs2_cal.fits>,
#  <IFUImageModel(2048, 2048) from jw01128009001_03108_00002_nrs2_cal.fits>,
#  <IFUImageModel(2048, 2048) from jw01128009001_03108_00003_nrs2_cal.fits>,
#  <IFUImageModel(2048, 2048) from jw01128009001_03108_00004_nrs2_cal.fits>]

# %%
# Print out the time benchmark
time1 = time.perf_counter()
print(f"Runtime so far: {time1 - time0:0.4f} seconds")
# Out:
# Runtime so far: 2223.2448 seconds

# %%
### Calling in the calibrated detector images produced by running the stage 2 pipeline on the modified NRS fits files
cal_files = glob.glob('stage2/*cal.fits')
print(cal_files)
# Out:
# ['stage2/jw01128009001_03108_00003_nrs2_cal.fits', 'stage2/jw01128009001_03108_00004_nrs2_cal.fits', 'stage2/jw01128009001_03108_00001_nrs2_cal.fits', 'stage2/jw01128009001_03108_00002_nrs2_cal.fits']

# %%
## create association file for dithered data. Make a json file for the dither set.
call(["asn_from_list", "-o","l3_asn.json"] + cal_files + ["--product-name", "dither"])
# Out:
# 0

# %%
# Start a timer to keep track of runtime
time0 = time.perf_counter()

# %%
# This initial setup is just to make sure that we get the latest parameter reference files
# pulled in for our files.  This is a temporary workaround to get around an issue with
# how this pipeline calling method works.
#
# Setting up steps and running the Spec3 portion of the pipeline. Outlier detector is skipped
# because it tends to cut high value pixels even if it is a part of the target.

json_file = 'l3_asn.json'
crds_config = Spec3Pipeline.get_config_from_reference(json_file)# The exact asn file used doesn't matter
spec3 = Spec3Pipeline.from_config_section(crds_config)
spec3.output_dir = spec3_dir
spec3.assign_mtwcs.skip = True               #skipped because VHS 1256b is not a moving target
spec3.master_background.skip = False
spec3.outlier_detection.skip = True
spec3.cube_build.skip = False
spec3.cube_build.coord_system = 'skyalign'   
spec3.cube_build.output_type = 'band'        # is the default mode for calspec3 and creates IFU cubes containing only one band (channel/sub-channel for MIRI or grating/filter combination for NIRSpec).

#used on MRS or other modes
spec3.mrs_imatch.skip = True
spec3.resample_spec.skip = False
spec3.combine_1d.skip = True

#save results
spec3.save_results = True
spec3(json_file)
# Out:
# 2022-12-08 15:10:18,762 - stpipe.Spec3Pipeline - INFO - Spec3Pipeline instance created.
# 2022-12-08 15:10:18,763 - stpipe.Spec3Pipeline.assign_mtwcs - INFO - AssignMTWcsStep instance created.
# 2022-12-08 15:10:18,763 - stpipe.Spec3Pipeline.master_background - INFO - MasterBackgroundStep instance created.
# 2022-12-08 15:10:18,764 - stpipe.Spec3Pipeline.mrs_imatch - INFO - MRSIMatchStep instance created.
# 2022-12-08 15:10:18,765 - stpipe.Spec3Pipeline.outlier_detection - INFO - OutlierDetectionStep instance created.
# 2022-12-08 15:10:18,766 - stpipe.Spec3Pipeline.resample_spec - INFO - ResampleSpecStep instance created.
# 2022-12-08 15:10:18,768 - stpipe.Spec3Pipeline.cube_build - INFO - CubeBuildStep instance created.
# 2022-12-08 15:10:18,769 - stpipe.Spec3Pipeline.extract_1d - INFO - Extract1dStep instance created.
# 2022-12-08 15:10:18,770 - stpipe.Spec3Pipeline.photom - INFO - PhotomStep instance created.
# 2022-12-08 15:10:18,770 - stpipe.Spec3Pipeline.combine_1d - INFO - Combine1dStep instance created.
# 2022-12-08 15:10:19,241 - stpipe.Spec3Pipeline - INFO - Step Spec3Pipeline running with args ('l3_asn.json',).
# 2022-12-08 15:10:19,247 - stpipe.Spec3Pipeline - INFO - Step Spec3Pipeline parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': 'stage3/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'steps': {'assign_mtwcs': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': 'assign_mtwcs', 'search_output_file': True, 'input_dir': ''}, 'master_background': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'user_background': None, 'save_background': False, 'force_subtract': False}, 'mrs_imatch': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'bkg_degree': 1, 'subtract': False}, 'outlier_detection': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': False, 'input_dir': '', 'weight_type': 'ivm', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'nlow': 0, 'nhigh': 0, 'maskpt': 0.7, 'grow': 1, 'snr': '5.0 4.0', 'scale': '1.2 0.7', 'backg': 0.0, 'save_intermediate_results': False, 'resample_data': True, 'good_bits': '~DO_NOT_USE', 'scale_detection': False, 'allowed_memory': None, 'in_memory': False}, 'resample_spec': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'weight_type': 'ivm', 'output_shape': None, 'crpix': None, 'crval': None, 'rotation': None, 'pixel_scale_ratio': 1.0, 'pixel_scale': None, 'single': False, 'blendheaders': True, 'allowed_memory': None, 'in_memory': True}, 'cube_build': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': False, 'input_dir': '', 'channel': 'all', 'band': 'all', 'grating': 'all', 'filter': 'all', 'output_type': 'band', 'scale1': 0.0, 'scale2': 0.0, 'scalew': 0.0, 'weighting': 'drizzle', 'coord_system': 'skyalign', 'rois': 0.0, 'roiw': 0.0, 'weight_power': 2.0, 'wavemin': None, 'wavemax': None, 'single': False, 'skip_dqflagging': False}, 'extract_1d': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'smoothing_length': None, 'bkg_fit': None, 'bkg_order': None, 'bkg_sigma_clip': 3.0, 'log_increment': 50, 'subtract_background': None, 'use_source_posn': None, 'center_xy': None, 'apply_apcorr': True, 'soss_threshold': 0.01, 'soss_n_os': 2, 'soss_transform': None, 'soss_tikfac': None, 'soss_width': 40.0, 'soss_bad_pix': 'model', 'soss_modelname': None}, 'photom': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'inverse': False, 'source_type': None}, 'combine_1d': {'pre_hooks': [], 'post_hooks': [], 'outp ...
# 2022-12-08 15:10:21,915 - stpipe.Spec3Pipeline - INFO - Prefetching reference files for dataset: 'jw01128009001_03108_00003_nrs2_cal.fits' reftypes = ['apcorr', 'area', 'cubepar', 'drizpars', 'extract1d', 'photom', 'speckernel', 'specprofile', 'spectrace', 'wavemap']
# 2022-12-08 15:10:21,918 - stpipe.Spec3Pipeline - INFO - Prefetch for APCORR reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_apcorr_0005.asdf'.
# 2022-12-08 15:10:21,918 - stpipe.Spec3Pipeline - INFO - Prefetch for AREA reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_area_0009.fits'.
# 2022-12-08 15:10:21,919 - stpipe.Spec3Pipeline - INFO - Prefetch for CUBEPAR reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_cubepar_0003.fits'.
# 2022-12-08 15:10:21,919 - stpipe.Spec3Pipeline - INFO - Prefetch for DRIZPARS reference file is 'N/A'.
# 2022-12-08 15:10:21,919 - stpipe.Spec3Pipeline - INFO - Prefetch for EXTRACT1D reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_extract1d_0001.asdf'.
# 2022-12-08 15:10:21,920 - stpipe.Spec3Pipeline - INFO - Prefetch for PHOTOM reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_photom_0016.fits'.
# 2022-12-08 15:10:21,920 - stpipe.Spec3Pipeline - INFO - Prefetch for SPECKERNEL reference file is 'N/A'.
# 2022-12-08 15:10:21,921 - stpipe.Spec3Pipeline - INFO - Prefetch for SPECPROFILE reference file is 'N/A'.
# 2022-12-08 15:10:21,921 - stpipe.Spec3Pipeline - INFO - Prefetch for SPECTRACE reference file is 'N/A'.
# 2022-12-08 15:10:21,921 - stpipe.Spec3Pipeline - INFO - Prefetch for WAVEMAP reference file is 'N/A'.
# 2022-12-08 15:10:21,922 - stpipe.Spec3Pipeline - INFO - Starting calwebb_spec3 ...
# 2022-12-08 15:10:35,325 - stpipe.Spec3Pipeline.outlier_detection - INFO - Step outlier_detection running with args (<ModelContainer>,).
# 2022-12-08 15:10:35,326 - stpipe.Spec3Pipeline.outlier_detection - INFO - Step outlier_detection parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': True, 'suffix': 'crf', 'search_output_file': False, 'input_dir': '', 'weight_type': 'ivm', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'nlow': 0, 'nhigh': 0, 'maskpt': 0.7, 'grow': 1, 'snr': '5.0 4.0', 'scale': '1.2 0.7', 'backg': 0.0, 'save_intermediate_results': False, 'resample_data': True, 'good_bits': '~DO_NOT_USE', 'scale_detection': False, 'allowed_memory': None, 'in_memory': False}
# 2022-12-08 15:10:35,327 - stpipe.Spec3Pipeline.outlier_detection - INFO - Step skipped.
# 2022-12-08 15:10:35,334 - stpipe.Spec3Pipeline.outlier_detection - INFO - Step outlier_detection done
# 2022-12-08 15:10:35,936 - stpipe.Spec3Pipeline.cube_build - INFO - Step cube_build running with args (<ModelContainer>,).
# 2022-12-08 15:10:35,937 - stpipe.Spec3Pipeline.cube_build - INFO - Step cube_build parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': 's3d', 'search_output_file': False, 'input_dir': '', 'channel': 'all', 'band': 'all', 'grating': 'all', 'filter': 'all', 'output_type': 'band', 'scale1': 0.0, 'scale2': 0.0, 'scalew': 0.0, 'weighting': 'drizzle', 'coord_system': 'skyalign', 'rois': 0.0, 'roiw': 0.0, 'weight_power': 2.0, 'wavemin': None, 'wavemax': None, 'single': False, 'skip_dqflagging': False}
# 2022-12-08 15:10:35,937 - stpipe.Spec3Pipeline.cube_build - INFO - Starting IFU Cube Building Step
# 2022-12-08 15:10:35,938 - stpipe.Spec3Pipeline.cube_build - INFO - Input interpolation: drizzle
# 2022-12-08 15:10:35,938 - stpipe.Spec3Pipeline.cube_build - INFO - Coordinate system to use: skyalign
# 2022-12-08 15:10:35,984 - stpipe.Spec3Pipeline.cube_build - INFO - Reading cube parameter file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_cubepar_0003.fits
# 2022-12-08 15:10:36,027 - stpipe.Spec3Pipeline.cube_build - INFO - Output Cubes are single grating, single filter IFU Cubes
# 2022-12-08 15:10:36,028 - stpipe.Spec3Pipeline.cube_build - INFO - Number of IFU cubes produced by this run = 1
# 2022-12-08 15:10:36,034 - stpipe.Spec3Pipeline.cube_build - INFO - Cube Geometry:
# 2022-12-08 15:10:36,034 - stpipe.Spec3Pipeline.cube_build - INFO - axis#  Naxis  CRPIX    CRVAL      CDELT(arcsec)  Min & Max (xi, eta arcsec)
# 2022-12-08 15:10:36,034 - stpipe.Spec3Pipeline.cube_build - INFO - Axis 1    71  36.00 -87.85534850   0.10000000  -3.55000005   3.55000005
# 2022-12-08 15:10:36,034 - stpipe.Spec3Pipeline.cube_build - INFO - Axis 2    73  37.00  69.45825957   0.10000000  -3.65000005   3.65000005
# 2022-12-08 15:10:36,035 - stpipe.Spec3Pipeline.cube_build - INFO - axis#  Naxis  CRPIX    CRVAL      CDELT(microns)  Min & Max (microns)
# 2022-12-08 15:10:36,035 - stpipe.Spec3Pipeline.cube_build - INFO - Axis 3  1800   1.00   4.08283417   0.00066500   4.08250167   5.27950167
# 2022-12-08 15:10:36,035 - stpipe.Spec3Pipeline.cube_build - INFO - Cube covers grating, filter: g395h, f290lp
# 2022-12-08 15:10:36,035 - stpipe.Spec3Pipeline.cube_build - INFO - Output Name: dither_g395h-f290lp_s3d.fits
# 2022-12-08 15:10:39,080 - stpipe.Spec3Pipeline.cube_build - INFO - Mapping each NIRSpec slice to sky for input file: jw01128009001_03108_00003_nrs2_cal.fits
# 2022-12-08 15:11:56,860 - stpipe.Spec3Pipeline.cube_build - INFO - Mapping each NIRSpec slice to sky for input file: jw01128009001_03108_00004_nrs2_cal.fits
# 2022-12-08 15:13:14,322 - stpipe.Spec3Pipeline.cube_build - INFO - Mapping each NIRSpec slice to sky for input file: jw01128009001_03108_00001_nrs2_cal.fits
# 2022-12-08 15:14:30,945 - stpipe.Spec3Pipeline.cube_build - INFO - Mapping each NIRSpec slice to sky for input file: jw01128009001_03108_00002_nrs2_cal.fits
# 2022-12-08 15:15:45,024 - stpipe.Spec3Pipeline.cube_build - INFO - Average # of holes/wavelength plane is < 1
# 2022-12-08 15:15:45,024 - stpipe.Spec3Pipeline.cube_build - INFO - Total # of holes for IFU cube is : 2
# 2022-12-08 15:15:45,026 - stpipe.Spec3Pipeline.cube_build - INFO - Number of wavelength planes removed with no data: 18
# 2022-12-08 15:15:49,056 - stpipe.Spec3Pipeline.cube_build - INFO - Update S_REGION to POLYGON ICRS  272.141880636 69.457259545 272.141880636 69.459259545 272.147422364 69.459259545 272.147422364 69.457259545
# 2022-12-08 15:15:49,722 - stpipe.Spec3Pipeline.cube_build - INFO - Saved model in stage3/dither_g395h-f290lp_s3d.fits
# 2022-12-08 15:15:49,722 - stpipe.Spec3Pipeline.cube_build - INFO - Step cube_build done
# 2022-12-08 15:15:50,407 - stpipe.Spec3Pipeline.extract_1d - INFO - Step extract_1d running with args (<ModelContainer>,).
# 2022-12-08 15:15:50,409 - stpipe.Spec3Pipeline.extract_1d - INFO - Step extract_1d parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': 'x1d', 'search_output_file': False, 'input_dir': '', 'smoothing_length': None, 'bkg_fit': None, 'bkg_order': None, 'bkg_sigma_clip': 3.0, 'log_increment': 50, 'subtract_background': None, 'use_source_posn': None, 'center_xy': None, 'apply_apcorr': True, 'soss_threshold': 0.01, 'soss_n_os': 2, 'soss_transform': None, 'soss_tikfac': None, 'soss_width': 40.0, 'soss_bad_pix': 'model', 'soss_modelname': None}
# 2022-12-08 15:15:50,423 - stpipe.Spec3Pipeline.extract_1d - INFO - Using EXTRACT1D reference file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_extract1d_0001.asdf
# 2022-12-08 15:15:50,432 - stpipe.Spec3Pipeline.extract_1d - INFO - Using APCORR file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_apcorr_0005.asdf
# 2022-12-08 15:15:51,316 - stpipe.Spec3Pipeline.extract_1d - INFO - Turning on source position correction for exp_type = NRS_IFU
# 2022-12-08 15:15:51,317 - stpipe.Spec3Pipeline.extract_1d - INFO - Source type = POINT
# 2022-12-08 15:15:51,330 - stpipe.Spec3Pipeline.extract_1d - INFO - Input model does not break out variance information. Passing only generalized errors.
# 2022-12-08 15:15:51,346 - stpipe.Spec3Pipeline.extract_1d - INFO - Using x_center = 34, y_center = 26, based on TARG_RA and TARG_DEC
# 2022-12-08 15:16:00,206 - stpipe.Spec3Pipeline.extract_1d - INFO - Applying Aperture correction.
# 2022-12-08 15:16:01,175 - stpipe.Spec3Pipeline.extract_1d - INFO - Saved model in stage3/dither_g395h-f290lp_x1d.fits
# 2022-12-08 15:16:01,175 - stpipe.Spec3Pipeline.extract_1d - INFO - Step extract_1d done
# 2022-12-08 15:16:01,177 - stpipe.Spec3Pipeline - INFO - Ending calwebb_spec3
# 2022-12-08 15:16:01,178 - stpipe.Spec3Pipeline - INFO - Step Spec3Pipeline done

# %%
# Print out the time benchmark
time1 = time.perf_counter()
print(f"Runtime so far: {time1 - time0:0.4f} seconds")
# Out:
# Runtime so far: 345.7138 seconds

# %%
# check the extracted spectrum from the JWST pipeline
data = fits.getdata('stage3/dither_g395h-f290lp_x1d.fits')
wavelength = data['wavelength']
flux  = data['flux']
flux_error = data['flux_error']

# %matplotlib notebook
plt.plot(wavelength, flux, label = 'stage 3')
#plt.ylim([0,8])
plt.ylabel('Jy')
plt.xlabel('Wavelength (microns)')
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
cube_data = fits.getdata('stage3/dither_g395h-f290lp_s3d.fits')
cube=SpectralCube.read('stage3/dither_g395h-f290lp_s3d.fits',hdu=1)

wavelength=cube.spectral_axis
wavelength=n.array(wavelength)

cube_collapse = n.nanmedian(cube_data, axis = 0)
cube_collapse /= n.nanmax(cube_collapse) #the image is normalized so the 2-D Gaussian fit is easier.

# %%
# %matplotlib notebook
plt.figure('collapsed cube')
plt.title('Median Collapsed Spectral Cube')
plt.imshow((cube_collapse))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
## fitting a gaussian to the collapsed cube which is a median image to remove high pixels
image = cube_collapse
y_len, x_len = image.shape
bounds = ((0, 0, n.nanmin(image), 1, 1, n.nanmedian(image)) , (x_len, y_len, n.nanmax(image), x_len, y_len, 2 * n.nanmax(image)) )
guess = n.array([34, 38, n.nanmin(image), 1.2, 1.2, n.nanmax(image)])
fit_arr = optimize.least_squares(image_solve, guess, args = (image,), bounds = bounds )#, bounds=bounds)
x0_fit, y0_fit, offset_fit, sigma_x_fit, sigma_y_fit, A_fit = fit_arr.x


x0_fit = n.round(x0_fit, decimals = 0) #rounding because jwst pipeline does not take float values
y0_fit = n.round(y0_fit, decimals = 0) #rounding because jwst pipeline does not take float values


print('centroids (x, y)')
print(x0_fit, y0_fit)
print('sigmax, sigma y')
print(sigma_x_fit, sigma_y_fit)
# Out:
# centroids (x, y)
# 34.0 38.0
# sigmax, sigma y
# 1.0026856425784758 1.0305046711747132

# %%
#re-running the jwst pipeline extraction step to ensure the extraction radius is centered.
spec3.extract_1d.center_xy = (int(x0_fit), int(y0_fit))
spec3.extract_1d('stage3/dither_g395h-f290lp_s3d.fits')
# Out:
# 2022-12-08 20:12:42,469 - stpipe.Spec3Pipeline.extract_1d - INFO - Step extract_1d running with args ('stage3/dither_g395h-f290lp_s3d.fits',).
# 2022-12-08 20:12:42,470 - stpipe.Spec3Pipeline.extract_1d - INFO - Step extract_1d parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': 'x1d', 'search_output_file': False, 'input_dir': '', 'smoothing_length': None, 'bkg_fit': None, 'bkg_order': None, 'bkg_sigma_clip': 3.0, 'log_increment': 50, 'subtract_background': None, 'use_source_posn': None, 'center_xy': [34, 38], 'apply_apcorr': True, 'soss_threshold': 0.01, 'soss_n_os': 2, 'soss_transform': None, 'soss_tikfac': None, 'soss_width': 40.0, 'soss_bad_pix': 'model', 'soss_modelname': None}
# 2022-12-08 20:12:42,814 - stpipe.Spec3Pipeline.extract_1d - INFO - Using EXTRACT1D reference file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_extract1d_0001.asdf
# 2022-12-08 20:12:42,824 - stpipe.Spec3Pipeline.extract_1d - INFO - Using APCORR file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_apcorr_0005.asdf
# 2022-12-08 20:12:43,777 - stpipe.Spec3Pipeline.extract_1d - INFO - Turning on source position correction for exp_type = NRS_IFU
# 2022-12-08 20:12:43,778 - stpipe.Spec3Pipeline.extract_1d - INFO - Source type = POINT
# 2022-12-08 20:12:43,793 - stpipe.Spec3Pipeline.extract_1d - INFO - Using user-supplied x_center=34, y_center=38
# 2022-12-08 20:12:43,793 - stpipe.Spec3Pipeline.extract_1d - INFO - Input model does not break out variance information. Passing only generalized errors.
# 2022-12-08 20:12:53,208 - stpipe.Spec3Pipeline.extract_1d - INFO - Applying Aperture correction.
# 2022-12-08 20:12:54,209 - stpipe.Spec3Pipeline.extract_1d - INFO - Saved model in stage3/dither_g395h-f290lp_x1d.fits
# 2022-12-08 20:12:54,209 - stpipe.Spec3Pipeline.extract_1d - INFO - Step extract_1d done
# <MultiSpecModel from dither_g395h-f290lp_x1d.fits>

# %%
# check the extracted spectrum from the JWST pipeline
data = fits.getdata('stage3/dither_g395h-f290lp_x1d.fits')
wavelength = data['wavelength']
flux  = data['flux']
flux_error = data['flux_error']

# %matplotlib notebook
plt.plot(wavelength, flux, label = 'stage 3')
plt.ylim([0,.008])
plt.ylabel('Jy')
plt.xlabel('Wavelength (microns)')
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
##save text
#data_out = n.vstack((wavelength,  flux , flux_error))
#data_out = n.transpose(data_out)
#
#spectra_dir = '../spectra/' # Detector1 pipeline outputs will go here
#if not os.path.exists(spectra_dir):
#    os.makedirs(spectra_dir)
#
#header = 'wavelength (microns) flux(Jy), flux error(Jy)'
#n.savetxt('../spectra/detector2_f290lp_g395h.txt', data_out, header = header)
