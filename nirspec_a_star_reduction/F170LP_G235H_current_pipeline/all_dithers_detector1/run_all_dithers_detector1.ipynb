# %% [markdown]
# This notebook was made to reduce NIRSpec dithers into a spectral cube by:
#
# 1. Using the Stage 1 Detector pipleine to turn uncalibrated detector images (_uncal.fits) into rate files (_rate.fits).
#
# 2. Using Stage 2 of the Spectroscopic pipeline to turn rate files(_rate.fits) into calibrated detector images (_cal.fits) and spectral cubes (_s3d.fits)
#
# 3. Using Stage 3 of the spectroscopic pipeline to combine the stage 2 rate files from each filter/grating combination.
#
# Other notes/caveats:
# Stage 2 cube building is redundant with Stage 3 if you are not combining dithers.

# %%
from astropy.io import fits
import glob, os
from subprocess import call
from astropy.io import fits
import time

import jwst
from jwst.pipeline import Detector1Pipeline, Spec2Pipeline, Spec3Pipeline

import matplotlib.pyplot as plt
import numpy as n

from spectral_cube import SpectralCube
from scipy import optimize


os.environ['CRDS_PATH'] = '/Users/zen/crds_cache/jwst_ops'
os.environ['CRDS_SERVER_URL'] = 'https://jwst-crds.stsci.edu'
os.environ['CRDS_CONTEXT'] = 'jwst_0977.pmap'
os.environ['CRDS_VERSION'] = '11.16.12'


# Print out what pipeline version we're using
print('JWST pipeline version',jwst.__version__)
# Out:
# JWST pipeline version 1.7.2

# %%
# Functions for fitting a 2-D guassian to images to find the PSF center in collapsed spectral cubes
def gauss2d(x, y, x0, y0, offset, sigma_x, sigma_y, A):

    x_exp = ( ( x - x0 )**2) / (2 * sigma_x ** 2)
    y_exp = ( ( y - y0 )**2) / (2 * sigma_y ** 2)
    f = A * n.exp( - x_exp - y_exp) + offset

    return f

def image_solve(constants, im):

    x0_val, y0_val, offset_val, sigma_x_val, sigma_y_val, A_val = constants

    y_len, x_len = im.shape
    y_arr = n.arange(0, y_len)
    x_arr = n.arange(0, x_len)
    xx, yy = n.meshgrid(x_arr, y_arr)

    fit = gauss2d(xx, yy, x0_val, y0_val, offset_val, sigma_x_val, sigma_y_val, A_val)

    min_diff = n.nansum(abs(im - fit)**2)

    return min_diff

# %%
det1_dir = 'stage1/' # Detector1 pipeline outputs will go here
spec2_dir = 'stage2/' # Spec2 pipeline outputs will go here
spec3_dir = 'stage3/' # Spec3 pipeline outputs will go here

# We need to check that the desired output directories exist, and if not create them
if not os.path.exists(det1_dir):
    os.makedirs(det1_dir)
if not os.path.exists(spec2_dir):
    os.makedirs(spec2_dir)
if not os.path.exists(spec3_dir):
    os.makedirs(spec3_dir)

# %%
uncal_file_dir = '../../../cal_data/'
uncal_files = ['jw01128009001_03106_00001_nrs1_uncal.fits',
              'jw01128009001_03106_00002_nrs1_uncal.fits',
              'jw01128009001_03106_00003_nrs1_uncal.fits',
              'jw01128009001_03106_00004_nrs1_uncal.fits']
for i, file in enumerate(uncal_files):
    uncal_files[i] = uncal_file_dir + uncal_files[i]
print(uncal_files)

print('Found ' + str(len(uncal_files)) + ' input files to process')
# Out:
# ['../../../cal_data/jw01128009001_03106_00001_nrs1_uncal.fits', '../../../cal_data/jw01128009001_03106_00002_nrs1_uncal.fits', '../../../cal_data/jw01128009001_03106_00003_nrs1_uncal.fits', '../../../cal_data/jw01128009001_03106_00004_nrs1_uncal.fits']
# Found 4 input files to process

# %%
# Start a timer to keep track of runtime
time0 = time.perf_counter()

# %%
for file in uncal_files:
    
    det1 = Detector1Pipeline() # Instantiate the pipeline

    #output directory
    det1.output_dir = det1_dir # Specify where the output should go

    #defining used pipeline steps
    det1.group_scale.skip = False  #scaling factor from group images
    det1.dq_init.skip = False      #data quality check
    det1.saturation.skip = False   #check for saturated pixels
    det1.ipc.skip = False          #interpixel capacitance scaling from a reference. Usually skipped in all instrument modes
    det1.superbias.skip = False    #subtract a bias frame from the data
    det1.refpix.skip = False       #correct for drifts in read outs using reference pixels or columns
    det1.linearity.skip = False    #used to correct for non-linearity in the frames
    det1.persistence.skip = True   #according to the docs it is supposed to be hardwired to skipped
    det1.dark_current.skip = False #
    det1.jump.skip = False         #
    det1.jump.maximum_cores = 'half' #distribute the computing load across half of your computer cores to speed it up
    det1.ramp_fit.skip = False     #
    det1.ramp_fit.maximum_cores = 'half' #distribute the computing load across half of your computer cores to speed it up
    det1.gain_scale.skip = False   #


    #skipped steps that are for MIRI
    det1.firstframe.skip = True    #
    det1.lastframe.skip = True     #
    det1.reset.skip = True         # The reset correction is a MIRI step that attempts to correct for the reset anomaly effect. Skipped
    det1.rscd.skip = True          # Performs an RSCD correction to MIRI data that is also caused by reset issues. Skipped



    #choose what results to save and from what steps
    #det1.dq_init.save_results = True # save the data quality flag information
    det1.save_results = True # Save the final resulting _rate.fits files

    det1.run(file)
# Out:
# 2022-12-08 13:16:09,661 - stpipe.Detector1Pipeline - INFO - Detector1Pipeline instance created.
# 2022-12-08 13:16:09,662 - stpipe.Detector1Pipeline.group_scale - INFO - GroupScaleStep instance created.
# 2022-12-08 13:16:09,664 - stpipe.Detector1Pipeline.dq_init - INFO - DQInitStep instance created.
# 2022-12-08 13:16:09,665 - stpipe.Detector1Pipeline.saturation - INFO - SaturationStep instance created.
# 2022-12-08 13:16:09,666 - stpipe.Detector1Pipeline.ipc - INFO - IPCStep instance created.
# 2022-12-08 13:16:09,667 - stpipe.Detector1Pipeline.superbias - INFO - SuperBiasStep instance created.
# 2022-12-08 13:16:09,668 - stpipe.Detector1Pipeline.refpix - INFO - RefPixStep instance created.
# 2022-12-08 13:16:09,670 - stpipe.Detector1Pipeline.rscd - INFO - RscdStep instance created.
# 2022-12-08 13:16:09,671 - stpipe.Detector1Pipeline.firstframe - INFO - FirstFrameStep instance created.
# 2022-12-08 13:16:09,672 - stpipe.Detector1Pipeline.lastframe - INFO - LastFrameStep instance created.
# 2022-12-08 13:16:09,673 - stpipe.Detector1Pipeline.linearity - INFO - LinearityStep instance created.
# 2022-12-08 13:16:09,675 - stpipe.Detector1Pipeline.dark_current - INFO - DarkCurrentStep instance created.
# 2022-12-08 13:16:09,676 - stpipe.Detector1Pipeline.reset - INFO - ResetStep instance created.
# 2022-12-08 13:16:09,677 - stpipe.Detector1Pipeline.persistence - INFO - PersistenceStep instance created.
# 2022-12-08 13:16:09,679 - stpipe.Detector1Pipeline.jump - INFO - JumpStep instance created.
# 2022-12-08 13:16:09,680 - stpipe.Detector1Pipeline.ramp_fit - INFO - RampFitStep instance created.
# 2022-12-08 13:16:09,682 - stpipe.Detector1Pipeline.gain_scale - INFO - GainScaleStep instance created.
# 2022-12-08 13:16:09,732 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline running with args ('../../../cal_data/jw01128009001_03106_00001_nrs1_uncal.fits',).
# 2022-12-08 13:16:09,740 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': 'stage1/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_calibrated_ramp': False, 'steps': {'group_scale': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'dq_init': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'saturation': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'n_pix_grow_sat': 1}, 'ipc': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'superbias': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'refpix': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'odd_even_columns': True, 'use_side_ref_pixels': True, 'side_smoothing_length': 11, 'side_gain': 1.0, 'odd_even_rows': True}, 'rscd': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'type': 'baseline'}, 'firstframe': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'lastframe': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'linearity': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'dark_current': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'dark_output': None}, 'reset': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'persistence': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': ...
# 2022-12-08 13:16:10,844 - stpipe.Detector1Pipeline - INFO - Prefetching reference files for dataset: 'jw01128009001_03106_00001_nrs1_uncal.fits' reftypes = ['dark', 'gain', 'ipc', 'linearity', 'mask', 'readnoise', 'refpix', 'saturation', 'superbias']
# 2022-12-08 13:16:11,065 - stpipe.Detector1Pipeline - INFO - Prefetch for DARK reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_dark_0204.fits'.
# 2022-12-08 13:16:11,065 - stpipe.Detector1Pipeline - INFO - Prefetch for GAIN reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_gain_0023.fits'.
# 2022-12-08 13:16:11,066 - stpipe.Detector1Pipeline - INFO - Prefetch for IPC reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_ipc_0011.fits'.
# 2022-12-08 13:16:11,066 - stpipe.Detector1Pipeline - INFO - Prefetch for LINEARITY reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_linearity_0022.fits'.
# 2022-12-08 13:16:11,066 - stpipe.Detector1Pipeline - INFO - Prefetch for MASK reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_mask_0030.fits'.
# 2022-12-08 13:16:11,067 - stpipe.Detector1Pipeline - INFO - Prefetch for READNOISE reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_readnoise_0018.fits'.
# 2022-12-08 13:16:11,067 - stpipe.Detector1Pipeline - INFO - Prefetch for REFPIX reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_refpix_0019.fits'.
# 2022-12-08 13:16:11,067 - stpipe.Detector1Pipeline - INFO - Prefetch for SATURATION reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_saturation_0027.fits'.
# 2022-12-08 13:16:11,068 - stpipe.Detector1Pipeline - INFO - Prefetch for SUPERBIAS reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_superbias_0254.fits'.
# 2022-12-08 13:16:11,068 - stpipe.Detector1Pipeline - INFO - Starting calwebb_detector1 ...
# 2022-12-08 13:16:11,755 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale running with args (<RampModel(1, 15, 3200, 2048) from jw01128009001_03106_00001_nrs1_uncal.fits>,).
# 2022-12-08 13:16:11,756 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../cal_data'}
# 2022-12-08 13:16:12,408 - stpipe.Detector1Pipeline.group_scale - INFO - NFRAMES and FRMDIVSR are equal; correction not needed
# 2022-12-08 13:16:12,409 - stpipe.Detector1Pipeline.group_scale - INFO - Step will be skipped
# 2022-12-08 13:16:12,411 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale done
# 2022-12-08 13:16:12,502 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init running with args (<RampModel(1, 15, 3200, 2048) from jw01128009001_03106_00001_nrs1_uncal.fits>,).
# 2022-12-08 13:16:12,504 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../cal_data'}
# 2022-12-08 13:16:12,524 - stpipe.Detector1Pipeline.dq_init - INFO - Using MASK reference file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_mask_0030.fits
# 2022-12-08 13:16:13,119 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init done
# 2022-12-08 13:16:13,199 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation running with args (<RampModel(1, 15, 3200, 2048) from jw01128009001_03106_00001_nrs1_uncal.fits>,).
# 2022-12-08 13:16:13,200 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../cal_data', 'n_pix_grow_sat': 1}
# 2022-12-08 13:16:13,220 - stpipe.Detector1Pipeline.saturation - INFO - Using SATURATION reference file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_saturation_0027.fits
# 2022-12-08 13:16:14,962 - stpipe.Detector1Pipeline.saturation - INFO - Detected 54907 saturated pixels
# 2022-12-08 13:16:14,981 - stpipe.Detector1Pipeline.saturation - INFO - Detected 1 A/D floor pixels
# 2022-12-08 13:16:14,998 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation done
# 2022-12-08 13:16:15,078 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc running with args (<RampModel(1, 15, 3200, 2048) from jw01128009001_03106_00001_nrs1_uncal.fits>,).
# 2022-12-08 13:16:15,079 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../cal_data'}
# 2022-12-08 13:16:15,099 - stpipe.Detector1Pipeline.ipc - INFO - Using IPC reference file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_ipc_0011.fits
# 2022-12-08 13:16:15,876 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc done
# 2022-12-08 13:16:15,964 - stpipe.Detector1Pipeline.superbias - INFO - Step superbias running with args (<RampModel(1, 15, 3200, 2048) from jw01128009001_03106_00001_nrs1_uncal.fits>,).
# 2022-12-08 13:16:15,965 - stpipe.Detector1Pipeline.superbias - INFO - Step superbias parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../cal_data'}
# 2022-12-08 13:16:15,986 - stpipe.Detector1Pipeline.superbias - INFO - Using SUPERBIAS reference file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_superbias_0254.fits
# 2022-12-08 13:16:16,428 - stpipe.Detector1Pipeline.superbias - INFO - Step superbias done
# 2022-12-08 13:16:16,519 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix running with args (<RampModel(1, 15, 3200, 2048) from jw01128009001_03106_00001_nrs1_uncal.fits>,).
# 2022-12-08 13:16:16,520 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../cal_data', 'odd_even_columns': True, 'use_side_ref_pixels': True, 'side_smoothing_length': 11, 'side_gain': 1.0, 'odd_even_rows': True}
# 2022-12-08 13:16:16,541 - stpipe.Detector1Pipeline.refpix - INFO - Using refpix reference file: /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_refpix_0019.fits
# 2022-12-08 13:16:16,773 - stpipe.Detector1Pipeline.refpix - INFO - Working on integration 1
# 2022-12-08 13:16:47,681 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix done
# 2022-12-08 13:16:47,889 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity running with args (<RampModel(1, 15, 3200, 2048) from jw01128009001_03106_00001_nrs1_uncal.fits>,).
# 2022-12-08 13:16:47,890 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../cal_data'}
# 2022-12-08 13:16:47,910 - stpipe.Detector1Pipeline.linearity - INFO - Using Linearity reference file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_linearity_0022.fits
# 2022-12-08 13:16:48,031 - stpipe.Detector1Pipeline.linearity - WARNING - Keyword BAD_LIN_CORR does not correspond to an existing DQ mnemonic, so will be ignored
# 2022-12-08 13:16:48,623 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity done
# 2022-12-08 13:16:48,735 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current running with args (<RampModel(1, 15, 3200, 2048) from jw01128009001_03106_00001_nrs1_uncal.fits>,).
# 2022-12-08 13:16:48,737 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': 'stage1/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../cal_data', 'dark_output': None}
# 2022-12-08 13:16:48,922 - stpipe.Detector1Pipeline.dark_current - INFO - Using DARK reference file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_dark_0204.fits
# 2022-12-08 13:16:55,053 - stpipe.Detector1Pipeline.dark_current - INFO - Science data nints=1, ngroups
- stpipe.Detector1Pipeline.linearity - INFO - Using Linearity reference file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_linearity_0022.fits
# 2022-12-08 13:20:20,064 - stpipe.Detector1Pipeline.linearity - WARNING - Keyword BAD_LIN_CORR does not correspond to an existing DQ mnemonic, so will be ignored
# 2022-12-08 13:20:20,561 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity done
# 2022-12-08 13:20:20,665 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current running with args (<RampModel(1, 15, 3200, 2048) from jw01128009001_03106_00004_nrs1_uncal.fits>,).
# 2022-12-08 13:20:20,666 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': 'stage1/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../cal_data', 'dark_output': None}
# 2022-12-08 13:20:20,838 - stpipe.Detector1Pipeline.dark_current - INFO - Using DARK reference file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_dark_0204.fits
# 2022-12-08 13:20:24,831 - stpipe.Detector1Pipeline.dark_current - INFO - Science data nints=1, ngroups=15, nframes=1, groupgap=0
# 2022-12-08 13:20:24,832 - stpipe.Detector1Pipeline.dark_current - INFO - Dark data nints=1, ngroups=245, nframes=1, groupgap=0
# 2022-12-08 13:20:29,373 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current done
# 2022-12-08 13:20:29,907 - stpipe.Detector1Pipeline.jump - INFO - Step jump running with args (<RampModel(1, 15, 3200, 2048) from jw01128009001_03106_00004_nrs1_uncal.fits>,).
# 2022-12-08 13:20:29,909 - stpipe.Detector1Pipeline.jump - INFO - Step jump parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../cal_data', 'rejection_threshold': 4.0, 'three_group_rejection_threshold': 6.0, 'four_group_rejection_threshold': 5.0, 'maximum_cores': 'half', 'flag_4_neighbors': True, 'max_jump_to_flag_neighbors': 1000.0, 'min_jump_to_flag_neighbors': 10.0, 'after_jump_flag_dn1': 0.0, 'after_jump_flag_time1': 0.0, 'after_jump_flag_dn2': 0.0, 'after_jump_flag_time2': 0.0}
# 2022-12-08 13:20:30,012 - stpipe.Detector1Pipeline.jump - INFO - CR rejection threshold = 4 sigma
# 2022-12-08 13:20:30,013 - stpipe.Detector1Pipeline.jump - INFO - Maximum cores to use = half
# 2022-12-08 13:20:30,118 - stpipe.Detector1Pipeline.jump - INFO - Using GAIN reference file: /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_gain_0023.fits
# 2022-12-08 13:20:30,273 - stpipe.Detector1Pipeline.jump - INFO - Using READNOISE reference file: /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_readnoise_0018.fits
# 2022-12-08 13:20:30,815 - stpipe.Detector1Pipeline.jump - INFO - Executing two-point difference method
# 2022-12-08 13:20:30,906 - stpipe.Detector1Pipeline.jump - INFO - Creating 5 processes for jump detection
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/jump/twopoint_difference.py:154: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/jump/twopoint_difference.py:154: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/jump/twopoint_difference.py:154: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/jump/twopoint_difference.py:154: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/jump/twopoint_difference.py:154: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
# 2022-12-08 13:20:36,974 - stpipe.Detector1Pipeline.jump - INFO - Total elapsed time = 6.15818 sec
# 2022-12-08 13:20:36,989 - stpipe.Detector1Pipeline.jump - INFO - The execution time in seconds: 6.977081
# 2022-12-08 13:20:36,994 - stpipe.Detector1Pipeline.jump - INFO - Step jump done
# 2022-12-08 13:20:37,146 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit running with args (<RampModel(1, 15, 3200, 2048) from jw01128009001_03106_00004_nrs1_uncal.fits>,).
# 2022-12-08 13:20:37,147 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': 'stage1/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '../../../cal_data', 'int_name': '', 'save_opt': False, 'opt_name': '', 'suppress_one_group': True, 'maximum_cores': 'half'}
# 2022-12-08 13:20:37,380 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using READNOISE reference file: /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_readnoise_0018.fits
# 2022-12-08 13:20:37,380 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using GAIN reference file: /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_gain_0023.fits
# 2022-12-08 13:20:37,461 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using algorithm = ols
# 2022-12-08 13:20:37,461 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using weighting = optimal
# 2022-12-08 13:20:37,739 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of processors used for multiprocessing: 5
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/ramp_fitting/ols_fit.py:1089: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/ramp_fitting/ols_fit.py:1089: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/ramp_fitting/ols_fit.py:1089: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/ramp_fitting/ols_fit.py:1089: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/stcal/ramp_fitting/ols_fit.py:1089: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# 2022-12-08 13:20:53,873 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit done
# 2022-12-08 13:20:54,013 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<IFUImageModel(2048, 2048) from jw01128009001_03106_00004_nrs1_uncal.fits>,).
# 2022-12-08 13:20:54,015 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'gain_scale', 'search_output_file': True, 'input_dir': '../../../cal_data'}
# 2022-12-08 13:20:54,085 - stpipe.Detector1Pipeline.gain_scale - INFO - Rescaling by 1.0
# 2022-12-08 13:20:54,099 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# 2022-12-08 13:20:54,160 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<CubeModel(1, 2048, 2048) from jw01128009001_03106_00004_nrs1_uncal.fits>,).
# 2022-12-08 13:20:54,161 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'gain_scaleints', 'search_output_file': True, 'input_dir': '../../../cal_data'}
# 2022-12-08 13:20:54,205 - stpipe.Detector1Pipeline.gain_scale - INFO - Rescaling by 1.0
# 2022-12-08 13:20:54,214 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# 2022-12-08 13:20:54,425 - stpipe.Detector1Pipeline - INFO - Saved model in stage1/jw01128009001_03106_00004_nrs1_rateints.fits
# 2022-12-08 13:20:54,425 - stpipe.Detector1Pipeline - INFO - ... ending calwebb_detector1
# 2022-12-08 13:20:54,426 - stpipe.Detector1Pipeline - INFO - Results used CRDS context: jwst_0977.pmap
# 2022-12-08 13:20:54,617 - stpipe.Detector1Pipeline - INFO - Saved model in stage1/jw01128009001_03106_00004_nrs1_rate.fits
# 2022-12-08 13:20:54,617 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline done

# %%
# Print out the time benchmark
time1 = time.perf_counter()
print(f"Runtime so far: {time1 - time0:0.4f} seconds")
# Out:
# Runtime so far: 285.1937 seconds

# %%
# Look for input uncalibrated slope files from the Detector1 pipeline
sstring = 'stage1/'+ '*_rate.fits'
rate_files = sorted(glob.glob(sstring))
print('Found ' + str(len(rate_files)) + ' input files to process')
# Out:
# Found 4 input files to process

# %%
# Start a timer to keep track of runtime
time0 = time.perf_counter()

# %%
# Setting up steps and running the Spec2 portion of the pipeline. 

spec2 = Spec2Pipeline()
spec2.output_dir = spec2_dir
spec2.assign_wcs.skip = False
spec2.bkg_subtract.skip = False
spec2.imprint_subtract.skip = False
spec2.msa_flagging.skip = False
spec2.srctype.source_type = 'POINT'
spec2.flat_field.skip = False
spec2.pathloss.skip = False
spec2.photom.skip = False
spec2.cube_build.skip = False
spec2.extract_1d.skip = True

##extra steps that only apply to other instruments modes.
spec2.extract_2d.skip = True
spec2.master_background_mos.skip = True
spec2.barshadow.skip = True
spec2.wavecorr.skip = True
spec2.straylight.skip = True
spec2.fringe.skip = True
#spec2.residual_fringe.skip = True   # is not used in 1.7.2 works in 1.8.4
spec2.wfss_contam.skip = True
spec2.resample_spec.skip = True

#choose what results to save and from what steps
spec2.save_results = True
spec2.run(rate_files)
# Out:
# 2022-12-08 13:20:54,649 - stpipe.Spec2Pipeline - INFO - Spec2Pipeline instance created.
# 2022-12-08 13:20:54,651 - stpipe.Spec2Pipeline.bkg_subtract - INFO - BackgroundStep instance created.
# 2022-12-08 13:20:54,653 - stpipe.Spec2Pipeline.assign_wcs - INFO - AssignWcsStep instance created.
# 2022-12-08 13:20:54,654 - stpipe.Spec2Pipeline.imprint_subtract - INFO - ImprintStep instance created.
# 
'/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_wavelengthrange_0006.asdf', 'camera': '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_camera_0007.asdf', 'collimator': '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_collimator_0007.asdf', 'disperser': '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_disperser_0057.asdf', 'fore': '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_fore_0048.asdf', 'fpa': '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_fpa_0008.asdf', 'msa': '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_msa_0008.asdf', 'ote': '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_ote_0008.asdf', 'ifupost': '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_ifupost_0009.asdf', 'ifufore': '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_ifufore_0010.asdf', 'ifuslicer': '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_ifuslicer_0010.asdf'}
# 2022-12-08 13:30:43,879 - stpipe.Spec2Pipeline.assign_wcs - INFO - Update S_REGION to POLYGON ICRS  272.143815124 69.457559151 272.147311207 69.457559151 272.147311207 69.458839632 272.143815124 69.458839632
# 2022-12-08 13:30:43,880 - stpipe.Spec2Pipeline.assign_wcs - INFO - COMPLETED assign_wcs
# 2022-12-08 13:30:43,892 - stpipe.Spec2Pipeline.assign_wcs - INFO - Step assign_wcs done
# 2022-12-08 13:30:44,112 - stpipe.Spec2Pipeline.bkg_subtract - INFO - Step bkg_subtract running with args (<IFUImageModel(2048, 2048) from jw01128009001_03106_00002_nrs1_rate.fits>, []).
# 2022-12-08 13:30:44,114 - stpipe.Spec2Pipeline.bkg_subtract - INFO - Step bkg_subtract parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': 'bkg_subtract', 'search_output_file': True, 'input_dir': '', 'save_combined_background': False, 'sigma': 3.0, 'maxiters': None, 'wfss_mmag_extract': None}
# 2022-12-08 13:30:44,114 - stpipe.Spec2Pipeline.bkg_subtract - INFO - Step skipped.
# 2022-12-08 13:30:44,117 - stpipe.Spec2Pipeline.bkg_subtract - INFO - Step bkg_subtract done
# ...
# 2022-12-08 13:50:19,861 - stpipe.Spec2Pipeline.imprint_subtract - INFO - Step skipped.
# 2022-12-08 13:50:19,863 - stpipe.Spec2Pipeline.imprint_subtract - INFO - Step imprint_subtract done
# 2022-12-08 13:50:20,215 - stpipe.Spec2Pipeline.msa_flagging - INFO - Step msa_flagging running with args (<IFUImageModel(2048, 2048) from jw01128009001_03106_00004_nrs1_rate.fits>,).
# 2022-12-08 13:50:20,216 - stpipe.Spec2Pipeline.msa_flagging - INFO - Step msa_flagging parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'msa_flagging', 'search_output_file': True, 'input_dir': ''}
# 2022-12-08 13:50:20,234 - stpipe.Spec2Pipeline.msa_flagging - INFO - Using reference file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_msaoper_0003.json
# 2022-12-08 13:50:20,235 - stpipe.JwstStep - INFO - JwstStep instance created.
# 2022-12-08 13:50:20,376 - stpipe.Spec2Pipeline.msa_flagging - INFO - gwa_ytilt is 0.1380488 deg
# 2022-12-08 13:50:20,377 - stpipe.Spec2Pipeline.msa_flagging - INFO - gwa_xtilt is 0.3532653150000012 deg
# 2022-12-08 13:50:20,378 - stpipe.Spec2Pipeline.msa_flagging - INFO - theta_y correction: 0.0018865959647736948 deg
# 2022-12-08 13:50:20,379 - stpipe.Spec2Pipeline.msa_flagging - INFO - theta_x correction: 0.00011620025040863247 deg
# 2022-12-08 13:50:20,394 - stpipe.Spec2Pipeline.msa_flagging - INFO - SPORDER= -1, wrange=[1.66e-06, 3.17e-06]
# 2022-12-08 13:50:20,489 - stpipe.Spec2Pipeline.msa_flagging - INFO - Applied Barycentric velocity correction : 1.0000003683883225
# 2022-12-08 13:50:20,525 - stpipe.Spec2Pipeline.msa_flagging - INFO - There are 6 open slits in quadrant 1
# 2022-12-08 13:50:20,578 - stpipe.Spec2Pipeline.msa_flagging - INFO - There are 3 open slits in quadrant 2
# 2022-12-08 13:50:20,602 - stpipe.Spec2Pipeline.msa_flagging - INFO - There are 10 open slits in quadrant 3
# 2022-12-08 13:50:20,685 - stpipe.Spec2Pipeline.msa_flagging - INFO - There are 2 open slits in quadrant 4
# 2022-12-08 13:50:20,702 - stpipe.Spec2Pipeline.msa_flagging - INFO - There are 0 open slits in quadrant 5
# 2022-12-08 13:50:24,652 - stpipe.Spec2Pipeline.msa_flagging - WARNING - /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/astropy/modeling/bounding_box.py:83: RuntimeWarning: Invalid interval: upper bound 2047.5 is strictly less than lower bound 2430.702940142594.
#   warnings.warn(f"Invalid interval: upper bound {upper} "
#
# 2022-12-08 13:50:25,035 - stpipe.Spec2Pipeline.msa_flagging - WARNING - /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/astropy/modeling/bounding_box.py:83: RuntimeWarning: Invalid interval: upper bound 2047.5 is strictly less than lower bound 2222.438837907135.
#   warnings.warn(f"Invalid interval: upper bound {upper} "
#
# 2022-12-08 13:50:25,414 - stpipe.Spec2Pipeline.msa_flagging - WARNING - /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/astropy/modeling/bounding_box.py:83: RuntimeWarning: Invalid interval: upper bound 2047.5 is strictly less than lower bound 2145.767535200422.
#   warnings.warn(f"Invalid interval: upper bound {upper} "
#
# 2022-12-08 13:50:27,517 - stpipe.Spec2Pipeline.msa_flagging - WARNING - /Users/zen/opt/miniconda3/envs/jwst_env_current/lib/python3.10/site-packages/astropy/modeling/bounding_box.py:83: RuntimeWarning: Invalid interval: upper bound 2047.5 is strictly less than lower bound 2289.3072263097847.
#   warnings.warn(f"Invalid interval: upper bound {upper} "
#
# 2022-12-08 13:50:34,400 - stpipe.Spec2Pipeline.msa_flagging - INFO - Step msa_flagging done
# 2022-12-08 13:50:35,057 - stpipe.Spec2Pipeline.srctype - INFO - Step srctype running with args (<IFUImageModel(2048, 2048) from jw01128009001_03106_00004_nrs1_rate.fits>,).
# 2022-12-08 13:50:35,058 - stpipe.Spec2Pipeline.srctype - INFO - Step srctype parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'srctype', 'search_output_file': True, 'input_dir': '', 'source_type': 'POINT'}
# 2022-12-08 13:50:35,066 - stpipe.Spec2Pipeline.srctype - INFO - Input EXP_TYPE is NRS_IFU
# 2022-12-08 13:50:35,067 - stpipe.Spec2Pipeline.srctype - INFO - Input SRCTYAPT = UNKNOWN
# 2022-12-08 13:50:35,067 - stpipe.Spec2Pipeline.srctype - WARNING - Based on user-input, setting SRCTYPE = POINT
# 2022-12-08 13:50:35,071 - stpipe.Spec2Pipeline.srctype - INFO - Step srctype done
# 
- stpipe.Spec2Pipeline.extract_1d - INFO - Step extract_1d done
# 2022-12-08 14:00:16,448 - stpipe.Spec2Pipeline - INFO - Finished processing product stage1/jw01128009001_03106_00004_nrs1
# 2022-12-08 14:00:16,448 - stpipe.Spec2Pipeline - INFO - Ending calwebb_spec2
# 2022-12-08 14:00:16,449 - stpipe.Spec2Pipeline - INFO - Results used CRDS context: jwst_0977.pmap
# 2022-12-08 14:00:16,450 - stpipe.Spec2Pipeline - INFO - Results used CRDS context: jwst_0977.pmap
# 2022-12-08 14:00:16,450 - stpipe.Spec2Pipeline - INFO - Results used CRDS context: jwst_0977.pmap
# 2022-12-08 14:00:16,451 - stpipe.Spec2Pipeline - INFO - Results used CRDS context: jwst_0977.pmap
# 2022-12-08 14:00:18,949 - stpipe.Spec2Pipeline - INFO - Saved model in stage2/jw01128009001_03106_00001_nrs1_cal.fits
# 2022-12-08 14:00:21,977 - stpipe.Spec2Pipeline - INFO - Saved model in stage2/jw01128009001_03106_00002_nrs1_cal.fits
# 2022-12-08 14:00:24,917 - stpipe.Spec2Pipeline - INFO - Saved model in stage2/jw01128009001_03106_00003_nrs1_cal.fits
# 2022-12-08 14:00:27,874 - stpipe.Spec2Pipeline - INFO - Saved model in stage2/jw01128009001_03106_00004_nrs1_cal.fits
# 2022-12-08 14:00:27,875 - stpipe.Spec2Pipeline - INFO - Step Spec2Pipeline done
# [<IFUImageModel(2048, 2048) from jw01128009001_03106_00001_nrs1_cal.fits>,
#  <IFUImageModel(2048, 2048) from jw01128009001_03106_00002_nrs1_cal.fits>,
#  <IFUImageModel(2048, 2048) from jw01128009001_03106_00003_nrs1_cal.fits>,
#  <IFUImageModel(2048, 2048) from jw01128009001_03106_00004_nrs1_cal.fits>]

# %%
# Print out the time benchmark
time1 = time.perf_counter()
print(f"Runtime so far: {time1 - time0:0.4f} seconds")
# Out:
# Runtime so far: 2373.2780 seconds

# %%
### Calling in the calibrated detector images produced by running the stage 2 pipeline on the modified NRS fits files
cal_files = glob.glob('stage2/*cal.fits')
print(cal_files)
# Out:
# ['stage2/jw01128009001_03106_00001_nrs1_cal.fits', 'stage2/jw01128009001_03106_00002_nrs1_cal.fits', 'stage2/jw01128009001_03106_00003_nrs1_cal.fits', 'stage2/jw01128009001_03106_00004_nrs1_cal.fits']

# %%
## create association file for dithered data. Make a json file for the dither set.
call(["asn_from_list", "-o","l3_asn.json"] + cal_files + ["--product-name", "dither"])
# Out:
# 0

# %%
# Start a timer to keep track of runtime
time0 = time.perf_counter()

# %%
# This initial setup is just to make sure that we get the latest parameter reference files
# pulled in for our files.  This is a temporary workaround to get around an issue with
# how this pipeline calling method works.
#
# Setting up steps and running the Spec3 portion of the pipeline. Outlier detector is skipped
# because it tends to cut high value pixels even if it is a part of the target.

json_file = 'l3_asn.json'
crds_config = Spec3Pipeline.get_config_from_reference(json_file)# The exact asn file used doesn't matter
spec3 = Spec3Pipeline.from_config_section(crds_config)
spec3.output_dir = spec3_dir
spec3.assign_mtwcs.skip = True               #skipped because VHS 1256b is not a moving target
spec3.master_background.skip = False
spec3.outlier_detection.skip = True
spec3.cube_build.skip = False
spec3.cube_build.coord_system = 'skyalign'   
spec3.cube_build.output_type = 'band'        # is the default mode for calspec3 and creates IFU cubes containing only one band (channel/sub-channel for MIRI or grating/filter combination for NIRSpec).

#used on MRS or other modes
spec3.mrs_imatch.skip = True
spec3.resample_spec.skip = False
spec3.combine_1d.skip = True

#save results
spec3.save_results = True
spec3(json_file)
# Out:
# 2022-12-08 14:00:33,300 - stpipe.Spec3Pipeline - INFO - Spec3Pipeline instance created.
# 2022-12-08 14:00:33,301 - stpipe.Spec3Pipeline.assign_mtwcs - INFO - AssignMTWcsStep instance created.
# 2022-12-08 14:00:33,302 - stpipe.Spec3Pipeline.master_background - INFO - MasterBackgroundStep instance created.
# 2022-12-08 14:00:33,303 - stpipe.Spec3Pipeline.mrs_imatch - INFO - MRSIMatchStep instance created.
# 2022-12-08 14:00:33,304 - stpipe.Spec3Pipeline.outlier_detection - INFO - OutlierDetectionStep instance created.
# 2022-12-08 14:00:33,306 - stpipe.Spec3Pipeline.resample_spec - INFO - ResampleSpecStep instance created.
# 2022-12-08 14:00:33,307 - stpipe.Spec3Pipeline.cube_build - INFO - CubeBuildStep instance created.
# 2022-12-08 14:00:33,309 - stpipe.Spec3Pipeline.extract_1d - INFO - Extract1dStep instance created.
# 2022-12-08 14:00:33,310 - stpipe.Spec3Pipeline.photom - INFO - PhotomStep instance created.
# 2022-12-08 14:00:33,311 - stpipe.Spec3Pipeline.combine_1d - INFO - Combine1dStep instance created.
# 2022-12-08 14:00:33,847 - stpipe.Spec3Pipeline - INFO - Step Spec3Pipeline running with args ('l3_asn.json',).
# 2022-12-08 14:00:33,854 - stpipe.Spec3Pipeline - INFO - Step Spec3Pipeline parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': 'stage3/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'steps': {'assign_mtwcs': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': 'assign_mtwcs', 'search_output_file': True, 'input_dir': ''}, 'master_background': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'user_background': None, 'save_background': False, 'force_subtract': False}, 'mrs_imatch': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'bkg_degree': 1, 'subtract': False}, 'outlier_detection': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': False, 'input_dir': '', 'weight_type': 'ivm', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'nlow': 0, 'nhigh': 0, 'maskpt': 0.7, 'grow': 1, 'snr': '5.0 4.0', 'scale': '1.2 0.7', 'backg': 0.0, 'save_intermediate_results': False, 'resample_data': True, 'good_bits': '~DO_NOT_USE', 'scale_detection': False, 'allowed_memory': None, 'in_memory': False}, 'resample_spec': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'weight_type': 'ivm', 'output_shape': None, 'crpix': None, 'crval': None, 'rotation': None, 'pixel_scale_ratio': 1.0, 'pixel_scale': None, 'single': False, 'blendheaders': True, 'allowed_memory': None, 'in_memory': True}, 'cube_build': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': False, 'input_dir': '', 'channel': 'all', 'band': 'all', 'grating': 'all', 'filter': 'all', 'output_type': 'band', 'scale1': 0.0, 'scale2': 0.0, 'scalew': 0.0, 'weighting': 'drizzle', 'coord_system': 'skyalign', 'rois': 0.0, 'roiw': 0.0, 'weight_power': 2.0, 'wavemin': None, 'wavemax': None, 'single': False, 'skip_dqflagging': False}, 'extract_1d': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'smoothing_length': None, 'bkg_fit': None, 'bkg_order': None, 'bkg_sigma_clip': 3.0, 'log_increment': 50, 'subtract_background': None, 'use_source_posn': None, 'center_xy': None, 'apply_apcorr': True, 'soss_threshold': 0.01, 'soss_n_os': 2, 'soss_transform': None, 'soss_tikfac': None, 'soss_width': 40.0, 'soss_bad_pix': 'model', 'soss_modelname': None}, 'photom': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'inverse': False, 'source_type': None}, 'combine_1d': {'pre_hooks': [], 'post_hooks': [], 'outp ...
# 2022-12-08 14:00:36,899 - stpipe.Spec3Pipeline - INFO - Prefetching reference files for dataset: 'jw01128009001_03106_00001_nrs1_cal.fits' reftypes = ['apcorr', 'area', 'cubepar', 'drizpars', 'extract1d', 'photom', 'speckernel', 'specprofile', 'spectrace', 'wavemap']
# 2022-12-08 14:00:36,903 - stpipe.Spec3Pipeline - INFO - Prefetch for APCORR reference file is '/Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_apcorr_
plt.ylabel('Jy')
plt.xlabel('Wavelength (microns)')
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
cube_data = fits.getdata('stage3/dither_g235h-f170lp_s3d.fits')
cube=SpectralCube.read('stage3/dither_g235h-f170lp_s3d.fits',hdu=1)

wavelength=cube.spectral_axis
wavelength=n.array(wavelength)

cube_collapse = n.nanmedian(cube_data, axis = 0)
cube_collapse /= n.nanmax(cube_collapse) #the image is normalized so the 2-D Gaussian fit is easier.

# %%
# %matplotlib notebook
plt.figure('collapsed cube')
plt.title('Median Collapsed Spectral Cube')
plt.imshow((cube_collapse))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
## fitting a gaussian to the collapsed cube which is a median image to remove high pixels
image = cube_collapse
y_len, x_len = image.shape
bounds = ((0, 0, n.nanmin(image), 1, 1, n.nanmedian(image)) , (x_len, y_len, n.nanmax(image), x_len, y_len, 2 * n.nanmax(image)) )
guess = n.array([34, 38, n.nanmin(image), 1.2, 1.2, n.nanmax(image)])
fit_arr = optimize.least_squares(image_solve, guess, args = (image,), bounds = bounds )#, bounds=bounds)
x0_fit, y0_fit, offset_fit, sigma_x_fit, sigma_y_fit, A_fit = fit_arr.x


x0_fit = n.round(x0_fit, decimals = 0) #rounding because jwst pipeline does not take float values
y0_fit = n.round(y0_fit, decimals = 0) #rounding because jwst pipeline does not take float values


print('centroids (x, y)')
print(x0_fit, y0_fit)
print('sigmax, sigma y')
print(sigma_x_fit, sigma_y_fit)
# Out:
# centroids (x, y)
# 34.0 38.0
# sigmax, sigma y
# 1.0000892339526266 1.0033829324675139

# %%
#re-running the jwst pipeline extraction step to ensure the extraction radius is centered.
spec3.extract_1d.center_xy = (int(x0_fit), int(y0_fit))
spec3.extract_1d('stage3/dither_g235h-f170lp_s3d.fits')
# Out:
# 2022-12-09 11:31:54,712 - stpipe.Spec3Pipeline.extract_1d - INFO - Step extract_1d running with args ('stage3/dither_g235h-f170lp_s3d.fits',).
# 2022-12-09 11:31:54,714 - stpipe.Spec3Pipeline.extract_1d - INFO - Step extract_1d parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': 'x1d', 'search_output_file': False, 'input_dir': '', 'smoothing_length': None, 'bkg_fit': None, 'bkg_order': None, 'bkg_sigma_clip': 3.0, 'log_increment': 50, 'subtract_background': None, 'use_source_posn': None, 'center_xy': [34, 38], 'apply_apcorr': True, 'soss_threshold': 0.01, 'soss_n_os': 2, 'soss_transform': None, 'soss_tikfac': None, 'soss_width': 40.0, 'soss_bad_pix': 'model', 'soss_modelname': None}
# 2022-12-09 11:31:55,021 - stpipe.Spec3Pipeline.extract_1d - INFO - Using EXTRACT1D reference file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_extract1d_0001.asdf
# 2022-12-09 11:31:55,033 - stpipe.Spec3Pipeline.extract_1d - INFO - Using APCORR file /Users/zen/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_apcorr_0007.asdf
# 2022-12-09 11:31:56,007 - stpipe.Spec3Pipeline.extract_1d - INFO - Turning on source position correction for exp_type = NRS_IFU
# 2022-12-09 11:31:56,008 - stpipe.Spec3Pipeline.extract_1d - INFO - Source type = POINT
# 2022-12-09 11:31:56,022 - stpipe.Spec3Pipeline.extract_1d - INFO - Using user-supplied x_center=34, y_center=38
# 2022-12-09 11:31:56,023 - stpipe.Spec3Pipeline.extract_1d - INFO - Input model does not break out variance information. Passing only generalized errors.
# 2022-12-09 11:32:06,181 - stpipe.Spec3Pipeline.extract_1d - INFO - Applying Aperture correction.
# 2022-12-09 11:32:07,271 - stpipe.Spec3Pipeline.extract_1d - INFO - Saved model in stage3/dither_g235h-f170lp_x1d.fits
# 2022-12-09 11:32:07,272 - stpipe.Spec3Pipeline.extract_1d - INFO - Step extract_1d done
# <MultiSpecModel from dither_g235h-f170lp_x1d.fits>

# %%
# check the extracted spectrum from the JWST pipeline
data = fits.getdata('stage3/dither_g235h-f170lp_x1d.fits')
wavelength = data['wavelength']
flux  = data['flux']
flux_error = data['flux_error']

# %matplotlib notebook
plt.plot(wavelength, flux, label = 'stage 3')
plt.ylim([0,.040])
plt.ylabel('Jy')
plt.xlabel('Wavelength (microns)')
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#save text
#data_out = n.vstack((wavelength,  flux , flux_error))
#data_out = n.transpose(data_out)
#
#spectra_dir = '../spectra/' # Detector1 pipeline outputs will go here
#if not os.path.exists(spectra_dir):
#    os.makedirs(spectra_dir)

#header = 'wavelength (microns) flux(Jy), flux error(Jy)'
#n.savetxt('../spectra/detector1_f170lp_g235h.txt', data_out, header = header)
